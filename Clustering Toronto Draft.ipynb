# %%
# import libraries
from bs4 import BeautifulSoup
import requests

# %%
# set website
postcodes_html='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# pass html to BS
source = requests.get(postcodes_html).text
soup = BeautifulSoup(source, 'lxml')

# show in readable format
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of postal codes of Canada: M - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className=document.documentElement.className.replace(/(^|\s)client-nojs(\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_postal_codes_of_Canada:_M","wgTitle":"List of postal codes of Canada: M","wgCurRevisionId":900271985,"wgRevisionId":900271985,"wgArticleId":539066,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Communications in Ontario","Postal codes in Canada","Toronto","Ontario-related lists"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],
# "wgRelevantPageName":"List_of_postal_codes_of_Canada:_M","wgRelevantArticleId":539066,"wgRequestId":"XPjqFQpAIC4AAKz40vQAAABK","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgWikibaseItemId":"Q3248240","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready",
# "ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin",
# "mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=ext.gadget.charinsert-styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.34.0-wmf.7" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M" rel="alternate"/>
#   <link href="/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;action=edit" rel="edit" title="Edit this page"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <!--[if lt IE 9]><script src="/w/load.php?lang=qqx&amp;modules=html5shiv&amp;only=scripts&amp;skin=fallback&amp;sync=1"></script><![endif]-->
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_postal_codes_of_Canada_M rootpage-List_of_postal_codes_of_Canada_M skin-vector action-view">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading" lang="en">
#     List of postal codes of Canada: M
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#p-search">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <p>
#        This is a list of
#        <a href="/wiki/Postal_codes_in_Canada" title="Postal codes in Canada">
#         postal codes in Canada
#        </a>
#        where the first letter is M. Postal codes beginning with M are located within the city of
#        <a href="/wiki/Toronto" title="Toronto">
#         Toronto
#        </a>
#        in the province of
#        <a href="/wiki/Ontario" title="Ontario">
#         Ontario
#        </a>
#        . Only the first three characters are listed, corresponding to the Forward Sortation Area.
#       </p>
#       <p>
#        <a href="/wiki/Canada_Post" title="Canada Post">
#         Canada Post
#        </a>
#        provides a free postal code look-up tool on its website,
#        <sup class="reference" id="cite_ref-1">
#         <a href="#cite_note-1">
#          [1]
#         </a>
#        </sup>
#        via its
#        <a href="/wiki/Mobile_app" title="Mobile app">
#         applications
#        </a>
#        for such
#        <a class="mw-redirect" href="/wiki/Smartphones" title="Smartphones">
#         smartphones
#        </a>
#        as the
#        <a href="/wiki/IPhone" title="IPhone">
#         iPhone
#        </a>
#        and
#        <a href="/wiki/BlackBerry" title="BlackBerry">
#         BlackBerry
#        </a>
#        ,
#        <sup class="reference" id="cite_ref-2">
#         <a href="#cite_note-2">
#          [2]
#         </a>
#        </sup>
#        and sells hard-copy directories and
#        <a href="/wiki/CD-ROM" title="CD-ROM">
#         CD-ROMs
#        </a>
#        . Many vendors also sell validation tools, which allow customers to properly match addresses and postal codes. Hard-copy directories can also be consulted in all post offices, and some libraries.
#       </p>
#       <h2>
#        <span class="mw-headline" id="Toronto_-_FSAs">
#         <a href="/wiki/Toronto" title="Toronto">
#          Toronto
#         </a>
#         -
#         <a href="/wiki/Postal_codes_in_Canada#Forward_sortation_areas" title="Postal codes in Canada">
#          FSAs
#         </a>
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;action=edit&amp;section=1" title="Edit section: Toronto - FSAs">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        Note: There are no rural FSAs in Toronto, hence no postal codes start with M0.
#       </p>
#       <table class="wikitable sortable">
#        <tbody>
#         <tr>
#          <th>
#           Postcode
#          </th>
#          <th>
#           Borough
#          </th>
#          <th>
#           Neighbourhood
#          </th>
#         </tr>
#         <tr>
#          <td>
#           M1A
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2A
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3A
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Parkwoods" title="Parkwoods">
#            Parkwoods
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4A
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Victoria_Village" title="Victoria Village">
#            Victoria Village
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5A
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Harbourfront_(Toronto)" title="Harbourfront (Toronto)">
#            Harbourfront
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5A
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Regent_Park" title="Regent Park">
#            Regent Park
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6A
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Lawrence_Heights" title="Lawrence Heights">
#            Lawrence Heights
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6A
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Lawrence_Manor" title="Lawrence Manor">
#            Lawrence Manor
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7A
#          </td>
#          <td>
#           <a href="/wiki/Queen%27s_Park_(Toronto)" title="Queen's Park (Toronto)">
#            Queen's Park
#           </a>
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8A
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9A
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Islington_Avenue" title="Islington Avenue">
#            Islington Avenue
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1B
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Rouge,_Toronto" title="Rouge, Toronto">
#            Rouge
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1B
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Malvern,_Toronto" title="Malvern, Toronto">
#            Malvern
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2B
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3B
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Don Mills North
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4B
#          </td>
#          <td>
#           <a href="/wiki/East_York" title="East York">
#            East York
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Woodbine_Gardens" title="Woodbine Gardens">
#            Woodbine Gardens
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4B
#          </td>
#          <td>
#           <a href="/wiki/East_York" title="East York">
#            East York
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Parkview_Hill" title="Parkview Hill">
#            Parkview Hill
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5B
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           Ryerson
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5B
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           Garden District
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6B
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Glencairn
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7B
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8B
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9B
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           Cloverdale
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9B
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Islington,_Toronto" title="Islington, Toronto">
#            Islington
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9B
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           Martin Grove
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9B
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Princess_Gardens" title="Princess Gardens">
#            Princess Gardens
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9B
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/West_Deane_Park" title="West Deane Park">
#            West Deane Park
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1C
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Highland_Creek_(Toronto)" title="Highland Creek (Toronto)">
#            Highland Creek
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1C
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Rouge_Hill" title="Rouge Hill">
#            Rouge Hill
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1C
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Port_Union,_Toronto" title="Port Union, Toronto">
#            Port Union
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2C
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3C
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Flemingdon_Park" title="Flemingdon Park">
#            Flemingdon Park
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3C
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Don Mills South
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4C
#          </td>
#          <td>
#           <a href="/wiki/East_York" title="East York">
#            East York
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Woodbine_Heights" title="Woodbine Heights">
#            Woodbine Heights
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5C
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/St._James_Town" title="St. James Town">
#            St. James Town
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6C
#          </td>
#          <td>
#           York
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Humewood-Cedarvale" title="Humewood-Cedarvale">
#            Humewood-Cedarvale
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7C
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8C
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9C
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           Bloordale Gardens
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9C
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           Eringate
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9C
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Markland_Wood" title="Markland Wood">
#            Markland Wood
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9C
#          </td>
#          <td>
#           <a href="/wiki/Etobicoke" title="Etobicoke">
#            Etobicoke
#           </a>
#          </td>
#          <td>
#           Old Burnhamthorpe
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1E
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           Guildwood
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1E
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Morningside,_Toronto" title="Morningside, Toronto">
#            Morningside
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1E
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/West_Hill,_Toronto" title="West Hill, Toronto">
#            West Hill
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2E
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3E
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4E
#          </td>
#          <td>
#           <a href="/wiki/East_Toronto" title="East Toronto">
#            East Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/The_Beaches" title="The Beaches">
#            The Beaches
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5E
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Berczy_Park" title="Berczy Park">
#            Berczy Park
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6E
#          </td>
#          <td>
#           York
#          </td>
#          <td>
#           Caledonia-Fairbanks
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7E
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8E
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9E
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1G
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Woburn,_Toronto" title="Woburn, Toronto">
#            Woburn
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2G
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3G
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4G
#          </td>
#          <td>
#           <a href="/wiki/East_York" title="East York">
#            East York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Leaside" title="Leaside">
#            Leaside
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5G
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           Central Bay Street
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6G
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           Christie
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7G
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8G
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9G
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1H
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           Cedarbrae
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2H
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Hillcrest_Village" title="Hillcrest Village">
#            Hillcrest Village
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3H
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Bathurst_Manor" title="Bathurst Manor">
#            Bathurst Manor
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3H
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Downsview North
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3H
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Wilson_Heights,_Toronto" title="Wilson Heights, Toronto">
#            Wilson Heights
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4H
#          </td>
#          <td>
#           <a href="/wiki/East_York" title="East York">
#            East York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Thorncliffe_Park" title="Thorncliffe Park">
#            Thorncliffe Park
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5H
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           Adelaide
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5H
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           King
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5H
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           Richmond
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6H
#          </td>
#          <td>
#           <a href="/wiki/West_Toronto" title="West Toronto">
#            West Toronto
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Dovercourt_Village" title="Dovercourt Village">
#            Dovercourt Village
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6H
#          </td>
#          <td>
#           <a href="/wiki/West_Toronto" title="West Toronto">
#            West Toronto
#           </a>
#          </td>
#          <td>
#           Dufferin
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7H
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8H
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9H
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1J
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Scarborough_Village" title="Scarborough Village">
#            Scarborough Village
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2J
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Fairview
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2J
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Henry_Farm" title="Henry Farm">
#            Henry Farm
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2J
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Oriole
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3J
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Northwood_Park" title="Northwood Park">
#            Northwood Park
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3J
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/York_University" title="York University">
#            York University
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4J
#          </td>
#          <td>
#           <a href="/wiki/East_York" title="East York">
#            East York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/East_Toronto" title="East Toronto">
#            East Toronto
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5J
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           Harbourfront East
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5J
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Toronto_Islands" title="Toronto Islands">
#            Toronto Islands
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5J
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Union_Station_(Toronto)" title="Union Station (Toronto)">
#            Union Station
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6J
#          </td>
#          <td>
#           <a href="/wiki/West_Toronto" title="West Toronto">
#            West Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Little_Portugal,_Toronto" title="Little Portugal, Toronto">
#            Little Portugal
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6J
#          </td>
#          <td>
#           <a href="/wiki/West_Toronto" title="West Toronto">
#            West Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Trinity%E2%80%93Bellwoods" title="Trinity–Bellwoods">
#            Trinity
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7J
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8J
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9J
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1K
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           East Birchmount Park
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1K
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Ionview" title="Ionview">
#            Ionview
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1K
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Kennedy_Park,_Toronto" title="Kennedy Park, Toronto">
#            Kennedy Park
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2K
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Bayview_Village" title="Bayview Village">
#            Bayview Village
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3K
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/CFB_Toronto" title="CFB Toronto">
#            CFB Toronto
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3K
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Downsview East
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4K
#          </td>
#          <td>
#           <a href="/wiki/East_Toronto" title="East Toronto">
#            East Toronto
#           </a>
#          </td>
#          <td>
#           The Danforth West
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4K
#          </td>
#          <td>
#           <a href="/wiki/East_Toronto" title="East Toronto">
#            East Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Riverdale,_Toronto" title="Riverdale, Toronto">
#            Riverdale
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5K
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Design_Exchange" title="Design Exchange">
#            Design Exchange
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5K
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Toronto_Dominion_Centre" title="Toronto Dominion Centre">
#            Toronto Dominion Centre
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6K
#          </td>
#          <td>
#           <a href="/wiki/West_Toronto" title="West Toronto">
#            West Toronto
#           </a>
#          </td>
#          <td>
#           Brockton
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6K
#          </td>
#          <td>
#           <a href="/wiki/West_Toronto" title="West Toronto">
#            West Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Exhibition_Place" title="Exhibition Place">
#            Exhibition Place
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6K
#          </td>
#          <td>
#           <a href="/wiki/West_Toronto" title="West Toronto">
#            West Toronto
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Parkdale_Village" title="Parkdale Village">
#            Parkdale Village
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7K
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8K
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9K
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1L
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Clairlea" title="Clairlea">
#            Clairlea
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1L
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Golden_Mile,_Toronto" title="Golden Mile, Toronto">
#            Golden Mile
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1L
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Oakridge,_Toronto" title="Oakridge, Toronto">
#            Oakridge
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2L
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Silver Hills
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2L
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/York_Mills" title="York Mills">
#            York Mills
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3L
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Downsview" title="Downsview">
#            Downsview West
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4L
#          </td>
#          <td>
#           <a href="/wiki/East_Toronto" title="East Toronto">
#            East Toronto
#           </a>
#          </td>
#          <td>
#           The Beaches West
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4L
#          </td>
#          <td>
#           <a href="/wiki/East_Toronto" title="East Toronto">
#            East Toronto
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/India_Bazaar" title="India Bazaar">
#            India Bazaar
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5L
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Commerce_Court" title="Commerce Court">
#            Commerce Court
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5L
#          </td>
#          <td>
#           <a href="/wiki/Downtown_Toronto" title="Downtown Toronto">
#            Downtown Toronto
#           </a>
#          </td>
#          <td>
#           Victoria Hotel
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6L
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Downsview,_Toronto" title="Downsview, Toronto">
#            Downsview
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6L
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           North Park
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6L
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Upwood Park
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7L
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8L
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M9L
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Humber_Summit" title="Humber Summit">
#            Humber Summit
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1M
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Cliffcrest" title="Cliffcrest">
#            Cliffcrest
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1M
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Cliffside,_Toronto" title="Cliffside, Toronto">
#            Cliffside
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M1M
#          </td>
#          <td>
#           <a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">
#            Scarborough
#           </a>
#          </td>
#          <td>
#           Scarborough Village West
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2M
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Newtonbrook" title="Newtonbrook">
#            Newtonbrook
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M2M
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Willowdale,_Toronto" title="Willowdale, Toronto">
#            Willowdale
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M3M
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Downsview Central
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M4M
#          </td>
#          <td>
#           <a href="/wiki/East_Toronto" title="East Toronto">
#            East Toronto
#           </a>
#          </td>
#          <td>
#           Studio District
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5M
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Bedford_Park,_Toronto" title="Bedford Park, Toronto">
#            Bedford Park
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M5M
#          </td>
#          <td>
#           <a href="/wiki/North_York" title="North York">
#            North York
#           </a>
#          </td>
#          <td>
#           Lawrence Manor East
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6M
#          </td>
#          <td>
#           <a href="/wiki/York,_Toronto" title="York, Toronto">
#            York
#           </a>
#          </td>
#          <td>
#           Del Ray
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6M
#          </td>
#          <td>
#           <a href="/wiki/York,_Toronto" title="York, Toronto">
#            York
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/Keelesdale" title="Keelesdale">
#            Keelesdale
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6M
#          </td>
#          <td>
#           <a href="/wiki/York,_Toronto" title="York, Toronto">
#            York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Mount_Dennis" title="Mount Dennis">
#            Mount Dennis
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M6M
#          </td>
#          <td>
#           <a href="/wiki/York,_Toronto" title="York, Toronto">
#            York
#           </a>
#          </td>
#          <td>
#           <a href="/wiki/Silverthorn,_Toronto" title="Silverthorn, Toronto">
#            Silverthorn
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M7M
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
#           M8M
#          </td>
#          <td>
#           Not assigned
#          </td>
#          <td>
#           Not assigned
#          </td>
#         </tr>
#         <tr>
#          <td>
# ...
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="visualClear">
#     </div>
#    </div>
#   </div>
#   <div id="mw-navigation">
#    <h2>
#     Navigation menu
#    </h2>
#    <div id="mw-head">
#     <div aria-labelledby="p-personal-label" id="p-personal" role="navigation">
#      <h3 id="p-personal-label">
#       Personal tools
#      </h3>
#      <ul>
#       <li id="pt-anonuserpage">
#        Not logged in
#       </li>
#       <li id="pt-anontalk">
#        <a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]">
#         Talk
#        </a>
#       </li>
#       <li id="pt-anoncontribs">
#        <a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]">
#         Contributions
#        </a>
#       </li>
#       <li id="pt-createaccount">
#        <a href="/w/index.php?title=Special:CreateAccount&amp;returnto=List+of+postal+codes+of+Canada%3A+M" title="You are encouraged to create an account and log in; however, it is not mandatory">
#         Create account
#        </a>
#       </li>
#       <li id="pt-login">
#        <a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+postal+codes+of+Canada%3A+M" title="You're encouraged to log in; however, it's not mandatory. [o]">
#         Log in
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div id="left-navigation">
#      <div aria-labelledby="p-namespaces-label" class="vectorTabs" id="p-namespaces" role="navigation">
#       <h3 id="p-namespaces-label">
#        Namespaces
#       </h3>
#       <ul>
#        <li class="selected" id="ca-nstab-main">
#         <span>
#          <a accesskey="c" href="/wiki/List_of_postal_codes_of_Canada:_M" title="View the content page [c]">
#           Article
#          </a>
#         </span>
#        </li>
#        <li id="ca-talk">
#         <span>
#          <a accesskey="t" href="/wiki/Talk:List_of_postal_codes_of_Canada:_M" rel="discussion" title="Discussion about the content page [t]">
#           Talk
#          </a>
#         </span>
#        </li>
#       </ul>
#      </div>
#      <div aria-labelledby="p-variants-label" class="vectorMenu emptyPortlet" id="p-variants" role="navigation">
#       <input aria-labelledby="p-variants-label" class="vectorMenuCheckbox" type="checkbox"/>
#       <h3 id="p-variants-label">
#        <span>
#         Variants
#        </span>
#       </h3>
#       <ul class="menu">
#       </ul>
#      </div>
#     </div>
#     <div id="right-navigation">
#      <div aria-labelledby="p-views-label" class="vectorTabs" id="p-views" role="navigation">
#       <h3 id="p-views-label">
#        Views
#       </h3>
#       <ul>
#        <li class="collapsible selected" id="ca-view">
#         <span>
#          <a href="/wiki/List_of_postal_codes_of_Canada:_M">
#           Read
#          </a>
#         </span>
#        </li>
#        <li class="collapsible" id="ca-edit">
#         <span>
#          <a accesskey="e" href="/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;action=edit" title="Edit this page [e]">
#           Edit
#          </a>
#         </span>
#        </li>
#        <li class="collapsible" id="ca-history">
#         <span>
#          <a accesskey="h" href="/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;action=history" title="Past revisions of this page [h]">
#           View history
#          </a>
#         </span>
#        </li>
#       </ul>
#      </div>
#      <div aria-labelledby="p-cactions-label" class="vectorMenu emptyPortlet" id="p-cactions" role="navigation">
#       <input aria-labelledby="p-cactions-label" class="vectorMenuCheckbox" type="checkbox"/>
#       <h3 id="p-cactions-label">
#        <span>
#         More
#        </span>
#       </h3>
#       <ul class="menu">
#       </ul>
#      </div>
#      <div id="p-search" role="search">
#       <h3>
#        <label for="searchInput">
#         Search
#        </label>
#       </h3>
#       <form action="/w/index.php" id="searchform">
#        <div id="simpleSearch">
#         <input accesskey="f" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#         <input name="title" type="hidden" value="Special:Search"/>
#         <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
#         <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
#        </div>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div id="mw-panel">
#     <div id="p-logo" role="banner">
#      <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page">
#      </a>
#     </div>
#     <div aria-labelledby="p-navigation-label" class="portal" id="p-navigation" role="navigation">
#      <h3 id="p-navigation-label">
#       Navigation
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="n-mainpage-description">
#         <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#          Main page
#         </a>
#        </li>
#        <li id="n-contents">
#         <a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">
#          Contents
#         </a>
#        </li>
#        <li id="n-featuredcontent">
#         <a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">
#          Featured content
#         </a>
#        </li>
#        <li id="n-currentevents">
#         <a href="/wiki/Portal:Current_events" title="Find background information on current events">
#          Current events
#         </a>
#        </li>
#        <li id="n-randompage">
#         <a accesskey="x" href="/wiki/Special:Random" title="Load a random article [x]">
#          Random article
#         </a>
#        </li>
#        <li id="n-sitesupport">
#         <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">
#          Donate to Wikipedia
#         </a>
#        </li>
#        <li id="n-shoplink">
#         <a href="//shop.wikimedia.org" title="Visit the Wikipedia store">
#          Wikipedia store
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-interaction-label" class="portal" id="p-interaction" role="navigation">
#      <h3 id="p-interaction-label">
#       Interaction
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="n-help">
#         <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#          Help
#         </a>
#        </li>
#        <li id="n-aboutsite">
#         <a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">
#          About Wikipedia
#         </a>
#        </li>
#        <li id="n-portal">
#         <a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">
#          Community portal
#         </a>
#        </li>
#        <li id="n-recentchanges">
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]">
#          Recent changes
#         </a>
#        </li>
#        <li id="n-contactpage">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#          Contact page
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-tb-label" class="portal" id="p-tb" role="navigation">
#      <h3 id="p-tb-label">
#       Tools
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/List_of_postal_codes_of_Canada:_M" title="List of all English Wikipedia pages containing links to this page [j]">
#          What links here
#         </a>
#        </li>
#        <li id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/List_of_postal_codes_of_Canada:_M" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          Related changes
#         </a>
#        </li>
#        <li id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          Upload file
#         </a>
#        </li>
#        <li id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          Special pages
#         </a>
#        </li>
#        <li id="t-permalink">
#         <a href="/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;oldid=900271985" title="Permanent link to this revision of the page">
#          Permanent link
#         </a>
#        </li>
#        <li id="t-info">
#         <a href="/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;action=info" title="More information about this page">
#          Page information
#         </a>
#        </li>
#        <li id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q3248240" title="Link to connected data repository item [g]">
#          Wikidata item
#         </a>
#        </li>
#        <li id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_postal_codes_of_Canada%3A_M&amp;id=900271985" title="Information on how to cite this page">
#          Cite this page
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-coll-print_export-label" class="portal" id="p-coll-print_export" role="navigation">
#      <h3 id="p-coll-print_export-label">
#       Print/export
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="coll-create_a_book">
#         <a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=List+of+postal+codes+of+Canada%3A+M">
#          Create a book
#         </a>
#        </li>
#        <li id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:ElectronPdf&amp;page=List+of+postal+codes+of+Canada%3A+M&amp;action=show-download-screen">
#          Download as PDF
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;printable=yes" title="Printable version of this page [p]">
#          Printable version
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-lang-label" class="portal" id="p-lang" role="navigation">
#      <h3 id="p-lang-label">
#       Languages
#      </h3>
#      <div class="body">
#       <ul>
#        <li class="interlanguage-link interwiki-fr">
#         <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Liste_des_codes_postaux_canadiens_d%C3%A9butant_par_M" hreflang="fr" lang="fr" title="Liste des codes postaux canadiens débutant par M – French">
#          Français
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q3248240#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 4 June 2019, at 14:58
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </div>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.204","walltime":"0.238","ppvisitednodes":{"value":575,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":10232,"limit":2097152},"templateargumentsize":{"value":13,"limit":2097152},"expansiondepth":{"value":4,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":9025,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  137.705      1 -total"," 83.72%  115.289      3 Template:Cite_web","  3.78%    5.211      1 Template:Col-2","  3.64%    5.019      1 Template:Canadian_postal_codes","  2.17%    2.986      1 Template:Col-break","  1.73%    2.385      1 Template:Col-begin","  1.33%    1.829      2 Template:Col-end"]},"scribunto":{"limitreport-timeusage":{"value":"0.079","limit":"10.000"},"limitreport-memusage":{"value":1788769,"limit":52428800}},"cachereport":{"origin":"mw1325","timestamp":"20190606102526","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"List of postal codes of Canada: M","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_postal_codes_of_Canada:_M","sameAs":"http:\/\/www.wikidata.org\/entity\/Q3248240","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q3248240","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-03-20T10:02:13Z","dateModified":"2019-06-04T14:58:52Z","headline":"Wikimedia list article"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":351,"wgHostname":"mw1325"});});
#   </script>
#  </body>
# </html>

# %%
# find first table row
table_data = soup.find('tr')
print(table_data)
# Out:
# <tr>
# <th>Postcode</th>
# <th>Borough</th>
# <th>Neighbourhood
# </th></tr>

# %%
# loop thru all table rows
for table_row in soup.find_all('tr'):
	for table_cell in table_row.find_all('td'):
		print(table_cell)
# Out:
# <td>M1A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M2A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>
# </td>
# <td>M4A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Victoria_Village" title="Victoria Village">Victoria Village</a>
# </td>
# <td>M5A</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Harbourfront_(Toronto)" title="Harbourfront (Toronto)">Harbourfront</a>
# </td>
# <td>M5A</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Regent_Park" title="Regent Park">Regent Park</a>
# </td>
# <td>M6A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Lawrence_Heights" title="Lawrence Heights">Lawrence Heights</a>
# </td>
# <td>M6A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Lawrence_Manor" title="Lawrence Manor">Lawrence Manor</a>
# </td>
# <td>M7A</td>
# <td><a href="/wiki/Queen%27s_Park_(Toronto)" title="Queen's Park (Toronto)">Queen's Park</a></td>
# <td>Not assigned
# </td>
# <td>M8A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9A</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Islington_Avenue" title="Islington Avenue">Islington Avenue</a>
# </td>
# <td>M1B</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Rouge,_Toronto" title="Rouge, Toronto">Rouge</a>
# </td>
# <td>M1B</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Malvern,_Toronto" title="Malvern, Toronto">Malvern</a>
# </td>
# <td>M2B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3B</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Don Mills North
# </td>
# <td>M4B</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Woodbine_Gardens" title="Woodbine Gardens">Woodbine Gardens</a>
# </td>
# <td>M4B</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Parkview_Hill" title="Parkview Hill">Parkview Hill</a>
# </td>
# <td>M5B</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Ryerson
# </td>
# <td>M5B</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Garden District
# </td>
# <td>M6B</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Glencairn
# </td>
# <td>M7B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Cloverdale
# </td>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Islington,_Toronto" title="Islington, Toronto">Islington</a>
# </td>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Martin Grove
# </td>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Princess_Gardens" title="Princess Gardens">Princess Gardens</a>
# </td>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/West_Deane_Park" title="West Deane Park">West Deane Park</a>
# </td>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Highland_Creek_(Toronto)" title="Highland Creek (Toronto)">Highland Creek</a>
# </td>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Rouge_Hill" title="Rouge Hill">Rouge Hill</a>
# </td>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Port_Union,_Toronto" title="Port Union, Toronto">Port Union</a>
# </td>
# <td>M2C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3C</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Flemingdon_Park" title="Flemingdon Park">Flemingdon Park</a>
# </td>
# <td>M3C</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Don Mills South
# </td>
# <td>M4C</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Woodbine_Heights" title="Woodbine Heights">Woodbine Heights</a>
# </td>
# <td>M5C</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/St._James_Town" title="St. James Town">St. James Town</a>
# </td>
# <td>M6C</td>
# <td>York</td>
# <td><a class="mw-redirect" href="/wiki/Humewood-Cedarvale" title="Humewood-Cedarvale">Humewood-Cedarvale</a>
# </td>
# <td>M7C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Bloordale Gardens
# </td>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Eringate
# </td>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Markland_Wood" title="Markland Wood">Markland Wood</a>
# </td>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Old Burnhamthorpe
# </td>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Guildwood
# </td>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Morningside,_Toronto" title="Morningside, Toronto">Morningside</a>
# </td>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/West_Hill,_Toronto" title="West Hill, Toronto">West Hill</a>
# </td>
# <td>M2E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4E</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a href="/wiki/The_Beaches" title="The Beaches">The Beaches</a>
# </td>
# <td>M5E</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Berczy_Park" title="Berczy Park">Berczy Park</a>
# </td>
# <td>M6E</td>
# <td>York</td>
# <td>Caledonia-Fairbanks
# </td>
# <td>M7E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1G</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Woburn,_Toronto" title="Woburn, Toronto">Woburn</a>
# </td>
# <td>M2G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4G</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/Leaside" title="Leaside">Leaside</a>
# </td>
# <td>M5G</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Central Bay Street
# </td>
# <td>M6G</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Christie
# </td>
# <td>M7G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1H</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Cedarbrae
# </td>
# <td>M2H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Hillcrest_Village" title="Hillcrest Village">Hillcrest Village</a>
# </td>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bathurst_Manor" title="Bathurst Manor">Bathurst Manor</a>
# </td>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview North
# </td>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Wilson_Heights,_Toronto" title="Wilson Heights, Toronto">Wilson Heights</a>
# </td>
# <td>M4H</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/Thorncliffe_Park" title="Thorncliffe Park">Thorncliffe Park</a>
# </td>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Adelaide
# </td>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>King
# </td>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Richmond
# </td>
# <td>M6H</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Dovercourt_Village" title="Dovercourt Village">Dovercourt Village</a>
# </td>
# <td>M6H</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>Dufferin
# </td>
# <td>M7H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1J</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Scarborough_Village" title="Scarborough Village">Scarborough Village</a>
# </td>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Fairview
# </td>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Henry_Farm" title="Henry Farm">Henry Farm</a>
# </td>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Oriole
# </td>
# <td>M3J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Northwood_Park" title="Northwood Park">Northwood Park</a>
# </td>
# <td>M3J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/York_University" title="York University">York University</a>
# </td>
# <td>M4J</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a>
# </td>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbourfront East
# </td>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Toronto_Islands" title="Toronto Islands">Toronto Islands</a>
# </td>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Union_Station_(Toronto)" title="Union Station (Toronto)">Union Station</a>
# </td>
# <td>M6J</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Little_Portugal,_Toronto" title="Little Portugal, Toronto">Little Portugal</a>
# </td>
# <td>M6J</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Trinity%E2%80%93Bellwoods" title="Trinity–Bellwoods">Trinity</a>
# </td>
# <td>M7J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>East Birchmount Park
# </td>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Ionview" title="Ionview">Ionview</a>
# </td>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Kennedy_Park,_Toronto" title="Kennedy Park, Toronto">Kennedy Park</a>
# </td>
# <td>M2K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bayview_Village" title="Bayview Village">Bayview Village</a>
# </td>
# <td>M3K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/CFB_Toronto" title="CFB Toronto">CFB Toronto</a>
# </td>
# <td>M3K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview East
# </td>
# <td>M4K</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>The Danforth West
# </td>
# <td>M4K</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a href="/wiki/Riverdale,_Toronto" title="Riverdale, Toronto">Riverdale</a>
# </td>
# <td>M5K</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Design_Exchange" title="Design Exchange">Design Exchange</a>
# </td>
# <td>M5K</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Toronto_Dominion_Centre" title="Toronto Dominion Centre">Toronto Dominion Centre</a>
# </td>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>Brockton
# </td>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Exhibition_Place" title="Exhibition Place">Exhibition Place</a>
# </td>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Parkdale_Village" title="Parkdale Village">Parkdale Village</a>
# </td>
# <td>M7K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Clairlea" title="Clairlea">Clairlea</a>
# </td>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Golden_Mile,_Toronto" title="Golden Mile, Toronto">Golden Mile</a>
# </td>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Oakridge,_Toronto" title="Oakridge, Toronto">Oakridge</a>
# </td>
# <td>M2L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Silver Hills
# </td>
# <td>M2L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/York_Mills" title="York Mills">York Mills</a>
# </td>
# <td>M3L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Downsview" title="Downsview">Downsview West</a>
# </td>
# <td>M4L</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>The Beaches West
# </td>
# <td>M4L</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/India_Bazaar" title="India Bazaar">India Bazaar</a>
# </td>
# <td>M5L</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Commerce_Court" title="Commerce Court">Commerce Court</a>
# </td>
# <td>M5L</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Victoria Hotel
# </td>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Downsview,_Toronto" title="Downsview, Toronto">Downsview</a>
# </td>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>North Park
# </td>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Upwood Park
# </td>
# <td>M7L</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8L</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Humber_Summit" title="Humber Summit">Humber Summit</a>
# </td>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Cliffcrest" title="Cliffcrest">Cliffcrest</a>
# </td>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Cliffside,_Toronto" title="Cliffside, Toronto">Cliffside</a>
# </td>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Scarborough Village West
# </td>
# <td>M2M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Newtonbrook" title="Newtonbrook">Newtonbrook</a>
# </td>
# <td>M2M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Willowdale,_Toronto" title="Willowdale, Toronto">Willowdale</a>
# </td>
# <td>M3M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview Central
# </td>
# <td>M4M</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>Studio District
# </td>
# <td>M5M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bedford_Park,_Toronto" title="Bedford Park, Toronto">Bedford Park</a>
# </td>
# <td>M5M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Lawrence Manor East
# </td>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>Del Ray
# </td>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a class="mw-redirect" href="/wiki/Keelesdale" title="Keelesdale">Keelesdale</a>
# </td>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Mount_Dennis" title="Mount Dennis">Mount Dennis</a>
# </td>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Silverthorn,_Toronto" title="Silverthorn, Toronto">Silverthorn</a>
# </td>
# <td>M7M</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8M</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Emery,_Toronto" title="Emery, Toronto">Emery</a>
# </td>
# <td>M9M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Humberlea" title="Humberlea">Humberlea</a>
# </td>
# <td>M1N</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Birch_Cliff" title="Birch Cliff">Birch Cliff</a>
# </td>
# <td>M1N</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Cliffside West
# </td>
# <td>M2N</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Willowdale South
# </td>
# <td>M3N</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview Northwest
# </td>
# <td>M4N</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Lawrence_Park,_Toronto" title="Lawrence Park, Toronto">Lawrence Park</a>
# </td>
# <td>M5N</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Roselawn
# </td>
# <td>M6N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>The Junction North
# </td>
# <td>M6N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>Runnymede
# </td>
# <td>M7N</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8N</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Weston,_Toronto" title="Weston, Toronto">Weston</a>
# </td>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Dorset_Park" title="Dorset Park">Dorset Park</a>
# </td>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Scarborough_Town_Centre" title="Scarborough Town Centre">Scarborough Town Centre</a>
# </td>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Wexford_Heights" title="Wexford Heights">Wexford Heights</a>
# </td>
# <td>M2P</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>York Mills West
# </td>
# <td>M3P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Davisville North
# </td>
# <td>M5P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Forest_Hill_North" title="Forest Hill North">Forest Hill North</a>
# </td>
# <td>M5P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Forest Hill West
# </td>
# <td>M6P</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/High_Park" title="High Park">High Park</a>
# </td>
# <td>M6P</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>The Junction South
# </td>
# <td>M7P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9P</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Westmount
# </td>
# <td>M1R</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Maryvale,_Toronto" title="Maryvale, Toronto">Maryvale</a>
# </td>
# <td>M1R</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Wexford,_Toronto" title="Wexford, Toronto">Wexford</a>
# </td>
# <td>M2R</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Willowdale_West" title="Willowdale West">Willowdale West</a>
# </td>
# <td>M3R</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>North Toronto West
# </td>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/The_Annex" title="The Annex">The Annex</a>
# </td>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>North Midtown
# </td>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Yorkville,_Toronto" title="Yorkville, Toronto">Yorkville</a>
# </td>
# <td>M6R</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Parkdale,_Toronto" title="Parkdale, Toronto">Parkdale</a>
# </td>
# <td>M6R</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Roncesvalles,_Toronto" title="Roncesvalles, Toronto">Roncesvalles</a>
# </td>
# <td>M7R</td>
# <td>Mississauga</td>
# <td>Canada Post Gateway Processing Centre
# </td>
# <td>M8R</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Kingsview_Village" title="Kingsview Village">Kingsview Village</a>
# </td>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Martin Grove Gardens
# </td>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Richview Gardens
# </td>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>St. Phillips
# </td>
# <td>M1S</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Agincourt,_Toronto" title="Agincourt, Toronto">Agincourt</a>
# </td>
# <td>M2S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4S</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Davisville
# </td>
# <td>M5S</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbord
# </td>
# <td>M5S</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/University_of_Toronto" title="University of Toronto">University of Toronto</a>
# </td>
# <td>M6S</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Runnymede,_Toronto" title="Runnymede, Toronto">Runnymede</a>
# </td>
# <td>M6S</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Swansea,_Toronto" title="Swansea, Toronto">Swansea</a>
# </td>
# <td>M7S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Clarks Corners
# </td>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Sullivan
# </td>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Tam_O%27Shanter_%E2%80%93_Sullivan" title="Tam O'Shanter – Sullivan">Tam O'Shanter</a>
# </td>
# <td>M2T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4T</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Moore_Park,_Toronto" title="Moore Park, Toronto">Moore Park</a>
# </td>
# <td>M4T</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Summerhill East
# </td>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Chinatown,_Toronto" title="Chinatown, Toronto">Chinatown</a>
# </td>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Grange_Park_(Toronto)" title="Grange Park (Toronto)">Grange Park</a>
# </td>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Kensington_Market" title="Kensington Market">Kensington Market</a>
# </td>
# <td>M6T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M7T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M9T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Agincourt_North" title="Agincourt North">Agincourt North</a>
# </td>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>L'Amoreaux East
# </td>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Milliken,_Ontario" title="Milliken, Ontario">Milliken</a>
# </td>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Steeles East
# </td>
# <td>M2V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Deer_Park,_Toronto" title="Deer Park, Toronto">Deer Park</a>
# </td>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Forest Hill SE
# </td>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Rathnelly" title="Rathnelly">Rathnelly</a>
# </td>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/South_Hill,_Toronto" title="South Hill, Toronto">South Hill</a>
# </td>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Summerhill West
# </td>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/CN_Tower" title="CN Tower">CN Tower</a>
# </td>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Bathurst Quay
# </td>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Island airport
# </td>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbourfront West
# </td>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/King_and_Spadina" title="King and Spadina">King and Spadina</a>
# </td>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Railway_Lands" title="Railway Lands">Railway Lands</a>
# </td>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/South_Niagara" title="South Niagara">South Niagara</a>
# </td>
# <td>M6V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M7V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Humber Bay Shores
# </td>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Mimico South
# </td>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/New_Toronto" title="New Toronto">New Toronto</a>
# </td>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Albion Gardens
# </td>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Beaumond_Heights" title="Beaumond Heights">Beaumond Heights</a>
# </td>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Humbergate
# </td>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Mount_Olive-Silverstone-Jamestown" title="Mount Olive-Silverstone-Jamestown">Jamestown</a>
# </td>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Mount_Olive-Silverstone-Jamestown" title="Mount Olive-Silverstone-Jamestown">Mount Olive</a>
# </td>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Silverstone,_Toronto" title="Silverstone, Toronto">Silverstone</a>
# </td>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/South_Steeles" title="South Steeles">South Steeles</a>
# </td>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Thistletown" title="Thistletown">Thistletown</a>
# </td>
# <td>M1W</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>L'Amoreaux West
# </td>
# <td>M2W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4W</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Rosedale,_Toronto" title="Rosedale, Toronto">Rosedale</a>
# </td>
# <td>M5W</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Stn A PO Boxes 25 The Esplanade
# </td>
# <td>M6W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M7W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Alderwood,_Toronto" title="Alderwood, Toronto">Alderwood</a>
# </td>
# <td>M8W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Long_Branch,_Toronto" title="Long Branch, Toronto">Long Branch</a>
# </td>
# <td>M9W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Northwest
# </td>
# <td>M1X</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Upper_Rouge" title="Upper Rouge">Upper Rouge</a>
# </td>
# <td>M2X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Cabbagetown,_Toronto" title="Cabbagetown, Toronto">Cabbagetown</a>
# </td>
# <td>M4X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/St._James_Town" title="St. James Town">St. James Town</a>
# </td>
# <td>M5X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/First_Canadian_Place" title="First Canadian Place">First Canadian Place</a>
# </td>
# <td>M5X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Underground_city" title="Underground city">Underground city</a>
# </td>
# <td>M6X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M7X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Kingsway" title="The Kingsway">The Kingsway</a>
# </td>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Montgomery Road
# </td>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Old Mill North
# </td>
# <td>M9X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M2Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4Y</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Church_and_Wellesley" title="Church and Wellesley">Church and Wellesley</a>
# </td>
# <td>M5Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M6Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M7Y</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>Business Reply Mail Processing Centre 969 Eastern
# </td>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Humber_Bay" title="Humber Bay">Humber Bay</a>
# </td>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>King's Mill Park
# </td>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Kingsway Park South East
# </td>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Mimico" title="Mimico">Mimico NE</a>
# </td>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Old_Mill,_Toronto" title="Old Mill, Toronto">Old Mill South</a>
# </td>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Queensway" title="The Queensway">The Queensway East</a>
# </td>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Fairmont_Royal_York_Hotel" title="Fairmont Royal York Hotel">Royal York South East</a>
# </td>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Sunnylea" title="Sunnylea">Sunnylea</a>
# </td>
# <td>M9Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M1Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M2Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M3Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M4Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M5Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M6Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M7Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Kingsway Park South West
# </td>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Mimico" title="Mimico">Mimico NW</a>
# </td>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Queensway" title="The Queensway">The Queensway West</a>
# </td>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Royal York South West
# </td>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>South of Bloor
# </td>
# <td>M9Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td>
# <td></td>
# <td style="width:36px; text-align:center"><a class="image" href="/wiki/File:Flag_of_Canada.svg" title="Flag of Canada"><img alt="Flag of Canada" data-file-height="600" data-file-width="1200" decoding="async" height="18" src="//upload.wikimedia.org/wikipedia/en/thumb/c/cf/Flag_of_Canada.svg/36px-Flag_of_Canada.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/c/cf/Flag_of_Canada.svg/54px-Flag_of_Canada.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/c/cf/Flag_of_Canada.svg/72px-Flag_of_Canada.svg.png 2x" width="36"/></a>
# </td>
# <td style="width:36px; text-align:center"><a class="image" href="/wiki/File:Canadian_postal_district_map_(without_legends).svg"><img alt="Canadian postal district map (without legends).svg" data-file-height="846" data-file-width="1000" decoding="async" height="18" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Canadian_postal_district_map_%28without_legends%29.svg/21px-Canadian_postal_district_map_%28without_legends%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Canadian_postal_district_map_%28without_legends%29.svg/32px-Canadian_postal_district_map_%28without_legends%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Canadian_postal_district_map_%28without_legends%29.svg/43px-Canadian_postal_district_map_%28without_legends%29.svg.png 2x" width="21"/></a>
# </td>
# <td colspan="3" style="text-align:center; font-size: 100%;">
# <table cellspacing="0" style="background-color: #F8F8F8;" width="100%">
# <tbody><tr>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Newfoundland_and_Labrador" title="Newfoundland and Labrador">NL</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Nova_Scotia" title="Nova Scotia">NS</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Prince_Edward_Island" title="Prince Edward Island">PE</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/New_Brunswick" title="New Brunswick">NB</a>
# </td>
# <td colspan="3" style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Quebec" title="Quebec">QC</a>
# </td>
# <td colspan="5" style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Ontario" title="Ontario">ON</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Manitoba" title="Manitoba">MB</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Saskatchewan" title="Saskatchewan">SK</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Alberta" title="Alberta">AB</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/British_Columbia" title="British Columbia">BC</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Nunavut" title="Nunavut">NU</a>/<a href="/wiki/Northwest_Territories" title="Northwest Territories">NT</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Yukon" title="Yukon">YT</a>
# </td></tr>
# <tr>
# <td align="center" style="border: 1px solid #FF0000; background-color: #FFE0E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_A" title="List of postal codes of Canada: A">A</a>
# </td>
# <td align="center" style="border: 1px solid #FF4000; background-color: #FFE8E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_B" title="List of postal codes of Canada: B">B</a>
# </td>
# <td align="center" style="border: 1px solid #FF8000; background-color: #FFF0E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_C" title="List of postal codes of Canada: C">C</a>
# </td>
# <td align="center" style="border: 1px solid #FFC000; background-color: #FFF8E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_E" title="List of postal codes of Canada: E">E</a>
# </td>
# <td align="center" style="border: 1px solid #FFFF00; background-color: #FFFFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_G" title="List of postal codes of Canada: G">G</a>
# </td>
# <td align="center" style="border: 1px solid #C0FF00; background-color: #F8FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_H" title="List of postal codes of Canada: H">H</a>
# </td>
# <td align="center" style="border: 1px solid #80FF00; background-color: #F0FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_J" title="List of postal codes of Canada: J">J</a>
# </td>
# <td align="center" style="border: 1px solid #00FF00; background-color: #E0FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_K" title="List of postal codes of Canada: K">K</a>
# </td>
# <td align="center" style="border: 1px solid #00FF80; background-color: #E0FFF0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_L" title="List of postal codes of Canada: L">L</a>
# </td>
# <td align="center" style="border: 1px solid #E0FFF8; background-color: #00FFC0; font-size: 135%; color: black;" width="5%"><a class="mw-selflink selflink">M</a>
# </td>
# <td align="center" style="border: 1px solid #00FFE0; background-color: #E0FFFC; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_N" title="List of postal codes of Canada: N">N</a>
# </td>
# <td align="center" style="border: 1px solid #00FFFF; background-color: #E0FFFF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_P" title="List of postal codes of Canada: P">P</a>
# </td>
# <td align="center" style="border: 1px solid #00C0FF; background-color: #E0F8FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_R" title="List of postal codes of Canada: R">R</a>
# </td>
# <td align="center" style="border: 1px solid #0080FF; background-color: #E0F0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_S" title="List of postal codes of Canada: S">S</a>
# </td>
# <td align="center" style="border: 1px solid #0040FF; background-color: #E0E8FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_T" title="List of postal codes of Canada: T">T</a>
# </td>
# <td align="center" style="border: 1px solid #0000FF; background-color: #E0E0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_V" title="List of postal codes of Canada: V">V</a>
# </td>
# <td align="center" style="border: 1px solid #A000FF; background-color: #E8E0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_X" title="List of postal codes of Canada: X">X</a>
# </td>
# <td align="center" style="border: 1px solid #FF00FF; background-color: #FFE0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_Y" title="List of postal codes of Canada: Y">Y</a>
# </td></tr></tbody></table>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Newfoundland_and_Labrador" title="Newfoundland and Labrador">NL</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Nova_Scotia" title="Nova Scotia">NS</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Prince_Edward_Island" title="Prince Edward Island">PE</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/New_Brunswick" title="New Brunswick">NB</a>
# </td>
# <td colspan="3" style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Quebec" title="Quebec">QC</a>
# </td>
# <td colspan="5" style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Ontario" title="Ontario">ON</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Manitoba" title="Manitoba">MB</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Saskatchewan" title="Saskatchewan">SK</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Alberta" title="Alberta">AB</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/British_Columbia" title="British Columbia">BC</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Nunavut" title="Nunavut">NU</a>/<a href="/wiki/Northwest_Territories" title="Northwest Territories">NT</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Yukon" title="Yukon">YT</a>
# </td>
# <td align="center" style="border: 1px solid #FF0000; background-color: #FFE0E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_A" title="List of postal codes of Canada: A">A</a>
# </td>
# <td align="center" style="border: 1px solid #FF4000; background-color: #FFE8E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_B" title="List of postal codes of Canada: B">B</a>
# </td>
# <td align="center" style="border: 1px solid #FF8000; background-color: #FFF0E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_C" title="List of postal codes of Canada: C">C</a>
# </td>
# <td align="center" style="border: 1px solid #FFC000; background-color: #FFF8E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_E" title="List of postal codes of Canada: E">E</a>
# </td>
# <td align="center" style="border: 1px solid #FFFF00; background-color: #FFFFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_G" title="List of postal codes of Canada: G">G</a>
# </td>
# <td align="center" style="border: 1px solid #C0FF00; background-color: #F8FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_H" title="List of postal codes of Canada: H">H</a>
# </td>
# <td align="center" style="border: 1px solid #80FF00; background-color: #F0FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_J" title="List of postal codes of Canada: J">J</a>
# </td>
# <td align="center" style="border: 1px solid #00FF00; background-color: #E0FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_K" title="List of postal codes of Canada: K">K</a>
# </td>
# <td align="center" style="border: 1px solid #00FF80; background-color: #E0FFF0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_L" title="List of postal codes of Canada: L">L</a>
# </td>
# <td align="center" style="border: 1px solid #E0FFF8; background-color: #00FFC0; font-size: 135%; color: black;" width="5%"><a class="mw-selflink selflink">M</a>
# </td>
# <td align="center" style="border: 1px solid #00FFE0; background-color: #E0FFFC; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_N" title="List of postal codes of Canada: N">N</a>
# </td>
# <td align="center" style="border: 1px solid #00FFFF; background-color: #E0FFFF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_P" title="List of postal codes of Canada: P">P</a>
# </td>
# <td align="center" style="border: 1px solid #00C0FF; background-color: #E0F8FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_R" title="List of postal codes of Canada: R">R</a>
# </td>
# <td align="center" style="border: 1px solid #0080FF; background-color: #E0F0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_S" title="List of postal codes of Canada: S">S</a>
# </td>
# <td align="center" style="border: 1px solid #0040FF; background-color: #E0E8FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_T" title="List of postal codes of Canada: T">T</a>
# </td>
# <td align="center" style="border: 1px solid #0000FF; background-color: #E0E0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_V" title="List of postal codes of Canada: V">V</a>
# </td>
# <td align="center" style="border: 1px solid #A000FF; background-color: #E8E0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_X" title="List of postal codes of Canada: X">X</a>
# </td>
# <td align="center" style="border: 1px solid #FF00FF; background-color: #FFE0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_Y" title="List of postal codes of Canada: Y">Y</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Newfoundland_and_Labrador" title="Newfoundland and Labrador">NL</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Nova_Scotia" title="Nova Scotia">NS</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Prince_Edward_Island" title="Prince Edward Island">PE</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/New_Brunswick" title="New Brunswick">NB</a>
# </td>
# <td colspan="3" style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Quebec" title="Quebec">QC</a>
# </td>
# <td colspan="5" style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Ontario" title="Ontario">ON</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Manitoba" title="Manitoba">MB</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Saskatchewan" title="Saskatchewan">SK</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Alberta" title="Alberta">AB</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/British_Columbia" title="British Columbia">BC</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Nunavut" title="Nunavut">NU</a>/<a href="/wiki/Northwest_Territories" title="Northwest Territories">NT</a>
# </td>
# <td style="text-align:center; border:1px solid #aaa;"><a href="/wiki/Yukon" title="Yukon">YT</a>
# </td>
# <td align="center" style="border: 1px solid #FF0000; background-color: #FFE0E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_A" title="List of postal codes of Canada: A">A</a>
# </td>
# <td align="center" style="border: 1px solid #FF4000; background-color: #FFE8E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_B" title="List of postal codes of Canada: B">B</a>
# </td>
# <td align="center" style="border: 1px solid #FF8000; background-color: #FFF0E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_C" title="List of postal codes of Canada: C">C</a>
# </td>
# <td align="center" style="border: 1px solid #FFC000; background-color: #FFF8E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_E" title="List of postal codes of Canada: E">E</a>
# </td>
# <td align="center" style="border: 1px solid #FFFF00; background-color: #FFFFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_G" title="List of postal codes of Canada: G">G</a>
# </td>
# <td align="center" style="border: 1px solid #C0FF00; background-color: #F8FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_H" title="List of postal codes of Canada: H">H</a>
# </td>
# <td align="center" style="border: 1px solid #80FF00; background-color: #F0FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_J" title="List of postal codes of Canada: J">J</a>
# </td>
# <td align="center" style="border: 1px solid #00FF00; background-color: #E0FFE0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_K" title="List of postal codes of Canada: K">K</a>
# </td>
# <td align="center" style="border: 1px solid #00FF80; background-color: #E0FFF0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_L" title="List of postal codes of Canada: L">L</a>
# </td>
# <td align="center" style="border: 1px solid #E0FFF8; background-color: #00FFC0; font-size: 135%; color: black;" width="5%"><a class="mw-selflink selflink">M</a>
# </td>
# <td align="center" style="border: 1px solid #00FFE0; background-color: #E0FFFC; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_N" title="List of postal codes of Canada: N">N</a>
# </td>
# <td align="center" style="border: 1px solid #00FFFF; background-color: #E0FFFF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_P" title="List of postal codes of Canada: P">P</a>
# </td>
# <td align="center" style="border: 1px solid #00C0FF; background-color: #E0F8FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_R" title="List of postal codes of Canada: R">R</a>
# </td>
# <td align="center" style="border: 1px solid #0080FF; background-color: #E0F0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_S" title="List of postal codes of Canada: S">S</a>
# </td>
# <td align="center" style="border: 1px solid #0040FF; background-color: #E0E8FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_T" title="List of postal codes of Canada: T">T</a>
# </td>
# <td align="center" style="border: 1px solid #0000FF; background-color: #E0E0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_V" title="List of postal codes of Canada: V">V</a>
# </td>
# <td align="center" style="border: 1px solid #A000FF; background-color: #E8E0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_X" title="List of postal codes of Canada: X">X</a>
# </td>
# <td align="center" style="border: 1px solid #FF00FF; background-color: #FFE0FF; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_Y" title="List of postal codes of Canada: Y">Y</a>
# </td>

# %%
full_table = soup.find('table', class_='wikitable sortable')
print(full_table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Postcode</th>
# <th>Borough</th>
# <th>Neighbourhood
# </th></tr>
# <tr>
# <td>M1A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>
# </td></tr>
# <tr>
# <td>M4A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Victoria_Village" title="Victoria Village">Victoria Village</a>
# </td></tr>
# <tr>
# <td>M5A</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Harbourfront_(Toronto)" title="Harbourfront (Toronto)">Harbourfront</a>
# </td></tr>
# <tr>
# <td>M5A</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Regent_Park" title="Regent Park">Regent Park</a>
# </td></tr>
# <tr>
# <td>M6A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Lawrence_Heights" title="Lawrence Heights">Lawrence Heights</a>
# </td></tr>
# <tr>
# <td>M6A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Lawrence_Manor" title="Lawrence Manor">Lawrence Manor</a>
# </td></tr>
# <tr>
# <td>M7A</td>
# <td><a href="/wiki/Queen%27s_Park_(Toronto)" title="Queen's Park (Toronto)">Queen's Park</a></td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9A</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Islington_Avenue" title="Islington Avenue">Islington Avenue</a>
# </td></tr>
# <tr>
# <td>M1B</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Rouge,_Toronto" title="Rouge, Toronto">Rouge</a>
# </td></tr>
# <tr>
# <td>M1B</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Malvern,_Toronto" title="Malvern, Toronto">Malvern</a>
# </td></tr>
# <tr>
# <td>M2B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3B</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Don Mills North
# </td></tr>
# <tr>
# <td>M4B</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Woodbine_Gardens" title="Woodbine Gardens">Woodbine Gardens</a>
# </td></tr>
# <tr>
# <td>M4B</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Parkview_Hill" title="Parkview Hill">Parkview Hill</a>
# </td></tr>
# <tr>
# <td>M5B</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Ryerson
# </td></tr>
# <tr>
# <td>M5B</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Garden District
# </td></tr>
# <tr>
# <td>M6B</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Glencairn
# </td></tr>
# <tr>
# <td>M7B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Cloverdale
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Islington,_Toronto" title="Islington, Toronto">Islington</a>
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Martin Grove
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Princess_Gardens" title="Princess Gardens">Princess Gardens</a>
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/West_Deane_Park" title="West Deane Park">West Deane Park</a>
# </td></tr>
# <tr>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Highland_Creek_(Toronto)" title="Highland Creek (Toronto)">Highland Creek</a>
# </td></tr>
# <tr>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Rouge_Hill" title="Rouge Hill">Rouge Hill</a>
# </td></tr>
# <tr>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Port_Union,_Toronto" title="Port Union, Toronto">Port Union</a>
# </td></tr>
# <tr>
# <td>M2C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3C</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Flemingdon_Park" title="Flemingdon Park">Flemingdon Park</a>
# </td></tr>
# <tr>
# <td>M3C</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Don Mills South
# </td></tr>
# <tr>
# <td>M4C</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Woodbine_Heights" title="Woodbine Heights">Woodbine Heights</a>
# </td></tr>
# <tr>
# <td>M5C</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/St._James_Town" title="St. James Town">St. James Town</a>
# </td></tr>
# <tr>
# <td>M6C</td>
# <td>York</td>
# <td><a class="mw-redirect" href="/wiki/Humewood-Cedarvale" title="Humewood-Cedarvale">Humewood-Cedarvale</a>
# </td></tr>
# <tr>
# <td>M7C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Bloordale Gardens
# </td></tr>
# <tr>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Eringate
# </td></tr>
# <tr>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Markland_Wood" title="Markland Wood">Markland Wood</a>
# </td></tr>
# <tr>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Old Burnhamthorpe
# </td></tr>
# <tr>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Guildwood
# </td></tr>
# <tr>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Morningside,_Toronto" title="Morningside, Toronto">Morningside</a>
# </td></tr>
# <tr>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/West_Hill,_Toronto" title="West Hill, Toronto">West Hill</a>
# </td></tr>
# <tr>
# <td>M2E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4E</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a href="/wiki/The_Beaches" title="The Beaches">The Beaches</a>
# </td></tr>
# <tr>
# <td>M5E</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Berczy_Park" title="Berczy Park">Berczy Park</a>
# </td></tr>
# <tr>
# <td>M6E</td>
# <td>York</td>
# <td>Caledonia-Fairbanks
# </td></tr>
# <tr>
# <td>M7E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1G</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Woburn,_Toronto" title="Woburn, Toronto">Woburn</a>
# </td></tr>
# <tr>
# <td>M2G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4G</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/Leaside" title="Leaside">Leaside</a>
# </td></tr>
# <tr>
# <td>M5G</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Central Bay Street
# </td></tr>
# <tr>
# <td>M6G</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Christie
# </td></tr>
# <tr>
# <td>M7G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1H</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Cedarbrae
# </td></tr>
# <tr>
# <td>M2H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Hillcrest_Village" title="Hillcrest Village">Hillcrest Village</a>
# </td></tr>
# <tr>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bathurst_Manor" title="Bathurst Manor">Bathurst Manor</a>
# </td></tr>
# <tr>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview North
# </td></tr>
# <tr>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Wilson_Heights,_Toronto" title="Wilson Heights, Toronto">Wilson Heights</a>
# </td></tr>
# <tr>
# <td>M4H</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/Thorncliffe_Park" title="Thorncliffe Park">Thorncliffe Park</a>
# </td></tr>
# <tr>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Adelaide
# </td></tr>
# <tr>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>King
# </td></tr>
# <tr>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Richmond
# </td></tr>
# <tr>
# <td>M6H</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Dovercourt_Village" title="Dovercourt Village">Dovercourt Village</a>
# </td></tr>
# <tr>
# <td>M6H</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>Dufferin
# </td></tr>
# <tr>
# <td>M7H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1J</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Scarborough_Village" title="Scarborough Village">Scarborough Village</a>
# </td></tr>
# <tr>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Fairview
# </td></tr>
# <tr>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Henry_Farm" title="Henry Farm">Henry Farm</a>
# </td></tr>
# <tr>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Oriole
# </td></tr>
# <tr>
# <td>M3J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Northwood_Park" title="Northwood Park">Northwood Park</a>
# </td></tr>
# <tr>
# <td>M3J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/York_University" title="York University">York University</a>
# </td></tr>
# <tr>
# <td>M4J</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a>
# </td></tr>
# <tr>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbourfront East
# </td></tr>
# <tr>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Toronto_Islands" title="Toronto Islands">Toronto Islands</a>
# </td></tr>
# <tr>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Union_Station_(Toronto)" title="Union Station (Toronto)">Union Station</a>
# </td></tr>
# <tr>
# <td>M6J</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Little_Portugal,_Toronto" title="Little Portugal, Toronto">Little Portugal</a>
# </td></tr>
# <tr>
# <td>M6J</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Trinity%E2%80%93Bellwoods" title="Trinity–Bellwoods">Trinity</a>
# </td></tr>
# <tr>
# <td>M7J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>East Birchmount Park
# </td></tr>
# <tr>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Ionview" title="Ionview">Ionview</a>
# </td></tr>
# <tr>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Kennedy_Park,_Toronto" title="Kennedy Park, Toronto">Kennedy Park</a>
# </td></tr>
# <tr>
# <td>M2K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bayview_Village" title="Bayview Village">Bayview Village</a>
# </td></tr>
# <tr>
# <td>M3K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/CFB_Toronto" title="CFB Toronto">CFB Toronto</a>
# </td></tr>
# <tr>
# <td>M3K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview East
# </td></tr>
# <tr>
# <td>M4K</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>The Danforth West
# </td></tr>
# <tr>
# <td>M4K</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a href="/wiki/Riverdale,_Toronto" title="Riverdale, Toronto">Riverdale</a>
# </td></tr>
# <tr>
# <td>M5K</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Design_Exchange" title="Design Exchange">Design Exchange</a>
# </td></tr>
# <tr>
# <td>M5K</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Toronto_Dominion_Centre" title="Toronto Dominion Centre">Toronto Dominion Centre</a>
# </td></tr>
# <tr>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>Brockton
# </td></tr>
# <tr>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Exhibition_Place" title="Exhibition Place">Exhibition Place</a>
# </td></tr>
# <tr>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Parkdale_Village" title="Parkdale Village">Parkdale Village</a>
# </td></tr>
# <tr>
# <td>M7K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Clairlea" title="Clairlea">Clairlea</a>
# </td></tr>
# <tr>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Golden_Mile,_Toronto" title="Golden Mile, Toronto">Golden Mile</a>
# </td></tr>
# <tr>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Oakridge,_Toronto" title="Oakridge, Toronto">Oakridge</a>
# </td></tr>
# <tr>
# <td>M2L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Silver Hills
# </td></tr>
# <tr>
# <td>M2L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/York_Mills" title="York Mills">York Mills</a>
# </td></tr>
# <tr>
# <td>M3L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Downsview" title="Downsview">Downsview West</a>
# </td></tr>
# <tr>
# <td>M4L</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>The Beaches West
# </td></tr>
# <tr>
# <td>M4L</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/India_Bazaar" title="India Bazaar">India Bazaar</a>
# </td></tr>
# <tr>
# <td>M5L</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Commerce_Court" title="Commerce Court">Commerce Court</a>
# </td></tr>
# <tr>
# <td>M5L</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Victoria Hotel
# </td></tr>
# <tr>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Downsview,_Toronto" title="Downsview, Toronto">Downsview</a>
# </td></tr>
# <tr>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>North Park
# </td></tr>
# <tr>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Upwood Park
# </td></tr>
# <tr>
# <td>M7L</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8L</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Humber_Summit" title="Humber Summit">Humber Summit</a>
# </td></tr>
# <tr>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Cliffcrest" title="Cliffcrest">Cliffcrest</a>
# </td></tr>
# <tr>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Cliffside,_Toronto" title="Cliffside, Toronto">Cliffside</a>
# </td></tr>
# <tr>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Scarborough Village West
# </td></tr>
# <tr>
# <td>M2M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Newtonbrook" title="Newtonbrook">Newtonbrook</a>
# </td></tr>
# <tr>
# <td>M2M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Willowdale,_Toronto" title="Willowdale, Toronto">Willowdale</a>
# </td></tr>
# <tr>
# <td>M3M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview Central
# </td></tr>
# <tr>
# <td>M4M</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>Studio District
# </td></tr>
# <tr>
# <td>M5M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bedford_Park,_Toronto" title="Bedford Park, Toronto">Bedford Park</a>
# </td></tr>
# <tr>
# <td>M5M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Lawrence Manor East
# </td></tr>
# <tr>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>Del Ray
# </td></tr>
# <tr>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a class="mw-redirect" href="/wiki/Keelesdale" title="Keelesdale">Keelesdale</a>
# </td></tr>
# <tr>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Mount_Dennis" title="Mount Dennis">Mount Dennis</a>
# </td></tr>
# <tr>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Silverthorn,_Toronto" title="Silverthorn, Toronto">Silverthorn</a>
# </td></tr>
# <tr>
# <td>M7M</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8M</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Emery,_Toronto" title="Emery, Toronto">Emery</a>
# </td></tr>
# <tr>
# <td>M9M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Humberlea" title="Humberlea">Humberlea</a>
# </td></tr>
# <tr>
# <td>M1N</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Birch_Cliff" title="Birch Cliff">Birch Cliff</a>
# </td></tr>
# <tr>
# <td>M1N</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Cliffside West
# </td></tr>
# <tr>
# <td>M2N</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Willowdale South
# </td></tr>
# <tr>
# <td>M3N</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview Northwest
# </td></tr>
# <tr>
# <td>M4N</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Lawrence_Park,_Toronto" title="Lawrence Park, Toronto">Lawrence Park</a>
# </td></tr>
# <tr>
# <td>M5N</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Roselawn
# </td></tr>
# <tr>
# <td>M6N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>The Junction North
# </td></tr>
# <tr>
# <td>M6N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>Runnymede
# </td></tr>
# <tr>
# <td>M7N</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8N</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Weston,_Toronto" title="Weston, Toronto">Weston</a>
# </td></tr>
# <tr>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Dorset_Park" title="Dorset Park">Dorset Park</a>
# </td></tr>
# <tr>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Scarborough_Town_Centre" title="Scarborough Town Centre">Scarborough Town Centre</a>
# </td></tr>
# <tr>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Wexford_Heights" title="Wexford Heights">Wexford Heights</a>
# </td></tr>
# <tr>
# <td>M2P</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>York Mills West
# </td></tr>
# <tr>
# <td>M3P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Davisville North
# </td></tr>
# <tr>
# <td>M5P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Forest_Hill_North" title="Forest Hill North">Forest Hill North</a>
# </td></tr>
# <tr>
# <td>M5P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Forest Hill West
# </td></tr>
# <tr>
# <td>M6P</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/High_Park" title="High Park">High Park</a>
# </td></tr>
# <tr>
# <td>M6P</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>The Junction South
# </td></tr>
# <tr>
# <td>M7P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9P</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Westmount
# </td></tr>
# <tr>
# <td>M1R</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Maryvale,_Toronto" title="Maryvale, Toronto">Maryvale</a>
# </td></tr>
# <tr>
# <td>M1R</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Wexford,_Toronto" title="Wexford, Toronto">Wexford</a>
# </td></tr>
# <tr>
# <td>M2R</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Willowdale_West" title="Willowdale West">Willowdale West</a>
# </td></tr>
# <tr>
# <td>M3R</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>North Toronto West
# </td></tr>
# <tr>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/The_Annex" title="The Annex">The Annex</a>
# </td></tr>
# <tr>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>North Midtown
# </td></tr>
# <tr>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Yorkville,_Toronto" title="Yorkville, Toronto">Yorkville</a>
# </td></tr>
# <tr>
# <td>M6R</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Parkdale,_Toronto" title="Parkdale, Toronto">Parkdale</a>
# </td></tr>
# <tr>
# <td>M6R</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Roncesvalles,_Toronto" title="Roncesvalles, Toronto">Roncesvalles</a>
# </td></tr>
# <tr>
# <td>M7R</td>
# <td>Mississauga</td>
# <td>Canada Post Gateway Processing Centre
# </td></tr>
# <tr>
# <td>M8R</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Kingsview_Village" title="Kingsview Village">Kingsview Village</a>
# </td></tr>
# <tr>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Martin Grove Gardens
# </td></tr>
# <tr>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Richview Gardens
# </td></tr>
# <tr>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>St. Phillips
# </td></tr>
# <tr>
# <td>M1S</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Agincourt,_Toronto" title="Agincourt, Toronto">Agincourt</a>
# </td></tr>
# <tr>
# <td>M2S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4S</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Davisville
# </td></tr>
# <tr>
# <td>M5S</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbord
# </td></tr>
# <tr>
# <td>M5S</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/University_of_Toronto" title="University of Toronto">University of Toronto</a>
# </td></tr>
# <tr>
# <td>M6S</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Runnymede,_Toronto" title="Runnymede, Toronto">Runnymede</a>
# </td></tr>
# <tr>
# <td>M6S</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Swansea,_Toronto" title="Swansea, Toronto">Swansea</a>
# </td></tr>
# <tr>
# <td>M7S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Clarks Corners
# </td></tr>
# <tr>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Sullivan
# </td></tr>
# <tr>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Tam_O%27Shanter_%E2%80%93_Sullivan" title="Tam O'Shanter – Sullivan">Tam O'Shanter</a>
# </td></tr>
# <tr>
# <td>M2T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4T</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Moore_Park,_Toronto" title="Moore Park, Toronto">Moore Park</a>
# </td></tr>
# <tr>
# <td>M4T</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Summerhill East
# </td></tr>
# <tr>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Chinatown,_Toronto" title="Chinatown, Toronto">Chinatown</a>
# </td></tr>
# <tr>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Grange_Park_(Toronto)" title="Grange Park (Toronto)">Grange Park</a>
# </td></tr>
# <tr>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Kensington_Market" title="Kensington Market">Kensington Market</a>
# </td></tr>
# <tr>
# <td>M6T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Agincourt_North" title="Agincourt North">Agincourt North</a>
# </td></tr>
# <tr>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>L'Amoreaux East
# </td></tr>
# <tr>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Milliken,_Ontario" title="Milliken, Ontario">Milliken</a>
# </td></tr>
# <tr>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Steeles East
# </td></tr>
# <tr>
# <td>M2V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Deer_Park,_Toronto" title="Deer Park, Toronto">Deer Park</a>
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Forest Hill SE
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Rathnelly" title="Rathnelly">Rathnelly</a>
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/South_Hill,_Toronto" title="South Hill, Toronto">South Hill</a>
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Summerhill West
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/CN_Tower" title="CN Tower">CN Tower</a>
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Bathurst Quay
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Island airport
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbourfront West
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/King_and_Spadina" title="King and Spadina">King and Spadina</a>
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Railway_Lands" title="Railway Lands">Railway Lands</a>
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/South_Niagara" title="South Niagara">South Niagara</a>
# </td></tr>
# <tr>
# <td>M6V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Humber Bay Shores
# </td></tr>
# <tr>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Mimico South
# </td></tr>
# <tr>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/New_Toronto" title="New Toronto">New Toronto</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Albion Gardens
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Beaumond_Heights" title="Beaumond Heights">Beaumond Heights</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Humbergate
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Mount_Olive-Silverstone-Jamestown" title="Mount Olive-Silverstone-Jamestown">Jamestown</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Mount_Olive-Silverstone-Jamestown" title="Mount Olive-Silverstone-Jamestown">Mount Olive</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Silverstone,_Toronto" title="Silverstone, Toronto">Silverstone</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/South_Steeles" title="South Steeles">South Steeles</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Thistletown" title="Thistletown">Thistletown</a>
# </td></tr>
# <tr>
# <td>M1W</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>L'Amoreaux West
# </td></tr>
# <tr>
# <td>M2W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4W</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Rosedale,_Toronto" title="Rosedale, Toronto">Rosedale</a>
# </td></tr>
# <tr>
# <td>M5W</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Stn A PO Boxes 25 The Esplanade
# </td></tr>
# <tr>
# <td>M6W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Alderwood,_Toronto" title="Alderwood, Toronto">Alderwood</a>
# </td></tr>
# <tr>
# <td>M8W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Long_Branch,_Toronto" title="Long Branch, Toronto">Long Branch</a>
# </td></tr>
# <tr>
# <td>M9W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Northwest
# </td></tr>
# <tr>
# <td>M1X</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Upper_Rouge" title="Upper Rouge">Upper Rouge</a>
# </td></tr>
# <tr>
# <td>M2X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Cabbagetown,_Toronto" title="Cabbagetown, Toronto">Cabbagetown</a>
# </td></tr>
# <tr>
# <td>M4X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/St._James_Town" title="St. James Town">St. James Town</a>
# </td></tr>
# <tr>
# <td>M5X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/First_Canadian_Place" title="First Canadian Place">First Canadian Place</a>
# </td></tr>
# <tr>
# <td>M5X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Underground_city" title="Underground city">Underground city</a>
# </td></tr>
# <tr>
# <td>M6X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Kingsway" title="The Kingsway">The Kingsway</a>
# </td></tr>
# <tr>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Montgomery Road
# </td></tr>
# <tr>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Old Mill North
# </td></tr>
# <tr>
# <td>M9X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4Y</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Church_and_Wellesley" title="Church and Wellesley">Church and Wellesley</a>
# </td></tr>
# <tr>
# <td>M5Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M6Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7Y</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>Business Reply Mail Processing Centre 969 Eastern
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Humber_Bay" title="Humber Bay">Humber Bay</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>King's Mill Park
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Kingsway Park South East
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Mimico" title="Mimico">Mimico NE</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Old_Mill,_Toronto" title="Old Mill, Toronto">Old Mill South</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Queensway" title="The Queensway">The Queensway East</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Fairmont_Royal_York_Hotel" title="Fairmont Royal York Hotel">Royal York South East</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Sunnylea" title="Sunnylea">Sunnylea</a>
# </td></tr>
# <tr>
# <td>M9Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M5Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M6Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Kingsway Park South West
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Mimico" title="Mimico">Mimico NW</a>
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Queensway" title="The Queensway">The Queensway West</a>
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Royal York South West
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>South of Bloor
# </td></tr>
# <tr>
# <td>M9Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# </tbody></table>

# %%
table_body = full_table.tbody
print(table_body)
# Out:
# <tbody><tr>
# <th>Postcode</th>
# <th>Borough</th>
# <th>Neighbourhood
# </th></tr>
# <tr>
# <td>M1A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>
# </td></tr>
# <tr>
# <td>M4A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Victoria_Village" title="Victoria Village">Victoria Village</a>
# </td></tr>
# <tr>
# <td>M5A</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Harbourfront_(Toronto)" title="Harbourfront (Toronto)">Harbourfront</a>
# </td></tr>
# <tr>
# <td>M5A</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Regent_Park" title="Regent Park">Regent Park</a>
# </td></tr>
# <tr>
# <td>M6A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Lawrence_Heights" title="Lawrence Heights">Lawrence Heights</a>
# </td></tr>
# <tr>
# <td>M6A</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Lawrence_Manor" title="Lawrence Manor">Lawrence Manor</a>
# </td></tr>
# <tr>
# <td>M7A</td>
# <td><a href="/wiki/Queen%27s_Park_(Toronto)" title="Queen's Park (Toronto)">Queen's Park</a></td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8A</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9A</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Islington_Avenue" title="Islington Avenue">Islington Avenue</a>
# </td></tr>
# <tr>
# <td>M1B</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Rouge,_Toronto" title="Rouge, Toronto">Rouge</a>
# </td></tr>
# <tr>
# <td>M1B</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Malvern,_Toronto" title="Malvern, Toronto">Malvern</a>
# </td></tr>
# <tr>
# <td>M2B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3B</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Don Mills North
# </td></tr>
# <tr>
# <td>M4B</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Woodbine_Gardens" title="Woodbine Gardens">Woodbine Gardens</a>
# </td></tr>
# <tr>
# <td>M4B</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Parkview_Hill" title="Parkview Hill">Parkview Hill</a>
# </td></tr>
# <tr>
# <td>M5B</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Ryerson
# </td></tr>
# <tr>
# <td>M5B</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Garden District
# </td></tr>
# <tr>
# <td>M6B</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Glencairn
# </td></tr>
# <tr>
# <td>M7B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8B</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Cloverdale
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Islington,_Toronto" title="Islington, Toronto">Islington</a>
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Martin Grove
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Princess_Gardens" title="Princess Gardens">Princess Gardens</a>
# </td></tr>
# <tr>
# <td>M9B</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/West_Deane_Park" title="West Deane Park">West Deane Park</a>
# </td></tr>
# <tr>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Highland_Creek_(Toronto)" title="Highland Creek (Toronto)">Highland Creek</a>
# </td></tr>
# <tr>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Rouge_Hill" title="Rouge Hill">Rouge Hill</a>
# </td></tr>
# <tr>
# <td>M1C</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Port_Union,_Toronto" title="Port Union, Toronto">Port Union</a>
# </td></tr>
# <tr>
# <td>M2C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3C</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Flemingdon_Park" title="Flemingdon Park">Flemingdon Park</a>
# </td></tr>
# <tr>
# <td>M3C</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Don Mills South
# </td></tr>
# <tr>
# <td>M4C</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a class="mw-redirect" href="/wiki/Woodbine_Heights" title="Woodbine Heights">Woodbine Heights</a>
# </td></tr>
# <tr>
# <td>M5C</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/St._James_Town" title="St. James Town">St. James Town</a>
# </td></tr>
# <tr>
# <td>M6C</td>
# <td>York</td>
# <td><a class="mw-redirect" href="/wiki/Humewood-Cedarvale" title="Humewood-Cedarvale">Humewood-Cedarvale</a>
# </td></tr>
# <tr>
# <td>M7C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8C</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Bloordale Gardens
# </td></tr>
# <tr>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Eringate
# </td></tr>
# <tr>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Markland_Wood" title="Markland Wood">Markland Wood</a>
# </td></tr>
# <tr>
# <td>M9C</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Old Burnhamthorpe
# </td></tr>
# <tr>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Guildwood
# </td></tr>
# <tr>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Morningside,_Toronto" title="Morningside, Toronto">Morningside</a>
# </td></tr>
# <tr>
# <td>M1E</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/West_Hill,_Toronto" title="West Hill, Toronto">West Hill</a>
# </td></tr>
# <tr>
# <td>M2E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4E</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a href="/wiki/The_Beaches" title="The Beaches">The Beaches</a>
# </td></tr>
# <tr>
# <td>M5E</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Berczy_Park" title="Berczy Park">Berczy Park</a>
# </td></tr>
# <tr>
# <td>M6E</td>
# <td>York</td>
# <td>Caledonia-Fairbanks
# </td></tr>
# <tr>
# <td>M7E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9E</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1G</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Woburn,_Toronto" title="Woburn, Toronto">Woburn</a>
# </td></tr>
# <tr>
# <td>M2G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4G</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/Leaside" title="Leaside">Leaside</a>
# </td></tr>
# <tr>
# <td>M5G</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Central Bay Street
# </td></tr>
# <tr>
# <td>M6G</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Christie
# </td></tr>
# <tr>
# <td>M7G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9G</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1H</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Cedarbrae
# </td></tr>
# <tr>
# <td>M2H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Hillcrest_Village" title="Hillcrest Village">Hillcrest Village</a>
# </td></tr>
# <tr>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bathurst_Manor" title="Bathurst Manor">Bathurst Manor</a>
# </td></tr>
# <tr>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview North
# </td></tr>
# <tr>
# <td>M3H</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Wilson_Heights,_Toronto" title="Wilson Heights, Toronto">Wilson Heights</a>
# </td></tr>
# <tr>
# <td>M4H</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/Thorncliffe_Park" title="Thorncliffe Park">Thorncliffe Park</a>
# </td></tr>
# <tr>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Adelaide
# </td></tr>
# <tr>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>King
# </td></tr>
# <tr>
# <td>M5H</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Richmond
# </td></tr>
# <tr>
# <td>M6H</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Dovercourt_Village" title="Dovercourt Village">Dovercourt Village</a>
# </td></tr>
# <tr>
# <td>M6H</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>Dufferin
# </td></tr>
# <tr>
# <td>M7H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9H</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1J</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Scarborough_Village" title="Scarborough Village">Scarborough Village</a>
# </td></tr>
# <tr>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Fairview
# </td></tr>
# <tr>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Henry_Farm" title="Henry Farm">Henry Farm</a>
# </td></tr>
# <tr>
# <td>M2J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Oriole
# </td></tr>
# <tr>
# <td>M3J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Northwood_Park" title="Northwood Park">Northwood Park</a>
# </td></tr>
# <tr>
# <td>M3J</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/York_University" title="York University">York University</a>
# </td></tr>
# <tr>
# <td>M4J</td>
# <td><a href="/wiki/East_York" title="East York">East York</a></td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a>
# </td></tr>
# <tr>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbourfront East
# </td></tr>
# <tr>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Toronto_Islands" title="Toronto Islands">Toronto Islands</a>
# </td></tr>
# <tr>
# <td>M5J</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Union_Station_(Toronto)" title="Union Station (Toronto)">Union Station</a>
# </td></tr>
# <tr>
# <td>M6J</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Little_Portugal,_Toronto" title="Little Portugal, Toronto">Little Portugal</a>
# </td></tr>
# <tr>
# <td>M6J</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Trinity%E2%80%93Bellwoods" title="Trinity–Bellwoods">Trinity</a>
# </td></tr>
# <tr>
# <td>M7J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9J</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>East Birchmount Park
# </td></tr>
# <tr>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Ionview" title="Ionview">Ionview</a>
# </td></tr>
# <tr>
# <td>M1K</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Kennedy_Park,_Toronto" title="Kennedy Park, Toronto">Kennedy Park</a>
# </td></tr>
# <tr>
# <td>M2K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bayview_Village" title="Bayview Village">Bayview Village</a>
# </td></tr>
# <tr>
# <td>M3K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/CFB_Toronto" title="CFB Toronto">CFB Toronto</a>
# </td></tr>
# <tr>
# <td>M3K</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview East
# </td></tr>
# <tr>
# <td>M4K</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>The Danforth West
# </td></tr>
# <tr>
# <td>M4K</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a href="/wiki/Riverdale,_Toronto" title="Riverdale, Toronto">Riverdale</a>
# </td></tr>
# <tr>
# <td>M5K</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Design_Exchange" title="Design Exchange">Design Exchange</a>
# </td></tr>
# <tr>
# <td>M5K</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Toronto_Dominion_Centre" title="Toronto Dominion Centre">Toronto Dominion Centre</a>
# </td></tr>
# <tr>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>Brockton
# </td></tr>
# <tr>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Exhibition_Place" title="Exhibition Place">Exhibition Place</a>
# </td></tr>
# <tr>
# <td>M6K</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Parkdale_Village" title="Parkdale Village">Parkdale Village</a>
# </td></tr>
# <tr>
# <td>M7K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9K</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Clairlea" title="Clairlea">Clairlea</a>
# </td></tr>
# <tr>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Golden_Mile,_Toronto" title="Golden Mile, Toronto">Golden Mile</a>
# </td></tr>
# <tr>
# <td>M1L</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Oakridge,_Toronto" title="Oakridge, Toronto">Oakridge</a>
# </td></tr>
# <tr>
# <td>M2L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Silver Hills
# </td></tr>
# <tr>
# <td>M2L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/York_Mills" title="York Mills">York Mills</a>
# </td></tr>
# <tr>
# <td>M3L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Downsview" title="Downsview">Downsview West</a>
# </td></tr>
# <tr>
# <td>M4L</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>The Beaches West
# </td></tr>
# <tr>
# <td>M4L</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/India_Bazaar" title="India Bazaar">India Bazaar</a>
# </td></tr>
# <tr>
# <td>M5L</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Commerce_Court" title="Commerce Court">Commerce Court</a>
# </td></tr>
# <tr>
# <td>M5L</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Victoria Hotel
# </td></tr>
# <tr>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Downsview,_Toronto" title="Downsview, Toronto">Downsview</a>
# </td></tr>
# <tr>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>North Park
# </td></tr>
# <tr>
# <td>M6L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Upwood Park
# </td></tr>
# <tr>
# <td>M7L</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8L</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9L</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Humber_Summit" title="Humber Summit">Humber Summit</a>
# </td></tr>
# <tr>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Cliffcrest" title="Cliffcrest">Cliffcrest</a>
# </td></tr>
# <tr>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Cliffside,_Toronto" title="Cliffside, Toronto">Cliffside</a>
# </td></tr>
# <tr>
# <td>M1M</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Scarborough Village West
# </td></tr>
# <tr>
# <td>M2M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Newtonbrook" title="Newtonbrook">Newtonbrook</a>
# </td></tr>
# <tr>
# <td>M2M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Willowdale,_Toronto" title="Willowdale, Toronto">Willowdale</a>
# </td></tr>
# <tr>
# <td>M3M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview Central
# </td></tr>
# <tr>
# <td>M4M</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>Studio District
# </td></tr>
# <tr>
# <td>M5M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a href="/wiki/Bedford_Park,_Toronto" title="Bedford Park, Toronto">Bedford Park</a>
# </td></tr>
# <tr>
# <td>M5M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Lawrence Manor East
# </td></tr>
# <tr>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>Del Ray
# </td></tr>
# <tr>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a class="mw-redirect" href="/wiki/Keelesdale" title="Keelesdale">Keelesdale</a>
# </td></tr>
# <tr>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Mount_Dennis" title="Mount Dennis">Mount Dennis</a>
# </td></tr>
# <tr>
# <td>M6M</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Silverthorn,_Toronto" title="Silverthorn, Toronto">Silverthorn</a>
# </td></tr>
# <tr>
# <td>M7M</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8M</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Emery,_Toronto" title="Emery, Toronto">Emery</a>
# </td></tr>
# <tr>
# <td>M9M</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Humberlea" title="Humberlea">Humberlea</a>
# </td></tr>
# <tr>
# <td>M1N</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Birch_Cliff" title="Birch Cliff">Birch Cliff</a>
# </td></tr>
# <tr>
# <td>M1N</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Cliffside West
# </td></tr>
# <tr>
# <td>M2N</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Willowdale South
# </td></tr>
# <tr>
# <td>M3N</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>Downsview Northwest
# </td></tr>
# <tr>
# <td>M4N</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Lawrence_Park,_Toronto" title="Lawrence Park, Toronto">Lawrence Park</a>
# </td></tr>
# <tr>
# <td>M5N</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Roselawn
# </td></tr>
# <tr>
# <td>M6N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>The Junction North
# </td></tr>
# <tr>
# <td>M6N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td>Runnymede
# </td></tr>
# <tr>
# <td>M7N</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8N</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9N</td>
# <td><a href="/wiki/York,_Toronto" title="York, Toronto">York</a></td>
# <td><a href="/wiki/Weston,_Toronto" title="Weston, Toronto">Weston</a>
# </td></tr>
# <tr>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Dorset_Park" title="Dorset Park">Dorset Park</a>
# </td></tr>
# <tr>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Scarborough_Town_Centre" title="Scarborough Town Centre">Scarborough Town Centre</a>
# </td></tr>
# <tr>
# <td>M1P</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Wexford_Heights" title="Wexford Heights">Wexford Heights</a>
# </td></tr>
# <tr>
# <td>M2P</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td>York Mills West
# </td></tr>
# <tr>
# <td>M3P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Davisville North
# </td></tr>
# <tr>
# <td>M5P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Forest_Hill_North" title="Forest Hill North">Forest Hill North</a>
# </td></tr>
# <tr>
# <td>M5P</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Forest Hill West
# </td></tr>
# <tr>
# <td>M6P</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/High_Park" title="High Park">High Park</a>
# </td></tr>
# <tr>
# <td>M6P</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td>The Junction South
# </td></tr>
# <tr>
# <td>M7P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8P</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9P</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Westmount
# </td></tr>
# <tr>
# <td>M1R</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Maryvale,_Toronto" title="Maryvale, Toronto">Maryvale</a>
# </td></tr>
# <tr>
# <td>M1R</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Wexford,_Toronto" title="Wexford, Toronto">Wexford</a>
# </td></tr>
# <tr>
# <td>M2R</td>
# <td><a href="/wiki/North_York" title="North York">North York</a></td>
# <td><a class="mw-redirect" href="/wiki/Willowdale_West" title="Willowdale West">Willowdale West</a>
# </td></tr>
# <tr>
# <td>M3R</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>North Toronto West
# </td></tr>
# <tr>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/The_Annex" title="The Annex">The Annex</a>
# </td></tr>
# <tr>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>North Midtown
# </td></tr>
# <tr>
# <td>M5R</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Yorkville,_Toronto" title="Yorkville, Toronto">Yorkville</a>
# </td></tr>
# <tr>
# <td>M6R</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Parkdale,_Toronto" title="Parkdale, Toronto">Parkdale</a>
# </td></tr>
# <tr>
# <td>M6R</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Roncesvalles,_Toronto" title="Roncesvalles, Toronto">Roncesvalles</a>
# </td></tr>
# <tr>
# <td>M7R</td>
# <td>Mississauga</td>
# <td>Canada Post Gateway Processing Centre
# </td></tr>
# <tr>
# <td>M8R</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Kingsview_Village" title="Kingsview Village">Kingsview Village</a>
# </td></tr>
# <tr>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Martin Grove Gardens
# </td></tr>
# <tr>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Richview Gardens
# </td></tr>
# <tr>
# <td>M9R</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>St. Phillips
# </td></tr>
# <tr>
# <td>M1S</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Agincourt,_Toronto" title="Agincourt, Toronto">Agincourt</a>
# </td></tr>
# <tr>
# <td>M2S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4S</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Davisville
# </td></tr>
# <tr>
# <td>M5S</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbord
# </td></tr>
# <tr>
# <td>M5S</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/University_of_Toronto" title="University of Toronto">University of Toronto</a>
# </td></tr>
# <tr>
# <td>M6S</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Runnymede,_Toronto" title="Runnymede, Toronto">Runnymede</a>
# </td></tr>
# <tr>
# <td>M6S</td>
# <td><a href="/wiki/West_Toronto" title="West Toronto">West Toronto</a></td>
# <td><a href="/wiki/Swansea,_Toronto" title="Swansea, Toronto">Swansea</a>
# </td></tr>
# <tr>
# <td>M7S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9S</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Clarks Corners
# </td></tr>
# <tr>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Sullivan
# </td></tr>
# <tr>
# <td>M1T</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Tam_O%27Shanter_%E2%80%93_Sullivan" title="Tam O'Shanter – Sullivan">Tam O'Shanter</a>
# </td></tr>
# <tr>
# <td>M2T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4T</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Moore_Park,_Toronto" title="Moore Park, Toronto">Moore Park</a>
# </td></tr>
# <tr>
# <td>M4T</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Summerhill East
# </td></tr>
# <tr>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Chinatown,_Toronto" title="Chinatown, Toronto">Chinatown</a>
# </td></tr>
# <tr>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Grange_Park_(Toronto)" title="Grange Park (Toronto)">Grange Park</a>
# </td></tr>
# <tr>
# <td>M5T</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Kensington_Market" title="Kensington Market">Kensington Market</a>
# </td></tr>
# <tr>
# <td>M6T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M9T</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Agincourt_North" title="Agincourt North">Agincourt North</a>
# </td></tr>
# <tr>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>L'Amoreaux East
# </td></tr>
# <tr>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a href="/wiki/Milliken,_Ontario" title="Milliken, Ontario">Milliken</a>
# </td></tr>
# <tr>
# <td>M1V</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>Steeles East
# </td></tr>
# <tr>
# <td>M2V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/Deer_Park,_Toronto" title="Deer Park, Toronto">Deer Park</a>
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Forest Hill SE
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/Rathnelly" title="Rathnelly">Rathnelly</a>
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td><a href="/wiki/South_Hill,_Toronto" title="South Hill, Toronto">South Hill</a>
# </td></tr>
# <tr>
# <td>M4V</td>
# <td><a class="mw-redirect" href="/wiki/Central_Toronto" title="Central Toronto">Central Toronto</a></td>
# <td>Summerhill West
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/CN_Tower" title="CN Tower">CN Tower</a>
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Bathurst Quay
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Island airport
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Harbourfront West
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/King_and_Spadina" title="King and Spadina">King and Spadina</a>
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Railway_Lands" title="Railway Lands">Railway Lands</a>
# </td></tr>
# <tr>
# <td>M5V</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a class="mw-redirect" href="/wiki/South_Niagara" title="South Niagara">South Niagara</a>
# </td></tr>
# <tr>
# <td>M6V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7V</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Humber Bay Shores
# </td></tr>
# <tr>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Mimico South
# </td></tr>
# <tr>
# <td>M8V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/New_Toronto" title="New Toronto">New Toronto</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Albion Gardens
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Beaumond_Heights" title="Beaumond Heights">Beaumond Heights</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Humbergate
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Mount_Olive-Silverstone-Jamestown" title="Mount Olive-Silverstone-Jamestown">Jamestown</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Mount_Olive-Silverstone-Jamestown" title="Mount Olive-Silverstone-Jamestown">Mount Olive</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Silverstone,_Toronto" title="Silverstone, Toronto">Silverstone</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/South_Steeles" title="South Steeles">South Steeles</a>
# </td></tr>
# <tr>
# <td>M9V</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Thistletown" title="Thistletown">Thistletown</a>
# </td></tr>
# <tr>
# <td>M1W</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td>L'Amoreaux West
# </td></tr>
# <tr>
# <td>M2W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4W</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Rosedale,_Toronto" title="Rosedale, Toronto">Rosedale</a>
# </td></tr>
# <tr>
# <td>M5W</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td>Stn A PO Boxes 25 The Esplanade
# </td></tr>
# <tr>
# <td>M6W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7W</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Alderwood,_Toronto" title="Alderwood, Toronto">Alderwood</a>
# </td></tr>
# <tr>
# <td>M8W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Long_Branch,_Toronto" title="Long Branch, Toronto">Long Branch</a>
# </td></tr>
# <tr>
# <td>M9W</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Northwest
# </td></tr>
# <tr>
# <td>M1X</td>
# <td><a href="/wiki/Scarborough,_Toronto" title="Scarborough, Toronto">Scarborough</a></td>
# <td><a class="mw-redirect" href="/wiki/Upper_Rouge" title="Upper Rouge">Upper Rouge</a>
# </td></tr>
# <tr>
# <td>M2X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Cabbagetown,_Toronto" title="Cabbagetown, Toronto">Cabbagetown</a>
# </td></tr>
# <tr>
# <td>M4X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/St._James_Town" title="St. James Town">St. James Town</a>
# </td></tr>
# <tr>
# <td>M5X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/First_Canadian_Place" title="First Canadian Place">First Canadian Place</a>
# </td></tr>
# <tr>
# <td>M5X</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Underground_city" title="Underground city">Underground city</a>
# </td></tr>
# <tr>
# <td>M6X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Kingsway" title="The Kingsway">The Kingsway</a>
# </td></tr>
# <tr>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Montgomery Road
# </td></tr>
# <tr>
# <td>M8X</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Old Mill North
# </td></tr>
# <tr>
# <td>M9X</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4Y</td>
# <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
# <td><a href="/wiki/Church_and_Wellesley" title="Church and Wellesley">Church and Wellesley</a>
# </td></tr>
# <tr>
# <td>M5Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M6Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7Y</td>
# <td><a href="/wiki/East_Toronto" title="East Toronto">East Toronto</a></td>
# <td>Business Reply Mail Processing Centre 969 Eastern
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Humber_Bay" title="Humber Bay">Humber Bay</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>King's Mill Park
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Kingsway Park South East
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Mimico" title="Mimico">Mimico NE</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Old_Mill,_Toronto" title="Old Mill, Toronto">Old Mill South</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Queensway" title="The Queensway">The Queensway East</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Fairmont_Royal_York_Hotel" title="Fairmont Royal York Hotel">Royal York South East</a>
# </td></tr>
# <tr>
# <td>M8Y</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a class="mw-redirect" href="/wiki/Sunnylea" title="Sunnylea">Sunnylea</a>
# </td></tr>
# <tr>
# <td>M9Y</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M1Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M2Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M3Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M4Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M5Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M6Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M7Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Kingsway Park South West
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/Mimico" title="Mimico">Mimico NW</a>
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td><a href="/wiki/The_Queensway" title="The Queensway">The Queensway West</a>
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>Royal York South West
# </td></tr>
# <tr>
# <td>M8Z</td>
# <td><a href="/wiki/Etobicoke" title="Etobicoke">Etobicoke</a></td>
# <td>South of Bloor
# </td></tr>
# <tr>
# <td>M9Z</td>
# <td>Not assigned</td>
# <td>Not assigned
# </td></tr>
# </tbody>

# %%
table_head = full_table.tbody.tr.th.text
print(table_head)
# Out:
# Postcode

# %%
# loop thru all table rows
for table_row in soup.find_all('tr'):
	for table_cell in table_row.find_all('td'):
		table_cell_text = table_cell.text
		print(table_cell_text)
# Out:
# M1A
# Not assigned
# Not assigned
#
# M2A
# Not assigned
# Not assigned
#
# M3A
# North York
# Parkwoods
#
# M4A
# North York
# Victoria Village
#
# M5A
# Downtown Toronto
# Harbourfront
#
# M5A
# Downtown Toronto
# Regent Park
#
# M6A
# North York
# Lawrence Heights
#
# M6A
# North York
# Lawrence Manor
#
# M7A
# Queen's Park
# Not assigned
#
# M8A
# Not assigned
# Not assigned
#
# M9A
# Etobicoke
# Islington Avenue
#
# M1B
# Scarborough
# Rouge
#
# M1B
# Scarborough
# Malvern
#
# M2B
# Not assigned
# Not assigned
#
# M3B
# North York
# Don Mills North
#
# M4B
# East York
# Woodbine Gardens
#
# M4B
# East York
# Parkview Hill
#
# M5B
# Downtown Toronto
# Ryerson
#
# M5B
# Downtown Toronto
# Garden District
#
# M6B
# North York
# Glencairn
#
# M7B
# Not assigned
# Not assigned
#
# M8B
# Not assigned
# Not assigned
#
# M9B
# Etobicoke
# Cloverdale
#
# M9B
# Etobicoke
# Islington
#
# M9B
# Etobicoke
# Martin Grove
#
# M9B
# Etobicoke
# Princess Gardens
#
# M9B
# Etobicoke
# West Deane Park
#
# M1C
# Scarborough
# Highland Creek
#
# M1C
# Scarborough
# Rouge Hill
#
# M1C
# Scarborough
# Port Union
#
# M2C
# Not assigned
# Not assigned
#
# M3C
# North York
# Flemingdon Park
#
# M3C
# North York
# Don Mills South
#
# M4C
# East York
# Woodbine Heights
#
# M5C
# Downtown Toronto
# St. James Town
#
# M6C
# York
# Humewood-Cedarvale
#
# M7C
# Not assigned
# Not assigned
#
# M8C
# Not assigned
# Not assigned
#
# M9C
# Etobicoke
# Bloordale Gardens
#
# M9C
# Etobicoke
# Eringate
#
# M9C
# Etobicoke
# Markland Wood
#
# M9C
# Etobicoke
# Old Burnhamthorpe
#
# M1E
# Scarborough
# Guildwood
#
# M1E
# Scarborough
# Morningside
#
# M1E
# Scarborough
# West Hill
#
# M2E
# Not assigned
# Not assigned
#
# M3E
# Not assigned
# Not assigned
#
# M4E
# East Toronto
# The Beaches
#
# M5E
# Downtown Toronto
# Berczy Park
#
# M6E
# York
# Caledonia-Fairbanks
#
# M7E
# Not assigned
# Not assigned
#
# M8E
# Not assigned
# Not assigned
#
# M9E
# Not assigned
# Not assigned
#
# M1G
# Scarborough
# Woburn
#
# M2G
# Not assigned
# Not assigned
#
# M3G
# Not assigned
# Not assigned
#
# M4G
# East York
# Leaside
#
# M5G
# Downtown Toronto
# Central Bay Street
#
# M6G
# Downtown Toronto
# Christie
#
# M7G
# Not assigned
# Not assigned
#
# M8G
# Not assigned
# Not assigned
#
# M9G
# Not assigned
# Not assigned
#
# M1H
# Scarborough
# Cedarbrae
#
# M2H
# North York
# Hillcrest Village
#
# M3H
# North York
# Bathurst Manor
#
# M3H
# North York
# Downsview North
#
# M3H
# North York
# Wilson Heights
#
# M4H
# East York
# Thorncliffe Park
#
# M5H
# Downtown Toronto
# Adelaide
#
# M5H
# Downtown Toronto
# King
#
# M5H
# Downtown Toronto
# Richmond
#
# M6H
# West Toronto
# Dovercourt Village
#
# M6H
# West Toronto
# Dufferin
#
# M7H
# Not assigned
# Not assigned
#
# M8H
# Not assigned
# Not assigned
#
# M9H
# Not assigned
# Not assigned
#
# M1J
# Scarborough
# Scarborough Village
#
# M2J
# North York
# Fairview
#
# M2J
# North York
# Henry Farm
#
# M2J
# North York
# Oriole
#
# M3J
# North York
# Northwood Park
#
# M3J
# North York
# York University
#
# M4J
# East York
# East Toronto
#
# M5J
# Downtown Toronto
# Harbourfront East
#
# M5J
# Downtown Toronto
# Toronto Islands
#
# M5J
# Downtown Toronto
# Union Station
#
# M6J
# West Toronto
# Little Portugal
#
# M6J
# West Toronto
# Trinity
#
# M7J
# Not assigned
# Not assigned
#
# M8J
# Not assigned
# Not assigned
#
# M9J
# Not assigned
# Not assigned
#
# M1K
# Scarborough
# East Birchmount Park
#
# M1K
# Scarborough
# Ionview
#
# M1K
# Scarborough
# Kennedy Park
#
# M2K
# North York
# Bayview Village
#
# M3K
# North York
# CFB Toronto
#
# M3K
# North York
# Downsview East
#
# M4K
# East Toronto
# The Danforth West
#
# M4K
# East Toronto
# Riverdale
#
# M5K
# Downtown Toronto
# Design Exchange
#
# M5K
# Downtown Toronto
# Toronto Dominion Centre
#
# M6K
# West Toronto
# Brockton
#
# M6K
# West Toronto
# Exhibition Place
#
# M6K
# West Toronto
# Parkdale Village
#
# M7K
# Not assigned
# Not assigned
#
# M8K
# Not assigned
# Not assigned
#
# M9K
# Not assigned
# Not assigned
#
# M1L
# Scarborough
# Clairlea
#
# M1L
# Scarborough
# Golden Mile
#
# M1L
# Scarborough
# Oakridge
#
# M2L
# North York
# Silver Hills
#
# M2L
# North York
# York Mills
#
# M3L
# North York
# Downsview West
#
# M4L
# East Toronto
# The Beaches West
#
# M4L
# East Toronto
# India Bazaar
#
# M5L
# Downtown Toronto
# Commerce Court
#
# M5L
# Downtown Toronto
# Victoria Hotel
#
# M6L
# North York
# Downsview
#
# M6L
# North York
# North Park
#
# M6L
# North York
# Upwood Park
#
# M7L
# Not assigned
# Not assigned
#
# M8L
# Not assigned
# Not assigned
#
# M9L
# North York
# Humber Summit
#
# M1M
# Scarborough
# Cliffcrest
#
# M1M
# Scarborough
# Cliffside
#
# M1M
# Scarborough
# Scarborough Village West
#
# M2M
# North York
# Newtonbrook
#
# M2M
# North York
# Willowdale
#
# M3M
# North York
# Downsview Central
#
# M4M
# East Toronto
# Studio District
#
# M5M
# North York
# Bedford Park
#
# M5M
# North York
# Lawrence Manor East
#
# M6M
# York
# Del Ray
#
# M6M
# York
# Keelesdale
#
# M6M
# York
# Mount Dennis
#
# M6M
# York
# Silverthorn
#
# M7M
# Not assigned
# Not assigned
#
# M8M
# Not assigned
# Not assigned
#
# M9M
# North York
# Emery
#
# M9M
# North York
# Humberlea
#
# M1N
# Scarborough
# Birch Cliff
#
# M1N
# Scarborough
# Cliffside West
#
# M2N
# North York
# Willowdale South
#
# M3N
# North York
# Downsview Northwest
#
# M4N
# Central Toronto
# Lawrence Park
#
# M5N
# Central Toronto
# Roselawn
#
# M6N
# York
# The Junction North
#
# M6N
# York
# Runnymede
#
# M7N
# Not assigned
# Not assigned
#
# M8N
# Not assigned
# Not assigned
#
# M9N
# York
# Weston
#
# M1P
# Scarborough
# Dorset Park
#
# M1P
# Scarborough
# Scarborough Town Centre
#
# M1P
# Scarborough
# Wexford Heights
#
# M2P
# North York
# York Mills West
#
# M3P
# Not assigned
# Not assigned
#
# M4P
# Central Toronto
# Davisville North
#
# M5P
# Central Toronto
# Forest Hill North
#
# M5P
# Central Toronto
# Forest Hill West
#
# M6P
# West Toronto
# High Park
#
# M6P
# West Toronto
# The Junction South
#
# M7P
# Not assigned
# Not assigned
#
# M8P
# Not assigned
# Not assigned
#
# M9P
# Etobicoke
# Westmount
#
# M1R
# Scarborough
# Maryvale
#
# M1R
# Scarborough
# Wexford
#
# M2R
# North York
# Willowdale West
#
# M3R
# Not assigned
# Not assigned
#
# M4R
# Central Toronto
# North Toronto West
#
# M5R
# Central Toronto
# The Annex
#
# M5R
# Central Toronto
# North Midtown
#
# M5R
# Central Toronto
# Yorkville
#
# M6R
# West Toronto
# Parkdale
#
# M6R
# West Toronto
# Roncesvalles
#
# M7R
# Mississauga
# Canada Post Gateway Processing Centre
#
# M8R
# Not assigned
# Not assigned
#
# M9R
# Etobicoke
# Kingsview Village
#
# M9R
# Etobicoke
# Martin Grove Gardens
#
# M9R
# Etobicoke
# Richview Gardens
#
# M9R
# Etobicoke
# St. Phillips
#
# M1S
# Scarborough
# Agincourt
#
# M2S
# Not assigned
# Not assigned
#
# M3S
# Not assigned
# Not assigned
#
# M4S
# Central Toronto
# Davisville
#
# M5S
# Downtown Toronto
# Harbord
#
# M5S
# Downtown Toronto
# University of Toronto
#
# M6S
# West Toronto
# Runnymede
#
# M6S
# West Toronto
# Swansea
#
# M7S
# Not assigned
# Not assigned
#
# M8S
# Not assigned
# Not assigned
#
# M9S
# Not assigned
# Not assigned
#
# M1T
# Scarborough
# Clarks Corners
#
# M1T
# Scarborough
# Sullivan
#
# M1T
# Scarborough
# Tam O'Shanter
#
# M2T
# Not assigned
# Not assigned
#
# M3T
# Not assigned
# Not assigned
#
# M4T
# Central Toronto
# Moore Park
#
# M4T
# Central Toronto
# Summerhill East
#
# M5T
# Downtown Toronto
# Chinatown
#
# M5T
# Downtown Toronto
# Grange Park
#
# M5T
# Downtown Toronto
# Kensington Market
#
# M6T
# Not assigned
# Not assigned
#
# M7T
# Not assigned
# Not assigned
#
# M8T
# Not assigned
# Not assigned
#
# M9T
# Not assigned
# Not assigned
#
# M1V
# Scarborough
# Agincourt North
#
# M1V
# Scarborough
# L'Amoreaux East
#
# M1V
# Scarborough
# Milliken
#
# M1V
# Scarborough
# Steeles East
#
# M2V
# Not assigned
# Not assigned
#
# M3V
# Not assigned
# Not assigned
#
# M4V
# Central Toronto
# Deer Park
#
# M4V
# Central Toronto
# Forest Hill SE
#
# M4V
# Central Toronto
# Rathnelly
#
# M4V
# Central Toronto
# South Hill
#
# M4V
# Central Toronto
# Summerhill West
#
# M5V
# Downtown Toronto
# CN Tower
#
# M5V
# Downtown Toronto
# Bathurst Quay
#
# M5V
# Downtown Toronto
# Island airport
#
# M5V
# Downtown Toronto
# Harbourfront West
#
# M5V
# Downtown Toronto
# King and Spadina
#
# M5V
# Downtown Toronto
# Railway Lands
#
# M5V
# Downtown Toronto
# South Niagara
#
# M6V
# Not assigned
# Not assigned
#
# M7V
# Not assigned
# Not assigned
#
# M8V
# Etobicoke
# Humber Bay Shores
#
# M8V
# Etobicoke
# Mimico South
#
# M8V
# Etobicoke
# New Toronto
#
# M9V
# Etobicoke
# Albion Gardens
#
# M9V
# Etobicoke
# Beaumond Heights
#
# M9V
# Etobicoke
# Humbergate
#
# M9V
# Etobicoke
# Jamestown
#
# M9V
# Etobicoke
# Mount Olive
#
# M9V
# Etobicoke
# Silverstone
#
# M9V
# Etobicoke
# South Steeles
#
# M9V
# Etobicoke
# Thistletown
#
# M1W
# Scarborough
# L'Amoreaux West
#
# M2W
# Not assigned
# Not assigned
#
# M3W
# Not assigned
# Not assigned
#
# M4W
# Downtown Toronto
# Rosedale
#
# M5W
# Downtown Toronto
# Stn A PO Boxes 25 The Esplanade
#
# M6W
# Not assigned
# Not assigned
#
# M7W
# Not assigned
# Not assigned
#
# M8W
# Etobicoke
# Alderwood
#
# M8W
# Etobicoke
# Long Branch
#
# M9W
# Etobicoke
# Northwest
#
# M1X
# Scarborough
# Upper Rouge
#
# M2X
# Not assigned
# Not assigned
#
# M3X
# Not assigned
# Not assigned
#
# M4X
# Downtown Toronto
# Cabbagetown
#
# M4X
# Downtown Toronto
# St. James Town
#
# M5X
# Downtown Toronto
# First Canadian Place
#
# M5X
# Downtown Toronto
# Underground city
#
# M6X
# Not assigned
# Not assigned
#
# M7X
# Not assigned
# Not assigned
#
# M8X
# Etobicoke
# The Kingsway
#
# M8X
# Etobicoke
# Montgomery Road
#
# M8X
# Etobicoke
# Old Mill North
#
# M9X
# Not assigned
# Not assigned
#
# M1Y
# Not assigned
# Not assigned
#
# M2Y
# Not assigned
# Not assigned
#
# M3Y
# Not assigned
# Not assigned
#
# M4Y
# Downtown Toronto
# Church and Wellesley
#
# M5Y
# Not assigned
# Not assigned
#
# M6Y
# Not assigned
# Not assigned
#
# M7Y
# East Toronto
# Business Reply Mail Processing Centre 969 Eastern
#
# M8Y
# Etobicoke
# Humber Bay
#
# M8Y
# Etobicoke
# King's Mill Park
#
# M8Y
# Etobicoke
# Kingsway Park South East
#
# M8Y
# Etobicoke
# Mimico NE
#
# M8Y
# Etobicoke
# Old Mill South
#
# M8Y
# Etobicoke
# The Queensway East
#
# M8Y
# Etobicoke
# Royal York South East
#
# M8Y
# Etobicoke
# Sunnylea
#
# M9Y
# Not assigned
# Not assigned
#
# M1Z
# Not assigned
# Not assigned
#
# M2Z
# Not assigned
# Not assigned
#
# M3Z
# Not assigned
# Not assigned
#
# M4Z
# Not assigned
# Not assigned
#
# M5Z
# Not assigned
# Not assigned
#
# M6Z
# Not assigned
# Not assigned
#
# M7Z
# Not assigned
# Not assigned
#
# M8Z
# Etobicoke
# Kingsway Park South West
#
# M8Z
# Etobicoke
# Mimico NW
#
# M8Z
# Etobicoke
# The Queensway West
#
# M8Z
# Etobicoke
# Royal York South West
#
# M8Z
# Etobicoke
# South of Bloor
#
# M9Z
# Not assigned
# Not assigned
#
#
#
#
#
#
#
#
#
# NL
#
# NS
#
# PE
#
# NB
#
# QC
#
# ON
#
# MB
#
# SK
#
# AB
#
# BC
#
# NU/NT
#
# YT
#
#
# A
#
# B
#
# C
#
# E
#
# G
#
# H
#
# J
#
# K
#
# L
#
# M
#
# N
#
# P
#
# R
#
# S
#
# T
#
# V
#
# X
#
# Y
#
#
# NL
#
# NS
#
# PE
#
# NB
#
# QC
#
# ON
#
# MB
#
# SK
#
# AB
#
# BC
#
# NU/NT
#
# YT
#
# A
#
# B
#
# C
#
# E
#
# G
#
# H
#
# J
#
# K
#
# L
#
# M
#
# N
#
# P
#
# R
#
# S
#
# T
#
# V
#
# X
#
# Y
#
# NL
#
# NS
#
# PE
#
# NB
#
# QC
#
# ON
#
# MB
#
# SK
#
# AB
#
# BC
#
# NU/NT
#
# YT
#
# A
#
# B
#
# C
#
# E
#
# G
#
# H
#
# J
#
# K
#
# L
#
# M
#
# N
#
# P
#
# R
#
# S
#
# T
#
# V
#
# X
#
# Y

# %%
for table_cell in full_table.find_all('td'):
	table_cell_text = table_cell.text
	print(table_cell_text)
# Out:
# M1A
# Not assigned
# Not assigned
#
# M2A
# Not assigned
# Not assigned
#
# M3A
# North York
# Parkwoods
#
# M4A
# North York
# Victoria Village
#
# M5A
# Downtown Toronto
# Harbourfront
#
# M5A
# Downtown Toronto
# Regent Park
#
# M6A
# North York
# Lawrence Heights
#
# M6A
# North York
# Lawrence Manor
#
# M7A
# Queen's Park
# Not assigned
#
# M8A
# Not assigned
# Not assigned
#
# M9A
# Etobicoke
# Islington Avenue
#
# M1B
# Scarborough
# Rouge
#
# M1B
# Scarborough
# Malvern
#
# M2B
# Not assigned
# Not assigned
#
# M3B
# North York
# Don Mills North
#
# M4B
# East York
# Woodbine Gardens
#
# M4B
# East York
# Parkview Hill
#
# M5B
# Downtown Toronto
# Ryerson
#
# M5B
# Downtown Toronto
# Garden District
#
# M6B
# North York
# Glencairn
#
# M7B
# Not assigned
# Not assigned
#
# M8B
# Not assigned
# Not assigned
#
# M9B
# Etobicoke
# Cloverdale
#
# M9B
# Etobicoke
# Islington
#
# M9B
# Etobicoke
# Martin Grove
#
# M9B
# Etobicoke
# Princess Gardens
#
# M9B
# Etobicoke
# West Deane Park
#
# M1C
# Scarborough
# Highland Creek
#
# M1C
# Scarborough
# Rouge Hill
#
# M1C
# Scarborough
# Port Union
#
# M2C
# Not assigned
# Not assigned
#
# M3C
# North York
# Flemingdon Park
#
# M3C
# North York
# Don Mills South
#
# M4C
# East York
# Woodbine Heights
#
# M5C
# Downtown Toronto
# St. James Town
#
# M6C
# York
# Humewood-Cedarvale
#
# M7C
# Not assigned
# Not assigned
#
# M8C
# Not assigned
# Not assigned
#
# M9C
# Etobicoke
# Bloordale Gardens
#
# M9C
# Etobicoke
# Eringate
#
# M9C
# Etobicoke
# Markland Wood
#
# M9C
# Etobicoke
# Old Burnhamthorpe
#
# M1E
# Scarborough
# Guildwood
#
# M1E
# Scarborough
# Morningside
#
# M1E
# Scarborough
# West Hill
#
# M2E
# Not assigned
# Not assigned
#
# M3E
# Not assigned
# Not assigned
#
# M4E
# East Toronto
# The Beaches
#
# M5E
# Downtown Toronto
# Berczy Park
#
# M6E
# York
# Caledonia-Fairbanks
#
# M7E
# Not assigned
# Not assigned
#
# M8E
# Not assigned
# Not assigned
#
# M9E
# Not assigned
# Not assigned
#
# M1G
# Scarborough
# Woburn
#
# M2G
# Not assigned
# Not assigned
#
# M3G
# Not assigned
# Not assigned
#
# M4G
# East York
# Leaside
#
# M5G
# Downtown Toronto
# Central Bay Street
#
# M6G
# Downtown Toronto
# Christie
#
# M7G
# Not assigned
# Not assigned
#
# M8G
# Not assigned
# Not assigned
#
# M9G
# Not assigned
# Not assigned
#
# M1H
# Scarborough
# Cedarbrae
#
# M2H
# North York
# Hillcrest Village
#
# M3H
# North York
# Bathurst Manor
#
# M3H
# North York
# Downsview North
#
# M3H
# North York
# Wilson Heights
#
# M4H
# East York
# Thorncliffe Park
#
# M5H
# Downtown Toronto
# Adelaide
#
# M5H
# Downtown Toronto
# King
#
# M5H
# Downtown Toronto
# Richmond
#
# M6H
# West Toronto
# Dovercourt Village
#
# M6H
# West Toronto
# Dufferin
#
# M7H
# Not assigned
# Not assigned
#
# M8H
# Not assigned
# Not assigned
#
# M9H
# Not assigned
# Not assigned
#
# M1J
# Scarborough
# Scarborough Village
#
# M2J
# North York
# Fairview
#
# M2J
# North York
# Henry Farm
#
# M2J
# North York
# Oriole
#
# M3J
# North York
# Northwood Park
#
# M3J
# North York
# York University
#
# M4J
# East York
# East Toronto
#
# M5J
# Downtown Toronto
# Harbourfront East
#
# M5J
# Downtown Toronto
# Toronto Islands
#
# M5J
# Downtown Toronto
# Union Station
#
# M6J
# West Toronto
# Little Portugal
#
# M6J
# West Toronto
# Trinity
#
# M7J
# Not assigned
# Not assigned
#
# M8J
# Not assigned
# Not assigned
#
# M9J
# Not assigned
# Not assigned
#
# M1K
# Scarborough
# East Birchmount Park
#
# M1K
# Scarborough
# Ionview
#
# M1K
# Scarborough
# Kennedy Park
#
# M2K
# North York
# Bayview Village
#
# M3K
# North York
# CFB Toronto
#
# M3K
# North York
# Downsview East
#
# M4K
# East Toronto
# The Danforth West
#
# M4K
# East Toronto
# Riverdale
#
# M5K
# Downtown Toronto
# Design Exchange
#
# M5K
# Downtown Toronto
# Toronto Dominion Centre
#
# M6K
# West Toronto
# Brockton
#
# M6K
# West Toronto
# Exhibition Place
#
# M6K
# West Toronto
# Parkdale Village
#
# M7K
# Not assigned
# Not assigned
#
# M8K
# Not assigned
# Not assigned
#
# M9K
# Not assigned
# Not assigned
#
# M1L
# Scarborough
# Clairlea
#
# M1L
# Scarborough
# Golden Mile
#
# M1L
# Scarborough
# Oakridge
#
# M2L
# North York
# Silver Hills
#
# M2L
# North York
# York Mills
#
# M3L
# North York
# Downsview West
#
# M4L
# East Toronto
# The Beaches West
#
# M4L
# East Toronto
# India Bazaar
#
# M5L
# Downtown Toronto
# Commerce Court
#
# M5L
# Downtown Toronto
# Victoria Hotel
#
# M6L
# North York
# Downsview
#
# M6L
# North York
# North Park
#
# M6L
# North York
# Upwood Park
#
# M7L
# Not assigned
# Not assigned
#
# M8L
# Not assigned
# Not assigned
#
# M9L
# North York
# Humber Summit
#
# M1M
# Scarborough
# Cliffcrest
#
# M1M
# Scarborough
# Cliffside
#
# M1M
# Scarborough
# Scarborough Village West
#
# M2M
# North York
# Newtonbrook
#
# M2M
# North York
# Willowdale
#
# M3M
# North York
# Downsview Central
#
# M4M
# East Toronto
# Studio District
#
# M5M
# North York
# Bedford Park
#
# M5M
# North York
# Lawrence Manor East
#
# M6M
# York
# Del Ray
#
# M6M
# York
# Keelesdale
#
# M6M
# York
# Mount Dennis
#
# M6M
# York
# Silverthorn
#
# M7M
# Not assigned
# Not assigned
#
# M8M
# Not assigned
# Not assigned
#
# M9M
# North York
# Emery
#
# M9M
# North York
# Humberlea
#
# M1N
# Scarborough
# Birch Cliff
#
# M1N
# Scarborough
# Cliffside West
#
# M2N
# North York
# Willowdale South
#
# M3N
# North York
# Downsview Northwest
#
# M4N
# Central Toronto
# Lawrence Park
#
# M5N
# Central Toronto
# Roselawn
#
# M6N
# York
# The Junction North
#
# M6N
# York
# Runnymede
#
# M7N
# Not assigned
# Not assigned
#
# M8N
# Not assigned
# Not assigned
#
# M9N
# York
# Weston
#
# M1P
# Scarborough
# Dorset Park
#
# M1P
# Scarborough
# Scarborough Town Centre
#
# M1P
# Scarborough
# Wexford Heights
#
# M2P
# North York
# York Mills West
#
# M3P
# Not assigned
# Not assigned
#
# M4P
# Central Toronto
# Davisville North
#
# M5P
# Central Toronto
# Forest Hill North
#
# M5P
# Central Toronto
# Forest Hill West
#
# M6P
# West Toronto
# High Park
#
# M6P
# West Toronto
# The Junction South
#
# M7P
# Not assigned
# Not assigned
#
# M8P
# Not assigned
# Not assigned
#
# M9P
# Etobicoke
# Westmount
#
# M1R
# Scarborough
# Maryvale
#
# M1R
# Scarborough
# Wexford
#
# M2R
# North York
# Willowdale West
#
# M3R
# Not assigned
# Not assigned
#
# M4R
# Central Toronto
# North Toronto West
#
# M5R
# Central Toronto
# The Annex
#
# M5R
# Central Toronto
# North Midtown
#
# M5R
# Central Toronto
# Yorkville
#
# M6R
# West Toronto
# Parkdale
#
# M6R
# West Toronto
# Roncesvalles
#
# M7R
# Mississauga
# Canada Post Gateway Processing Centre
#
# M8R
# Not assigned
# Not assigned
#
# M9R
# Etobicoke
# Kingsview Village
#
# M9R
# Etobicoke
# Martin Grove Gardens
#
# M9R
# Etobicoke
# Richview Gardens
#
# M9R
# Etobicoke
# St. Phillips
#
# M1S
# Scarborough
# Agincourt
#
# M2S
# Not assigned
# Not assigned
#
# M3S
# Not assigned
# Not assigned
#
# M4S
# Central Toronto
# Davisville
#
# M5S
# Downtown Toronto
# Harbord
#
# M5S
# Downtown Toronto
# University of Toronto
#
# M6S
# West Toronto
# Runnymede
#
# M6S
# West Toronto
# Swansea
#
# M7S
# Not assigned
# Not assigned
#
# M8S
# Not assigned
# Not assigned
#
# M9S
# Not assigned
# Not assigned
#
# M1T
# Scarborough
# Clarks Corners
#
# M1T
# Scarborough
# Sullivan
#
# M1T
# Scarborough
# Tam O'Shanter
#
# M2T
# Not assigned
# Not assigned
#
# M3T
# Not assigned
# Not assigned
#
# M4T
# Central Toronto
# Moore Park
#
# M4T
# Central Toronto
# Summerhill East
#
# M5T
# Downtown Toronto
# Chinatown
#
# M5T
# Downtown Toronto
# Grange Park
#
# M5T
# Downtown Toronto
# Kensington Market
#
# M6T
# Not assigned
# Not assigned
#
# M7T
# Not assigned
# Not assigned
#
# M8T
# Not assigned
# Not assigned
#
# M9T
# Not assigned
# Not assigned
#
# M1V
# Scarborough
# Agincourt North
#
# M1V
# Scarborough
# L'Amoreaux East
#
# M1V
# Scarborough
# Milliken
#
# M1V
# Scarborough
# Steeles East
#
# M2V
# Not assigned
# Not assigned
#
# M3V
# Not assigned
# Not assigned
#
# M4V
# Central Toronto
# Deer Park
#
# M4V
# Central Toronto
# Forest Hill SE
#
# M4V
# Central Toronto
# Rathnelly
#
# M4V
# Central Toronto
# South Hill
#
# M4V
# Central Toronto
# Summerhill West
#
# M5V
# Downtown Toronto
# CN Tower
#
# M5V
# Downtown Toronto
# Bathurst Quay
#
# M5V
# Downtown Toronto
# Island airport
#
# M5V
# Downtown Toronto
# Harbourfront West
#
# M5V
# Downtown Toronto
# King and Spadina
#
# M5V
# Downtown Toronto
# Railway Lands
#
# M5V
# Downtown Toronto
# South Niagara
#
# M6V
# Not assigned
# Not assigned
#
# M7V
# Not assigned
# Not assigned
#
# M8V
# Etobicoke
# Humber Bay Shores
#
# M8V
# Etobicoke
# Mimico South
#
# M8V
# Etobicoke
# New Toronto
#
# M9V
# Etobicoke
# Albion Gardens
#
# M9V
# Etobicoke
# Beaumond Heights
#
# M9V
# Etobicoke
# Humbergate
#
# M9V
# Etobicoke
# Jamestown
#
# M9V
# Etobicoke
# Mount Olive
#
# M9V
# Etobicoke
# Silverstone
#
# M9V
# Etobicoke
# South Steeles
#
# M9V
# Etobicoke
# Thistletown
#
# M1W
# Scarborough
# L'Amoreaux West
#
# M2W
# Not assigned
# Not assigned
#
# M3W
# Not assigned
# Not assigned
#
# M4W
# Downtown Toronto
# Rosedale
#
# M5W
# Downtown Toronto
# Stn A PO Boxes 25 The Esplanade
#
# M6W
# Not assigned
# Not assigned
#
# M7W
# Not assigned
# Not assigned
#
# M8W
# Etobicoke
# Alderwood
#
# M8W
# Etobicoke
# Long Branch
#
# M9W
# Etobicoke
# Northwest
#
# M1X
# Scarborough
# Upper Rouge
#
# M2X
# Not assigned
# Not assigned
#
# M3X
# Not assigned
# Not assigned
#
# M4X
# Downtown Toronto
# Cabbagetown
#
# M4X
# Downtown Toronto
# St. James Town
#
# M5X
# Downtown Toronto
# First Canadian Place
#
# M5X
# Downtown Toronto
# Underground city
#
# M6X
# Not assigned
# Not assigned
#
# M7X
# Not assigned
# Not assigned
#
# M8X
# Etobicoke
# The Kingsway
#
# M8X
# Etobicoke
# Montgomery Road
#
# M8X
# Etobicoke
# Old Mill North
#
# M9X
# Not assigned
# Not assigned
#
# M1Y
# Not assigned
# Not assigned
#
# M2Y
# Not assigned
# Not assigned
#
# M3Y
# Not assigned
# Not assigned
#
# M4Y
# Downtown Toronto
# Church and Wellesley
#
# M5Y
# Not assigned
# Not assigned
#
# M6Y
# Not assigned
# Not assigned
#
# M7Y
# East Toronto
# Business Reply Mail Processing Centre 969 Eastern
#
# M8Y
# Etobicoke
# Humber Bay
#
# M8Y
# Etobicoke
# King's Mill Park
#
# M8Y
# Etobicoke
# Kingsway Park South East
#
# M8Y
# Etobicoke
# Mimico NE
#
# M8Y
# Etobicoke
# Old Mill South
#
# M8Y
# Etobicoke
# The Queensway East
#
# M8Y
# Etobicoke
# Royal York South East
#
# M8Y
# Etobicoke
# Sunnylea
#
# M9Y
# Not assigned
# Not assigned
#
# M1Z
# Not assigned
# Not assigned
#
# M2Z
# Not assigned
# Not assigned
#
# M3Z
# Not assigned
# Not assigned
#
# M4Z
# Not assigned
# Not assigned
#
# M5Z
# Not assigned
# Not assigned
#
# M6Z
# Not assigned
# Not assigned
#
# M7Z
# Not assigned
# Not assigned
#
# M8Z
# Etobicoke
# Kingsway Park South West
#
# M8Z
# Etobicoke
# Mimico NW
#
# M8Z
# Etobicoke
# The Queensway West
#
# M8Z
# Etobicoke
# Royal York South West
#
# M8Z
# Etobicoke
# South of Bloor
#
# M9Z
# Not assigned
# Not assigned

# %%
for table_row in full_table.find_all('tr'):
	for table_cell in table_row.find_all('td'):
		table_cell_text = table_cell.text
		print(table_cell_text)
# Out:
# M1A
# Not assigned
# Not assigned
#
# M2A
# Not assigned
# Not assigned
#
# M3A
# North York
# Parkwoods
#
# M4A
# North York
# Victoria Village
#
# M5A
# Downtown Toronto
# Harbourfront
#
# M5A
# Downtown Toronto
# Regent Park
#
# M6A
# North York
# Lawrence Heights
#
# M6A
# North York
# Lawrence Manor
#
# M7A
# Queen's Park
# Not assigned
#
# M8A
# Not assigned
# Not assigned
#
# M9A
# Etobicoke
# Islington Avenue
#
# M1B
# Scarborough
# Rouge
#
# M1B
# Scarborough
# Malvern
#
# M2B
# Not assigned
# Not assigned
#
# M3B
# North York
# Don Mills North
#
# M4B
# East York
# Woodbine Gardens
#
# M4B
# East York
# Parkview Hill
#
# M5B
# Downtown Toronto
# Ryerson
#
# M5B
# Downtown Toronto
# Garden District
#
# M6B
# North York
# Glencairn
#
# M7B
# Not assigned
# Not assigned
#
# M8B
# Not assigned
# Not assigned
#
# M9B
# Etobicoke
# Cloverdale
#
# M9B
# Etobicoke
# Islington
#
# M9B
# Etobicoke
# Martin Grove
#
# M9B
# Etobicoke
# Princess Gardens
#
# M9B
# Etobicoke
# West Deane Park
#
# M1C
# Scarborough
# Highland Creek
#
# M1C
# Scarborough
# Rouge Hill
#
# M1C
# Scarborough
# Port Union
#
# M2C
# Not assigned
# Not assigned
#
# M3C
# North York
# Flemingdon Park
#
# M3C
# North York
# Don Mills South
#
# M4C
# East York
# Woodbine Heights
#
# M5C
# Downtown Toronto
# St. James Town
#
# M6C
# York
# Humewood-Cedarvale
#
# M7C
# Not assigned
# Not assigned
#
# M8C
# Not assigned
# Not assigned
#
# M9C
# Etobicoke
# Bloordale Gardens
#
# M9C
# Etobicoke
# Eringate
#
# M9C
# Etobicoke
# Markland Wood
#
# M9C
# Etobicoke
# Old Burnhamthorpe
#
# M1E
# Scarborough
# Guildwood
#
# M1E
# Scarborough
# Morningside
#
# M1E
# Scarborough
# West Hill
#
# M2E
# Not assigned
# Not assigned
#
# M3E
# Not assigned
# Not assigned
#
# M4E
# East Toronto
# The Beaches
#
# M5E
# Downtown Toronto
# Berczy Park
#
# M6E
# York
# Caledonia-Fairbanks
#
# M7E
# Not assigned
# Not assigned
#
# M8E
# Not assigned
# Not assigned
#
# M9E
# Not assigned
# Not assigned
#
# M1G
# Scarborough
# Woburn
#
# M2G
# Not assigned
# Not assigned
#
# M3G
# Not assigned
# Not assigned
#
# M4G
# East York
# Leaside
#
# M5G
# Downtown Toronto
# Central Bay Street
#
# M6G
# Downtown Toronto
# Christie
#
# M7G
# Not assigned
# Not assigned
#
# M8G
# Not assigned
# Not assigned
#
# M9G
# Not assigned
# Not assigned
#
# M1H
# Scarborough
# Cedarbrae
#
# M2H
# North York
# Hillcrest Village
#
# M3H
# North York
# Bathurst Manor
#
# M3H
# North York
# Downsview North
#
# M3H
# North York
# Wilson Heights
#
# M4H
# East York
# Thorncliffe Park
#
# M5H
# Downtown Toronto
# Adelaide
#
# M5H
# Downtown Toronto
# King
#
# M5H
# Downtown Toronto
# Richmond
#
# M6H
# West Toronto
# Dovercourt Village
#
# M6H
# West Toronto
# Dufferin
#
# M7H
# Not assigned
# Not assigned
#
# M8H
# Not assigned
# Not assigned
#
# M9H
# Not assigned
# Not assigned
#
# M1J
# Scarborough
# Scarborough Village
#
# M2J
# North York
# Fairview
#
# M2J
# North York
# Henry Farm
#
# M2J
# North York
# Oriole
#
# M3J
# North York
# Northwood Park
#
# M3J
# North York
# York University
#
# M4J
# East York
# East Toronto
#
# M5J
# Downtown Toronto
# Harbourfront East
#
# M5J
# Downtown Toronto
# Toronto Islands
#
# M5J
# Downtown Toronto
# Union Station
#
# M6J
# West Toronto
# Little Portugal
#
# M6J
# West Toronto
# Trinity
#
# M7J
# Not assigned
# Not assigned
#
# M8J
# Not assigned
# Not assigned
#
# M9J
# Not assigned
# Not assigned
#
# M1K
# Scarborough
# East Birchmount Park
#
# M1K
# Scarborough
# Ionview
#
# M1K
# Scarborough
# Kennedy Park
#
# M2K
# North York
# Bayview Village
#
# M3K
# North York
# CFB Toronto
#
# M3K
# North York
# Downsview East
#
# M4K
# East Toronto
# The Danforth West
#
# M4K
# East Toronto
# Riverdale
#
# M5K
# Downtown Toronto
# Design Exchange
#
# M5K
# Downtown Toronto
# Toronto Dominion Centre
#
# M6K
# West Toronto
# Brockton
#
# M6K
# West Toronto
# Exhibition Place
#
# M6K
# West Toronto
# Parkdale Village
#
# M7K
# Not assigned
# Not assigned
#
# M8K
# Not assigned
# Not assigned
#
# M9K
# Not assigned
# Not assigned
#
# M1L
# Scarborough
# Clairlea
#
# M1L
# Scarborough
# Golden Mile
#
# M1L
# Scarborough
# Oakridge
#
# M2L
# North York
# Silver Hills
#
# M2L
# North York
# York Mills
#
# M3L
# North York
# Downsview West
#
# M4L
# East Toronto
# The Beaches West
#
# M4L
# East Toronto
# India Bazaar
#
# M5L
# Downtown Toronto
# Commerce Court
#
# M5L
# Downtown Toronto
# Victoria Hotel
#
# M6L
# North York
# Downsview
#
# M6L
# North York
# North Park
#
# M6L
# North York
# Upwood Park
#
# M7L
# Not assigned
# Not assigned
#
# M8L
# Not assigned
# Not assigned
#
# M9L
# North York
# Humber Summit
#
# M1M
# Scarborough
# Cliffcrest
#
# M1M
# Scarborough
# Cliffside
#
# M1M
# Scarborough
# Scarborough Village West
#
# M2M
# North York
# Newtonbrook
#
# M2M
# North York
# Willowdale
#
# M3M
# North York
# Downsview Central
#
# M4M
# East Toronto
# Studio District
#
# M5M
# North York
# Bedford Park
#
# M5M
# North York
# Lawrence Manor East
#
# M6M
# York
# Del Ray
#
# M6M
# York
# Keelesdale
#
# M6M
# York
# Mount Dennis
#
# M6M
# York
# Silverthorn
#
# M7M
# Not assigned
# Not assigned
#
# M8M
# Not assigned
# Not assigned
#
# M9M
# North York
# Emery
#
# M9M
# North York
# Humberlea
#
# M1N
# Scarborough
# Birch Cliff
#
# M1N
# Scarborough
# Cliffside West
#
# M2N
# North York
# Willowdale South
#
# M3N
# North York
# Downsview Northwest
#
# M4N
# Central Toronto
# Lawrence Park
#
# M5N
# Central Toronto
# Roselawn
#
# M6N
# York
# The Junction North
#
# M6N
# York
# Runnymede
#
# M7N
# Not assigned
# Not assigned
#
# M8N
# Not assigned
# Not assigned
#
# M9N
# York
# Weston
#
# M1P
# Scarborough
# Dorset Park
#
# M1P
# Scarborough
# Scarborough Town Centre
#
# M1P
# Scarborough
# Wexford Heights
#
# M2P
# North York
# York Mills West
#
# M3P
# Not assigned
# Not assigned
#
# M4P
# Central Toronto
# Davisville North
#
# M5P
# Central Toronto
# Forest Hill North
#
# M5P
# Central Toronto
# Forest Hill West
#
# M6P
# West Toronto
# High Park
#
# M6P
# West Toronto
# The Junction South
#
# M7P
# Not assigned
# Not assigned
#
# M8P
# Not assigned
# Not assigned
#
# M9P
# Etobicoke
# Westmount
#
# M1R
# Scarborough
# Maryvale
#
# M1R
# Scarborough
# Wexford
#
# M2R
# North York
# Willowdale West
#
# M3R
# Not assigned
# Not assigned
#
# M4R
# Central Toronto
# North Toronto West
#
# M5R
# Central Toronto
# The Annex
#
# M5R
# Central Toronto
# North Midtown
#
# M5R
# Central Toronto
# Yorkville
#
# M6R
# West Toronto
# Parkdale
#
# M6R
# West Toronto
# Roncesvalles
#
# M7R
# Mississauga
# Canada Post Gateway Processing Centre
#
# M8R
# Not assigned
# Not assigned
#
# M9R
# Etobicoke
# Kingsview Village
#
# M9R
# Etobicoke
# Martin Grove Gardens
#
# M9R
# Etobicoke
# Richview Gardens
#
# M9R
# Etobicoke
# St. Phillips
#
# M1S
# Scarborough
# Agincourt
#
# M2S
# Not assigned
# Not assigned
#
# M3S
# Not assigned
# Not assigned
#
# M4S
# Central Toronto
# Davisville
#
# M5S
# Downtown Toronto
# Harbord
#
# M5S
# Downtown Toronto
# University of Toronto
#
# M6S
# West Toronto
# Runnymede
#
# M6S
# West Toronto
# Swansea
#
# M7S
# Not assigned
# Not assigned
#
# M8S
# Not assigned
# Not assigned
#
# M9S
# Not assigned
# Not assigned
#
# M1T
# Scarborough
# Clarks Corners
#
# M1T
# Scarborough
# Sullivan
#
# M1T
# Scarborough
# Tam O'Shanter
#
# M2T
# Not assigned
# Not assigned
#
# M3T
# Not assigned
# Not assigned
#
# M4T
# Central Toronto
# Moore Park
#
# M4T
# Central Toronto
# Summerhill East
#
# M5T
# Downtown Toronto
# Chinatown
#
# M5T
# Downtown Toronto
# Grange Park
#
# M5T
# Downtown Toronto
# Kensington Market
#
# M6T
# Not assigned
# Not assigned
#
# M7T
# Not assigned
# Not assigned
#
# M8T
# Not assigned
# Not assigned
#
# M9T
# Not assigned
# Not assigned
#
# M1V
# Scarborough
# Agincourt North
#
# M1V
# Scarborough
# L'Amoreaux East
#
# M1V
# Scarborough
# Milliken
#
# M1V
# Scarborough
# Steeles East
#
# M2V
# Not assigned
# Not assigned
#
# M3V
# Not assigned
# Not assigned
#
# M4V
# Central Toronto
# Deer Park
#
# M4V
# Central Toronto
# Forest Hill SE
#
# M4V
# Central Toronto
# Rathnelly
#
# M4V
# Central Toronto
# South Hill
#
# M4V
# Central Toronto
# Summerhill West
#
# M5V
# Downtown Toronto
# CN Tower
#
# M5V
# Downtown Toronto
# Bathurst Quay
#
# M5V
# Downtown Toronto
# Island airport
#
# M5V
# Downtown Toronto
# Harbourfront West
#
# M5V
# Downtown Toronto
# King and Spadina
#
# M5V
# Downtown Toronto
# Railway Lands
#
# M5V
# Downtown Toronto
# South Niagara
#
# M6V
# Not assigned
# Not assigned
#
# M7V
# Not assigned
# Not assigned
#
# M8V
# Etobicoke
# Humber Bay Shores
#
# M8V
# Etobicoke
# Mimico South
#
# M8V
# Etobicoke
# New Toronto
#
# M9V
# Etobicoke
# Albion Gardens
#
# M9V
# Etobicoke
# Beaumond Heights
#
# M9V
# Etobicoke
# Humbergate
#
# M9V
# Etobicoke
# Jamestown
#
# M9V
# Etobicoke
# Mount Olive
#
# M9V
# Etobicoke
# Silverstone
#
# M9V
# Etobicoke
# South Steeles
#
# M9V
# Etobicoke
# Thistletown
#
# M1W
# Scarborough
# L'Amoreaux West
#
# M2W
# Not assigned
# Not assigned
#
# M3W
# Not assigned
# Not assigned
#
# M4W
# Downtown Toronto
# Rosedale
#
# M5W
# Downtown Toronto
# Stn A PO Boxes 25 The Esplanade
#
# M6W
# Not assigned
# Not assigned
#
# M7W
# Not assigned
# Not assigned
#
# M8W
# Etobicoke
# Alderwood
#
# M8W
# Etobicoke
# Long Branch
#
# M9W
# Etobicoke
# Northwest
#
# M1X
# Scarborough
# Upper Rouge
#
# M2X
# Not assigned
# Not assigned
#
# M3X
# Not assigned
# Not assigned
#
# M4X
# Downtown Toronto
# Cabbagetown
#
# M4X
# Downtown Toronto
# St. James Town
#
# M5X
# Downtown Toronto
# First Canadian Place
#
# M5X
# Downtown Toronto
# Underground city
#
# M6X
# Not assigned
# Not assigned
#
# M7X
# Not assigned
# Not assigned
#
# M8X
# Etobicoke
# The Kingsway
#
# M8X
# Etobicoke
# Montgomery Road
#
# M8X
# Etobicoke
# Old Mill North
#
# M9X
# Not assigned
# Not assigned
#
# M1Y
# Not assigned
# Not assigned
#
# M2Y
# Not assigned
# Not assigned
#
# M3Y
# Not assigned
# Not assigned
#
# M4Y
# Downtown Toronto
# Church and Wellesley
#
# M5Y
# Not assigned
# Not assigned
#
# M6Y
# Not assigned
# Not assigned
#
# M7Y
# East Toronto
# Business Reply Mail Processing Centre 969 Eastern
#
# M8Y
# Etobicoke
# Humber Bay
#
# M8Y
# Etobicoke
# King's Mill Park
#
# M8Y
# Etobicoke
# Kingsway Park South East
#
# M8Y
# Etobicoke
# Mimico NE
#
# M8Y
# Etobicoke
# Old Mill South
#
# M8Y
# Etobicoke
# The Queensway East
#
# M8Y
# Etobicoke
# Royal York South East
#
# M8Y
# Etobicoke
# Sunnylea
#
# M9Y
# Not assigned
# Not assigned
#
# M1Z
# Not assigned
# Not assigned
#
# M2Z
# Not assigned
# Not assigned
#
# M3Z
# Not assigned
# Not assigned
#
# M4Z
# Not assigned
# Not assigned
#
# M5Z
# Not assigned
# Not assigned
#
# M6Z
# Not assigned
# Not assigned
#
# M7Z
# Not assigned
# Not assigned
#
# M8Z
# Etobicoke
# Kingsway Park South West
#
# M8Z
# Etobicoke
# Mimico NW
#
# M8Z
# Etobicoke
# The Queensway West
#
# M8Z
# Etobicoke
# Royal York South West
#
# M8Z
# Etobicoke
# South of Bloor
#
# M9Z
# Not assigned
# Not assigned

# %%
for table_row in full_table.find_all('tr'):
	counter = 1
	for table_cell in table_row.find_all('td'):
		if counter == 1:
			postcode = table_cell.text
			print("Postcode is "+postcode )
		elif counter == 2:
			borough = table_cell.text
			print("Borough is "+borough )
		else:
			neighborhood = table_cell.text
			print("Neighborhood is "+neighborhood )
		counter = counter + 1
# Out:
# Postcode is M1A
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M2A
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3A
# Borough is North York
# Neighborhood is Parkwoods
#
# Postcode is M4A
# Borough is North York
# Neighborhood is Victoria Village
#
# Postcode is M5A
# Borough is Downtown Toronto
# Neighborhood is Harbourfront
#
# Postcode is M5A
# Borough is Downtown Toronto
# Neighborhood is Regent Park
#
# Postcode is M6A
# Borough is North York
# Neighborhood is Lawrence Heights
#
# Postcode is M6A
# Borough is North York
# Neighborhood is Lawrence Manor
#
# Postcode is M7A
# Borough is Queen's Park
# Neighborhood is Not assigned
#
# Postcode is M8A
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9A
# Borough is Etobicoke
# Neighborhood is Islington Avenue
#
# Postcode is M1B
# Borough is Scarborough
# Neighborhood is Rouge
#
# Postcode is M1B
# Borough is Scarborough
# Neighborhood is Malvern
#
# Postcode is M2B
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3B
# Borough is North York
# Neighborhood is Don Mills North
#
# Postcode is M4B
# Borough is East York
# Neighborhood is Woodbine Gardens
#
# Postcode is M4B
# Borough is East York
# Neighborhood is Parkview Hill
#
# Postcode is M5B
# Borough is Downtown Toronto
# Neighborhood is Ryerson
#
# Postcode is M5B
# Borough is Downtown Toronto
# Neighborhood is Garden District
#
# Postcode is M6B
# Borough is North York
# Neighborhood is Glencairn
#
# Postcode is M7B
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8B
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Cloverdale
#
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Islington
#
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Martin Grove
#
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Princess Gardens
#
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is West Deane Park
#
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Highland Creek
#
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Rouge Hill
#
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Port Union
#
# Postcode is M2C
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3C
# Borough is North York
# Neighborhood is Flemingdon Park
#
# Postcode is M3C
# Borough is North York
# Neighborhood is Don Mills South
#
# Postcode is M4C
# Borough is East York
# Neighborhood is Woodbine Heights
#
# Postcode is M5C
# Borough is Downtown Toronto
# Neighborhood is St. James Town
#
# Postcode is M6C
# Borough is York
# Neighborhood is Humewood-Cedarvale
#
# Postcode is M7C
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8C
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Bloordale Gardens
#
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Eringate
#
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Markland Wood
#
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Old Burnhamthorpe
#
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is Guildwood
#
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is Morningside
#
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is West Hill
#
# Postcode is M2E
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3E
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4E
# Borough is East Toronto
# Neighborhood is The Beaches
#
# Postcode is M5E
# Borough is Downtown Toronto
# Neighborhood is Berczy Park
#
# Postcode is M6E
# Borough is York
# Neighborhood is Caledonia-Fairbanks
#
# Postcode is M7E
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8E
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9E
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1G
# Borough is Scarborough
# Neighborhood is Woburn
#
# Postcode is M2G
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3G
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4G
# Borough is East York
# Neighborhood is Leaside
#
# Postcode is M5G
# Borough is Downtown Toronto
# Neighborhood is Central Bay Street
#
# Postcode is M6G
# Borough is Downtown Toronto
# Neighborhood is Christie
#
# Postcode is M7G
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8G
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9G
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1H
# Borough is Scarborough
# Neighborhood is Cedarbrae
#
# Postcode is M2H
# Borough is North York
# Neighborhood is Hillcrest Village
#
# Postcode is M3H
# Borough is North York
# Neighborhood is Bathurst Manor
#
# Postcode is M3H
# Borough is North York
# Neighborhood is Downsview North
#
# Postcode is M3H
# Borough is North York
# Neighborhood is Wilson Heights
#
# Postcode is M4H
# Borough is East York
# Neighborhood is Thorncliffe Park
#
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is Adelaide
#
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is King
#
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is Richmond
#
# Postcode is M6H
# Borough is West Toronto
# Neighborhood is Dovercourt Village
#
# Postcode is M6H
# Borough is West Toronto
# Neighborhood is Dufferin
#
# Postcode is M7H
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8H
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9H
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1J
# Borough is Scarborough
# Neighborhood is Scarborough Village
#
# Postcode is M2J
# Borough is North York
# Neighborhood is Fairview
#
# Postcode is M2J
# Borough is North York
# Neighborhood is Henry Farm
#
# Postcode is M2J
# Borough is North York
# Neighborhood is Oriole
#
# Postcode is M3J
# Borough is North York
# Neighborhood is Northwood Park
#
# Postcode is M3J
# Borough is North York
# Neighborhood is York University
#
# Postcode is M4J
# Borough is East York
# Neighborhood is East Toronto
#
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Harbourfront East
#
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Toronto Islands
#
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Union Station
#
# Postcode is M6J
# Borough is West Toronto
# Neighborhood is Little Portugal
#
# Postcode is M6J
# Borough is West Toronto
# Neighborhood is Trinity
#
# Postcode is M7J
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8J
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9J
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is East Birchmount Park
#
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is Ionview
#
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is Kennedy Park
#
# Postcode is M2K
# Borough is North York
# Neighborhood is Bayview Village
#
# Postcode is M3K
# Borough is North York
# Neighborhood is CFB Toronto
#
# Postcode is M3K
# Borough is North York
# Neighborhood is Downsview East
#
# Postcode is M4K
# Borough is East Toronto
# Neighborhood is The Danforth West
#
# Postcode is M4K
# Borough is East Toronto
# Neighborhood is Riverdale
#
# Postcode is M5K
# Borough is Downtown Toronto
# Neighborhood is Design Exchange
#
# Postcode is M5K
# Borough is Downtown Toronto
# Neighborhood is Toronto Dominion Centre
#
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Brockton
#
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Exhibition Place
#
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Parkdale Village
#
# Postcode is M7K
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8K
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9K
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Clairlea
#
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Golden Mile
#
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Oakridge
#
# Postcode is M2L
# Borough is North York
# Neighborhood is Silver Hills
#
# Postcode is M2L
# Borough is North York
# Neighborhood is York Mills
#
# Postcode is M3L
# Borough is North York
# Neighborhood is Downsview West
#
# Postcode is M4L
# Borough is East Toronto
# Neighborhood is The Beaches West
#
# Postcode is M4L
# Borough is East Toronto
# Neighborhood is India Bazaar
#
# Postcode is M5L
# Borough is Downtown Toronto
# Neighborhood is Commerce Court
#
# Postcode is M5L
# Borough is Downtown Toronto
# Neighborhood is Victoria Hotel
#
# Postcode is M6L
# Borough is North York
# Neighborhood is Downsview
#
# Postcode is M6L
# Borough is North York
# Neighborhood is North Park
#
# Postcode is M6L
# Borough is North York
# Neighborhood is Upwood Park
#
# Postcode is M7L
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8L
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9L
# Borough is North York
# Neighborhood is Humber Summit
#
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Cliffcrest
#
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Cliffside
#
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Scarborough Village West
#
# Postcode is M2M
# Borough is North York
# Neighborhood is Newtonbrook
#
# Postcode is M2M
# Borough is North York
# Neighborhood is Willowdale
#
# Postcode is M3M
# Borough is North York
# Neighborhood is Downsview Central
#
# Postcode is M4M
# Borough is East Toronto
# Neighborhood is Studio District
#
# Postcode is M5M
# Borough is North York
# Neighborhood is Bedford Park
#
# Postcode is M5M
# Borough is North York
# Neighborhood is Lawrence Manor East
#
# Postcode is M6M
# Borough is York
# Neighborhood is Del Ray
#
# Postcode is M6M
# Borough is York
# Neighborhood is Keelesdale
#
# Postcode is M6M
# Borough is York
# Neighborhood is Mount Dennis
#
# Postcode is M6M
# Borough is York
# Neighborhood is Silverthorn
#
# Postcode is M7M
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8M
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9M
# Borough is North York
# Neighborhood is Emery
#
# Postcode is M9M
# Borough is North York
# Neighborhood is Humberlea
#
# Postcode is M1N
# Borough is Scarborough
# Neighborhood is Birch Cliff
#
# Postcode is M1N
# Borough is Scarborough
# Neighborhood is Cliffside West
#
# Postcode is M2N
# Borough is North York
# Neighborhood is Willowdale South
#
# Postcode is M3N
# Borough is North York
# Neighborhood is Downsview Northwest
#
# Postcode is M4N
# Borough is Central Toronto
# Neighborhood is Lawrence Park
#
# Postcode is M5N
# Borough is Central Toronto
# Neighborhood is Roselawn
#
# Postcode is M6N
# Borough is York
# Neighborhood is The Junction North
#
# Postcode is M6N
# Borough is York
# Neighborhood is Runnymede
#
# Postcode is M7N
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8N
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9N
# Borough is York
# Neighborhood is Weston
#
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Dorset Park
#
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Scarborough Town Centre
#
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Wexford Heights
#
# Postcode is M2P
# Borough is North York
# Neighborhood is York Mills West
#
# Postcode is M3P
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4P
# Borough is Central Toronto
# Neighborhood is Davisville North
#
# Postcode is M5P
# Borough is Central Toronto
# Neighborhood is Forest Hill North
#
# Postcode is M5P
# Borough is Central Toronto
# Neighborhood is Forest Hill West
#
# Postcode is M6P
# Borough is West Toronto
# Neighborhood is High Park
#
# Postcode is M6P
# Borough is West Toronto
# Neighborhood is The Junction South
#
# Postcode is M7P
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8P
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9P
# Borough is Etobicoke
# Neighborhood is Westmount
#
# Postcode is M1R
# Borough is Scarborough
# Neighborhood is Maryvale
#
# Postcode is M1R
# Borough is Scarborough
# Neighborhood is Wexford
#
# Postcode is M2R
# Borough is North York
# Neighborhood is Willowdale West
#
# Postcode is M3R
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4R
# Borough is Central Toronto
# Neighborhood is North Toronto West
#
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is The Annex
#
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is North Midtown
#
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is Yorkville
#
# Postcode is M6R
# Borough is West Toronto
# Neighborhood is Parkdale
#
# Postcode is M6R
# Borough is West Toronto
# Neighborhood is Roncesvalles
#
# Postcode is M7R
# Borough is Mississauga
# Neighborhood is Canada Post Gateway Processing Centre
#
# Postcode is M8R
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Kingsview Village
#
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Martin Grove Gardens
#
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Richview Gardens
#
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is St. Phillips
#
# Postcode is M1S
# Borough is Scarborough
# Neighborhood is Agincourt
#
# Postcode is M2S
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3S
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4S
# Borough is Central Toronto
# Neighborhood is Davisville
#
# Postcode is M5S
# Borough is Downtown Toronto
# Neighborhood is Harbord
#
# Postcode is M5S
# Borough is Downtown Toronto
# Neighborhood is University of Toronto
#
# Postcode is M6S
# Borough is West Toronto
# Neighborhood is Runnymede
#
# Postcode is M6S
# Borough is West Toronto
# Neighborhood is Swansea
#
# Postcode is M7S
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8S
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9S
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Clarks Corners
#
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Sullivan
#
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Tam O'Shanter
#
# Postcode is M2T
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3T
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4T
# Borough is Central Toronto
# Neighborhood is Moore Park
#
# Postcode is M4T
# Borough is Central Toronto
# Neighborhood is Summerhill East
#
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Chinatown
#
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Grange Park
#
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Kensington Market
#
# Postcode is M6T
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M7T
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8T
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M9T
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Agincourt North
#
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is L'Amoreaux East
#
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Milliken
#
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Steeles East
#
# Postcode is M2V
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3V
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Deer Park
#
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Forest Hill SE
#
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Rathnelly
#
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is South Hill
#
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Summerhill West
#
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is CN Tower
#
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Bathurst Quay
#
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Island airport
#
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Harbourfront West
#
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is King and Spadina
#
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Railway Lands
#
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is South Niagara
#
# Postcode is M6V
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M7V
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is Humber Bay Shores
#
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is Mimico South
#
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is New Toronto
#
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Albion Gardens
#
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Beaumond Heights
#
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Humbergate
#
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Jamestown
#
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Mount Olive
#
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Silverstone
#
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is South Steeles
#
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Thistletown
#
# Postcode is M1W
# Borough is Scarborough
# Neighborhood is L'Amoreaux West
#
# Postcode is M2W
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3W
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4W
# Borough is Downtown Toronto
# Neighborhood is Rosedale
#
# Postcode is M5W
# Borough is Downtown Toronto
# Neighborhood is Stn A PO Boxes 25 The Esplanade
#
# Postcode is M6W
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M7W
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8W
# Borough is Etobicoke
# Neighborhood is Alderwood
#
# Postcode is M8W
# Borough is Etobicoke
# Neighborhood is Long Branch
#
# Postcode is M9W
# Borough is Etobicoke
# Neighborhood is Northwest
#
# Postcode is M1X
# Borough is Scarborough
# Neighborhood is Upper Rouge
#
# Postcode is M2X
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3X
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4X
# Borough is Downtown Toronto
# Neighborhood is Cabbagetown
#
# Postcode is M4X
# Borough is Downtown Toronto
# Neighborhood is St. James Town
#
# Postcode is M5X
# Borough is Downtown Toronto
# Neighborhood is First Canadian Place
#
# Postcode is M5X
# Borough is Downtown Toronto
# Neighborhood is Underground city
#
# Postcode is M6X
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M7X
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is The Kingsway
#
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is Montgomery Road
#
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is Old Mill North
#
# Postcode is M9X
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1Y
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M2Y
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3Y
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4Y
# Borough is Downtown Toronto
# Neighborhood is Church and Wellesley
#
# Postcode is M5Y
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M6Y
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M7Y
# Borough is East Toronto
# Neighborhood is Business Reply Mail Processing Centre 969 Eastern
#
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Humber Bay
#
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is King's Mill Park
#
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Kingsway Park South East
#
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Mimico NE
#
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Old Mill South
#
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is The Queensway East
#
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Royal York South East
#
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Sunnylea
#
# Postcode is M9Y
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M1Z
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M2Z
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M3Z
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M4Z
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M5Z
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M6Z
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M7Z
# Borough is Not assigned
# Neighborhood is Not assigned
#
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Kingsway Park South West
#
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Mimico NW
#
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is The Queensway West
#
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Royal York South West
#
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is South of Bloor
#
# Postcode is M9Z
# Borough is Not assigned
# Neighborhood is Not assigned

# %%
for table_row in full_table.find_all('tr'):
	counter = 1
	postcode = 'NA'
	borough = 'NA'
	neighborhood = 'NA'
	for table_cell in table_row.find_all('td'):
		if counter == 1:
			postcode = table_cell.text
			print("Postcode is "+postcode )
		elif counter == 2:
			borough = table_cell.text
			print("Borough is "+borough )
		else:
			neighborhood = table_cell.text.strip('\n')
			print("Neighborhood is "+neighborhood )
		counter = counter + 1
	print('The postcode is {}, borough is {}, and neighborhood is {}.'.format(postcode, borough, neighborhood))
# Out:
# The postcode is NA, borough is NA, and neighborhood is NA.
# Postcode is M1A
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M1A, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M2A
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2A, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3A
# Borough is North York
# Neighborhood is Parkwoods
# The postcode is M3A, borough is North York, and neighborhood is Parkwoods.
# Postcode is M4A
# Borough is North York
# Neighborhood is Victoria Village
# The postcode is M4A, borough is North York, and neighborhood is Victoria Village.
# Postcode is M5A
# Borough is Downtown Toronto
# Neighborhood is Harbourfront
# The postcode is M5A, borough is Downtown Toronto, and neighborhood is Harbourfront.
# Postcode is M5A
# Borough is Downtown Toronto
# Neighborhood is Regent Park
# The postcode is M5A, borough is Downtown Toronto, and neighborhood is Regent Park.
# Postcode is M6A
# Borough is North York
# Neighborhood is Lawrence Heights
# The postcode is M6A, borough is North York, and neighborhood is Lawrence Heights.
# Postcode is M6A
# Borough is North York
# Neighborhood is Lawrence Manor
# The postcode is M6A, borough is North York, and neighborhood is Lawrence Manor.
# Postcode is M7A
# Borough is Queen's Park
# Neighborhood is Not assigned
# The postcode is M7A, borough is Queen's Park, and neighborhood is Not assigned.
# Postcode is M8A
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8A, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9A
# Borough is Etobicoke
# Neighborhood is Islington Avenue
# The postcode is M9A, borough is Etobicoke, and neighborhood is Islington Avenue.
# Postcode is M1B
# Borough is Scarborough
# Neighborhood is Rouge
# The postcode is M1B, borough is Scarborough, and neighborhood is Rouge.
# Postcode is M1B
# Borough is Scarborough
# Neighborhood is Malvern
# The postcode is M1B, borough is Scarborough, and neighborhood is Malvern.
# Postcode is M2B
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2B, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3B
# Borough is North York
# Neighborhood is Don Mills North
# The postcode is M3B, borough is North York, and neighborhood is Don Mills North.
# Postcode is M4B
# Borough is East York
# Neighborhood is Woodbine Gardens
# The postcode is M4B, borough is East York, and neighborhood is Woodbine Gardens.
# Postcode is M4B
# Borough is East York
# Neighborhood is Parkview Hill
# The postcode is M4B, borough is East York, and neighborhood is Parkview Hill.
# Postcode is M5B
# Borough is Downtown Toronto
# Neighborhood is Ryerson
# The postcode is M5B, borough is Downtown Toronto, and neighborhood is Ryerson.
# Postcode is M5B
# Borough is Downtown Toronto
# Neighborhood is Garden District
# The postcode is M5B, borough is Downtown Toronto, and neighborhood is Garden District.
# Postcode is M6B
# Borough is North York
# Neighborhood is Glencairn
# The postcode is M6B, borough is North York, and neighborhood is Glencairn.
# Postcode is M7B
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7B, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8B
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8B, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Cloverdale
# The postcode is M9B, borough is Etobicoke, and neighborhood is Cloverdale.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Islington
# The postcode is M9B, borough is Etobicoke, and neighborhood is Islington.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Martin Grove
# The postcode is M9B, borough is Etobicoke, and neighborhood is Martin Grove.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Princess Gardens
# The postcode is M9B, borough is Etobicoke, and neighborhood is Princess Gardens.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is West Deane Park
# The postcode is M9B, borough is Etobicoke, and neighborhood is West Deane Park.
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Highland Creek
# The postcode is M1C, borough is Scarborough, and neighborhood is Highland Creek.
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Rouge Hill
# The postcode is M1C, borough is Scarborough, and neighborhood is Rouge Hill.
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Port Union
# The postcode is M1C, borough is Scarborough, and neighborhood is Port Union.
# Postcode is M2C
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2C, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3C
# Borough is North York
# Neighborhood is Flemingdon Park
# The postcode is M3C, borough is North York, and neighborhood is Flemingdon Park.
# Postcode is M3C
# Borough is North York
# Neighborhood is Don Mills South
# The postcode is M3C, borough is North York, and neighborhood is Don Mills South.
# Postcode is M4C
# Borough is East York
# Neighborhood is Woodbine Heights
# The postcode is M4C, borough is East York, and neighborhood is Woodbine Heights.
# Postcode is M5C
# Borough is Downtown Toronto
# Neighborhood is St. James Town
# The postcode is M5C, borough is Downtown Toronto, and neighborhood is St. James Town.
# Postcode is M6C
# Borough is York
# Neighborhood is Humewood-Cedarvale
# The postcode is M6C, borough is York, and neighborhood is Humewood-Cedarvale.
# Postcode is M7C
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7C, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8C
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8C, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Bloordale Gardens
# The postcode is M9C, borough is Etobicoke, and neighborhood is Bloordale Gardens.
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Eringate
# The postcode is M9C, borough is Etobicoke, and neighborhood is Eringate.
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Markland Wood
# The postcode is M9C, borough is Etobicoke, and neighborhood is Markland Wood.
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Old Burnhamthorpe
# The postcode is M9C, borough is Etobicoke, and neighborhood is Old Burnhamthorpe.
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is Guildwood
# The postcode is M1E, borough is Scarborough, and neighborhood is Guildwood.
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is Morningside
# The postcode is M1E, borough is Scarborough, and neighborhood is Morningside.
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is West Hill
# The postcode is M1E, borough is Scarborough, and neighborhood is West Hill.
# Postcode is M2E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2E, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3E, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4E
# Borough is East Toronto
# Neighborhood is The Beaches
# The postcode is M4E, borough is East Toronto, and neighborhood is The Beaches.
# Postcode is M5E
# Borough is Downtown Toronto
# Neighborhood is Berczy Park
# The postcode is M5E, borough is Downtown Toronto, and neighborhood is Berczy Park.
# Postcode is M6E
# Borough is York
# Neighborhood is Caledonia-Fairbanks
# The postcode is M6E, borough is York, and neighborhood is Caledonia-Fairbanks.
# Postcode is M7E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7E, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8E, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9E, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1G
# Borough is Scarborough
# Neighborhood is Woburn
# The postcode is M1G, borough is Scarborough, and neighborhood is Woburn.
# Postcode is M2G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2G, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3G, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4G
# Borough is East York
# Neighborhood is Leaside
# The postcode is M4G, borough is East York, and neighborhood is Leaside.
# Postcode is M5G
# Borough is Downtown Toronto
# Neighborhood is Central Bay Street
# The postcode is M5G, borough is Downtown Toronto, and neighborhood is Central Bay Street.
# Postcode is M6G
# Borough is Downtown Toronto
# Neighborhood is Christie
# The postcode is M6G, borough is Downtown Toronto, and neighborhood is Christie.
# Postcode is M7G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7G, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8G, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9G, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1H
# Borough is Scarborough
# Neighborhood is Cedarbrae
# The postcode is M1H, borough is Scarborough, and neighborhood is Cedarbrae.
# Postcode is M2H
# Borough is North York
# Neighborhood is Hillcrest Village
# The postcode is M2H, borough is North York, and neighborhood is Hillcrest Village.
# Postcode is M3H
# Borough is North York
# Neighborhood is Bathurst Manor
# The postcode is M3H, borough is North York, and neighborhood is Bathurst Manor.
# Postcode is M3H
# Borough is North York
# Neighborhood is Downsview North
# The postcode is M3H, borough is North York, and neighborhood is Downsview North.
# Postcode is M3H
# Borough is North York
# Neighborhood is Wilson Heights
# The postcode is M3H, borough is North York, and neighborhood is Wilson Heights.
# Postcode is M4H
# Borough is East York
# Neighborhood is Thorncliffe Park
# The postcode is M4H, borough is East York, and neighborhood is Thorncliffe Park.
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is Adelaide
# The postcode is M5H, borough is Downtown Toronto, and neighborhood is Adelaide.
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is King
# The postcode is M5H, borough is Downtown Toronto, and neighborhood is King.
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is Richmond
# The postcode is M5H, borough is Downtown Toronto, and neighborhood is Richmond.
# Postcode is M6H
# Borough is West Toronto
# Neighborhood is Dovercourt Village
# The postcode is M6H, borough is West Toronto, and neighborhood is Dovercourt Village.
# Postcode is M6H
# Borough is West Toronto
# Neighborhood is Dufferin
# The postcode is M6H, borough is West Toronto, and neighborhood is Dufferin.
# Postcode is M7H
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7H, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8H
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8H, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9H
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9H, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1J
# Borough is Scarborough
# Neighborhood is Scarborough Village
# The postcode is M1J, borough is Scarborough, and neighborhood is Scarborough Village.
# Postcode is M2J
# Borough is North York
# Neighborhood is Fairview
# The postcode is M2J, borough is North York, and neighborhood is Fairview.
# Postcode is M2J
# Borough is North York
# Neighborhood is Henry Farm
# The postcode is M2J, borough is North York, and neighborhood is Henry Farm.
# Postcode is M2J
# Borough is North York
# Neighborhood is Oriole
# The postcode is M2J, borough is North York, and neighborhood is Oriole.
# Postcode is M3J
# Borough is North York
# Neighborhood is Northwood Park
# The postcode is M3J, borough is North York, and neighborhood is Northwood Park.
# Postcode is M3J
# Borough is North York
# Neighborhood is York University
# The postcode is M3J, borough is North York, and neighborhood is York University.
# Postcode is M4J
# Borough is East York
# Neighborhood is East Toronto
# The postcode is M4J, borough is East York, and neighborhood is East Toronto.
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Harbourfront East
# The postcode is M5J, borough is Downtown Toronto, and neighborhood is Harbourfront East.
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Toronto Islands
# The postcode is M5J, borough is Downtown Toronto, and neighborhood is Toronto Islands.
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Union Station
# The postcode is M5J, borough is Downtown Toronto, and neighborhood is Union Station.
# Postcode is M6J
# Borough is West Toronto
# Neighborhood is Little Portugal
# The postcode is M6J, borough is West Toronto, and neighborhood is Little Portugal.
# Postcode is M6J
# Borough is West Toronto
# Neighborhood is Trinity
# The postcode is M6J, borough is West Toronto, and neighborhood is Trinity.
# Postcode is M7J
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7J, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8J
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8J, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9J
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9J, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is East Birchmount Park
# The postcode is M1K, borough is Scarborough, and neighborhood is East Birchmount Park.
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is Ionview
# The postcode is M1K, borough is Scarborough, and neighborhood is Ionview.
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is Kennedy Park
# The postcode is M1K, borough is Scarborough, and neighborhood is Kennedy Park.
# Postcode is M2K
# Borough is North York
# Neighborhood is Bayview Village
# The postcode is M2K, borough is North York, and neighborhood is Bayview Village.
# Postcode is M3K
# Borough is North York
# Neighborhood is CFB Toronto
# The postcode is M3K, borough is North York, and neighborhood is CFB Toronto.
# Postcode is M3K
# Borough is North York
# Neighborhood is Downsview East
# The postcode is M3K, borough is North York, and neighborhood is Downsview East.
# Postcode is M4K
# Borough is East Toronto
# Neighborhood is The Danforth West
# The postcode is M4K, borough is East Toronto, and neighborhood is The Danforth West.
# Postcode is M4K
# Borough is East Toronto
# Neighborhood is Riverdale
# The postcode is M4K, borough is East Toronto, and neighborhood is Riverdale.
# Postcode is M5K
# Borough is Downtown Toronto
# Neighborhood is Design Exchange
# The postcode is M5K, borough is Downtown Toronto, and neighborhood is Design Exchange.
# Postcode is M5K
# Borough is Downtown Toronto
# Neighborhood is Toronto Dominion Centre
# The postcode is M5K, borough is Downtown Toronto, and neighborhood is Toronto Dominion Centre.
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Brockton
# The postcode is M6K, borough is West Toronto, and neighborhood is Brockton.
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Exhibition Place
# The postcode is M6K, borough is West Toronto, and neighborhood is Exhibition Place.
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Parkdale Village
# The postcode is M6K, borough is West Toronto, and neighborhood is Parkdale Village.
# Postcode is M7K
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7K, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8K
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8K, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9K
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9K, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Clairlea
# The postcode is M1L, borough is Scarborough, and neighborhood is Clairlea.
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Golden Mile
# The postcode is M1L, borough is Scarborough, and neighborhood is Golden Mile.
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Oakridge
# The postcode is M1L, borough is Scarborough, and neighborhood is Oakridge.
# Postcode is M2L
# Borough is North York
# Neighborhood is Silver Hills
# The postcode is M2L, borough is North York, and neighborhood is Silver Hills.
# Postcode is M2L
# Borough is North York
# Neighborhood is York Mills
# The postcode is M2L, borough is North York, and neighborhood is York Mills.
# Postcode is M3L
# Borough is North York
# Neighborhood is Downsview West
# The postcode is M3L, borough is North York, and neighborhood is Downsview West.
# Postcode is M4L
# Borough is East Toronto
# Neighborhood is The Beaches West
# The postcode is M4L, borough is East Toronto, and neighborhood is The Beaches West.
# Postcode is M4L
# Borough is East Toronto
# Neighborhood is India Bazaar
# The postcode is M4L, borough is East Toronto, and neighborhood is India Bazaar.
# Postcode is M5L
# Borough is Downtown Toronto
# Neighborhood is Commerce Court
# The postcode is M5L, borough is Downtown Toronto, and neighborhood is Commerce Court.
# Postcode is M5L
# Borough is Downtown Toronto
# Neighborhood is Victoria Hotel
# The postcode is M5L, borough is Downtown Toronto, and neighborhood is Victoria Hotel.
# Postcode is M6L
# Borough is North York
# Neighborhood is Downsview
# The postcode is M6L, borough is North York, and neighborhood is Downsview.
# Postcode is M6L
# Borough is North York
# Neighborhood is North Park
# The postcode is M6L, borough is North York, and neighborhood is North Park.
# Postcode is M6L
# Borough is North York
# Neighborhood is Upwood Park
# The postcode is M6L, borough is North York, and neighborhood is Upwood Park.
# Postcode is M7L
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7L, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8L
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8L, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9L
# Borough is North York
# Neighborhood is Humber Summit
# The postcode is M9L, borough is North York, and neighborhood is Humber Summit.
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Cliffcrest
# The postcode is M1M, borough is Scarborough, and neighborhood is Cliffcrest.
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Cliffside
# The postcode is M1M, borough is Scarborough, and neighborhood is Cliffside.
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Scarborough Village West
# The postcode is M1M, borough is Scarborough, and neighborhood is Scarborough Village West.
# Postcode is M2M
# Borough is North York
# Neighborhood is Newtonbrook
# The postcode is M2M, borough is North York, and neighborhood is Newtonbrook.
# Postcode is M2M
# Borough is North York
# Neighborhood is Willowdale
# The postcode is M2M, borough is North York, and neighborhood is Willowdale.
# Postcode is M3M
# Borough is North York
# Neighborhood is Downsview Central
# The postcode is M3M, borough is North York, and neighborhood is Downsview Central.
# Postcode is M4M
# Borough is East Toronto
# Neighborhood is Studio District
# The postcode is M4M, borough is East Toronto, and neighborhood is Studio District.
# Postcode is M5M
# Borough is North York
# Neighborhood is Bedford Park
# The postcode is M5M, borough is North York, and neighborhood is Bedford Park.
# Postcode is M5M
# Borough is North York
# Neighborhood is Lawrence Manor East
# The postcode is M5M, borough is North York, and neighborhood is Lawrence Manor East.
# Postcode is M6M
# Borough is York
# Neighborhood is Del Ray
# The postcode is M6M, borough is York, and neighborhood is Del Ray.
# Postcode is M6M
# Borough is York
# Neighborhood is Keelesdale
# The postcode is M6M, borough is York, and neighborhood is Keelesdale.
# Postcode is M6M
# Borough is York
# Neighborhood is Mount Dennis
# The postcode is M6M, borough is York, and neighborhood is Mount Dennis.
# Postcode is M6M
# Borough is York
# Neighborhood is Silverthorn
# The postcode is M6M, borough is York, and neighborhood is Silverthorn.
# Postcode is M7M
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7M, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8M
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8M, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9M
# Borough is North York
# Neighborhood is Emery
# The postcode is M9M, borough is North York, and neighborhood is Emery.
# Postcode is M9M
# Borough is North York
# Neighborhood is Humberlea
# The postcode is M9M, borough is North York, and neighborhood is Humberlea.
# Postcode is M1N
# Borough is Scarborough
# Neighborhood is Birch Cliff
# The postcode is M1N, borough is Scarborough, and neighborhood is Birch Cliff.
# Postcode is M1N
# Borough is Scarborough
# Neighborhood is Cliffside West
# The postcode is M1N, borough is Scarborough, and neighborhood is Cliffside West.
# Postcode is M2N
# Borough is North York
# Neighborhood is Willowdale South
# The postcode is M2N, borough is North York, and neighborhood is Willowdale South.
# Postcode is M3N
# Borough is North York
# Neighborhood is Downsview Northwest
# The postcode is M3N, borough is North York, and neighborhood is Downsview Northwest.
# Postcode is M4N
# Borough is Central Toronto
# Neighborhood is Lawrence Park
# The postcode is M4N, borough is Central Toronto, and neighborhood is Lawrence Park.
# Postcode is M5N
# Borough is Central Toronto
# Neighborhood is Roselawn
# The postcode is M5N, borough is Central Toronto, and neighborhood is Roselawn.
# Postcode is M6N
# Borough is York
# Neighborhood is The Junction North
# The postcode is M6N, borough is York, and neighborhood is The Junction North.
# Postcode is M6N
# Borough is York
# Neighborhood is Runnymede
# The postcode is M6N, borough is York, and neighborhood is Runnymede.
# Postcode is M7N
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7N, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8N
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8N, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9N
# Borough is York
# Neighborhood is Weston
# The postcode is M9N, borough is York, and neighborhood is Weston.
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Dorset Park
# The postcode is M1P, borough is Scarborough, and neighborhood is Dorset Park.
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Scarborough Town Centre
# The postcode is M1P, borough is Scarborough, and neighborhood is Scarborough Town Centre.
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Wexford Heights
# The postcode is M1P, borough is Scarborough, and neighborhood is Wexford Heights.
# Postcode is M2P
# Borough is North York
# Neighborhood is York Mills West
# The postcode is M2P, borough is North York, and neighborhood is York Mills West.
# Postcode is M3P
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3P, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4P
# Borough is Central Toronto
# Neighborhood is Davisville North
# The postcode is M4P, borough is Central Toronto, and neighborhood is Davisville North.
# Postcode is M5P
# Borough is Central Toronto
# Neighborhood is Forest Hill North
# The postcode is M5P, borough is Central Toronto, and neighborhood is Forest Hill North.
# Postcode is M5P
# Borough is Central Toronto
# Neighborhood is Forest Hill West
# The postcode is M5P, borough is Central Toronto, and neighborhood is Forest Hill West.
# Postcode is M6P
# Borough is West Toronto
# Neighborhood is High Park
# The postcode is M6P, borough is West Toronto, and neighborhood is High Park.
# Postcode is M6P
# Borough is West Toronto
# Neighborhood is The Junction South
# The postcode is M6P, borough is West Toronto, and neighborhood is The Junction South.
# Postcode is M7P
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7P, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8P
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8P, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9P
# Borough is Etobicoke
# Neighborhood is Westmount
# The postcode is M9P, borough is Etobicoke, and neighborhood is Westmount.
# Postcode is M1R
# Borough is Scarborough
# Neighborhood is Maryvale
# The postcode is M1R, borough is Scarborough, and neighborhood is Maryvale.
# Postcode is M1R
# Borough is Scarborough
# Neighborhood is Wexford
# The postcode is M1R, borough is Scarborough, and neighborhood is Wexford.
# Postcode is M2R
# Borough is North York
# Neighborhood is Willowdale West
# The postcode is M2R, borough is North York, and neighborhood is Willowdale West.
# Postcode is M3R
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3R, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4R
# Borough is Central Toronto
# Neighborhood is North Toronto West
# The postcode is M4R, borough is Central Toronto, and neighborhood is North Toronto West.
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is The Annex
# The postcode is M5R, borough is Central Toronto, and neighborhood is The Annex.
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is North Midtown
# The postcode is M5R, borough is Central Toronto, and neighborhood is North Midtown.
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is Yorkville
# The postcode is M5R, borough is Central Toronto, and neighborhood is Yorkville.
# Postcode is M6R
# Borough is West Toronto
# Neighborhood is Parkdale
# The postcode is M6R, borough is West Toronto, and neighborhood is Parkdale.
# Postcode is M6R
# Borough is West Toronto
# Neighborhood is Roncesvalles
# The postcode is M6R, borough is West Toronto, and neighborhood is Roncesvalles.
# Postcode is M7R
# Borough is Mississauga
# Neighborhood is Canada Post Gateway Processing Centre
# The postcode is M7R, borough is Mississauga, and neighborhood is Canada Post Gateway Processing Centre.
# Postcode is M8R
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8R, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Kingsview Village
# The postcode is M9R, borough is Etobicoke, and neighborhood is Kingsview Village.
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Martin Grove Gardens
# The postcode is M9R, borough is Etobicoke, and neighborhood is Martin Grove Gardens.
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Richview Gardens
# The postcode is M9R, borough is Etobicoke, and neighborhood is Richview Gardens.
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is St. Phillips
# The postcode is M9R, borough is Etobicoke, and neighborhood is St. Phillips.
# Postcode is M1S
# Borough is Scarborough
# Neighborhood is Agincourt
# The postcode is M1S, borough is Scarborough, and neighborhood is Agincourt.
# Postcode is M2S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2S, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3S, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4S
# Borough is Central Toronto
# Neighborhood is Davisville
# The postcode is M4S, borough is Central Toronto, and neighborhood is Davisville.
# Postcode is M5S
# Borough is Downtown Toronto
# Neighborhood is Harbord
# The postcode is M5S, borough is Downtown Toronto, and neighborhood is Harbord.
# Postcode is M5S
# Borough is Downtown Toronto
# Neighborhood is University of Toronto
# The postcode is M5S, borough is Downtown Toronto, and neighborhood is University of Toronto.
# Postcode is M6S
# Borough is West Toronto
# Neighborhood is Runnymede
# The postcode is M6S, borough is West Toronto, and neighborhood is Runnymede.
# Postcode is M6S
# Borough is West Toronto
# Neighborhood is Swansea
# The postcode is M6S, borough is West Toronto, and neighborhood is Swansea.
# Postcode is M7S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7S, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8S, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9S, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Clarks Corners
# The postcode is M1T, borough is Scarborough, and neighborhood is Clarks Corners.
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Sullivan
# The postcode is M1T, borough is Scarborough, and neighborhood is Sullivan.
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Tam O'Shanter
# The postcode is M1T, borough is Scarborough, and neighborhood is Tam O'Shanter.
# Postcode is M2T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2T, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3T, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4T
# Borough is Central Toronto
# Neighborhood is Moore Park
# The postcode is M4T, borough is Central Toronto, and neighborhood is Moore Park.
# Postcode is M4T
# Borough is Central Toronto
# Neighborhood is Summerhill East
# The postcode is M4T, borough is Central Toronto, and neighborhood is Summerhill East.
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Chinatown
# The postcode is M5T, borough is Downtown Toronto, and neighborhood is Chinatown.
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Grange Park
# The postcode is M5T, borough is Downtown Toronto, and neighborhood is Grange Park.
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Kensington Market
# The postcode is M5T, borough is Downtown Toronto, and neighborhood is Kensington Market.
# Postcode is M6T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6T, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M7T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7T, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8T, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M9T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9T, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Agincourt North
# The postcode is M1V, borough is Scarborough, and neighborhood is Agincourt North.
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is L'Amoreaux East
# The postcode is M1V, borough is Scarborough, and neighborhood is L'Amoreaux East.
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Milliken
# The postcode is M1V, borough is Scarborough, and neighborhood is Milliken.
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Steeles East
# The postcode is M1V, borough is Scarborough, and neighborhood is Steeles East.
# Postcode is M2V
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2V, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3V
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3V, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Deer Park
# The postcode is M4V, borough is Central Toronto, and neighborhood is Deer Park.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Forest Hill SE
# The postcode is M4V, borough is Central Toronto, and neighborhood is Forest Hill SE.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Rathnelly
# The postcode is M4V, borough is Central Toronto, and neighborhood is Rathnelly.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is South Hill
# The postcode is M4V, borough is Central Toronto, and neighborhood is South Hill.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Summerhill West
# The postcode is M4V, borough is Central Toronto, and neighborhood is Summerhill West.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is CN Tower
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is CN Tower.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Bathurst Quay
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is Bathurst Quay.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Island airport
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is Island airport.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Harbourfront West
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is Harbourfront West.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is King and Spadina
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is King and Spadina.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Railway Lands
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is Railway Lands.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is South Niagara
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is South Niagara.
# Postcode is M6V
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6V, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M7V
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7V, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is Humber Bay Shores
# The postcode is M8V, borough is Etobicoke, and neighborhood is Humber Bay Shores.
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is Mimico South
# The postcode is M8V, borough is Etobicoke, and neighborhood is Mimico South.
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is New Toronto
# The postcode is M8V, borough is Etobicoke, and neighborhood is New Toronto.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Albion Gardens
# The postcode is M9V, borough is Etobicoke, and neighborhood is Albion Gardens.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Beaumond Heights
# The postcode is M9V, borough is Etobicoke, and neighborhood is Beaumond Heights.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Humbergate
# The postcode is M9V, borough is Etobicoke, and neighborhood is Humbergate.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Jamestown
# The postcode is M9V, borough is Etobicoke, and neighborhood is Jamestown.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Mount Olive
# The postcode is M9V, borough is Etobicoke, and neighborhood is Mount Olive.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Silverstone
# The postcode is M9V, borough is Etobicoke, and neighborhood is Silverstone.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is South Steeles
# The postcode is M9V, borough is Etobicoke, and neighborhood is South Steeles.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Thistletown
# The postcode is M9V, borough is Etobicoke, and neighborhood is Thistletown.
# Postcode is M1W
# Borough is Scarborough
# Neighborhood is L'Amoreaux West
# The postcode is M1W, borough is Scarborough, and neighborhood is L'Amoreaux West.
# Postcode is M2W
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2W, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3W
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3W, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4W
# Borough is Downtown Toronto
# Neighborhood is Rosedale
# The postcode is M4W, borough is Downtown Toronto, and neighborhood is Rosedale.
# Postcode is M5W
# Borough is Downtown Toronto
# Neighborhood is Stn A PO Boxes 25 The Esplanade
# The postcode is M5W, borough is Downtown Toronto, and neighborhood is Stn A PO Boxes 25 The Esplanade.
# Postcode is M6W
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6W, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M7W
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7W, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8W
# Borough is Etobicoke
# Neighborhood is Alderwood
# The postcode is M8W, borough is Etobicoke, and neighborhood is Alderwood.
# Postcode is M8W
# Borough is Etobicoke
# Neighborhood is Long Branch
# The postcode is M8W, borough is Etobicoke, and neighborhood is Long Branch.
# Postcode is M9W
# Borough is Etobicoke
# Neighborhood is Northwest
# The postcode is M9W, borough is Etobicoke, and neighborhood is Northwest.
# Postcode is M1X
# Borough is Scarborough
# Neighborhood is Upper Rouge
# The postcode is M1X, borough is Scarborough, and neighborhood is Upper Rouge.
# Postcode is M2X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2X, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3X, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4X
# Borough is Downtown Toronto
# Neighborhood is Cabbagetown
# The postcode is M4X, borough is Downtown Toronto, and neighborhood is Cabbagetown.
# Postcode is M4X
# Borough is Downtown Toronto
# Neighborhood is St. James Town
# The postcode is M4X, borough is Downtown Toronto, and neighborhood is St. James Town.
# Postcode is M5X
# Borough is Downtown Toronto
# Neighborhood is First Canadian Place
# The postcode is M5X, borough is Downtown Toronto, and neighborhood is First Canadian Place.
# Postcode is M5X
# Borough is Downtown Toronto
# Neighborhood is Underground city
# The postcode is M5X, borough is Downtown Toronto, and neighborhood is Underground city.
# Postcode is M6X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6X, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M7X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7X, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is The Kingsway
# The postcode is M8X, borough is Etobicoke, and neighborhood is The Kingsway.
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is Montgomery Road
# The postcode is M8X, borough is Etobicoke, and neighborhood is Montgomery Road.
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is Old Mill North
# The postcode is M8X, borough is Etobicoke, and neighborhood is Old Mill North.
# Postcode is M9X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9X, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M1Y, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M2Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2Y, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3Y, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4Y
# Borough is Downtown Toronto
# Neighborhood is Church and Wellesley
# The postcode is M4Y, borough is Downtown Toronto, and neighborhood is Church and Wellesley.
# Postcode is M5Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M5Y, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M6Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6Y, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M7Y
# Borough is East Toronto
# Neighborhood is Business Reply Mail Processing Centre 969 Eastern
# The postcode is M7Y, borough is East Toronto, and neighborhood is Business Reply Mail Processing Centre 969 Eastern.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Humber Bay
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Humber Bay.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is King's Mill Park
# The postcode is M8Y, borough is Etobicoke, and neighborhood is King's Mill Park.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Kingsway Park South East
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Kingsway Park South East.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Mimico NE
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Mimico NE.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Old Mill South
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Old Mill South.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is The Queensway East
# The postcode is M8Y, borough is Etobicoke, and neighborhood is The Queensway East.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Royal York South East
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Royal York South East.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Sunnylea
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Sunnylea.
# Postcode is M9Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9Y, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M1Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M1Z, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M2Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2Z, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M3Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3Z, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M4Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M4Z, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M5Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M5Z, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M6Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6Z, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M7Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7Z, borough is Not assigned, and neighborhood is Not assigned.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Kingsway Park South West
# The postcode is M8Z, borough is Etobicoke, and neighborhood is Kingsway Park South West.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Mimico NW
# The postcode is M8Z, borough is Etobicoke, and neighborhood is Mimico NW.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is The Queensway West
# The postcode is M8Z, borough is Etobicoke, and neighborhood is The Queensway West.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Royal York South West
# The postcode is M8Z, borough is Etobicoke, and neighborhood is Royal York South West.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is South of Bloor
# The postcode is M8Z, borough is Etobicoke, and neighborhood is South of Bloor.
# Postcode is M9Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9Z, borough is Not assigned, and neighborhood is Not assigned.

# %%
# create empty dataframe
import pandas as pd
column_names = ['Postcode', 'Borough', 'Neighborhood'] 
neighborhoods = pd.DataFrame(columns=column_names)

# %%
neighborhoods.head()
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighborhood]
# Index: []

# %%
# load data into dataframe
for table_row in full_table.find_all('tr'):
	counter = 1
	postcode = 'NA'
	borough = 'NA'
	neighborhood = 'NA'
	for table_cell in table_row.find_all('td'):
		if counter == 1:
			postcode = table_cell.text
			print("Postcode is "+postcode )
		elif counter == 2:
			borough = table_cell.text
			print("Borough is "+borough )
		else:
			neighborhood = table_cell.text.strip('\n')
			print("Neighborhood is "+neighborhood )
		counter = counter + 1
	print('The postcode is {}, borough is {}, and neighborhood is {}.'.format(postcode, borough, neighborhood))
	if (postcode == 'NA') or (borough == 'Not assigned'):
		print('Skipping this row')
	elif neighborhood == 'Not assigned':
		neighborhoods = neighborhoods.append({'Postcode':postcode,
		                                      'Borough': borough,
											  'Neighborhood': borough}, ignore_index=True)
	else:
		neighborhoods = neighborhoods.append({'Postcode':postcode,
		                                      'Borough': borough,
											  'Neighborhood': neighborhood}, ignore_index=True)
# Out:
# The postcode is NA, borough is NA, and neighborhood is NA.
# Skipping this row
# Postcode is M1A
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M1A, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M2A
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2A, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3A
# Borough is North York
# Neighborhood is Parkwoods
# The postcode is M3A, borough is North York, and neighborhood is Parkwoods.
# Postcode is M4A
# Borough is North York
# Neighborhood is Victoria Village
# The postcode is M4A, borough is North York, and neighborhood is Victoria Village.
# Postcode is M5A
# Borough is Downtown Toronto
# Neighborhood is Harbourfront
# The postcode is M5A, borough is Downtown Toronto, and neighborhood is Harbourfront.
# Postcode is M5A
# Borough is Downtown Toronto
# Neighborhood is Regent Park
# The postcode is M5A, borough is Downtown Toronto, and neighborhood is Regent Park.
# Postcode is M6A
# Borough is North York
# Neighborhood is Lawrence Heights
# The postcode is M6A, borough is North York, and neighborhood is Lawrence Heights.
# Postcode is M6A
# Borough is North York
# Neighborhood is Lawrence Manor
# The postcode is M6A, borough is North York, and neighborhood is Lawrence Manor.
# Postcode is M7A
# Borough is Queen's Park
# Neighborhood is Not assigned
# The postcode is M7A, borough is Queen's Park, and neighborhood is Not assigned.
# Postcode is M8A
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8A, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9A
# Borough is Etobicoke
# Neighborhood is Islington Avenue
# The postcode is M9A, borough is Etobicoke, and neighborhood is Islington Avenue.
# Postcode is M1B
# Borough is Scarborough
# Neighborhood is Rouge
# The postcode is M1B, borough is Scarborough, and neighborhood is Rouge.
# Postcode is M1B
# Borough is Scarborough
# Neighborhood is Malvern
# The postcode is M1B, borough is Scarborough, and neighborhood is Malvern.
# Postcode is M2B
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2B, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3B
# Borough is North York
# Neighborhood is Don Mills North
# The postcode is M3B, borough is North York, and neighborhood is Don Mills North.
# Postcode is M4B
# Borough is East York
# Neighborhood is Woodbine Gardens
# The postcode is M4B, borough is East York, and neighborhood is Woodbine Gardens.
# Postcode is M4B
# Borough is East York
# Neighborhood is Parkview Hill
# The postcode is M4B, borough is East York, and neighborhood is Parkview Hill.
# Postcode is M5B
# Borough is Downtown Toronto
# Neighborhood is Ryerson
# The postcode is M5B, borough is Downtown Toronto, and neighborhood is Ryerson.
# Postcode is M5B
# Borough is Downtown Toronto
# Neighborhood is Garden District
# The postcode is M5B, borough is Downtown Toronto, and neighborhood is Garden District.
# Postcode is M6B
# Borough is North York
# Neighborhood is Glencairn
# The postcode is M6B, borough is North York, and neighborhood is Glencairn.
# Postcode is M7B
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7B, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8B
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8B, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Cloverdale
# The postcode is M9B, borough is Etobicoke, and neighborhood is Cloverdale.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Islington
# The postcode is M9B, borough is Etobicoke, and neighborhood is Islington.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Martin Grove
# The postcode is M9B, borough is Etobicoke, and neighborhood is Martin Grove.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is Princess Gardens
# The postcode is M9B, borough is Etobicoke, and neighborhood is Princess Gardens.
# Postcode is M9B
# Borough is Etobicoke
# Neighborhood is West Deane Park
# The postcode is M9B, borough is Etobicoke, and neighborhood is West Deane Park.
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Highland Creek
# The postcode is M1C, borough is Scarborough, and neighborhood is Highland Creek.
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Rouge Hill
# The postcode is M1C, borough is Scarborough, and neighborhood is Rouge Hill.
# Postcode is M1C
# Borough is Scarborough
# Neighborhood is Port Union
# The postcode is M1C, borough is Scarborough, and neighborhood is Port Union.
# Postcode is M2C
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2C, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3C
# Borough is North York
# Neighborhood is Flemingdon Park
# The postcode is M3C, borough is North York, and neighborhood is Flemingdon Park.
# Postcode is M3C
# Borough is North York
# Neighborhood is Don Mills South
# The postcode is M3C, borough is North York, and neighborhood is Don Mills South.
# Postcode is M4C
# Borough is East York
# Neighborhood is Woodbine Heights
# The postcode is M4C, borough is East York, and neighborhood is Woodbine Heights.
# Postcode is M5C
# Borough is Downtown Toronto
# Neighborhood is St. James Town
# The postcode is M5C, borough is Downtown Toronto, and neighborhood is St. James Town.
# Postcode is M6C
# Borough is York
# Neighborhood is Humewood-Cedarvale
# The postcode is M6C, borough is York, and neighborhood is Humewood-Cedarvale.
# Postcode is M7C
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7C, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8C
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8C, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Bloordale Gardens
# The postcode is M9C, borough is Etobicoke, and neighborhood is Bloordale Gardens.
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Eringate
# The postcode is M9C, borough is Etobicoke, and neighborhood is Eringate.
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Markland Wood
# The postcode is M9C, borough is Etobicoke, and neighborhood is Markland Wood.
# Postcode is M9C
# Borough is Etobicoke
# Neighborhood is Old Burnhamthorpe
# The postcode is M9C, borough is Etobicoke, and neighborhood is Old Burnhamthorpe.
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is Guildwood
# The postcode is M1E, borough is Scarborough, and neighborhood is Guildwood.
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is Morningside
# The postcode is M1E, borough is Scarborough, and neighborhood is Morningside.
# Postcode is M1E
# Borough is Scarborough
# Neighborhood is West Hill
# The postcode is M1E, borough is Scarborough, and neighborhood is West Hill.
# Postcode is M2E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2E, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3E, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4E
# Borough is East Toronto
# Neighborhood is The Beaches
# The postcode is M4E, borough is East Toronto, and neighborhood is The Beaches.
# Postcode is M5E
# Borough is Downtown Toronto
# Neighborhood is Berczy Park
# The postcode is M5E, borough is Downtown Toronto, and neighborhood is Berczy Park.
# Postcode is M6E
# Borough is York
# Neighborhood is Caledonia-Fairbanks
# The postcode is M6E, borough is York, and neighborhood is Caledonia-Fairbanks.
# Postcode is M7E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7E, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8E, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9E
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9E, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1G
# Borough is Scarborough
# Neighborhood is Woburn
# The postcode is M1G, borough is Scarborough, and neighborhood is Woburn.
# Postcode is M2G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2G, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3G, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4G
# Borough is East York
# Neighborhood is Leaside
# The postcode is M4G, borough is East York, and neighborhood is Leaside.
# Postcode is M5G
# Borough is Downtown Toronto
# Neighborhood is Central Bay Street
# The postcode is M5G, borough is Downtown Toronto, and neighborhood is Central Bay Street.
# Postcode is M6G
# Borough is Downtown Toronto
# Neighborhood is Christie
# The postcode is M6G, borough is Downtown Toronto, and neighborhood is Christie.
# Postcode is M7G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7G, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8G, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9G
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9G, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1H
# Borough is Scarborough
# Neighborhood is Cedarbrae
# The postcode is M1H, borough is Scarborough, and neighborhood is Cedarbrae.
# Postcode is M2H
# Borough is North York
# Neighborhood is Hillcrest Village
# The postcode is M2H, borough is North York, and neighborhood is Hillcrest Village.
# Postcode is M3H
# Borough is North York
# Neighborhood is Bathurst Manor
# The postcode is M3H, borough is North York, and neighborhood is Bathurst Manor.
# Postcode is M3H
# Borough is North York
# Neighborhood is Downsview North
# The postcode is M3H, borough is North York, and neighborhood is Downsview North.
# Postcode is M3H
# Borough is North York
# Neighborhood is Wilson Heights
# The postcode is M3H, borough is North York, and neighborhood is Wilson Heights.
# Postcode is M4H
# Borough is East York
# Neighborhood is Thorncliffe Park
# The postcode is M4H, borough is East York, and neighborhood is Thorncliffe Park.
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is Adelaide
# The postcode is M5H, borough is Downtown Toronto, and neighborhood is Adelaide.
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is King
# The postcode is M5H, borough is Downtown Toronto, and neighborhood is King.
# Postcode is M5H
# Borough is Downtown Toronto
# Neighborhood is Richmond
# The postcode is M5H, borough is Downtown Toronto, and neighborhood is Richmond.
# Postcode is M6H
# Borough is West Toronto
# Neighborhood is Dovercourt Village
# The postcode is M6H, borough is West Toronto, and neighborhood is Dovercourt Village.
# Postcode is M6H
# Borough is West Toronto
# Neighborhood is Dufferin
# The postcode is M6H, borough is West Toronto, and neighborhood is Dufferin.
# Postcode is M7H
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7H, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8H
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8H, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9H
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9H, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1J
# Borough is Scarborough
# Neighborhood is Scarborough Village
# The postcode is M1J, borough is Scarborough, and neighborhood is Scarborough Village.
# Postcode is M2J
# Borough is North York
# Neighborhood is Fairview
# The postcode is M2J, borough is North York, and neighborhood is Fairview.
# Postcode is M2J
# Borough is North York
# Neighborhood is Henry Farm
# The postcode is M2J, borough is North York, and neighborhood is Henry Farm.
# Postcode is M2J
# Borough is North York
# Neighborhood is Oriole
# The postcode is M2J, borough is North York, and neighborhood is Oriole.
# Postcode is M3J
# Borough is North York
# Neighborhood is Northwood Park
# The postcode is M3J, borough is North York, and neighborhood is Northwood Park.
# Postcode is M3J
# Borough is North York
# Neighborhood is York University
# The postcode is M3J, borough is North York, and neighborhood is York University.
# Postcode is M4J
# Borough is East York
# Neighborhood is East Toronto
# The postcode is M4J, borough is East York, and neighborhood is East Toronto.
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Harbourfront East
# The postcode is M5J, borough is Downtown Toronto, and neighborhood is Harbourfront East.
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Toronto Islands
# The postcode is M5J, borough is Downtown Toronto, and neighborhood is Toronto Islands.
# Postcode is M5J
# Borough is Downtown Toronto
# Neighborhood is Union Station
# The postcode is M5J, borough is Downtown Toronto, and neighborhood is Union Station.
# Postcode is M6J
# Borough is West Toronto
# Neighborhood is Little Portugal
# The postcode is M6J, borough is West Toronto, and neighborhood is Little Portugal.
# Postcode is M6J
# Borough is West Toronto
# Neighborhood is Trinity
# The postcode is M6J, borough is West Toronto, and neighborhood is Trinity.
# Postcode is M7J
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7J, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8J
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8J, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9J
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9J, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is East Birchmount Park
# The postcode is M1K, borough is Scarborough, and neighborhood is East Birchmount Park.
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is Ionview
# The postcode is M1K, borough is Scarborough, and neighborhood is Ionview.
# Postcode is M1K
# Borough is Scarborough
# Neighborhood is Kennedy Park
# The postcode is M1K, borough is Scarborough, and neighborhood is Kennedy Park.
# Postcode is M2K
# Borough is North York
# Neighborhood is Bayview Village
# The postcode is M2K, borough is North York, and neighborhood is Bayview Village.
# Postcode is M3K
# Borough is North York
# Neighborhood is CFB Toronto
# The postcode is M3K, borough is North York, and neighborhood is CFB Toronto.
# Postcode is M3K
# Borough is North York
# Neighborhood is Downsview East
# The postcode is M3K, borough is North York, and neighborhood is Downsview East.
# Postcode is M4K
# Borough is East Toronto
# Neighborhood is The Danforth West
# The postcode is M4K, borough is East Toronto, and neighborhood is The Danforth West.
# Postcode is M4K
# Borough is East Toronto
# Neighborhood is Riverdale
# The postcode is M4K, borough is East Toronto, and neighborhood is Riverdale.
# Postcode is M5K
# Borough is Downtown Toronto
# Neighborhood is Design Exchange
# The postcode is M5K, borough is Downtown Toronto, and neighborhood is Design Exchange.
# Postcode is M5K
# Borough is Downtown Toronto
# Neighborhood is Toronto Dominion Centre
# The postcode is M5K, borough is Downtown Toronto, and neighborhood is Toronto Dominion Centre.
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Brockton
# The postcode is M6K, borough is West Toronto, and neighborhood is Brockton.
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Exhibition Place
# The postcode is M6K, borough is West Toronto, and neighborhood is Exhibition Place.
# Postcode is M6K
# Borough is West Toronto
# Neighborhood is Parkdale Village
# The postcode is M6K, borough is West Toronto, and neighborhood is Parkdale Village.
# Postcode is M7K
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7K, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8K
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8K, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9K
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9K, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Clairlea
# The postcode is M1L, borough is Scarborough, and neighborhood is Clairlea.
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Golden Mile
# The postcode is M1L, borough is Scarborough, and neighborhood is Golden Mile.
# Postcode is M1L
# Borough is Scarborough
# Neighborhood is Oakridge
# The postcode is M1L, borough is Scarborough, and neighborhood is Oakridge.
# Postcode is M2L
# Borough is North York
# Neighborhood is Silver Hills
# The postcode is M2L, borough is North York, and neighborhood is Silver Hills.
# Postcode is M2L
# Borough is North York
# Neighborhood is York Mills
# The postcode is M2L, borough is North York, and neighborhood is York Mills.
# Postcode is M3L
# Borough is North York
# Neighborhood is Downsview West
# The postcode is M3L, borough is North York, and neighborhood is Downsview West.
# Postcode is M4L
# Borough is East Toronto
# Neighborhood is The Beaches West
# The postcode is M4L, borough is East Toronto, and neighborhood is The Beaches West.
# Postcode is M4L
# Borough is East Toronto
# Neighborhood is India Bazaar
# The postcode is M4L, borough is East Toronto, and neighborhood is India Bazaar.
# Postcode is M5L
# Borough is Downtown Toronto
# Neighborhood is Commerce Court
# The postcode is M5L, borough is Downtown Toronto, and neighborhood is Commerce Court.
# Postcode is M5L
# Borough is Downtown Toronto
# Neighborhood is Victoria Hotel
# The postcode is M5L, borough is Downtown Toronto, and neighborhood is Victoria Hotel.
# Postcode is M6L
# Borough is North York
# Neighborhood is Downsview
# The postcode is M6L, borough is North York, and neighborhood is Downsview.
# Postcode is M6L
# Borough is North York
# Neighborhood is North Park
# The postcode is M6L, borough is North York, and neighborhood is North Park.
# Postcode is M6L
# Borough is North York
# Neighborhood is Upwood Park
# The postcode is M6L, borough is North York, and neighborhood is Upwood Park.
# Postcode is M7L
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7L, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8L
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8L, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9L
# Borough is North York
# Neighborhood is Humber Summit
# The postcode is M9L, borough is North York, and neighborhood is Humber Summit.
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Cliffcrest
# The postcode is M1M, borough is Scarborough, and neighborhood is Cliffcrest.
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Cliffside
# The postcode is M1M, borough is Scarborough, and neighborhood is Cliffside.
# Postcode is M1M
# Borough is Scarborough
# Neighborhood is Scarborough Village West
# The postcode is M1M, borough is Scarborough, and neighborhood is Scarborough Village West.
# Postcode is M2M
# Borough is North York
# Neighborhood is Newtonbrook
# The postcode is M2M, borough is North York, and neighborhood is Newtonbrook.
# Postcode is M2M
# Borough is North York
# Neighborhood is Willowdale
# The postcode is M2M, borough is North York, and neighborhood is Willowdale.
# Postcode is M3M
# Borough is North York
# Neighborhood is Downsview Central
# The postcode is M3M, borough is North York, and neighborhood is Downsview Central.
# Postcode is M4M
# Borough is East Toronto
# Neighborhood is Studio District
# The postcode is M4M, borough is East Toronto, and neighborhood is Studio District.
# Postcode is M5M
# Borough is North York
# Neighborhood is Bedford Park
# The postcode is M5M, borough is North York, and neighborhood is Bedford Park.
# Postcode is M5M
# Borough is North York
# Neighborhood is Lawrence Manor East
# The postcode is M5M, borough is North York, and neighborhood is Lawrence Manor East.
# Postcode is M6M
# Borough is York
# Neighborhood is Del Ray
# The postcode is M6M, borough is York, and neighborhood is Del Ray.
# Postcode is M6M
# Borough is York
# Neighborhood is Keelesdale
# The postcode is M6M, borough is York, and neighborhood is Keelesdale.
# Postcode is M6M
# Borough is York
# Neighborhood is Mount Dennis
# The postcode is M6M, borough is York, and neighborhood is Mount Dennis.
# Postcode is M6M
# Borough is York
# Neighborhood is Silverthorn
# The postcode is M6M, borough is York, and neighborhood is Silverthorn.
# Postcode is M7M
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7M, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8M
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8M, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9M
# Borough is North York
# Neighborhood is Emery
# The postcode is M9M, borough is North York, and neighborhood is Emery.
# Postcode is M9M
# Borough is North York
# Neighborhood is Humberlea
# The postcode is M9M, borough is North York, and neighborhood is Humberlea.
# Postcode is M1N
# Borough is Scarborough
# Neighborhood is Birch Cliff
# The postcode is M1N, borough is Scarborough, and neighborhood is Birch Cliff.
# Postcode is M1N
# Borough is Scarborough
# Neighborhood is Cliffside West
# The postcode is M1N, borough is Scarborough, and neighborhood is Cliffside West.
# Postcode is M2N
# Borough is North York
# Neighborhood is Willowdale South
# The postcode is M2N, borough is North York, and neighborhood is Willowdale South.
# Postcode is M3N
# Borough is North York
# Neighborhood is Downsview Northwest
# The postcode is M3N, borough is North York, and neighborhood is Downsview Northwest.
# Postcode is M4N
# Borough is Central Toronto
# Neighborhood is Lawrence Park
# The postcode is M4N, borough is Central Toronto, and neighborhood is Lawrence Park.
# Postcode is M5N
# Borough is Central Toronto
# Neighborhood is Roselawn
# The postcode is M5N, borough is Central Toronto, and neighborhood is Roselawn.
# Postcode is M6N
# Borough is York
# Neighborhood is The Junction North
# The postcode is M6N, borough is York, and neighborhood is The Junction North.
# Postcode is M6N
# Borough is York
# Neighborhood is Runnymede
# The postcode is M6N, borough is York, and neighborhood is Runnymede.
# Postcode is M7N
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7N, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8N
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8N, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9N
# Borough is York
# Neighborhood is Weston
# The postcode is M9N, borough is York, and neighborhood is Weston.
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Dorset Park
# The postcode is M1P, borough is Scarborough, and neighborhood is Dorset Park.
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Scarborough Town Centre
# The postcode is M1P, borough is Scarborough, and neighborhood is Scarborough Town Centre.
# Postcode is M1P
# Borough is Scarborough
# Neighborhood is Wexford Heights
# The postcode is M1P, borough is Scarborough, and neighborhood is Wexford Heights.
# Postcode is M2P
# Borough is North York
# Neighborhood is York Mills West
# The postcode is M2P, borough is North York, and neighborhood is York Mills West.
# Postcode is M3P
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3P, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4P
# Borough is Central Toronto
# Neighborhood is Davisville North
# The postcode is M4P, borough is Central Toronto, and neighborhood is Davisville North.
# Postcode is M5P
# Borough is Central Toronto
# Neighborhood is Forest Hill North
# The postcode is M5P, borough is Central Toronto, and neighborhood is Forest Hill North.
# Postcode is M5P
# Borough is Central Toronto
# Neighborhood is Forest Hill West
# The postcode is M5P, borough is Central Toronto, and neighborhood is Forest Hill West.
# Postcode is M6P
# Borough is West Toronto
# Neighborhood is High Park
# The postcode is M6P, borough is West Toronto, and neighborhood is High Park.
# Postcode is M6P
# Borough is West Toronto
# Neighborhood is The Junction South
# The postcode is M6P, borough is West Toronto, and neighborhood is The Junction South.
# Postcode is M7P
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7P, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8P
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8P, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9P
# Borough is Etobicoke
# Neighborhood is Westmount
# The postcode is M9P, borough is Etobicoke, and neighborhood is Westmount.
# Postcode is M1R
# Borough is Scarborough
# Neighborhood is Maryvale
# The postcode is M1R, borough is Scarborough, and neighborhood is Maryvale.
# Postcode is M1R
# Borough is Scarborough
# Neighborhood is Wexford
# The postcode is M1R, borough is Scarborough, and neighborhood is Wexford.
# Postcode is M2R
# Borough is North York
# Neighborhood is Willowdale West
# The postcode is M2R, borough is North York, and neighborhood is Willowdale West.
# Postcode is M3R
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3R, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4R
# Borough is Central Toronto
# Neighborhood is North Toronto West
# The postcode is M4R, borough is Central Toronto, and neighborhood is North Toronto West.
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is The Annex
# The postcode is M5R, borough is Central Toronto, and neighborhood is The Annex.
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is North Midtown
# The postcode is M5R, borough is Central Toronto, and neighborhood is North Midtown.
# Postcode is M5R
# Borough is Central Toronto
# Neighborhood is Yorkville
# The postcode is M5R, borough is Central Toronto, and neighborhood is Yorkville.
# Postcode is M6R
# Borough is West Toronto
# Neighborhood is Parkdale
# The postcode is M6R, borough is West Toronto, and neighborhood is Parkdale.
# Postcode is M6R
# Borough is West Toronto
# Neighborhood is Roncesvalles
# The postcode is M6R, borough is West Toronto, and neighborhood is Roncesvalles.
# Postcode is M7R
# Borough is Mississauga
# Neighborhood is Canada Post Gateway Processing Centre
# The postcode is M7R, borough is Mississauga, and neighborhood is Canada Post Gateway Processing Centre.
# Postcode is M8R
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8R, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Kingsview Village
# The postcode is M9R, borough is Etobicoke, and neighborhood is Kingsview Village.
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Martin Grove Gardens
# The postcode is M9R, borough is Etobicoke, and neighborhood is Martin Grove Gardens.
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is Richview Gardens
# The postcode is M9R, borough is Etobicoke, and neighborhood is Richview Gardens.
# Postcode is M9R
# Borough is Etobicoke
# Neighborhood is St. Phillips
# The postcode is M9R, borough is Etobicoke, and neighborhood is St. Phillips.
# Postcode is M1S
# Borough is Scarborough
# Neighborhood is Agincourt
# The postcode is M1S, borough is Scarborough, and neighborhood is Agincourt.
# Postcode is M2S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2S, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3S, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4S
# Borough is Central Toronto
# Neighborhood is Davisville
# The postcode is M4S, borough is Central Toronto, and neighborhood is Davisville.
# Postcode is M5S
# Borough is Downtown Toronto
# Neighborhood is Harbord
# The postcode is M5S, borough is Downtown Toronto, and neighborhood is Harbord.
# Postcode is M5S
# Borough is Downtown Toronto
# Neighborhood is University of Toronto
# The postcode is M5S, borough is Downtown Toronto, and neighborhood is University of Toronto.
# Postcode is M6S
# Borough is West Toronto
# Neighborhood is Runnymede
# The postcode is M6S, borough is West Toronto, and neighborhood is Runnymede.
# Postcode is M6S
# Borough is West Toronto
# Neighborhood is Swansea
# The postcode is M6S, borough is West Toronto, and neighborhood is Swansea.
# Postcode is M7S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7S, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8S, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9S
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9S, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Clarks Corners
# The postcode is M1T, borough is Scarborough, and neighborhood is Clarks Corners.
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Sullivan
# The postcode is M1T, borough is Scarborough, and neighborhood is Sullivan.
# Postcode is M1T
# Borough is Scarborough
# Neighborhood is Tam O'Shanter
# The postcode is M1T, borough is Scarborough, and neighborhood is Tam O'Shanter.
# Postcode is M2T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2T, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3T, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4T
# Borough is Central Toronto
# Neighborhood is Moore Park
# The postcode is M4T, borough is Central Toronto, and neighborhood is Moore Park.
# Postcode is M4T
# Borough is Central Toronto
# Neighborhood is Summerhill East
# The postcode is M4T, borough is Central Toronto, and neighborhood is Summerhill East.
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Chinatown
# The postcode is M5T, borough is Downtown Toronto, and neighborhood is Chinatown.
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Grange Park
# The postcode is M5T, borough is Downtown Toronto, and neighborhood is Grange Park.
# Postcode is M5T
# Borough is Downtown Toronto
# Neighborhood is Kensington Market
# The postcode is M5T, borough is Downtown Toronto, and neighborhood is Kensington Market.
# Postcode is M6T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6T, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M7T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7T, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M8T, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M9T
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9T, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Agincourt North
# The postcode is M1V, borough is Scarborough, and neighborhood is Agincourt North.
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is L'Amoreaux East
# The postcode is M1V, borough is Scarborough, and neighborhood is L'Amoreaux East.
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Milliken
# The postcode is M1V, borough is Scarborough, and neighborhood is Milliken.
# Postcode is M1V
# Borough is Scarborough
# Neighborhood is Steeles East
# The postcode is M1V, borough is Scarborough, and neighborhood is Steeles East.
# Postcode is M2V
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2V, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3V
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3V, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Deer Park
# The postcode is M4V, borough is Central Toronto, and neighborhood is Deer Park.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Forest Hill SE
# The postcode is M4V, borough is Central Toronto, and neighborhood is Forest Hill SE.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Rathnelly
# The postcode is M4V, borough is Central Toronto, and neighborhood is Rathnelly.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is South Hill
# The postcode is M4V, borough is Central Toronto, and neighborhood is South Hill.
# Postcode is M4V
# Borough is Central Toronto
# Neighborhood is Summerhill West
# The postcode is M4V, borough is Central Toronto, and neighborhood is Summerhill West.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is CN Tower
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is CN Tower.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Bathurst Quay
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is Bathurst Quay.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Island airport
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is Island airport.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Harbourfront West
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is Harbourfront West.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is King and Spadina
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is King and Spadina.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is Railway Lands
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is Railway Lands.
# Postcode is M5V
# Borough is Downtown Toronto
# Neighborhood is South Niagara
# The postcode is M5V, borough is Downtown Toronto, and neighborhood is South Niagara.
# Postcode is M6V
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6V, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M7V
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7V, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is Humber Bay Shores
# The postcode is M8V, borough is Etobicoke, and neighborhood is Humber Bay Shores.
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is Mimico South
# The postcode is M8V, borough is Etobicoke, and neighborhood is Mimico South.
# Postcode is M8V
# Borough is Etobicoke
# Neighborhood is New Toronto
# The postcode is M8V, borough is Etobicoke, and neighborhood is New Toronto.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Albion Gardens
# The postcode is M9V, borough is Etobicoke, and neighborhood is Albion Gardens.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Beaumond Heights
# The postcode is M9V, borough is Etobicoke, and neighborhood is Beaumond Heights.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Humbergate
# The postcode is M9V, borough is Etobicoke, and neighborhood is Humbergate.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Jamestown
# The postcode is M9V, borough is Etobicoke, and neighborhood is Jamestown.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Mount Olive
# The postcode is M9V, borough is Etobicoke, and neighborhood is Mount Olive.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Silverstone
# The postcode is M9V, borough is Etobicoke, and neighborhood is Silverstone.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is South Steeles
# The postcode is M9V, borough is Etobicoke, and neighborhood is South Steeles.
# Postcode is M9V
# Borough is Etobicoke
# Neighborhood is Thistletown
# The postcode is M9V, borough is Etobicoke, and neighborhood is Thistletown.
# Postcode is M1W
# Borough is Scarborough
# Neighborhood is L'Amoreaux West
# The postcode is M1W, borough is Scarborough, and neighborhood is L'Amoreaux West.
# Postcode is M2W
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2W, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3W
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3W, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4W
# Borough is Downtown Toronto
# Neighborhood is Rosedale
# The postcode is M4W, borough is Downtown Toronto, and neighborhood is Rosedale.
# Postcode is M5W
# Borough is Downtown Toronto
# Neighborhood is Stn A PO Boxes 25 The Esplanade
# The postcode is M5W, borough is Downtown Toronto, and neighborhood is Stn A PO Boxes 25 The Esplanade.
# Postcode is M6W
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6W, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M7W
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7W, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8W
# Borough is Etobicoke
# Neighborhood is Alderwood
# The postcode is M8W, borough is Etobicoke, and neighborhood is Alderwood.
# Postcode is M8W
# Borough is Etobicoke
# Neighborhood is Long Branch
# The postcode is M8W, borough is Etobicoke, and neighborhood is Long Branch.
# Postcode is M9W
# Borough is Etobicoke
# Neighborhood is Northwest
# The postcode is M9W, borough is Etobicoke, and neighborhood is Northwest.
# Postcode is M1X
# Borough is Scarborough
# Neighborhood is Upper Rouge
# The postcode is M1X, borough is Scarborough, and neighborhood is Upper Rouge.
# Postcode is M2X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2X, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3X, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4X
# Borough is Downtown Toronto
# Neighborhood is Cabbagetown
# The postcode is M4X, borough is Downtown Toronto, and neighborhood is Cabbagetown.
# Postcode is M4X
# Borough is Downtown Toronto
# Neighborhood is St. James Town
# The postcode is M4X, borough is Downtown Toronto, and neighborhood is St. James Town.
# Postcode is M5X
# Borough is Downtown Toronto
# Neighborhood is First Canadian Place
# The postcode is M5X, borough is Downtown Toronto, and neighborhood is First Canadian Place.
# Postcode is M5X
# Borough is Downtown Toronto
# Neighborhood is Underground city
# The postcode is M5X, borough is Downtown Toronto, and neighborhood is Underground city.
# Postcode is M6X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6X, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M7X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7X, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is The Kingsway
# The postcode is M8X, borough is Etobicoke, and neighborhood is The Kingsway.
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is Montgomery Road
# The postcode is M8X, borough is Etobicoke, and neighborhood is Montgomery Road.
# Postcode is M8X
# Borough is Etobicoke
# Neighborhood is Old Mill North
# The postcode is M8X, borough is Etobicoke, and neighborhood is Old Mill North.
# Postcode is M9X
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9X, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M1Y, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M2Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2Y, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3Y, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4Y
# Borough is Downtown Toronto
# Neighborhood is Church and Wellesley
# The postcode is M4Y, borough is Downtown Toronto, and neighborhood is Church and Wellesley.
# Postcode is M5Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M5Y, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M6Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6Y, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M7Y
# Borough is East Toronto
# Neighborhood is Business Reply Mail Processing Centre 969 Eastern
# The postcode is M7Y, borough is East Toronto, and neighborhood is Business Reply Mail Processing Centre 969 Eastern.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Humber Bay
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Humber Bay.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is King's Mill Park
# The postcode is M8Y, borough is Etobicoke, and neighborhood is King's Mill Park.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Kingsway Park South East
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Kingsway Park South East.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Mimico NE
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Mimico NE.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Old Mill South
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Old Mill South.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is The Queensway East
# The postcode is M8Y, borough is Etobicoke, and neighborhood is The Queensway East.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Royal York South East
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Royal York South East.
# Postcode is M8Y
# Borough is Etobicoke
# Neighborhood is Sunnylea
# The postcode is M8Y, borough is Etobicoke, and neighborhood is Sunnylea.
# Postcode is M9Y
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9Y, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M1Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M1Z, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M2Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M2Z, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M3Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M3Z, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M4Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M4Z, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M5Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M5Z, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M6Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M6Z, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M7Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M7Z, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Kingsway Park South West
# The postcode is M8Z, borough is Etobicoke, and neighborhood is Kingsway Park South West.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Mimico NW
# The postcode is M8Z, borough is Etobicoke, and neighborhood is Mimico NW.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is The Queensway West
# The postcode is M8Z, borough is Etobicoke, and neighborhood is The Queensway West.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is Royal York South West
# The postcode is M8Z, borough is Etobicoke, and neighborhood is Royal York South West.
# Postcode is M8Z
# Borough is Etobicoke
# Neighborhood is South of Bloor
# The postcode is M8Z, borough is Etobicoke, and neighborhood is South of Bloor.
# Postcode is M9Z
# Borough is Not assigned
# Neighborhood is Not assigned
# The postcode is M9Z, borough is Not assigned, and neighborhood is Not assigned.
# Skipping this row

# %%
neighborhoods.head(5)
# Out:
#   Postcode           Borough      Neighborhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights

# %%
neighborhoods.shape
# Out:
# (211, 3)

# %% [markdown]
# # Data Analysis

# %%
# import geocoder
! pip install geocoder
import geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\kdj\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: click in c:\users\kdj\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: future in c:\users\kdj\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: six in c:\users\kdj\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: requests in c:\users\kdj\anaconda3\lib\site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: ratelim in c:\users\kdj\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\kdj\anaconda3\lib\site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kdj\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kdj\anaconda3\lib\site-packages (from requests->geocoder) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kdj\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: decorator in c:\users\kdj\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)

# %%
# create a load new dataframe
column_names = ['Postcode', 'Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
hoods_ll = pd.DataFrame(columns=column_names)
hoods_ll.head()
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
# load data into dataframe
for table_row in full_table.find_all('tr'):
	counter = 1
	postcode = 'NA'
	borough = 'NA'
	neighborhood = 'NA'
	for table_cell in table_row.find_all('td'):
		if counter == 1:
			postcode = table_cell.text
		elif counter == 2:
			borough = table_cell.text
		else:
			neighborhood = table_cell.text.strip('\n')
		counter = counter + 1
	if (postcode == 'NA') or (borough == 'Not assigned'):
		print('Skipping this row')
	elif neighborhood == 'Not assigned':
		hoods_ll = hoods_ll.append({'Postcode':postcode,
		                                      'Borough': borough,
											  'Neighborhood': borough}, ignore_index=True)
	else:
		hoods_ll = hoods_ll.append({'Postcode':postcode,
		                                      'Borough': borough,
											  'Neighborhood': neighborhood}, ignore_index=True)
											  
hoods_ll.head(5)
# Out:
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
# Skipping this row
#   Postcode           Borough      Neighborhood Latitude Longitude
# 0      M3A        North York         Parkwoods      NaN       NaN
# 1      M4A        North York  Victoria Village      NaN       NaN
# 2      M5A  Downtown Toronto      Harbourfront      NaN       NaN
# 3      M5A  Downtown Toronto       Regent Park      NaN       NaN
# 4      M6A        North York  Lawrence Heights      NaN       NaN

# %%
# initialize your variable to None
lat_lng_coords = None

# set postal code
postal_code = hoods_ll.at[11, 'Postcode']
print(postal_code)
# Out:
# M4B

# %%
# Read data from CSV file into a dataframe
csv_path = 'http://cocl.us/Geospatial_data'
geo_df = pd.read_csv(csv_path)	
geo_df.head(5)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
postal_code = geo_df.loc[geo_df['Postal Code'] == 'M3A']
print(postal_code)
# Out:
#    Postal Code   Latitude  Longitude
# 25         M3A  43.753259 -79.329656

# %%
latitude = geo_df.loc[geo_df['Postal Code'] == 'M3A'].Latitude
print(latitude)
# Out:
# 25    43.753259
# Name: Latitude, dtype: float64

# %%
index_num = geo_df.index[geo_df['Postal Code'] == 'M3A'].tolist()
print(geo_df.loc[index_num].Latitude.values[0])
# Out:
# 43.7532586

# %%
for i in hoods_ll.index:
	print(hoods_ll.iloc[i])
# Out:
# Postcode               M3A
# Borough         North York
# Neighborhood     Parkwoods
# Latitude               NaN
# Longitude              NaN
# Name: 0, dtype: object
# Postcode                     M4A
# Borough               North York
# Neighborhood    Victoria Village
# Latitude                     NaN
# Longitude                    NaN
# Name: 1, dtype: object
# Postcode                     M5A
# Borough         Downtown Toronto
# Neighborhood        Harbourfront
# Latitude                     NaN
# Longitude                    NaN
# Name: 2, dtype: object
# Postcode                     M5A
# Borough         Downtown Toronto
# Neighborhood         Regent Park
# Latitude                     NaN
# Longitude                    NaN
# Name: 3, dtype: object
# Postcode                     M6A
# Borough               North York
# Neighborhood    Lawrence Heights
# Latitude                     NaN
# Longitude                    NaN
# Name: 4, dtype: object
# Postcode                   M6A
# Borough             North York
# Neighborhood    Lawrence Manor
# Latitude                   NaN
# Longitude                  NaN
# Name: 5, dtype: object
# Postcode                 M7A
# Borough         Queen's Park
# Neighborhood    Queen's Park
# Latitude                 NaN
# Longitude                NaN
# Name: 6, dtype: object
# Postcode                     M9A
# Borough                Etobicoke
# Neighborhood    Islington Avenue
# Latitude                     NaN
# Longitude                    NaN
# Name: 7, dtype: object
# Postcode                M1B
# Borough         Scarborough
# Neighborhood          Rouge
# Latitude                NaN
# Longitude               NaN
# Name: 8, dtype: object
# Postcode                M1B
# Borough         Scarborough
# Neighborhood        Malvern
# Latitude                NaN
# Longitude               NaN
# Name: 9, dtype: object
# Postcode                    M3B
# Borough              North York
# Neighborhood    Don Mills North
# Latitude                    NaN
# Longitude                   NaN
# Name: 10, dtype: object
# Postcode                     M4B
# Borough                East York
# Neighborhood    Woodbine Gardens
# Latitude                     NaN
# Longitude                    NaN
# Name: 11, dtype: object
# Postcode                  M4B
# Borough             East York
# Neighborhood    Parkview Hill
# Latitude                  NaN
# Longitude                 NaN
# Name: 12, dtype: object
# Postcode                     M5B
# Borough         Downtown Toronto
# Neighborhood             Ryerson
# Latitude                     NaN
# Longitude                    NaN
# Name: 13, dtype: object
# Postcode                     M5B
# Borough         Downtown Toronto
# Neighborhood     Garden District
# Latitude                     NaN
# Longitude                    NaN
# Name: 14, dtype: object
# Postcode               M6B
# Borough         North York
# Neighborhood     Glencairn
# Latitude               NaN
# Longitude              NaN
# Name: 15, dtype: object
# Postcode               M9B
# Borough          Etobicoke
# Neighborhood    Cloverdale
# Latitude               NaN
# Longitude              NaN
# Name: 16, dtype: object
# Postcode              M9B
# Borough         Etobicoke
# Neighborhood    Islington
# Latitude              NaN
# Longitude             NaN
# Name: 17, dtype: object
# Postcode                 M9B
# Borough            Etobicoke
# Neighborhood    Martin Grove
# Latitude                 NaN
# Longitude                NaN
# Name: 18, dtype: object
# Postcode                     M9B
# Borough                Etobicoke
# Neighborhood    Princess Gardens
# Latitude                     NaN
# Longitude                    NaN
# Name: 19, dtype: object
# Postcode                    M9B
# Borough               Etobicoke
# Neighborhood    West Deane Park
# Latitude                    NaN
# Longitude                   NaN
# Name: 20, dtype: object
# Postcode                   M1C
# Borough            Scarborough
# Neighborhood    Highland Creek
# Latitude                   NaN
# Longitude                  NaN
# Name: 21, dtype: object
# Postcode                M1C
# Borough         Scarborough
# Neighborhood     Rouge Hill
# Latitude                NaN
# Longitude               NaN
# Name: 22, dtype: object
# Postcode                M1C
# Borough         Scarborough
# Neighborhood     Port Union
# Latitude                NaN
# Longitude               NaN
# Name: 23, dtype: object
# Postcode                    M3C
# Borough              North York
# Neighborhood    Flemingdon Park
# Latitude                    NaN
# Longitude                   NaN
# Name: 24, dtype: object
# Postcode                    M3C
# Borough              North York
# Neighborhood    Don Mills South
# Latitude                    NaN
# Longitude                   NaN
# Name: 25, dtype: object
# Postcode                     M4C
# Borough                East York
# Neighborhood    Woodbine Heights
# Latitude                     NaN
# Longitude                    NaN
# Name: 26, dtype: object
# Postcode                     M5C
# Borough         Downtown Toronto
# Neighborhood      St. James Town
# Latitude                     NaN
# Longitude                    NaN
# Name: 27, dtype: object
# Postcode                       M6C
# Borough                       York
# Neighborhood    Humewood-Cedarvale
# Latitude                       NaN
# Longitude                      NaN
# Name: 28, dtype: object
# Postcode                      M9C
# Borough                 Etobicoke
# Neighborhood    Bloordale Gardens
# Latitude                      NaN
# Longitude                     NaN
# Name: 29, dtype: object
# Postcode              M9C
# Borough         Etobicoke
# Neighborhood     Eringate
# Latitude              NaN
# Longitude             NaN
# Name: 30, dtype: object
# Postcode                  M9C
# Borough             Etobicoke
# Neighborhood    Markland Wood
# Latitude                  NaN
# Longitude                 NaN
# Name: 31, dtype: object
# Postcode                      M9C
# Borough                 Etobicoke
# Neighborhood    Old Burnhamthorpe
# Latitude                      NaN
# Longitude                     NaN
# Name: 32, dtype: object
# Postcode                M1E
# Borough         Scarborough
# Neighborhood      Guildwood
# Latitude                NaN
# Longitude               NaN
# Name: 33, dtype: object
# Postcode                M1E
# Borough         Scarborough
# Neighborhood    Morningside
# Latitude                NaN
# Longitude               NaN
# Name: 34, dtype: object
# Postcode                M1E
# Borough         Scarborough
# Neighborhood      West Hill
# Latitude                NaN
# Longitude               NaN
# Name: 35, dtype: object
# Postcode                 M4E
# Borough         East Toronto
# Neighborhood     The Beaches
# Latitude                 NaN
# Longitude                NaN
# Name: 36, dtype: object
# Postcode                     M5E
# Borough         Downtown Toronto
# Neighborhood         Berczy Park
# Latitude                     NaN
# Longitude                    NaN
# Name: 37, dtype: object
# Postcode                        M6E
# Borough                        York
# Neighborhood    Caledonia-Fairbanks
# Latitude                        NaN
# Longitude                       NaN
# Name: 38, dtype: object
# Postcode                M1G
# Borough         Scarborough
# Neighborhood         Woburn
# Latitude                NaN
# Longitude               NaN
# Name: 39, dtype: object
# Postcode              M4G
# Borough         East York
# Neighborhood      Leaside
# Latitude              NaN
# Longitude             NaN
# Name: 40, dtype: object
# Postcode                       M5G
# Borough           Downtown Toronto
# Neighborhood    Central Bay Street
# Latitude                       NaN
# Longitude                      NaN
# Name: 41, dtype: object
# Postcode                     M6G
# Borough         Downtown Toronto
# Neighborhood            Christie
# Latitude                     NaN
# Longitude                    NaN
# Name: 42, dtype: object
# Postcode                M1H
# Borough         Scarborough
# Neighborhood      Cedarbrae
# Latitude                NaN
# Longitude               NaN
# Name: 43, dtype: object
# Postcode                      M2H
# Borough                North York
# Neighborhood    Hillcrest Village
# Latitude                      NaN
# Longitude                     NaN
# Name: 44, dtype: object
# Postcode                   M3H
# Borough             North York
# Neighborhood    Bathurst Manor
# Latitude                   NaN
# Longitude                  NaN
# Name: 45, dtype: object
# Postcode                    M3H
# Borough              North York
# Neighborhood    Downsview North
# Latitude                    NaN
# Longitude                   NaN
# Name: 46, dtype: object
# Postcode                   M3H
# Borough             North York
# Neighborhood    Wilson Heights
# Latitude                   NaN
# Longitude                  NaN
# Name: 47, dtype: object
# Postcode                     M4H
# Borough                East York
# Neighborhood    Thorncliffe Park
# Latitude                     NaN
# Longitude                    NaN
# Name: 48, dtype: object
# Postcode                     M5H
# Borough         Downtown Toronto
# Neighborhood            Adelaide
# Latitude                     NaN
# Longitude                    NaN
# Name: 49, dtype: object
# Postcode                     M5H
# Borough         Downtown Toronto
# Neighborhood                King
# Latitude                     NaN
# Longitude                    NaN
# Name: 50, dtype: object
# Postcode                     M5H
# Borough         Downtown Toronto
# Neighborhood            Richmond
# Latitude                     NaN
# Longitude                    NaN
# Name: 51, dtype: object
# Postcode                       M6H
# Borough               West Toronto
# Neighborhood    Dovercourt Village
# Latitude                       NaN
# Longitude                      NaN
# Name: 52, dtype: object
# Postcode                 M6H
# Borough         West Toronto
# Neighborhood        Dufferin
# Latitude                 NaN
# Longitude                NaN
# Name: 53, dtype: object
# Postcode                        M1J
# Borough                 Scarborough
# Neighborhood    Scarborough Village
# Latitude                        NaN
# Longitude                       NaN
# Name: 54, dtype: object
# Postcode               M2J
# Borough         North York
# Neighborhood      Fairview
# Latitude               NaN
# Longitude              NaN
# Name: 55, dtype: object
# Postcode               M2J
# Borough         North York
# Neighborhood    Henry Farm
# Latitude               NaN
# Longitude              NaN
# Name: 56, dtype: object
# Postcode               M2J
# Borough         North York
# Neighborhood        Oriole
# Latitude               NaN
# Longitude              NaN
# Name: 57, dtype: object
# Postcode                   M3J
# Borough             North York
# Neighborhood    Northwood Park
# Latitude                   NaN
# Longitude                  NaN
# Name: 58, dtype: object
# Postcode                    M3J
# Borough              North York
# Neighborhood    York University
# Latitude                    NaN
# Longitude                   NaN
# Name: 59, dtype: object
# Postcode                 M4J
# Borough            East York
# Neighborhood    East Toronto
# Latitude                 NaN
# Longitude                NaN
# Name: 60, dtype: object
# Postcode                      M5J
# Borough          Downtown Toronto
# Neighborhood    Harbourfront East
# Latitude                      NaN
# Longitude                     NaN
# Name: 61, dtype: object
# Postcode                     M5J
# Borough         Downtown Toronto
# Neighborhood     Toronto Islands
# Latitude                     NaN
# Longitude                    NaN
# Name: 62, dtype: object
# Postcode                     M5J
# Borough         Downtown Toronto
# Neighborhood       Union Station
# Latitude                     NaN
# Longitude                    NaN
# Name: 63, dtype: object
# Postcode                    M6J
# Borough            West Toronto
# Neighborhood    Little Portugal
# Latitude                    NaN
# Longitude                   NaN
# Name: 64, dtype: object
# Postcode                 M6J
# Borough         West Toronto
# Neighborhood         Trinity
# Latitude                 NaN
# Longitude                NaN
# Name: 65, dtype: object
# Postcode                         M1K
# Borough                  Scarborough
# Neighborhood    East Birchmount Park
# Latitude                         NaN
# Longitude                        NaN
# Name: 66, dtype: object
# Postcode                M1K
# Borough         Scarborough
# Neighborhood        Ionview
# Latitude                NaN
# Longitude               NaN
# Name: 67, dtype: object
# Postcode                 M1K
# Borough          Scarborough
# Neighborhood    Kennedy Park
# Latitude                 NaN
# Longitude                NaN
# Name: 68, dtype: object
# Postcode                    M2K
# Borough              North York
# Neighborhood    Bayview Village
# Latitude                    NaN
# Longitude                   NaN
# Name: 69, dtype: object
# Postcode                M3K
# Borough          North York
# Neighborhood    CFB Toronto
# Latitude                NaN
# Longitude               NaN
# Name: 70, dtype: object
# Postcode                   M3K
# Borough             North York
# Neighborhood    Downsview East
# Latitude                   NaN
# Longitude                  NaN
# Name: 71, dtype: object
# Postcode                      M4K
# Borough              East Toronto
# Neighborhood    The Danforth West
# Latitude                      NaN
# Longitude                     NaN
# Name: 72, dtype: object
# Postcode                 M4K
# Borough         East Toronto
# Neighborhood       Riverdale
# Latitude                 NaN
# Longitude                NaN
# Name: 73, dtype: object
# Postcode                     M5K
# Borough         Downtown Toronto
# Neighborhood     Design Exchange
# Latitude                     NaN
# Longitude                    NaN
# Name: 74, dtype: object
# Postcode                            M5K
# Borough                Downtown Toronto
# Neighborhood    Toronto Dominion Centre
# Latitude                            NaN
# Longitude                           NaN
# Name: 75, dtype: object
# Postcode                 M6K
# Borough         West Toronto
# Neighborhood        Brockton
# Latitude                 NaN
# Longitude                NaN
# Name: 76, dtype: object
# Postcode                     M6K
# Borough             West Toronto
# Neighborhood    Exhibition Place
# Latitude                     NaN
# Longitude                    NaN
# Name: 77, dtype: object
# Postcode                     M6K
# Borough             West Toronto
# Neighborhood    Parkdale Village
# Latitude                     NaN
# Longitude                    NaN
# Name: 78, dtype: object
# Postcode                M1L
# Borough         Scarborough
# Neighborhood       Clairlea
# Latitude                NaN
# Longitude               NaN
# Name: 79, dtype: object
# Postcode                M1L
# Borough         Scarborough
# Neighborhood    Golden Mile
# Latitude                NaN
# Longitude               NaN
# Name: 80, dtype: object
# Postcode                M1L
# Borough         Scarborough
# Neighborhood       Oakridge
# Latitude                NaN
# Longitude               NaN
# Name: 81, dtype: object
# Postcode                 M2L
# Borough           North York
# Neighborhood    Silver Hills
# Latitude                 NaN
# Longitude                NaN
# Name: 82, dtype: object
# Postcode               M2L
# Borough         North York
# Neighborhood    York Mills
# Latitude               NaN
# Longitude              NaN
# Name: 83, dtype: object
# Postcode                   M3L
# Borough             North York
# Neighborhood    Downsview West
# Latitude                   NaN
# Longitude                  NaN
# Name: 84, dtype: object
# Postcode                     M4L
# Borough             East Toronto
# Neighborhood    The Beaches West
# Latitude                     NaN
# Longitude                    NaN
# Name: 85, dtype: object
# Postcode                 M4L
# Borough         East Toronto
# Neighborhood    India Bazaar
# Latitude                 NaN
# Longitude                NaN
# Name: 86, dtype: object
# Postcode                     M5L
# Borough         Downtown Toronto
# Neighborhood      Commerce Court
# Latitude                     NaN
# Longitude                    NaN
# Name: 87, dtype: object
# Postcode                     M5L
# Borough         Downtown Toronto
# Neighborhood      Victoria Hotel
# Latitude                     NaN
# Longitude                    NaN
# Name: 88, dtype: object
# Postcode               M6L
# Borough         North York
# Neighborhood     Downsview
# Latitude               NaN
# Longitude              NaN
# Name: 89, dtype: object
# Postcode               M6L
# Borough         North York
# Neighborhood    North Park
# Latitude               NaN
# Longitude              NaN
# Name: 90, dtype: object
# Postcode                M6L
# Borough          North York
# Neighborhood    Upwood Park
# Latitude                NaN
# Longitude               NaN
# Name: 91, dtype: object
# Postcode                  M9L
# Borough            North York
# Neighborhood    Humber Summit
# Latitude                  NaN
# Longitude                 NaN
# Name: 92, dtype: object
# Postcode                M1M
# Borough         Scarborough
# Neighborhood     Cliffcrest
# Latitude                NaN
# Longitude               NaN
# Name: 93, dtype: object
# Postcode                M1M
# Borough         Scarborough
# Neighborhood      Cliffside
# Latitude                NaN
# Longitude               NaN
# Name: 94, dtype: object
# Postcode                             M1M
# Borough                      Scarborough
# Neighborhood    Scarborough Village West
# Latitude                             NaN
# Longitude                            NaN
# Name: 95, dtype: object
# Postcode                M2M
# Borough          North York
# Neighborhood    Newtonbrook
# Latitude                NaN
# Longitude               NaN
# Name: 96, dtype: object
# Postcode               M2M
# Borough         North York
# Neighborhood    Willowdale
# Latitude               NaN
# Longitude              NaN
# Name: 97, dtype: object
# Postcode                      M3M
# Borough                North York
# Neighborhood    Downsview Central
# Latitude                      NaN
# Longitude                     NaN
# Name: 98, dtype: object
# Postcode                    M4M
# Borough            East Toronto
# Neighborhood    Studio District
# Latitude                    NaN
# Longitude                   NaN
# Name: 99, dtype: object
# Postcode                 M5M
# Borough           North York
# Neighborhood    Bedford Park
# Latitude                 NaN
# Longitude                NaN
# Name: 100, dtype: object
# Postcode                        M5M
# Borough                  North York
# Neighborhood    Lawrence Manor East
# Latitude                        NaN
# Longitude                       NaN
# Name: 101, dtype: object
# Postcode            M6M
# Borough            York
# Neighborhood    Del Ray
# Latitude            NaN
# Longitude           NaN
# Name: 102, dtype: object
# Postcode               M6M
# Borough               York
# Neighborhood    Keelesdale
# Latitude               NaN
# Longitude              NaN
# Name: 103, dtype: object
# Postcode                 M6M
# Borough                 York
# Neighborhood    Mount Dennis
# Latitude                 NaN
# Longitude                NaN
# Name: 104, dtype: object
# Postcode                M6M
# Borough                York
# Neighborhood    Silverthorn
# Latitude                NaN
# Longitude               NaN
# Name: 105, dtype: object
# Postcode               M9M
# Borough         North York
# Neighborhood         Emery
# Latitude               NaN
# Longitude              NaN
# Name: 106, dtype: object
# Postcode               M9M
# Borough         North York
# Neighborhood     Humberlea
# Latitude               NaN
# Longitude              NaN
# Name: 107, dtype: object
# Postcode                M1N
# Borough         Scarborough
# Neighborhood    Birch Cliff
# Latitude                NaN
# Longitude               NaN
# Name: 108, dtype: object
# Postcode                   M1N
# Borough            Scarborough
# Neighborhood    Cliffside West
# Latitude                   NaN
# Longitude                  NaN
# Name: 109, dtype: object
# Postcode                     M2N
# Borough               North York
# Neighborhood    Willowdale South
# Latitude                     NaN
# Longitude                    NaN
# Name: 110, dtype: object
# Postcode                        M3N
# Borough                  North York
# Neighborhood    Downsview Northwest
# Latitude                        NaN
# Longitude                       NaN
# Name: 111, dtype: object
# Postcode                    M4N
# Borough         Central Toronto
# Neighborhood      Lawrence Park
# Latitude                    NaN
# Longitude                   NaN
# Name: 112, dtype: object
# Postcode                    M5N
# Borough         Central Toronto
# Neighborhood           Roselawn
# Latitude                    NaN
# Longitude                   NaN
# Name: 113, dtype: object
# Postcode                       M6N
# Borough                       York
# Neighborhood    The Junction North
# Latitude                       NaN
# Longitude                      NaN
# Name: 114, dtype: object
# Postcode              M6N
# Borough              York
# Neighborhood    Runnymede
# Latitude              NaN
# Longitude             NaN
# Name: 115, dtype: object
# Postcode           M9N
# Borough           York
# Neighborhood    Weston
# Latitude           NaN
# Longitude          NaN
# Name: 116, dtype: object
# Postcode                M1P
# Borough         Scarborough
# Neighborhood    Dorset Park
# Latitude                NaN
# Longitude               NaN
# Name: 117, dtype: object
# Postcode                            M1P
# Borough                     Scarborough
# Neighborhood    Scarborough Town Centre
# Latitude                            NaN
# Longitude                           NaN
# Name: 118, dtype: object
# Postcode                    M1P
# Borough             Scarborough
# Neighborhood    Wexford Heights
# Latitude                    NaN
# Longitude                   NaN
# Name: 119, dtype: object
# Postcode                    M2P
# Borough              North York
# Neighborhood    York Mills West
# Latitude                    NaN
# Longitude                   NaN
# Name: 120, dtype: object
# Postcode                     M4P
# Borough          Central Toronto
# Neighborhood    Davisville North
# Latitude                     NaN
# Longitude                    NaN
# Name: 121, dtype: object
# Postcode                      M5P
# Borough           Central Toronto
# Neighborhood    Forest Hill North
# Latitude                      NaN
# Longitude                     NaN
# Name: 122, dtype: object
# Postcode                     M5P
# Borough          Central Toronto
# Neighborhood    Forest Hill West
# Latitude                     NaN
# Longitude                    NaN
# Name: 123, dtype: object
# Postcode                 M6P
# Borough         West Toronto
# Neighborhood       High Park
# Latitude                 NaN
# Longitude                NaN
# Name: 124, dtype: object
# Postcode                       M6P
# Borough               West Toronto
# Neighborhood    The Junction South
# Latitude                       NaN
# Longitude                      NaN
# Name: 125, dtype: object
# Postcode              M9P
# Borough         Etobicoke
# Neighborhood    Westmount
# Latitude              NaN
# Longitude             NaN
# Name: 126, dtype: object
# Postcode                M1R
# Borough         Scarborough
# Neighborhood       Maryvale
# Latitude                NaN
# Longitude               NaN
# Name: 127, dtype: object
# Postcode                M1R
# Borough         Scarborough
# Neighborhood        Wexford
# Latitude                NaN
# Longitude               NaN
# Name: 128, dtype: object
# Postcode                    M2R
# Borough              North York
# Neighborhood    Willowdale West
# Latitude                    NaN
# Longitude                   NaN
# Name: 129, dtype: object
# Postcode                       M4R
# Borough            Central Toronto
# Neighborhood    North Toronto West
# Latitude                       NaN
# Longitude                      NaN
# Name: 130, dtype: object
# Postcode                    M5R
# Borough         Central Toronto
# Neighborhood          The Annex
# Latitude                    NaN
# Longitude                   NaN
# Name: 131, dtype: object
# Postcode                    M5R
# Borough         Central Toronto
# Neighborhood      North Midtown
# Latitude                    NaN
# Longitude                   NaN
# Name: 132, dtype: object
# Postcode                    M5R
# Borough         Central Toronto
# Neighborhood          Yorkville
# Latitude                    NaN
# Longitude                   NaN
# Name: 133, dtype: object
# Postcode                 M6R
# Borough         West Toronto
# Neighborhood        Parkdale
# Latitude                 NaN
# Longitude                NaN
# Name: 134, dtype: object
# Postcode                 M6R
# Borough         West Toronto
# Neighborhood    Roncesvalles
# Latitude                 NaN
# Longitude                NaN
# Name: 135, dtype: object
# Postcode                                          M7R
# Borough                                   Mississauga
# Neighborhood    Canada Post Gateway Processing Centre
# Latitude                                          NaN
# Longitude                                         NaN
# Name: 136, dtype: object
# Postcode                      M9R
# Borough                 Etobicoke
# Neighborhood    Kingsview Village
# Latitude                      NaN
# Longitude                     NaN
# Name: 137, dtype: object
# Postcode                         M9R
# Borough                    Etobicoke
# Neighborhood    Martin Grove Gardens
# Latitude                         NaN
# Longitude                        NaN
# Name: 138, dtype: object
# Postcode                     M9R
# Borough                Etobicoke
# Neighborhood    Richview Gardens
# Latitude                     NaN
# Longitude                    NaN
# Name: 139, dtype: object
# Postcode                 M9R
# Borough            Etobicoke
# Neighborhood    St. Phillips
# Latitude                 NaN
# Longitude                NaN
# Name: 140, dtype: object
# Postcode                M1S
# Borough         Scarborough
# Neighborhood      Agincourt
# Latitude                NaN
# Longitude               NaN
# Name: 141, dtype: object
# Postcode                    M4S
# Borough         Central Toronto
# Neighborhood         Davisville
# Latitude                    NaN
# Longitude                   NaN
# Name: 142, dtype: object
# Postcode                     M5S
# Borough         Downtown Toronto
# Neighborhood             Harbord
# Latitude                     NaN
# Longitude                    NaN
# Name: 143, dtype: object
# Postcode                          M5S
# Borough              Downtown Toronto
# Neighborhood    University of Toronto
# Latitude                          NaN
# Longitude                         NaN
# Name: 144, dtype: object
# Postcode                 M6S
# Borough         West Toronto
# Neighborhood       Runnymede
# Latitude                 NaN
# Longitude                NaN
# Name: 145, dtype: object
# Postcode                 M6S
# Borough         West Toronto
# Neighborhood         Swansea
# Latitude                 NaN
# Longitude                NaN
# Name: 146, dtype: object
# Postcode                   M1T
# Borough            Scarborough
# Neighborhood    Clarks Corners
# Latitude                   NaN
# Longitude                  NaN
# Name: 147, dtype: object
# Postcode                M1T
# Borough         Scarborough
# Neighborhood       Sullivan
# Latitude                NaN
# Longitude               NaN
# Name: 148, dtype: object
# Postcode                  M1T
# Borough           Scarborough
# Neighborhood    Tam O'Shanter
# Latitude                  NaN
# Longitude                 NaN
# Name: 149, dtype: object
# Postcode                    M4T
# Borough         Central Toronto
# Neighborhood         Moore Park
# Latitude                    NaN
# Longitude                   NaN
# Name: 150, dtype: object
# Postcode                    M4T
# Borough         Central Toronto
# Neighborhood    Summerhill East
# Latitude                    NaN
# Longitude                   NaN
# Name: 151, dtype: object
# Postcode                     M5T
# Borough         Downtown Toronto
# Neighborhood           Chinatown
# Latitude                     NaN
# Longitude                    NaN
# Name: 152, dtype: object
# Postcode                     M5T
# Borough         Downtown Toronto
# Neighborhood         Grange Park
# Latitude                     NaN
# Longitude                    NaN
# Name: 153, dtype: object
# Postcode                      M5T
# Borough          Downtown Toronto
# Neighborhood    Kensington Market
# Latitude                      NaN
# Longitude                     NaN
# Name: 154, dtype: object
# Postcode                    M1V
# Borough             Scarborough
# Neighborhood    Agincourt North
# Latitude                    NaN
# Longitude                   NaN
# Name: 155, dtype: object
# Postcode                    M1V
# Borough             Scarborough
# Neighborhood    L'Amoreaux East
# Latitude                    NaN
# Longitude                   NaN
# Name: 156, dtype: object
# Postcode                M1V
# Borough         Scarborough
# Neighborhood       Milliken
# Latitude                NaN
# Longitude               NaN
# Name: 157, dtype: object
# Postcode                 M1V
# Borough          Scarborough
# Neighborhood    Steeles East
# Latitude                 NaN
# Longitude                NaN
# Name: 158, dtype: object
# Postcode                    M4V
# Borough         Central Toronto
# Neighborhood          Deer Park
# Latitude                    NaN
# Longitude                   NaN
# Name: 159, dtype: object
# Postcode                    M4V
# Borough         Central Toronto
# Neighborhood     Forest Hill SE
# Latitude                    NaN
# Longitude                   NaN
# Name: 160, dtype: object
# Postcode                    M4V
# Borough         Central Toronto
# Neighborhood          Rathnelly
# Latitude                    NaN
# Longitude                   NaN
# Name: 161, dtype: object
# Postcode                    M4V
# Borough         Central Toronto
# Neighborhood         South Hill
# Latitude                    NaN
# Longitude                   NaN
# Name: 162, dtype: object
# Postcode                    M4V
# Borough         Central Toronto
# Neighborhood    Summerhill West
# Latitude                    NaN
# Longitude                   NaN
# Name: 163, dtype: object
# Postcode                     M5V
# Borough         Downtown Toronto
# Neighborhood            CN Tower
# Latitude                     NaN
# Longitude                    NaN
# Name: 164, dtype: object
# Postcode                     M5V
# Borough         Downtown Toronto
# Neighborhood       Bathurst Quay
# Latitude                     NaN
# Longitude                    NaN
# Name: 165, dtype: object
# Postcode                     M5V
# Borough         Downtown Toronto
# Neighborhood      Island airport
# Latitude                     NaN
# Longitude                    NaN
# Name: 166, dtype: object
# Postcode                      M5V
# Borough          Downtown Toronto
# Neighborhood    Harbourfront West
# Latitude                      NaN
# Longitude                     NaN
# Name: 167, dtype: object
# Postcode                     M5V
# Borough         Downtown Toronto
# Neighborhood    King and Spadina
# Latitude                     NaN
# Longitude                    NaN
# Name: 168, dtype: object
# Postcode                     M5V
# Borough         Downtown Toronto
# Neighborhood       Railway Lands
# Latitude                     NaN
# Longitude                    NaN
# Name: 169, dtype: object
# Postcode                     M5V
# Borough         Downtown Toronto
# Neighborhood       South Niagara
# Latitude                     NaN
# Longitude                    NaN
# Name: 170, dtype: object
# Postcode                      M8V
# Borough                 Etobicoke
# Neighborhood    Humber Bay Shores
# Latitude                      NaN
# Longitude                     NaN
# Name: 171, dtype: object
# Postcode                 M8V
# Borough            Etobicoke
# Neighborhood    Mimico South
# Latitude                 NaN
# Longitude                NaN
# Name: 172, dtype: object
# Postcode                M8V
# Borough           Etobicoke
# Neighborhood    New Toronto
# Latitude                NaN
# Longitude               NaN
# Name: 173, dtype: object
# Postcode                   M9V
# Borough              Etobicoke
# Neighborhood    Albion Gardens
# Latitude                   NaN
# Longitude                  NaN
# Name: 174, dtype: object
# Postcode                     M9V
# Borough                Etobicoke
# Neighborhood    Beaumond Heights
# Latitude                     NaN
# Longitude                    NaN
# Name: 175, dtype: object
# Postcode               M9V
# Borough          Etobicoke
# Neighborhood    Humbergate
# Latitude               NaN
# Longitude              NaN
# Name: 176, dtype: object
# Postcode              M9V
# Borough         Etobicoke
# Neighborhood    Jamestown
# Latitude              NaN
# Longitude             NaN
# Name: 177, dtype: object
# Postcode                M9V
# Borough           Etobicoke
# Neighborhood    Mount Olive
# Latitude                NaN
# Longitude               NaN
# Name: 178, dtype: object
# Postcode                M9V
# Borough           Etobicoke
# Neighborhood    Silverstone
# Latitude                NaN
# Longitude               NaN
# Name: 179, dtype: object
# Postcode                  M9V
# Borough             Etobicoke
# Neighborhood    South Steeles
# Latitude                  NaN
# Longitude                 NaN
# Name: 180, dtype: object
# Postcode                M9V
# Borough           Etobicoke
# Neighborhood    Thistletown
# Latitude                NaN
# Longitude               NaN
# Name: 181, dtype: object
# Postcode                    M1W
# Borough             Scarborough
# Neighborhood    L'Amoreaux West
# Latitude                    NaN
# Longitude                   NaN
# Name: 182, dtype: object
# Postcode                     M4W
# Borough         Downtown Toronto
# Neighborhood            Rosedale
# Latitude                     NaN
# Longitude                    NaN
# Name: 183, dtype: object
# Postcode                                    M5W
# Borough                        Downtown Toronto
# Neighborhood    Stn A PO Boxes 25 The Esplanade
# Latitude                                    NaN
# Longitude                                   NaN
# Name: 184, dtype: object
# Postcode              M8W
# Borough         Etobicoke
# Neighborhood    Alderwood
# Latitude              NaN
# Longitude             NaN
# Name: 185, dtype: object
# Postcode                M8W
# Borough           Etobicoke
# Neighborhood    Long Branch
# Latitude                NaN
# Longitude               NaN
# Name: 186, dtype: object
# Postcode              M9W
# Borough         Etobicoke
# Neighborhood    Northwest
# Latitude              NaN
# Longitude             NaN
# Name: 187, dtype: object
# Postcode                M1X
# Borough         Scarborough
# Neighborhood    Upper Rouge
# Latitude                NaN
# Longitude               NaN
# Name: 188, dtype: object
# Postcode                     M4X
# Borough         Downtown Toronto
# Neighborhood         Cabbagetown
# Latitude                     NaN
# Longitude                    NaN
# Name: 189, dtype: object
# Postcode                     M4X
# Borough         Downtown Toronto
# Neighborhood      St. James Town
# Latitude                     NaN
# Longitude                    NaN
# Name: 190, dtype: object
# Postcode                         M5X
# Borough             Downtown Toronto
# Neighborhood    First Canadian Place
# Latitude                         NaN
# Longitude                        NaN
# Name: 191, dtype: object
# Postcode                     M5X
# Borough         Downtown Toronto
# Neighborhood    Underground city
# Latitude                     NaN
# Longitude                    NaN
# Name: 192, dtype: object
# Postcode                 M8X
# Borough            Etobicoke
# Neighborhood    The Kingsway
# Latitude                 NaN
# Longitude                NaN
# Name: 193, dtype: object
# Postcode                    M8X
# Borough               Etobicoke
# Neighborhood    Montgomery Road
# Latitude                    NaN
# Longitude                   NaN
# Name: 194, dtype: object
# Postcode                   M8X
# Borough              Etobicoke
# Neighborhood    Old Mill North
# Latitude                   NaN
# Longitude                  NaN
# Name: 195, dtype: object
# Postcode                         M4Y
# Borough             Downtown Toronto
# Neighborhood    Church and Wellesley
# Latitude                         NaN
# Longitude                        NaN
# Name: 196, dtype: object
# Postcode                                                      M7Y
# Borough                                              East Toronto
# Neighborhood    Business Reply Mail Processing Centre 969 Eastern
# Latitude                                                      NaN
# Longitude                                                     NaN
# Name: 197, dtype: object
# Postcode               M8Y
# Borough          Etobicoke
# Neighborhood    Humber Bay
# Latitude               NaN
# Longitude              NaN
# Name: 198, dtype: object
# Postcode                     M8Y
# Borough                Etobicoke
# Neighborhood    King's Mill Park
# Latitude                     NaN
# Longitude                    NaN
# Name: 199, dtype: object
# Postcode                             M8Y
# Borough                        Etobicoke
# Neighborhood    Kingsway Park South East
# Latitude                             NaN
# Longitude                            NaN
# Name: 200, dtype: object
# Postcode              M8Y
# Borough         Etobicoke
# Neighborhood    Mimico NE
# Latitude              NaN
# Longitude             NaN
# Name: 201, dtype: object
# Postcode                   M8Y
# Borough              Etobicoke
# Neighborhood    Old Mill South
# Latitude                   NaN
# Longitude                  NaN
# Name: 202, dtype: object
# Postcode                       M8Y
# Borough                  Etobicoke
# Neighborhood    The Queensway East
# Latitude                       NaN
# Longitude                      NaN
# Name: 203, dtype: object
# Postcode                          M8Y
# Borough                     Etobicoke
# Neighborhood    Royal York South East
# Latitude                          NaN
# Longitude                         NaN
# Name: 204, dtype: object
# Postcode              M8Y
# Borough         Etobicoke
# Neighborhood     Sunnylea
# Latitude              NaN
# Longitude             NaN
# Name: 205, dtype: object
# Postcode                             M8Z
# Borough                        Etobicoke
# Neighborhood    Kingsway Park South West
# Latitude                             NaN
# Longitude                            NaN
# Name: 206, dtype: object
# Postcode              M8Z
# Borough         Etobicoke
# Neighborhood    Mimico NW
# Latitude              NaN
# Longitude             NaN
# Name: 207, dtype: object
# Postcode                       M8Z
# Borough                  Etobicoke
# Neighborhood    The Queensway West
# Latitude                       NaN
# Longitude                      NaN
# Name: 208, dtype: object
# Postcode                          M8Z
# Borough                     Etobicoke
# Neighborhood    Royal York South West
# Latitude                          NaN
# Longitude                         NaN
# Name: 209, dtype: object
# Postcode                   M8Z
# Borough              Etobicoke
# Neighborhood    South of Bloor
# Latitude                   NaN
# Longitude                  NaN
# Name: 210, dtype: object

# %%
for i in hoods_ll.index:
	# print(hoods_ll.iloc[i])
	# set postal code
	postal_code = hoods_ll.loc[i, 'Postcode']
	print(postal_code)
# Out:
# M3A
# M4A
# M5A
# M5A
# M6A
# M6A
# M7A
# M9A
# M1B
# M1B
# M3B
# M4B
# M4B
# M5B
# M5B
# M6B
# M9B
# M9B
# M9B
# M9B
# M9B
# M1C
# M1C
# M1C
# M3C
# M3C
# M4C
# M5C
# M6C
# M9C
# M9C
# M9C
# M9C
# M1E
# M1E
# M1E
# M4E
# M5E
# M6E
# M1G
# M4G
# M5G
# M6G
# M1H
# M2H
# M3H
# M3H
# M3H
# M4H
# M5H
# M5H
# M5H
# M6H
# M6H
# M1J
# M2J
# M2J
# M2J
# M3J
# M3J
# M4J
# M5J
# M5J
# M5J
# M6J
# M6J
# M1K
# M1K
# M1K
# M2K
# M3K
# M3K
# M4K
# M4K
# M5K
# M5K
# M6K
# M6K
# M6K
# M1L
# M1L
# M1L
# M2L
# M2L
# M3L
# M4L
# M4L
# M5L
# M5L
# M6L
# M6L
# M6L
# M9L
# M1M
# M1M
# M1M
# M2M
# M2M
# M3M
# M4M
# M5M
# M5M
# M6M
# M6M
# M6M
# M6M
# M9M
# M9M
# M1N
# M1N
# M2N
# M3N
# M4N
# M5N
# M6N
# M6N
# M9N
# M1P
# M1P
# M1P
# M2P
# M4P
# M5P
# M5P
# M6P
# M6P
# M9P
# M1R
# M1R
# M2R
# M4R
# M5R
# M5R
# M5R
# M6R
# M6R
# M7R
# M9R
# M9R
# M9R
# M9R
# M1S
# M4S
# M5S
# M5S
# M6S
# M6S
# M1T
# M1T
# M1T
# M4T
# M4T
# M5T
# M5T
# M5T
# M1V
# M1V
# M1V
# M1V
# M4V
# M4V
# M4V
# M4V
# M4V
# M5V
# M5V
# M5V
# M5V
# M5V
# M5V
# M5V
# M8V
# M8V
# M8V
# M9V
# M9V
# M9V
# M9V
# M9V
# M9V
# M9V
# M9V
# M1W
# M4W
# M5W
# M8W
# M8W
# M9W
# M1X
# M4X
# M4X
# M5X
# M5X
# M8X
# M8X
# M8X
# M4Y
# M7Y
# M8Y
# M8Y
# M8Y
# M8Y
# M8Y
# M8Y
# M8Y
# M8Y
# M8Z
# M8Z
# M8Z
# M8Z
# M8Z

# %%
for i in hoods_ll.index:
	# print(hoods_ll.iloc[i])
	# set postal code
	postal_code = hoods_ll.loc[i, 'Postcode']
	print(postal_code)
	
	pc_row = geo_df.loc[geo_df['Postal Code'] == postal_code]
	print(pc_row)
# Out:
# M3A
#    Postal Code   Latitude  Longitude
# 25         M3A  43.753259 -79.329656
# M4A
#    Postal Code   Latitude  Longitude
# 34         M4A  43.725882 -79.315572
# M5A
#    Postal Code  Latitude  Longitude
# 53         M5A  43.65426 -79.360636
# M5A
#    Postal Code  Latitude  Longitude
# 53         M5A  43.65426 -79.360636
# M6A
#    Postal Code   Latitude  Longitude
# 71         M6A  43.718518 -79.464763
# M6A
#    Postal Code   Latitude  Longitude
# 71         M6A  43.718518 -79.464763
# M7A
#    Postal Code   Latitude  Longitude
# 85         M7A  43.662301 -79.389494
# M9A
#    Postal Code   Latitude  Longitude
# 93         M9A  43.667856 -79.532242
# M1B
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# M1B
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# M3B
#    Postal Code   Latitude  Longitude
# 26         M3B  43.745906 -79.352188
# M4B
#    Postal Code   Latitude  Longitude
# 35         M4B  43.706397 -79.309937
# M4B
#    Postal Code   Latitude  Longitude
# 35         M4B  43.706397 -79.309937
# M5B
#    Postal Code   Latitude  Longitude
# 54         M5B  43.657162 -79.378937
# M5B
#    Postal Code   Latitude  Longitude
# 54         M5B  43.657162 -79.378937
# M6B
#    Postal Code   Latitude  Longitude
# 72         M6B  43.709577 -79.445073
# M9B
#    Postal Code   Latitude  Longitude
# 94         M9B  43.650943 -79.554724
# M9B
#    Postal Code   Latitude  Longitude
# 94         M9B  43.650943 -79.554724
# M9B
#    Postal Code   Latitude  Longitude
# 94         M9B  43.650943 -79.554724
# M9B
#    Postal Code   Latitude  Longitude
# 94         M9B  43.650943 -79.554724
# M9B
#    Postal Code   Latitude  Longitude
# 94         M9B  43.650943 -79.554724
# M1C
#   Postal Code   Latitude  Longitude
# 1         M1C  43.784535 -79.160497
# M1C
#   Postal Code   Latitude  Longitude
# 1         M1C  43.784535 -79.160497
# M1C
#   Postal Code   Latitude  Longitude
# 1         M1C  43.784535 -79.160497
# M3C
#    Postal Code  Latitude  Longitude
# 27         M3C   43.7259 -79.340923
# M3C
#    Postal Code  Latitude  Longitude
# 27         M3C   43.7259 -79.340923
# M4C
#    Postal Code   Latitude  Longitude
# 36         M4C  43.695344 -79.318389
# M5C
#    Postal Code   Latitude  Longitude
# 55         M5C  43.651494 -79.375418
# M6C
#    Postal Code   Latitude  Longitude
# 73         M6C  43.693781 -79.428191
# M9C
#    Postal Code   Latitude  Longitude
# 95         M9C  43.643515 -79.577201
# M9C
#    Postal Code   Latitude  Longitude
# 95         M9C  43.643515 -79.577201
# M9C
#    Postal Code   Latitude  Longitude
# 95         M9C  43.643515 -79.577201
# M9C
#    Postal Code   Latitude  Longitude
# 95         M9C  43.643515 -79.577201
# M1E
#   Postal Code   Latitude  Longitude
# 2         M1E  43.763573 -79.188711
# M1E
#   Postal Code   Latitude  Longitude
# 2         M1E  43.763573 -79.188711
# M1E
#   Postal Code   Latitude  Longitude
# 2         M1E  43.763573 -79.188711
# M4E
#    Postal Code   Latitude  Longitude
# 37         M4E  43.676357 -79.293031
# M5E
#    Postal Code   Latitude  Longitude
# 56         M5E  43.644771 -79.373306
# M6E
#    Postal Code   Latitude  Longitude
# 74         M6E  43.689026 -79.453512
# M1G
#   Postal Code   Latitude  Longitude
# 3         M1G  43.770992 -79.216917
# M4G
#    Postal Code  Latitude  Longitude
# 38         M4G  43.70906 -79.363452
# M5G
#    Postal Code   Latitude  Longitude
# 57         M5G  43.657952 -79.387383
# M6G
#    Postal Code   Latitude  Longitude
# 75         M6G  43.669542 -79.422564
# M1H
#   Postal Code   Latitude  Longitude
# 4         M1H  43.773136 -79.239476
# M2H
#    Postal Code   Latitude  Longitude
# 17         M2H  43.803762 -79.363452
# M3H
#    Postal Code   Latitude  Longitude
# 28         M3H  43.754328 -79.442259
# M3H
#    Postal Code   Latitude  Longitude
# 28         M3H  43.754328 -79.442259
# M3H
#    Postal Code   Latitude  Longitude
# 28         M3H  43.754328 -79.442259
# M4H
#    Postal Code   Latitude  Longitude
# 39         M4H  43.705369 -79.349372
# M5H
#    Postal Code   Latitude  Longitude
# 58         M5H  43.650571 -79.384568
# M5H
#    Postal Code   Latitude  Longitude
# 58         M5H  43.650571 -79.384568
# M5H
#    Postal Code   Latitude  Longitude
# 58         M5H  43.650571 -79.384568
# M6H
#    Postal Code   Latitude  Longitude
# 76         M6H  43.669005 -79.442259
# M6H
#    Postal Code   Latitude  Longitude
# 76         M6H  43.669005 -79.442259
# M1J
#   Postal Code   Latitude  Longitude
# 5         M1J  43.744734 -79.239476
# M2J
#    Postal Code   Latitude  Longitude
# 18         M2J  43.778517 -79.346556
# M2J
#    Postal Code   Latitude  Longitude
# 18         M2J  43.778517 -79.346556
# M2J
#    Postal Code   Latitude  Longitude
# 18         M2J  43.778517 -79.346556
# M3J
#    Postal Code  Latitude  Longitude
# 29         M3J  43.76798 -79.487262
# M3J
#    Postal Code  Latitude  Longitude
# 29         M3J  43.76798 -79.487262
# M4J
#    Postal Code   Latitude  Longitude
# 40         M4J  43.685347 -79.338106
# M5J
#    Postal Code   Latitude  Longitude
# 59         M5J  43.640816 -79.381752
# M5J
#    Postal Code   Latitude  Longitude
# 59         M5J  43.640816 -79.381752
# M5J
#    Postal Code   Latitude  Longitude
# 59         M5J  43.640816 -79.381752
# M6J
#    Postal Code   Latitude  Longitude
# 77         M6J  43.647927  -79.41975
# M6J
#    Postal Code   Latitude  Longitude
# 77         M6J  43.647927  -79.41975
# M1K
#   Postal Code   Latitude  Longitude
# 6         M1K  43.727929 -79.262029
# M1K
#   Postal Code   Latitude  Longitude
# 6         M1K  43.727929 -79.262029
# M1K
#   Postal Code   Latitude  Longitude
# 6         M1K  43.727929 -79.262029
# M2K
#    Postal Code   Latitude  Longitude
# 19         M2K  43.786947 -79.385975
# M3K
#    Postal Code   Latitude  Longitude
# 30         M3K  43.737473 -79.464763
# M3K
#    Postal Code   Latitude  Longitude
# 30         M3K  43.737473 -79.464763
# M4K
#    Postal Code   Latitude  Longitude
# 41         M4K  43.679557 -79.352188
# M4K
#    Postal Code   Latitude  Longitude
# 41         M4K  43.679557 -79.352188
# M5K
#    Postal Code   Latitude  Longitude
# 60         M5K  43.647177 -79.381576
# M5K
#    Postal Code   Latitude  Longitude
# 60         M5K  43.647177 -79.381576
# M6K
#    Postal Code   Latitude  Longitude
# 78         M6K  43.636847 -79.428191
# M6K
#    Postal Code   Latitude  Longitude
# 78         M6K  43.636847 -79.428191
# M6K
#    Postal Code   Latitude  Longitude
# 78         M6K  43.636847 -79.428191
# M1L
#   Postal Code   Latitude  Longitude
# 7         M1L  43.711112 -79.284577
# M1L
#   Postal Code   Latitude  Longitude
# 7         M1L  43.711112 -79.284577
# M1L
#   Postal Code   Latitude  Longitude
# 7         M1L  43.711112 -79.284577
# M2L
#    Postal Code  Latitude  Longitude
# 20         M2L  43.75749 -79.374714
# M2L
#    Postal Code  Latitude  Longitude
# 20         M2L  43.75749 -79.374714
# M3L
#    Postal Code   Latitude  Longitude
# 31         M3L  43.739015 -79.506944
# M4L
#    Postal Code   Latitude  Longitude
# 42         M4L  43.668999 -79.315572
# M4L
#    Postal Code   Latitude  Longitude
# 42         M4L  43.668999 -79.315572
# M5L
#    Postal Code   Latitude  Longitude
# 61         M5L  43.648198 -79.379817
# M5L
#    Postal Code   Latitude  Longitude
# 61         M5L  43.648198 -79.379817
# M6L
#    Postal Code   Latitude  Longitude
# 79         M6L  43.713756 -79.490074
# M6L
#    Postal Code   Latitude  Longitude
# 79         M6L  43.713756 -79.490074
# M6L
#    Postal Code   Latitude  Longitude
# 79         M6L  43.713756 -79.490074
# M9L
#    Postal Code   Latitude  Longitude
# 96         M9L  43.756303 -79.565963
# M1M
#   Postal Code   Latitude  Longitude
# 8         M1M  43.716316 -79.239476
# M1M
#   Postal Code   Latitude  Longitude
# 8         M1M  43.716316 -79.239476
# M1M
#   Postal Code   Latitude  Longitude
# 8         M1M  43.716316 -79.239476
# M2M
#    Postal Code   Latitude  Longitude
# 21         M2M  43.789053 -79.408493
# M2M
#    Postal Code   Latitude  Longitude
# 21         M2M  43.789053 -79.408493
# M3M
#    Postal Code   Latitude  Longitude
# 32         M3M  43.728496 -79.495697
# M4M
#    Postal Code   Latitude  Longitude
# 43         M4M  43.659526 -79.340923
# M5M
#    Postal Code   Latitude  Longitude
# 62         M5M  43.733283  -79.41975
# M5M
#    Postal Code   Latitude  Longitude
# 62         M5M  43.733283  -79.41975
# M6M
#    Postal Code   Latitude  Longitude
# 80         M6M  43.691116 -79.476013
# M6M
#    Postal Code   Latitude  Longitude
# 80         M6M  43.691116 -79.476013
# M6M
#    Postal Code   Latitude  Longitude
# 80         M6M  43.691116 -79.476013
# M6M
#    Postal Code   Latitude  Longitude
# 80         M6M  43.691116 -79.476013
# M9M
#    Postal Code   Latitude  Longitude
# 97         M9M  43.724766 -79.532242
# M9M
#    Postal Code   Latitude  Longitude
# 97         M9M  43.724766 -79.532242
# M1N
#   Postal Code   Latitude  Longitude
# 9         M1N  43.692657 -79.264848
# M1N
#   Postal Code   Latitude  Longitude
# 9         M1N  43.692657 -79.264848
# M2N
#    Postal Code  Latitude  Longitude
# 22         M2N  43.77012 -79.408493
# M3N
#    Postal Code   Latitude  Longitude
# 33         M3N  43.761631 -79.520999
# M4N
#    Postal Code  Latitude  Longitude
# 44         M4N  43.72802  -79.38879
# M5N
#    Postal Code   Latitude  Longitude
# 63         M5N  43.711695 -79.416936
# M6N
#    Postal Code   Latitude  Longitude
# 81         M6N  43.673185 -79.487262
# M6N
#    Postal Code   Latitude  Longitude
# 81         M6N  43.673185 -79.487262
# M9N
#    Postal Code   Latitude  Longitude
# 98         M9N  43.706876 -79.518188
# M1P
#    Postal Code  Latitude  Longitude
# 10         M1P  43.75741 -79.273304
# M1P
#    Postal Code  Latitude  Longitude
# 10         M1P  43.75741 -79.273304
# M1P
#    Postal Code  Latitude  Longitude
# 10         M1P  43.75741 -79.273304
# M2P
#    Postal Code   Latitude  Longitude
# 23         M2P  43.752758 -79.400049
# M4P
#    Postal Code   Latitude  Longitude
# 45         M4P  43.712751 -79.390197
# M5P
#    Postal Code   Latitude  Longitude
# 64         M5P  43.696948 -79.411307
# M5P
#    Postal Code   Latitude  Longitude
# 64         M5P  43.696948 -79.411307
# M6P
#    Postal Code   Latitude  Longitude
# 82         M6P  43.661608 -79.464763
# M6P
#    Postal Code   Latitude  Longitude
# 82         M6P  43.661608 -79.464763
# M9P
#    Postal Code   Latitude  Longitude
# 99         M9P  43.696319 -79.532242
# M1R
#    Postal Code   Latitude  Longitude
# 11         M1R  43.750072 -79.295849
# M1R
#    Postal Code   Latitude  Longitude
# 11         M1R  43.750072 -79.295849
# M2R
#    Postal Code   Latitude  Longitude
# 24         M2R  43.782736 -79.442259
# M4R
#    Postal Code   Latitude  Longitude
# 46         M4R  43.715383 -79.405678
# M5R
#    Postal Code  Latitude  Longitude
# 65         M5R  43.67271 -79.405678
# M5R
#    Postal Code  Latitude  Longitude
# 65         M5R  43.67271 -79.405678
# M5R
#    Postal Code  Latitude  Longitude
# 65         M5R  43.67271 -79.405678
# M6R
#    Postal Code  Latitude  Longitude
# 83         M6R  43.64896 -79.456325
# M6R
#    Postal Code  Latitude  Longitude
# 83         M6R  43.64896 -79.456325
# M7R
#    Postal Code   Latitude  Longitude
# 86         M7R  43.636966 -79.615819
# M9R
#     Postal Code   Latitude  Longitude
# 100         M9R  43.688905 -79.554724
# M9R
#     Postal Code   Latitude  Longitude
# 100         M9R  43.688905 -79.554724
# M9R
#     Postal Code   Latitude  Longitude
# 100         M9R  43.688905 -79.554724
# M9R
#     Postal Code   Latitude  Longitude
# 100         M9R  43.688905 -79.554724
# M1S
#    Postal Code  Latitude  Longitude
# 12         M1S   43.7942 -79.262029
# M4S
#    Postal Code   Latitude  Longitude
# 47         M4S  43.704324  -79.38879
# M5S
#    Postal Code   Latitude  Longitude
# 66         M5S  43.662696 -79.400049
# M5S
#    Postal Code   Latitude  Longitude
# 66         M5S  43.662696 -79.400049
# M6S
#    Postal Code   Latitude  Longitude
# 84         M6S  43.651571  -79.48445
# M6S
#    Postal Code   Latitude  Longitude
# 84         M6S  43.651571  -79.48445
# M1T
#    Postal Code   Latitude  Longitude
# 13         M1T  43.781638 -79.304302
# M1T
#    Postal Code   Latitude  Longitude
# 13         M1T  43.781638 -79.304302
# M1T
#    Postal Code   Latitude  Longitude
# 13         M1T  43.781638 -79.304302
# M4T
#    Postal Code   Latitude  Longitude
# 48         M4T  43.689574  -79.38316
# M4T
#    Postal Code   Latitude  Longitude
# 48         M4T  43.689574  -79.38316
# M5T
#    Postal Code   Latitude  Longitude
# 67         M5T  43.653206 -79.400049
# M5T
#    Postal Code   Latitude  Longitude
# 67         M5T  43.653206 -79.400049
# M5T
#    Postal Code   Latitude  Longitude
# 67         M5T  43.653206 -79.400049
# M1V
#    Postal Code   Latitude  Longitude
# 14         M1V  43.815252 -79.284577
# M1V
#    Postal Code   Latitude  Longitude
# 14         M1V  43.815252 -79.284577
# M1V
#    Postal Code   Latitude  Longitude
# 14         M1V  43.815252 -79.284577
# M1V
#    Postal Code   Latitude  Longitude
# 14         M1V  43.815252 -79.284577
# M4V
#    Postal Code   Latitude  Longitude
# 49         M4V  43.686412 -79.400049
# M4V
#    Postal Code   Latitude  Longitude
# 49         M4V  43.686412 -79.400049
# M4V
#    Postal Code   Latitude  Longitude
# 49         M4V  43.686412 -79.400049
# M4V
#    Postal Code   Latitude  Longitude
# 49         M4V  43.686412 -79.400049
# M4V
#    Postal Code   Latitude  Longitude
# 49         M4V  43.686412 -79.400049
# M5V
#    Postal Code   Latitude  Longitude
# 68         M5V  43.628947  -79.39442
# M5V
#    Postal Code   Latitude  Longitude
# 68         M5V  43.628947  -79.39442
# M5V
#    Postal Code   Latitude  Longitude
# 68         M5V  43.628947  -79.39442
# M5V
#    Postal Code   Latitude  Longitude
# 68         M5V  43.628947  -79.39442
# M5V
#    Postal Code   Latitude  Longitude
# 68         M5V  43.628947  -79.39442
# M5V
#    Postal Code   Latitude  Longitude
# 68         M5V  43.628947  -79.39442
# M5V
#    Postal Code   Latitude  Longitude
# 68         M5V  43.628947  -79.39442
# M8V
#    Postal Code   Latitude  Longitude
# 88         M8V  43.605647 -79.501321
# M8V
#    Postal Code   Latitude  Longitude
# 88         M8V  43.605647 -79.501321
# M8V
#    Postal Code   Latitude  Longitude
# 88         M8V  43.605647 -79.501321
# M9V
#     Postal Code   Latitude  Longitude
# 101         M9V  43.739416 -79.588437
# M9V
#     Postal Code   Latitude  Longitude
# 101         M9V  43.739416 -79.588437
# M9V
#     Postal Code   Latitude  Longitude
# 101         M9V  43.739416 -79.588437
# M9V
#     Postal Code   Latitude  Longitude
# 101         M9V  43.739416 -79.588437
# M9V
#     Postal Code   Latitude  Longitude
# 101         M9V  43.739416 -79.588437
# M9V
#     Postal Code   Latitude  Longitude
# 101         M9V  43.739416 -79.588437
# M9V
#     Postal Code   Latitude  Longitude
# 101         M9V  43.739416 -79.588437
# M9V
#     Postal Code   Latitude  Longitude
# 101         M9V  43.739416 -79.588437
# M1W
#    Postal Code   Latitude  Longitude
# 15         M1W  43.799525 -79.318389
# M4W
#    Postal Code   Latitude  Longitude
# 50         M4W  43.679563 -79.377529
# M5W
#    Postal Code   Latitude  Longitude
# 69         M5W  43.646435 -79.374846
# M8W
#    Postal Code   Latitude  Longitude
# 89         M8W  43.602414 -79.543484
# M8W
#    Postal Code   Latitude  Longitude
# 89         M8W  43.602414 -79.543484
# M9W
#     Postal Code   Latitude  Longitude
# 102         M9W  43.706748 -79.594054
# M1X
#    Postal Code   Latitude  Longitude
# 16         M1X  43.836125 -79.205636
# M4X
#    Postal Code   Latitude  Longitude
# 51         M4X  43.667967 -79.367675
# M4X
#    Postal Code   Latitude  Longitude
# 51         M4X  43.667967 -79.367675
# M5X
#    Postal Code   Latitude  Longitude
# 70         M5X  43.648429  -79.38228
# M5X
#    Postal Code   Latitude  Longitude
# 70         M5X  43.648429  -79.38228
# M8X
#    Postal Code   Latitude  Longitude
# 90         M8X  43.653654 -79.506944
# M8X
#    Postal Code   Latitude  Longitude
# 90         M8X  43.653654 -79.506944
# M8X
#    Postal Code   Latitude  Longitude
# 90         M8X  43.653654 -79.506944
# M4Y
#    Postal Code  Latitude  Longitude
# 52         M4Y  43.66586  -79.38316
# M7Y
#    Postal Code   Latitude  Longitude
# 87         M7Y  43.662744 -79.321558
# M8Y
#    Postal Code   Latitude  Longitude
# 91         M8Y  43.636258 -79.498509
# M8Y
#    Postal Code   Latitude  Longitude
# 91         M8Y  43.636258 -79.498509
# M8Y
#    Postal Code   Latitude  Longitude
# 91         M8Y  43.636258 -79.498509
# M8Y
#    Postal Code   Latitude  Longitude
# 91         M8Y  43.636258 -79.498509
# M8Y
#    Postal Code   Latitude  Longitude
# 91         M8Y  43.636258 -79.498509
# M8Y
#    Postal Code   Latitude  Longitude
# 91         M8Y  43.636258 -79.498509
# M8Y
#    Postal Code   Latitude  Longitude
# 91         M8Y  43.636258 -79.498509
# M8Y
#    Postal Code   Latitude  Longitude
# 91         M8Y  43.636258 -79.498509
# M8Z
#    Postal Code   Latitude  Longitude
# 92         M8Z  43.628841 -79.520999
# M8Z
#    Postal Code   Latitude  Longitude
# 92         M8Z  43.628841 -79.520999
# M8Z
#    Postal Code   Latitude  Longitude
# 92         M8Z  43.628841 -79.520999
# M8Z
#    Postal Code   Latitude  Longitude
# 92         M8Z  43.628841 -79.520999
# M8Z
#    Postal Code   Latitude  Longitude
# 92         M8Z  43.628841 -79.520999

# %%
for i in hoods_ll.index:
	# print(hoods_ll.iloc[i])
	# set postal code
	postal_code = hoods_ll.loc[i, 'Postcode']
	print(postal_code)
	
	pc_row = geo_df.loc[geo_df['Postal Code'] == postal_code]
	print(pc_row['Latitude'])
# Out:
# M3A
# 25    43.753259
# Name: Latitude, dtype: float64
# M4A
# 34    43.725882
# Name: Latitude, dtype: float64
# M5A
# 53    43.65426
# Name: Latitude, dtype: float64
# M5A
# 53    43.65426
# Name: Latitude, dtype: float64
# M6A
# 71    43.718518
# Name: Latitude, dtype: float64
# M6A
# 71    43.718518
# Name: Latitude, dtype: float64
# M7A
# 85    43.662301
# Name: Latitude, dtype: float64
# M9A
# 93    43.667856
# Name: Latitude, dtype: float64
# M1B
# 0    43.806686
# Name: Latitude, dtype: float64
# M1B
# 0    43.806686
# Name: Latitude, dtype: float64
# M3B
# 26    43.745906
# Name: Latitude, dtype: float64
# M4B
# 35    43.706397
# Name: Latitude, dtype: float64
# M4B
# 35    43.706397
# Name: Latitude, dtype: float64
# M5B
# 54    43.657162
# Name: Latitude, dtype: float64
# M5B
# 54    43.657162
# Name: Latitude, dtype: float64
# M6B
# 72    43.709577
# Name: Latitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# M1C
# 1    43.784535
# Name: Latitude, dtype: float64
# M1C
# 1    43.784535
# Name: Latitude, dtype: float64
# M1C
# 1    43.784535
# Name: Latitude, dtype: float64
# M3C
# 27    43.7259
# Name: Latitude, dtype: float64
# M3C
# 27    43.7259
# Name: Latitude, dtype: float64
# M4C
# 36    43.695344
# Name: Latitude, dtype: float64
# M5C
# 55    43.651494
# Name: Latitude, dtype: float64
# M6C
# 73    43.693781
# Name: Latitude, dtype: float64
# M9C
# 95    43.643515
# Name: Latitude, dtype: float64
# M9C
# 95    43.643515
# Name: Latitude, dtype: float64
# M9C
# 95    43.643515
# Name: Latitude, dtype: float64
# M9C
# 95    43.643515
# Name: Latitude, dtype: float64
# M1E
# 2    43.763573
# Name: Latitude, dtype: float64
# M1E
# 2    43.763573
# Name: Latitude, dtype: float64
# M1E
# 2    43.763573
# Name: Latitude, dtype: float64
# M4E
# 37    43.676357
# Name: Latitude, dtype: float64
# M5E
# 56    43.644771
# Name: Latitude, dtype: float64
# M6E
# 74    43.689026
# Name: Latitude, dtype: float64
# M1G
# 3    43.770992
# Name: Latitude, dtype: float64
# M4G
# 38    43.70906
# Name: Latitude, dtype: float64
# M5G
# 57    43.657952
# Name: Latitude, dtype: float64
# M6G
# 75    43.669542
# Name: Latitude, dtype: float64
# M1H
# 4    43.773136
# Name: Latitude, dtype: float64
# M2H
# 17    43.803762
# Name: Latitude, dtype: float64
# M3H
# 28    43.754328
# Name: Latitude, dtype: float64
# M3H
# 28    43.754328
# Name: Latitude, dtype: float64
# M3H
# 28    43.754328
# Name: Latitude, dtype: float64
# M4H
# 39    43.705369
# Name: Latitude, dtype: float64
# M5H
# 58    43.650571
# Name: Latitude, dtype: float64
# M5H
# 58    43.650571
# Name: Latitude, dtype: float64
# M5H
# 58    43.650571
# Name: Latitude, dtype: float64
# M6H
# 76    43.669005
# Name: Latitude, dtype: float64
# M6H
# 76    43.669005
# Name: Latitude, dtype: float64
# M1J
# 5    43.744734
# Name: Latitude, dtype: float64
# M2J
# 18    43.778517
# Name: Latitude, dtype: float64
# M2J
# 18    43.778517
# Name: Latitude, dtype: float64
# M2J
# 18    43.778517
# Name: Latitude, dtype: float64
# M3J
# 29    43.76798
# Name: Latitude, dtype: float64
# M3J
# 29    43.76798
# Name: Latitude, dtype: float64
# M4J
# 40    43.685347
# Name: Latitude, dtype: float64
# M5J
# 59    43.640816
# Name: Latitude, dtype: float64
# M5J
# 59    43.640816
# Name: Latitude, dtype: float64
# M5J
# 59    43.640816
# Name: Latitude, dtype: float64
# M6J
# 77    43.647927
# Name: Latitude, dtype: float64
# M6J
# 77    43.647927
# Name: Latitude, dtype: float64
# M1K
# 6    43.727929
# Name: Latitude, dtype: float64
# M1K
# 6    43.727929
# Name: Latitude, dtype: float64
# M1K
# 6    43.727929
# Name: Latitude, dtype: float64
# M2K
# 19    43.786947
# Name: Latitude, dtype: float64
# M3K
# 30    43.737473
# Name: Latitude, dtype: float64
# M3K
# 30    43.737473
# Name: Latitude, dtype: float64
# M4K
# 41    43.679557
# Name: Latitude, dtype: float64
# M4K
# 41    43.679557
# Name: Latitude, dtype: float64
# M5K
# 60    43.647177
# Name: Latitude, dtype: float64
# M5K
# 60    43.647177
# Name: Latitude, dtype: float64
# M6K
# 78    43.636847
# Name: Latitude, dtype: float64
# M6K
# 78    43.636847
# Name: Latitude, dtype: float64
# M6K
# 78    43.636847
# Name: Latitude, dtype: float64
# M1L
# 7    43.711112
# Name: Latitude, dtype: float64
# M1L
# 7    43.711112
# Name: Latitude, dtype: float64
# M1L
# 7    43.711112
# Name: Latitude, dtype: float64
# M2L
# 20    43.75749
# Name: Latitude, dtype: float64
# M2L
# 20    43.75749
# Name: Latitude, dtype: float64
# M3L
# 31    43.739015
# Name: Latitude, dtype: float64
# M4L
# 42    43.668999
# Name: Latitude, dtype: float64
# M4L
# 42    43.668999
# Name: Latitude, dtype: float64
# M5L
# 61    43.648198
# Name: Latitude, dtype: float64
# M5L
# 61    43.648198
# Name: Latitude, dtype: float64
# M6L
# 79    43.713756
# Name: Latitude, dtype: float64
# M6L
# 79    43.713756
# Name: Latitude, dtype: float64
# M6L
# 79    43.713756
# Name: Latitude, dtype: float64
# M9L
# 96    43.756303
# Name: Latitude, dtype: float64
# M1M
# 8    43.716316
# Name: Latitude, dtype: float64
# M1M
# 8    43.716316
# Name: Latitude, dtype: float64
# M1M
# 8    43.716316
# Name: Latitude, dtype: float64
# M2M
# 21    43.789053
# Name: Latitude, dtype: float64
# M2M
# 21    43.789053
# Name: Latitude, dtype: float64
# M3M
# 32    43.728496
# Name: Latitude, dtype: float64
# M4M
# 43    43.659526
# Name: Latitude, dtype: float64
# M5M
# 62    43.733283
# Name: Latitude, dtype: float64
# M5M
# 62    43.733283
# Name: Latitude, dtype: float64
# M6M
# 80    43.691116
# Name: Latitude, dtype: float64
# M6M
# 80    43.691116
# Name: Latitude, dtype: float64
# M6M
# 80    43.691116
# Name: Latitude, dtype: float64
# M6M
# 80    43.691116
# Name: Latitude, dtype: float64
# M9M
# 97    43.724766
# Name: Latitude, dtype: float64
# M9M
# 97    43.724766
# Name: Latitude, dtype: float64
# M1N
# 9    43.692657
# Name: Latitude, dtype: float64
# M1N
# 9    43.692657
# Name: Latitude, dtype: float64
# M2N
# 22    43.77012
# Name: Latitude, dtype: float64
# M3N
# 33    43.761631
# Name: Latitude, dtype: float64
# M4N
# 44    43.72802
# Name: Latitude, dtype: float64
# M5N
# 63    43.711695
# Name: Latitude, dtype: float64
# M6N
# 81    43.673185
# Name: Latitude, dtype: float64
# M6N
# 81    43.673185
# Name: Latitude, dtype: float64
# M9N
# 98    43.706876
# Name: Latitude, dtype: float64
# M1P
# 10    43.75741
# Name: Latitude, dtype: float64
# M1P
# 10    43.75741
# Name: Latitude, dtype: float64
# M1P
# 10    43.75741
# Name: Latitude, dtype: float64
# M2P
# 23    43.752758
# Name: Latitude, dtype: float64
# M4P
# 45    43.712751
# Name: Latitude, dtype: float64
# M5P
# 64    43.696948
# Name: Latitude, dtype: float64
# M5P
# 64    43.696948
# Name: Latitude, dtype: float64
# M6P
# 82    43.661608
# Name: Latitude, dtype: float64
# M6P
# 82    43.661608
# Name: Latitude, dtype: float64
# M9P
# 99    43.696319
# Name: Latitude, dtype: float64
# M1R
# 11    43.750072
# Name: Latitude, dtype: float64
# M1R
# 11    43.750072
# Name: Latitude, dtype: float64
# M2R
# 24    43.782736
# Name: Latitude, dtype: float64
# M4R
# 46    43.715383
# Name: Latitude, dtype: float64
# M5R
# 65    43.67271
# Name: Latitude, dtype: float64
# M5R
# 65    43.67271
# Name: Latitude, dtype: float64
# M5R
# 65    43.67271
# Name: Latitude, dtype: float64
# M6R
# 83    43.64896
# Name: Latitude, dtype: float64
# M6R
# 83    43.64896
# Name: Latitude, dtype: float64
# M7R
# 86    43.636966
# Name: Latitude, dtype: float64
# M9R
# 100    43.688905
# Name: Latitude, dtype: float64
# M9R
# 100    43.688905
# Name: Latitude, dtype: float64
# M9R
# 100    43.688905
# Name: Latitude, dtype: float64
# M9R
# 100    43.688905
# Name: Latitude, dtype: float64
# M1S
# 12    43.7942
# Name: Latitude, dtype: float64
# M4S
# 47    43.704324
# Name: Latitude, dtype: float64
# M5S
# 66    43.662696
# Name: Latitude, dtype: float64
# M5S
# 66    43.662696
# Name: Latitude, dtype: float64
# M6S
# 84    43.651571
# Name: Latitude, dtype: float64
# M6S
# 84    43.651571
# Name: Latitude, dtype: float64
# M1T
# 13    43.781638
# Name: Latitude, dtype: float64
# M1T
# 13    43.781638
# Name: Latitude, dtype: float64
# M1T
# 13    43.781638
# Name: Latitude, dtype: float64
# M4T
# 48    43.689574
# Name: Latitude, dtype: float64
# M4T
# 48    43.689574
# Name: Latitude, dtype: float64
# M5T
# 67    43.653206
# Name: Latitude, dtype: float64
# M5T
# 67    43.653206
# Name: Latitude, dtype: float64
# M5T
# 67    43.653206
# Name: Latitude, dtype: float64
# M1V
# 14    43.815252
# Name: Latitude, dtype: float64
# M1V
# 14    43.815252
# Name: Latitude, dtype: float64
# M1V
# 14    43.815252
# Name: Latitude, dtype: float64
# M1V
# 14    43.815252
# Name: Latitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# M8V
# 88    43.605647
# Name: Latitude, dtype: float64
# M8V
# 88    43.605647
# Name: Latitude, dtype: float64
# M8V
# 88    43.605647
# Name: Latitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# M1W
# 15    43.799525
# Name: Latitude, dtype: float64
# M4W
# 50    43.679563
# Name: Latitude, dtype: float64
# M5W
# 69    43.646435
# Name: Latitude, dtype: float64
# M8W
# 89    43.602414
# Name: Latitude, dtype: float64
# M8W
# 89    43.602414
# Name: Latitude, dtype: float64
# M9W
# 102    43.706748
# Name: Latitude, dtype: float64
# M1X
# 16    43.836125
# Name: Latitude, dtype: float64
# M4X
# 51    43.667967
# Name: Latitude, dtype: float64
# M4X
# 51    43.667967
# Name: Latitude, dtype: float64
# M5X
# 70    43.648429
# Name: Latitude, dtype: float64
# M5X
# 70    43.648429
# Name: Latitude, dtype: float64
# M8X
# 90    43.653654
# Name: Latitude, dtype: float64
# M8X
# 90    43.653654
# Name: Latitude, dtype: float64
# M8X
# 90    43.653654
# Name: Latitude, dtype: float64
# M4Y
# 52    43.66586
# Name: Latitude, dtype: float64
# M7Y
# 87    43.662744
# Name: Latitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64

# %%
for i in hoods_ll.index:
	# print(hoods_ll.iloc[i])
	# set postal code
	postal_code = hoods_ll.loc[i, 'Postcode']
	print(postal_code)
	
	pc_row = geo_df.loc[geo_df['Postal Code'] == postal_code]
	print(pc_row['Latitude'])
	print(pc_row['Longitude'])
# Out:
# M3A
# 25    43.753259
# Name: Latitude, dtype: float64
# 25   -79.329656
# Name: Longitude, dtype: float64
# M4A
# 34    43.725882
# Name: Latitude, dtype: float64
# 34   -79.315572
# Name: Longitude, dtype: float64
# M5A
# 53    43.65426
# Name: Latitude, dtype: float64
# 53   -79.360636
# Name: Longitude, dtype: float64
# M5A
# 53    43.65426
# Name: Latitude, dtype: float64
# 53   -79.360636
# Name: Longitude, dtype: float64
# M6A
# 71    43.718518
# Name: Latitude, dtype: float64
# 71   -79.464763
# Name: Longitude, dtype: float64
# M6A
# 71    43.718518
# Name: Latitude, dtype: float64
# 71   -79.464763
# Name: Longitude, dtype: float64
# M7A
# 85    43.662301
# Name: Latitude, dtype: float64
# 85   -79.389494
# Name: Longitude, dtype: float64
# M9A
# 93    43.667856
# Name: Latitude, dtype: float64
# 93   -79.532242
# Name: Longitude, dtype: float64
# M1B
# 0    43.806686
# Name: Latitude, dtype: float64
# 0   -79.194353
# Name: Longitude, dtype: float64
# M1B
# 0    43.806686
# Name: Latitude, dtype: float64
# 0   -79.194353
# Name: Longitude, dtype: float64
# M3B
# 26    43.745906
# Name: Latitude, dtype: float64
# 26   -79.352188
# Name: Longitude, dtype: float64
# M4B
# 35    43.706397
# Name: Latitude, dtype: float64
# 35   -79.309937
# Name: Longitude, dtype: float64
# M4B
# 35    43.706397
# Name: Latitude, dtype: float64
# 35   -79.309937
# Name: Longitude, dtype: float64
# M5B
# 54    43.657162
# Name: Latitude, dtype: float64
# 54   -79.378937
# Name: Longitude, dtype: float64
# M5B
# 54    43.657162
# Name: Latitude, dtype: float64
# 54   -79.378937
# Name: Longitude, dtype: float64
# M6B
# 72    43.709577
# Name: Latitude, dtype: float64
# 72   -79.445073
# Name: Longitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# 94   -79.554724
# Name: Longitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# 94   -79.554724
# Name: Longitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# 94   -79.554724
# Name: Longitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# 94   -79.554724
# Name: Longitude, dtype: float64
# M9B
# 94    43.650943
# Name: Latitude, dtype: float64
# 94   -79.554724
# Name: Longitude, dtype: float64
# M1C
# 1    43.784535
# Name: Latitude, dtype: float64
# 1   -79.160497
# Name: Longitude, dtype: float64
# M1C
# 1    43.784535
# Name: Latitude, dtype: float64
# 1   -79.160497
# Name: Longitude, dtype: float64
# M1C
# 1    43.784535
# Name: Latitude, dtype: float64
# 1   -79.160497
# Name: Longitude, dtype: float64
# M3C
# 27    43.7259
# Name: Latitude, dtype: float64
# 27   -79.340923
# Name: Longitude, dtype: float64
# M3C
# 27    43.7259
# Name: Latitude, dtype: float64
# 27   -79.340923
# Name: Longitude, dtype: float64
# M4C
# 36    43.695344
# Name: Latitude, dtype: float64
# 36   -79.318389
# Name: Longitude, dtype: float64
# M5C
# 55    43.651494
# Name: Latitude, dtype: float64
# 55   -79.375418
# Name: Longitude, dtype: float64
# M6C
# 73    43.693781
# Name: Latitude, dtype: float64
# 73   -79.428191
# Name: Longitude, dtype: float64
# M9C
# 95    43.643515
# Name: Latitude, dtype: float64
# 95   -79.577201
# Name: Longitude, dtype: float64
# M9C
# 95    43.643515
# Name: Latitude, dtype: float64
# 95   -79.577201
# Name: Longitude, dtype: float64
# M9C
# 95    43.643515
# Name: Latitude, dtype: float64
# 95   -79.577201
# Name: Longitude, dtype: float64
# M9C
# 95    43.643515
# Name: Latitude, dtype: float64
# 95   -79.577201
# Name: Longitude, dtype: float64
# M1E
# 2    43.763573
# Name: Latitude, dtype: float64
# 2   -79.188711
# Name: Longitude, dtype: float64
# M1E
# 2    43.763573
# Name: Latitude, dtype: float64
# 2   -79.188711
# Name: Longitude, dtype: float64
# M1E
# 2    43.763573
# Name: Latitude, dtype: float64
# 2   -79.188711
# Name: Longitude, dtype: float64
# M4E
# 37    43.676357
# Name: Latitude, dtype: float64
# 37   -79.293031
# Name: Longitude, dtype: float64
# M5E
# 56    43.644771
# Name: Latitude, dtype: float64
# 56   -79.373306
# Name: Longitude, dtype: float64
# M6E
# 74    43.689026
# Name: Latitude, dtype: float64
# 74   -79.453512
# Name: Longitude, dtype: float64
# M1G
# 3    43.770992
# Name: Latitude, dtype: float64
# 3   -79.216917
# Name: Longitude, dtype: float64
# M4G
# 38    43.70906
# Name: Latitude, dtype: float64
# 38   -79.363452
# Name: Longitude, dtype: float64
# M5G
# 57    43.657952
# Name: Latitude, dtype: float64
# 57   -79.387383
# Name: Longitude, dtype: float64
# M6G
# 75    43.669542
# Name: Latitude, dtype: float64
# 75   -79.422564
# Name: Longitude, dtype: float64
# M1H
# 4    43.773136
# Name: Latitude, dtype: float64
# 4   -79.239476
# Name: Longitude, dtype: float64
# M2H
# 17    43.803762
# Name: Latitude, dtype: float64
# 17   -79.363452
# Name: Longitude, dtype: float64
# M3H
# 28    43.754328
# Name: Latitude, dtype: float64
# 28   -79.442259
# Name: Longitude, dtype: float64
# M3H
# 28    43.754328
# Name: Latitude, dtype: float64
# 28   -79.442259
# Name: Longitude, dtype: float64
# M3H
# 28    43.754328
# Name: Latitude, dtype: float64
# 28   -79.442259
# Name: Longitude, dtype: float64
# M4H
# 39    43.705369
# Name: Latitude, dtype: float64
# 39   -79.349372
# Name: Longitude, dtype: float64
# M5H
# 58    43.650571
# Name: Latitude, dtype: float64
# 58   -79.384568
# Name: Longitude, dtype: float64
# M5H
# 58    43.650571
# Name: Latitude, dtype: float64
# 58   -79.384568
# Name: Longitude, dtype: float64
# M5H
# 58    43.650571
# Name: Latitude, dtype: float64
# 58   -79.384568
# Name: Longitude, dtype: float64
# M6H
# 76    43.669005
# Name: Latitude, dtype: float64
# 76   -79.442259
# Name: Longitude, dtype: float64
# M6H
# 76    43.669005
# Name: Latitude, dtype: float64
# 76   -79.442259
# Name: Longitude, dtype: float64
# M1J
# 5    43.744734
# Name: Latitude, dtype: float64
# 5   -79.239476
# Name: Longitude, dtype: float64
# M2J
# 18    43.778517
# Name: Latitude, dtype: float64
# 18   -79.346556
# Name: Longitude, dtype: float64
# M2J
# 18    43.778517
# Name: Latitude, dtype: float64
# 18   -79.346556
# Name: Longitude, dtype: float64
# M2J
# 18    43.778517
# Name: Latitude, dtype: float64
# 18   -79.346556
# Name: Longitude, dtype: float64
# M3J
# 29    43.76798
# Name: Latitude, dtype: float64
# 29   -79.487262
# Name: Longitude, dtype: float64
# M3J
# 29    43.76798
# Name: Latitude, dtype: float64
# 29   -79.487262
# Name: Longitude, dtype: float64
# M4J
# 40    43.685347
# Name: Latitude, dtype: float64
# 40   -79.338106
# Name: Longitude, dtype: float64
# M5J
# 59    43.640816
# Name: Latitude, dtype: float64
# 59   -79.381752
# Name: Longitude, dtype: float64
# M5J
# 59    43.640816
# Name: Latitude, dtype: float64
# 59   -79.381752
# Name: Longitude, dtype: float64
# M5J
# 59    43.640816
# Name: Latitude, dtype: float64
# 59   -79.381752
# Name: Longitude, dtype: float64
# M6J
# 77    43.647927
# Name: Latitude, dtype: float64
# 77   -79.41975
# Name: Longitude, dtype: float64
# M6J
# 77    43.647927
# Name: Latitude, dtype: float64
# 77   -79.41975
# Name: Longitude, dtype: float64
# M1K
# 6    43.727929
# Name: Latitude, dtype: float64
# 6   -79.262029
# Name: Longitude, dtype: float64
# M1K
# 6    43.727929
# Name: Latitude, dtype: float64
# 6   -79.262029
# Name: Longitude, dtype: float64
# M1K
# 6    43.727929
# Name: Latitude, dtype: float64
# 6   -79.262029
# Name: Longitude, dtype: float64
# M2K
# 19    43.786947
# Name: Latitude, dtype: float64
# 19   -79.385975
# Name: Longitude, dtype: float64
# M3K
# 30    43.737473
# Name: Latitude, dtype: float64
# 30   -79.464763
# Name: Longitude, dtype: float64
# M3K
# 30    43.737473
# Name: Latitude, dtype: float64
# 30   -79.464763
# Name: Longitude, dtype: float64
# M4K
# 41    43.679557
# Name: Latitude, dtype: float64
# 41   -79.352188
# Name: Longitude, dtype: float64
# M4K
# 41    43.679557
# Name: Latitude, dtype: float64
# 41   -79.352188
# Name: Longitude, dtype: float64
# M5K
# 60    43.647177
# Name: Latitude, dtype: float64
# 60   -79.381576
# Name: Longitude, dtype: float64
# M5K
# 60    43.647177
# Name: Latitude, dtype: float64
# 60   -79.381576
# Name: Longitude, dtype: float64
# M6K
# 78    43.636847
# Name: Latitude, dtype: float64
# 78   -79.428191
# Name: Longitude, dtype: float64
# M6K
# 78    43.636847
# Name: Latitude, dtype: float64
# 78   -79.428191
# Name: Longitude, dtype: float64
# M6K
# 78    43.636847
# Name: Latitude, dtype: float64
# 78   -79.428191
# Name: Longitude, dtype: float64
# M1L
# 7    43.711112
# Name: Latitude, dtype: float64
# 7   -79.284577
# Name: Longitude, dtype: float64
# M1L
# 7    43.711112
# Name: Latitude, dtype: float64
# 7   -79.284577
# Name: Longitude, dtype: float64
# M1L
# 7    43.711112
# Name: Latitude, dtype: float64
# 7   -79.284577
# Name: Longitude, dtype: float64
# M2L
# 20    43.75749
# Name: Latitude, dtype: float64
# 20   -79.374714
# Name: Longitude, dtype: float64
# M2L
# 20    43.75749
# Name: Latitude, dtype: float64
# 20   -79.374714
# Name: Longitude, dtype: float64
# M3L
# 31    43.739015
# Name: Latitude, dtype: float64
# 31   -79.506944
# Name: Longitude, dtype: float64
# M4L
# 42    43.668999
# Name: Latitude, dtype: float64
# 42   -79.315572
# Name: Longitude, dtype: float64
# M4L
# 42    43.668999
# Name: Latitude, dtype: float64
# 42   -79.315572
# Name: Longitude, dtype: float64
# M5L
# 61    43.648198
# Name: Latitude, dtype: float64
# 61   -79.379817
# Name: Longitude, dtype: float64
# M5L
# 61    43.648198
# Name: Latitude, dtype: float64
# 61   -79.379817
# Name: Longitude, dtype: float64
# M6L
# 79    43.713756
# Name: Latitude, dtype: float64
# 79   -79.490074
# Name: Longitude, dtype: float64
# M6L
# 79    43.713756
# Name: Latitude, dtype: float64
# 79   -79.490074
# Name: Longitude, dtype: float64
# M6L
# 79    43.713756
# Name: Latitude, dtype: float64
# 79   -79.490074
# Name: Longitude, dtype: float64
# M9L
# 96    43.756303
# Name: Latitude, dtype: float64
# 96   -79.565963
# Name: Longitude, dtype: float64
# M1M
# 8    43.716316
# Name: Latitude, dtype: float64
# 8   -79.239476
# Name: Longitude, dtype: float64
# M1M
# 8    43.716316
# Name: Latitude, dtype: float64
# 8   -79.239476
# Name: Longitude, dtype: float64
# M1M
# 8    43.716316
# Name: Latitude, dtype: float64
# 8   -79.239476
# Name: Longitude, dtype: float64
# M2M
# 21    43.789053
# Name: Latitude, dtype: float64
# 21   -79.408493
# Name: Longitude, dtype: float64
# M2M
# 21    43.789053
# Name: Latitude, dtype: float64
# 21   -79.408493
# Name: Longitude, dtype: float64
# M3M
# 32    43.728496
# Name: Latitude, dtype: float64
# 32   -79.495697
# Name: Longitude, dtype: float64
# M4M
# 43    43.659526
# Name: Latitude, dtype: float64
# 43   -79.340923
# Name: Longitude, dtype: float64
# M5M
# 62    43.733283
# Name: Latitude, dtype: float64
# 62   -79.41975
# Name: Longitude, dtype: float64
# M5M
# 62    43.733283
# Name: Latitude, dtype: float64
# 62   -79.41975
# Name: Longitude, dtype: float64
# M6M
# 80    43.691116
# Name: Latitude, dtype: float64
# 80   -79.476013
# Name: Longitude, dtype: float64
# M6M
# 80    43.691116
# Name: Latitude, dtype: float64
# 80   -79.476013
# Name: Longitude, dtype: float64
# M6M
# 80    43.691116
# Name: Latitude, dtype: float64
# 80   -79.476013
# Name: Longitude, dtype: float64
# M6M
# 80    43.691116
# Name: Latitude, dtype: float64
# 80   -79.476013
# Name: Longitude, dtype: float64
# M9M
# 97    43.724766
# Name: Latitude, dtype: float64
# 97   -79.532242
# Name: Longitude, dtype: float64
# M9M
# 97    43.724766
# Name: Latitude, dtype: float64
# 97   -79.532242
# Name: Longitude, dtype: float64
# M1N
# 9    43.692657
# Name: Latitude, dtype: float64
# 9   -79.264848
# Name: Longitude, dtype: float64
# M1N
# 9    43.692657
# Name: Latitude, dtype: float64
# 9   -79.264848
# Name: Longitude, dtype: float64
# M2N
# 22    43.77012
# Name: Latitude, dtype: float64
# 22   -79.408493
# Name: Longitude, dtype: float64
# M3N
# 33    43.761631
# Name: Latitude, dtype: float64
# 33   -79.520999
# Name: Longitude, dtype: float64
# M4N
# 44    43.72802
# Name: Latitude, dtype: float64
# 44   -79.38879
# Name: Longitude, dtype: float64
# M5N
# 63    43.711695
# Name: Latitude, dtype: float64
# 63   -79.416936
# Name: Longitude, dtype: float64
# M6N
# 81    43.673185
# Name: Latitude, dtype: float64
# 81   -79.487262
# Name: Longitude, dtype: float64
# M6N
# 81    43.673185
# Name: Latitude, dtype: float64
# 81   -79.487262
# Name: Longitude, dtype: float64
# M9N
# 98    43.706876
# Name: Latitude, dtype: float64
# 98   -79.518188
# Name: Longitude, dtype: float64
# M1P
# 10    43.75741
# Name: Latitude, dtype: float64
# 10   -79.273304
# Name: Longitude, dtype: float64
# M1P
# 10    43.75741
# Name: Latitude, dtype: float64
# 10   -79.273304
# Name: Longitude, dtype: float64
# M1P
# 10    43.75741
# Name: Latitude, dtype: float64
# 10   -79.273304
# Name: Longitude, dtype: float64
# M2P
# 23    43.752758
# Name: Latitude, dtype: float64
# 23   -79.400049
# Name: Longitude, dtype: float64
# M4P
# 45    43.712751
# Name: Latitude, dtype: float64
# 45   -79.390197
# Name: Longitude, dtype: float64
# M5P
# 64    43.696948
# Name: Latitude, dtype: float64
# 64   -79.411307
# Name: Longitude, dtype: float64
# M5P
# 64    43.696948
# Name: Latitude, dtype: float64
# 64   -79.411307
# Name: Longitude, dtype: float64
# M6P
# 82    43.661608
# Name: Latitude, dtype: float64
# 82   -79.464763
# Name: Longitude, dtype: float64
# M6P
# 82    43.661608
# Name: Latitude, dtype: float64
# 82   -79.464763
# Name: Longitude, dtype: float64
# M9P
# 99    43.696319
# Name: Latitude, dtype: float64
# 99   -79.532242
# Name: Longitude, dtype: float64
# M1R
# 11    43.750072
# Name: Latitude, dtype: float64
# 11   -79.295849
# Name: Longitude, dtype: float64
# M1R
# 11    43.750072
# Name: Latitude, dtype: float64
# 11   -79.295849
# Name: Longitude, dtype: float64
# M2R
# 24    43.782736
# Name: Latitude, dtype: float64
# 24   -79.442259
# Name: Longitude, dtype: float64
# M4R
# 46    43.715383
# Name: Latitude, dtype: float64
# 46   -79.405678
# Name: Longitude, dtype: float64
# M5R
# 65    43.67271
# Name: Latitude, dtype: float64
# 65   -79.405678
# Name: Longitude, dtype: float64
# M5R
# 65    43.67271
# Name: Latitude, dtype: float64
# 65   -79.405678
# Name: Longitude, dtype: float64
# M5R
# 65    43.67271
# Name: Latitude, dtype: float64
# 65   -79.405678
# Name: Longitude, dtype: float64
# M6R
# 83    43.64896
# Name: Latitude, dtype: float64
# 83   -79.456325
# Name: Longitude, dtype: float64
# M6R
# 83    43.64896
# Name: Latitude, dtype: float64
# 83   -79.456325
# Name: Longitude, dtype: float64
# M7R
# 86    43.636966
# Name: Latitude, dtype: float64
# 86   -79.615819
# Name: Longitude, dtype: float64
# M9R
# 100    43.688905
# Name: Latitude, dtype: float64
# 100   -79.554724
# Name: Longitude, dtype: float64
# M9R
# 100    43.688905
# Name: Latitude, dtype: float64
# 100   -79.554724
# Name: Longitude, dtype: float64
# M9R
# 100    43.688905
# Name: Latitude, dtype: float64
# 100   -79.554724
# Name: Longitude, dtype: float64
# M9R
# 100    43.688905
# Name: Latitude, dtype: float64
# 100   -79.554724
# Name: Longitude, dtype: float64
# M1S
# 12    43.7942
# Name: Latitude, dtype: float64
# 12   -79.262029
# Name: Longitude, dtype: float64
# M4S
# 47    43.704324
# Name: Latitude, dtype: float64
# 47   -79.38879
# Name: Longitude, dtype: float64
# M5S
# 66    43.662696
# Name: Latitude, dtype: float64
# 66   -79.400049
# Name: Longitude, dtype: float64
# M5S
# 66    43.662696
# Name: Latitude, dtype: float64
# 66   -79.400049
# Name: Longitude, dtype: float64
# M6S
# 84    43.651571
# Name: Latitude, dtype: float64
# 84   -79.48445
# Name: Longitude, dtype: float64
# M6S
# 84    43.651571
# Name: Latitude, dtype: float64
# 84   -79.48445
# Name: Longitude, dtype: float64
# M1T
# 13    43.781638
# Name: Latitude, dtype: float64
# 13   -79.304302
# Name: Longitude, dtype: float64
# M1T
# 13    43.781638
# Name: Latitude, dtype: float64
# 13   -79.304302
# Name: Longitude, dtype: float64
# M1T
# 13    43.781638
# Name: Latitude, dtype: float64
# 13   -79.304302
# Name: Longitude, dtype: float64
# M4T
# 48    43.689574
# Name: Latitude, dtype: float64
# 48   -79.38316
# Name: Longitude, dtype: float64
# M4T
# 48    43.689574
# Name: Latitude, dtype: float64
# 48   -79.38316
# Name: Longitude, dtype: float64
# M5T
# 67    43.653206
# Name: Latitude, dtype: float64
# 67   -79.400049
# Name: Longitude, dtype: float64
# M5T
# 67    43.653206
# Name: Latitude, dtype: float64
# 67   -79.400049
# Name: Longitude, dtype: float64
# M5T
# 67    43.653206
# Name: Latitude, dtype: float64
# 67   -79.400049
# Name: Longitude, dtype: float64
# M1V
# 14    43.815252
# Name: Latitude, dtype: float64
# 14   -79.284577
# Name: Longitude, dtype: float64
# M1V
# 14    43.815252
# Name: Latitude, dtype: float64
# 14   -79.284577
# Name: Longitude, dtype: float64
# M1V
# 14    43.815252
# Name: Latitude, dtype: float64
# 14   -79.284577
# Name: Longitude, dtype: float64
# M1V
# 14    43.815252
# Name: Latitude, dtype: float64
# 14   -79.284577
# Name: Longitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# 49   -79.400049
# Name: Longitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# 49   -79.400049
# Name: Longitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# 49   -79.400049
# Name: Longitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# 49   -79.400049
# Name: Longitude, dtype: float64
# M4V
# 49    43.686412
# Name: Latitude, dtype: float64
# 49   -79.400049
# Name: Longitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# 68   -79.39442
# Name: Longitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# 68   -79.39442
# Name: Longitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# 68   -79.39442
# Name: Longitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# 68   -79.39442
# Name: Longitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# 68   -79.39442
# Name: Longitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# 68   -79.39442
# Name: Longitude, dtype: float64
# M5V
# 68    43.628947
# Name: Latitude, dtype: float64
# 68   -79.39442
# Name: Longitude, dtype: float64
# M8V
# 88    43.605647
# Name: Latitude, dtype: float64
# 88   -79.501321
# Name: Longitude, dtype: float64
# M8V
# 88    43.605647
# Name: Latitude, dtype: float64
# 88   -79.501321
# Name: Longitude, dtype: float64
# M8V
# 88    43.605647
# Name: Latitude, dtype: float64
# 88   -79.501321
# Name: Longitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# 101   -79.588437
# Name: Longitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# 101   -79.588437
# Name: Longitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# 101   -79.588437
# Name: Longitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# 101   -79.588437
# Name: Longitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# 101   -79.588437
# Name: Longitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# 101   -79.588437
# Name: Longitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# 101   -79.588437
# Name: Longitude, dtype: float64
# M9V
# 101    43.739416
# Name: Latitude, dtype: float64
# 101   -79.588437
# Name: Longitude, dtype: float64
# M1W
# 15    43.799525
# Name: Latitude, dtype: float64
# 15   -79.318389
# Name: Longitude, dtype: float64
# M4W
# 50    43.679563
# Name: Latitude, dtype: float64
# 50   -79.377529
# Name: Longitude, dtype: float64
# M5W
# 69    43.646435
# Name: Latitude, dtype: float64
# 69   -79.374846
# Name: Longitude, dtype: float64
# M8W
# 89    43.602414
# Name: Latitude, dtype: float64
# 89   -79.543484
# Name: Longitude, dtype: float64
# M8W
# 89    43.602414
# Name: Latitude, dtype: float64
# 89   -79.543484
# Name: Longitude, dtype: float64
# M9W
# 102    43.706748
# Name: Latitude, dtype: float64
# 102   -79.594054
# Name: Longitude, dtype: float64
# M1X
# 16    43.836125
# Name: Latitude, dtype: float64
# 16   -79.205636
# Name: Longitude, dtype: float64
# M4X
# 51    43.667967
# Name: Latitude, dtype: float64
# 51   -79.367675
# Name: Longitude, dtype: float64
# M4X
# 51    43.667967
# Name: Latitude, dtype: float64
# 51   -79.367675
# Name: Longitude, dtype: float64
# M5X
# 70    43.648429
# Name: Latitude, dtype: float64
# 70   -79.38228
# Name: Longitude, dtype: float64
# M5X
# 70    43.648429
# Name: Latitude, dtype: float64
# 70   -79.38228
# Name: Longitude, dtype: float64
# M8X
# 90    43.653654
# Name: Latitude, dtype: float64
# 90   -79.506944
# Name: Longitude, dtype: float64
# M8X
# 90    43.653654
# Name: Latitude, dtype: float64
# 90   -79.506944
# Name: Longitude, dtype: float64
# M8X
# 90    43.653654
# Name: Latitude, dtype: float64
# 90   -79.506944
# Name: Longitude, dtype: float64
# M4Y
# 52    43.66586
# Name: Latitude, dtype: float64
# 52   -79.38316
# Name: Longitude, dtype: float64
# M7Y
# 87    43.662744
# Name: Latitude, dtype: float64
# 87   -79.321558
# Name: Longitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# 91   -79.498509
# Name: Longitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# 91   -79.498509
# Name: Longitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# 91   -79.498509
# Name: Longitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# 91   -79.498509
# Name: Longitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# 91   -79.498509
# Name: Longitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# 91   -79.498509
# Name: Longitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# 91   -79.498509
# Name: Longitude, dtype: float64
# M8Y
# 91    43.636258
# Name: Latitude, dtype: float64
# 91   -79.498509
# Name: Longitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# 92   -79.520999
# Name: Longitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# 92   -79.520999
# Name: Longitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# 92   -79.520999
# Name: Longitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# 92   -79.520999
# Name: Longitude, dtype: float64
# M8Z
# 92    43.628841
# Name: Latitude, dtype: float64
# 92   -79.520999
# Name: Longitude, dtype: float64

# %%
for i in hoods_ll.index:
	# set postal code
	postal_code = hoods_ll.loc[i, 'Postcode']
	
	latitude = geo_df.loc[geo_df['Postal Code'] == postal_code].Latitude.values[0]
	longitude = geo_df.loc[geo_df['Postal Code'] == postal_code].Longitude.values[0]
	print('The location of {} is {}, {}'.format(postal_code, latitude, longitude))
# Out:
# The location of M3A is 43.7532586, -79.3296565
# The location of M4A is 43.725882299999995, -79.31557159999998
# The location of M5A is 43.6542599, -79.3606359
# The location of M5A is 43.6542599, -79.3606359
# The location of M6A is 43.718517999999996, -79.46476329999999
# The location of M6A is 43.718517999999996, -79.46476329999999
# The location of M7A is 43.6623015, -79.3894938
# The location of M9A is 43.6678556, -79.53224240000002
# The location of M1B is 43.806686299999996, -79.19435340000001
# The location of M1B is 43.806686299999996, -79.19435340000001
# The location of M3B is 43.745905799999996, -79.352188
# The location of M4B is 43.7063972, -79.309937
# The location of M4B is 43.7063972, -79.309937
# The location of M5B is 43.6571618, -79.37893709999999
# The location of M5B is 43.6571618, -79.37893709999999
# The location of M6B is 43.709577, -79.44507259999999
# The location of M9B is 43.6509432, -79.55472440000001
# The location of M9B is 43.6509432, -79.55472440000001
# The location of M9B is 43.6509432, -79.55472440000001
# The location of M9B is 43.6509432, -79.55472440000001
# The location of M9B is 43.6509432, -79.55472440000001
# The location of M1C is 43.7845351, -79.16049709999999
# The location of M1C is 43.7845351, -79.16049709999999
# The location of M1C is 43.7845351, -79.16049709999999
# The location of M3C is 43.72589970000001, -79.340923
# The location of M3C is 43.72589970000001, -79.340923
# The location of M4C is 43.695343900000005, -79.3183887
# The location of M5C is 43.6514939, -79.3754179
# The location of M6C is 43.6937813, -79.42819140000002
# The location of M9C is 43.6435152, -79.57720079999999
# The location of M9C is 43.6435152, -79.57720079999999
# The location of M9C is 43.6435152, -79.57720079999999
# The location of M9C is 43.6435152, -79.57720079999999
# The location of M1E is 43.7635726, -79.1887115
# The location of M1E is 43.7635726, -79.1887115
# The location of M1E is 43.7635726, -79.1887115
# The location of M4E is 43.67635739999999, -79.2930312
# The location of M5E is 43.644770799999996, -79.3733064
# The location of M6E is 43.6890256, -79.453512
# The location of M1G is 43.7709921, -79.21691740000001
# The location of M4G is 43.7090604, -79.3634517
# The location of M5G is 43.6579524, -79.3873826
# The location of M6G is 43.669542, -79.4225637
# The location of M1H is 43.773136, -79.23947609999999
# The location of M2H is 43.8037622, -79.3634517
# The location of M3H is 43.7543283, -79.4422593
# The location of M3H is 43.7543283, -79.4422593
# The location of M3H is 43.7543283, -79.4422593
# The location of M4H is 43.7053689, -79.34937190000001
# The location of M5H is 43.65057120000001, -79.3845675
# The location of M5H is 43.65057120000001, -79.3845675
# The location of M5H is 43.65057120000001, -79.3845675
# The location of M6H is 43.66900510000001, -79.4422593
# The location of M6H is 43.66900510000001, -79.4422593
# The location of M1J is 43.7447342, -79.23947609999999
# The location of M2J is 43.7785175, -79.3465557
# The location of M2J is 43.7785175, -79.3465557
# The location of M2J is 43.7785175, -79.3465557
# The location of M3J is 43.7679803, -79.48726190000001
# The location of M3J is 43.7679803, -79.48726190000001
# The location of M4J is 43.685347, -79.3381065
# The location of M5J is 43.6408157, -79.38175229999999
# The location of M5J is 43.6408157, -79.38175229999999
# The location of M5J is 43.6408157, -79.38175229999999
# The location of M6J is 43.647926700000006, -79.4197497
# The location of M6J is 43.647926700000006, -79.4197497
# The location of M1K is 43.7279292, -79.26202940000002
# The location of M1K is 43.7279292, -79.26202940000002
# The location of M1K is 43.7279292, -79.26202940000002
# The location of M2K is 43.7869473, -79.385975
# The location of M3K is 43.737473200000004, -79.46476329999999
# The location of M3K is 43.737473200000004, -79.46476329999999
# The location of M4K is 43.6795571, -79.352188
# The location of M4K is 43.6795571, -79.352188
# The location of M5K is 43.6471768, -79.38157640000001
# The location of M5K is 43.6471768, -79.38157640000001
# The location of M6K is 43.6368472, -79.42819140000002
# The location of M6K is 43.6368472, -79.42819140000002
# The location of M6K is 43.6368472, -79.42819140000002
# The location of M1L is 43.711111700000004, -79.2845772
# The location of M1L is 43.711111700000004, -79.2845772
# The location of M1L is 43.711111700000004, -79.2845772
# The location of M2L is 43.7574902, -79.37471409999999
# The location of M2L is 43.7574902, -79.37471409999999
# The location of M3L is 43.7390146, -79.5069436
# The location of M4L is 43.6689985, -79.31557159999998
# The location of M4L is 43.6689985, -79.31557159999998
# The location of M5L is 43.6481985, -79.37981690000001
# The location of M5L is 43.6481985, -79.37981690000001
# The location of M6L is 43.713756200000006, -79.4900738
# The location of M6L is 43.713756200000006, -79.4900738
# The location of M6L is 43.713756200000006, -79.4900738
# The location of M9L is 43.7563033, -79.56596329999999
# The location of M1M is 43.716316, -79.23947609999999
# The location of M1M is 43.716316, -79.23947609999999
# The location of M1M is 43.716316, -79.23947609999999
# The location of M2M is 43.789053, -79.40849279999999
# The location of M2M is 43.789053, -79.40849279999999
# The location of M3M is 43.7284964, -79.49569740000001
# The location of M4M is 43.6595255, -79.340923
# The location of M5M is 43.7332825, -79.4197497
# The location of M5M is 43.7332825, -79.4197497
# The location of M6M is 43.6911158, -79.47601329999999
# The location of M6M is 43.6911158, -79.47601329999999
# The location of M6M is 43.6911158, -79.47601329999999
# The location of M6M is 43.6911158, -79.47601329999999
# The location of M9M is 43.7247659, -79.53224240000002
# The location of M9M is 43.7247659, -79.53224240000002
# The location of M1N is 43.692657000000004, -79.2648481
# The location of M1N is 43.692657000000004, -79.2648481
# The location of M2N is 43.7701199, -79.40849279999999
# The location of M3N is 43.7616313, -79.52099940000001
# The location of M4N is 43.7280205, -79.3887901
# The location of M5N is 43.7116948, -79.41693559999999
# The location of M6N is 43.67318529999999, -79.48726190000001
# The location of M6N is 43.67318529999999, -79.48726190000001
# The location of M9N is 43.706876, -79.51818840000001
# The location of M1P is 43.7574096, -79.27330400000001
# The location of M1P is 43.7574096, -79.27330400000001
# The location of M1P is 43.7574096, -79.27330400000001
# The location of M2P is 43.752758299999996, -79.4000493
# The location of M4P is 43.7127511, -79.3901975
# The location of M5P is 43.6969476, -79.41130720000001
# The location of M5P is 43.6969476, -79.41130720000001
# The location of M6P is 43.6616083, -79.46476329999999
# The location of M6P is 43.6616083, -79.46476329999999
# The location of M9P is 43.696319, -79.53224240000002
# The location of M1R is 43.750071500000004, -79.2958491
# The location of M1R is 43.750071500000004, -79.2958491
# The location of M2R is 43.7827364, -79.4422593
# The location of M4R is 43.7153834, -79.40567840000001
# The location of M5R is 43.6727097, -79.40567840000001
# The location of M5R is 43.6727097, -79.40567840000001
# The location of M5R is 43.6727097, -79.40567840000001
# The location of M6R is 43.6489597, -79.456325
# The location of M6R is 43.6489597, -79.456325
# The location of M7R is 43.6369656, -79.61581899999999
# The location of M9R is 43.6889054, -79.55472440000001
# The location of M9R is 43.6889054, -79.55472440000001
# The location of M9R is 43.6889054, -79.55472440000001
# The location of M9R is 43.6889054, -79.55472440000001
# The location of M1S is 43.7942003, -79.26202940000002
# The location of M4S is 43.7043244, -79.3887901
# The location of M5S is 43.6626956, -79.4000493
# The location of M5S is 43.6626956, -79.4000493
# The location of M6S is 43.6515706, -79.4844499
# The location of M6S is 43.6515706, -79.4844499
# The location of M1T is 43.7816375, -79.3043021
# The location of M1T is 43.7816375, -79.3043021
# The location of M1T is 43.7816375, -79.3043021
# The location of M4T is 43.6895743, -79.38315990000001
# The location of M4T is 43.6895743, -79.38315990000001
# The location of M5T is 43.6532057, -79.4000493
# The location of M5T is 43.6532057, -79.4000493
# The location of M5T is 43.6532057, -79.4000493
# The location of M1V is 43.8152522, -79.2845772
# The location of M1V is 43.8152522, -79.2845772
# The location of M1V is 43.8152522, -79.2845772
# The location of M1V is 43.8152522, -79.2845772
# The location of M4V is 43.68641229999999, -79.4000493
# The location of M4V is 43.68641229999999, -79.4000493
# The location of M4V is 43.68641229999999, -79.4000493
# The location of M4V is 43.68641229999999, -79.4000493
# The location of M4V is 43.68641229999999, -79.4000493
# The location of M5V is 43.6289467, -79.3944199
# The location of M5V is 43.6289467, -79.3944199
# The location of M5V is 43.6289467, -79.3944199
# The location of M5V is 43.6289467, -79.3944199
# The location of M5V is 43.6289467, -79.3944199
# The location of M5V is 43.6289467, -79.3944199
# The location of M5V is 43.6289467, -79.3944199
# The location of M8V is 43.6056466, -79.50132070000001
# The location of M8V is 43.6056466, -79.50132070000001
# The location of M8V is 43.6056466, -79.50132070000001
# The location of M9V is 43.739416399999996, -79.5884369
# The location of M9V is 43.739416399999996, -79.5884369
# The location of M9V is 43.739416399999996, -79.5884369
# The location of M9V is 43.739416399999996, -79.5884369
# The location of M9V is 43.739416399999996, -79.5884369
# The location of M9V is 43.739416399999996, -79.5884369
# The location of M9V is 43.739416399999996, -79.5884369
# The location of M9V is 43.739416399999996, -79.5884369
# The location of M1W is 43.799525200000005, -79.3183887
# The location of M4W is 43.6795626, -79.37752940000001
# The location of M5W is 43.6464352, -79.37484599999999
# The location of M8W is 43.60241370000001, -79.54348409999999
# The location of M8W is 43.60241370000001, -79.54348409999999
# The location of M9W is 43.706748299999994, -79.5940544
# The location of M1X is 43.836124700000006, -79.20563609999999
# The location of M4X is 43.667967, -79.3676753
# The location of M4X is 43.667967, -79.3676753
# The location of M5X is 43.6484292, -79.3822802
# The location of M5X is 43.6484292, -79.3822802
# The location of M8X is 43.653653600000005, -79.5069436
# The location of M8X is 43.653653600000005, -79.5069436
# The location of M8X is 43.653653600000005, -79.5069436
# The location of M4Y is 43.6658599, -79.38315990000001
# The location of M7Y is 43.6627439, -79.321558
# The location of M8Y is 43.6362579, -79.49850909999999
# The location of M8Y is 43.6362579, -79.49850909999999
# The location of M8Y is 43.6362579, -79.49850909999999
# The location of M8Y is 43.6362579, -79.49850909999999
# The location of M8Y is 43.6362579, -79.49850909999999
# The location of M8Y is 43.6362579, -79.49850909999999
# The location of M8Y is 43.6362579, -79.49850909999999
# The location of M8Y is 43.6362579, -79.49850909999999
# The location of M8Z is 43.6288408, -79.52099940000001
# The location of M8Z is 43.6288408, -79.52099940000001
# The location of M8Z is 43.6288408, -79.52099940000001
# The location of M8Z is 43.6288408, -79.52099940000001
# The location of M8Z is 43.6288408, -79.52099940000001

# %%
for i in hoods_ll.index:
	# set postal code
	postal_code = hoods_ll.loc[i, 'Postcode']
	
	latitude = geo_df.loc[geo_df['Postal Code'] == postal_code].Latitude.values[0]
	longitude = geo_df.loc[geo_df['Postal Code'] == postal_code].Longitude.values[0]
	# print('The location of {} is {}, {}'.format(postal_code, latitude, longitude))

	hoods_ll.at[i, 'Latitude'] = latitude
	hoods_ll.at[i, 'Longitude'] = longitude

hoods_ll.head(10)
# Out:
#   Postcode           Borough      Neighborhood Latitude Longitude
# 0      M3A        North York         Parkwoods  43.7533  -79.3297
# 1      M4A        North York  Victoria Village  43.7259  -79.3156
# 2      M5A  Downtown Toronto      Harbourfront  43.6543  -79.3606
# 3      M5A  Downtown Toronto       Regent Park  43.6543  -79.3606
# 4      M6A        North York  Lawrence Heights  43.7185  -79.4648
# 5      M6A        North York    Lawrence Manor  43.7185  -79.4648
# 6      M7A      Queen's Park      Queen's Park  43.6623  -79.3895
# 7      M9A         Etobicoke  Islington Avenue  43.6679  -79.5322
# 8      M1B       Scarborough             Rouge  43.8067  -79.1944
# 9      M1B       Scarborough           Malvern  43.8067  -79.1944

# %%
! conda install -c conda-forge geopy --yes
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\KDJ\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.3.9           |           py37_0         149 KB  conda-forge
#     conda-4.6.14               |           py37_0         2.1 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.49-py_0
#   geopy              conda-forge/noarch::geopy-1.20.0-py_0
#
# The following packages will be UPDATED:
#
#   conda                      pkgs/main::conda-4.6.11-py37_0 --> conda-forge::conda-4.6.14-py37_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> conda-forge
#
#
#
# Downloading and Extracting Packages
#
# geographiclib-1.49   | 32 KB     |            |   0%
# geographiclib-1.49   | 32 KB     | ########## | 100%
#
# conda-4.6.14         | 2.1 MB    |            |   0%
# conda-4.6.14         | 2.1 MB    | #2         |  12%
# conda-4.6.14         | 2.1 MB    | ####       |  40%
# conda-4.6.14         | 2.1 MB    | ######5    |  65%
# conda-4.6.14         | 2.1 MB    | #######9   |  79%
# conda-4.6.14         | 2.1 MB    | #########2 |  93%
# conda-4.6.14         | 2.1 MB    | ########## | 100%
#
# certifi-2019.3.9     | 149 KB    |            |   0%
# certifi-2019.3.9     | 149 KB    | ########## | 100%
#
# geopy-1.20.0         | 57 KB     |            |   0%
# geopy-1.20.0         | 57 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# (base) C:\Users\KDJ\Data Science>ET _sysp=%~dpA
#
# (base) C:\Users\KDJ\Data Science>IF NOT EXIST "!_sysp!\Scripts\conda.exe"
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
# WARNING: The conda.compat module is deprecated and will be removed in a future release.
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.6.11
#   latest version: 4.6.14
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# 'ET' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\KDJ\Anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-3.1.0               |           py37_0         721 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         819 KB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/win-64::altair-3.1.0-py37_0
#   branca             conda-forge/noarch::branca-0.3.1-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
#
# altair-3.1.0         | 721 KB    |            |   0%
# altair-3.1.0         | 721 KB    | 1          |   2%
# altair-3.1.0         | 721 KB    | ######1    |  62%
# altair-3.1.0         | 721 KB    | #######9   |  80%
# altair-3.1.0         | 721 KB    | #########5 |  96%
# altair-3.1.0         | 721 KB    | ########## | 100%
#
# vincent-0.4.4        | 28 KB     |            |   0%
# vincent-0.4.4        | 28 KB     | ########## | 100%
#
# folium-0.5.0         | 45 KB     |            |   0%
# folium-0.5.0         | 45 KB     | ########## | 100%
#
# branca-0.3.1         | 25 KB     |            |   0%
# branca-0.3.1         | 25 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# import libraries
import numpy as np # library to handle data in a vectorized manner

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# slice df to create new df for just Toronto
toronto_data = hoods_ll[hoods_ll['Borough'].str.contains("Toronto")].reset_index(drop=True)
toronto_data.head()
# Out:
#   Postcode           Borough     Neighborhood Latitude Longitude
# 0      M5A  Downtown Toronto     Harbourfront  43.6543  -79.3606
# 1      M5A  Downtown Toronto      Regent Park  43.6543  -79.3606
# 2      M5B  Downtown Toronto          Ryerson  43.6572  -79.3789
# 3      M5B  Downtown Toronto  Garden District  43.6572  -79.3789
# 4      M5C  Downtown Toronto   St. James Town  43.6515  -79.3754

# %%
# get coordinates for Manhattan
address = 'Toronto, ON'
address
# Out:
# 'Toronto, ON'

# %%
geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
# add markers to map
for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define Foursquare variables
CLIENT_ID = 'CT3K4Z2AEBTWGOKQLQKZ135JJ3B44KOQTB4BMEJ4R0AXXWSD' # your Foursquare ID
CLIENT_SECRET = 'TSJKVMWFPKG2ZV4NYZQDVIR5FIYOSRICDTHHKHWSMV5JHDMZ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
# create a function to repeat the same process to all the neighborhoods in Toronto
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
radius = 500
LIMIT=100

# write the code to run the above function on each neighborhood and create a new dataframe called toronto_venues
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )

# check size of resulting df
print(toronto_venues.shape)
# Out:
# Harbourfront
# Regent Park
# Ryerson
# Garden District
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Adelaide
# King
# Richmond
# Dovercourt Village
# Dufferin
# Harbourfront East
# Toronto Islands
# Union Station
# Little Portugal
# Trinity
# The Danforth West
# Riverdale
# Design Exchange
# Toronto Dominion Centre
# Brockton
# Exhibition Place
# Parkdale Village
# The Beaches West
# India Bazaar
# Commerce Court
# Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North
# Forest Hill West
# High Park
# The Junction South
# North Toronto West
# The Annex
# North Midtown
# Yorkville
# Parkdale
# Roncesvalles
# Davisville
# Harbord
# University of Toronto
# Runnymede
# Swansea
# Moore Park
# Summerhill East
# Chinatown
# Grange Park
# Kensington Market
# Deer Park
# Forest Hill SE
# Rathnelly
# South Hill
# Summerhill West
# CN Tower
# Bathurst Quay
# Island airport
# Harbourfront West
# King and Spadina
# Railway Lands
# South Niagara
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Cabbagetown
# St. James Town
# First Canadian Place
# Underground city
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern
# (3275, 7)

# %%
# how many venues for each neighborhood
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# Adelaide                                                             100
# Bathurst Quay                                                         14
# Berczy Park                                                           55
# Brockton                                                              21
# Business Reply Mail Processing Centre 969 Eastern                     19
# CN Tower                                                              14
# Cabbagetown                                                           46
# Central Bay Street                                                    88
# Chinatown                                                            100
# Christie                                                              15
# Church and Wellesley                                                  87
# Commerce Court                                                       100
# Davisville                                                            38
# Davisville North                                                       8
# Deer Park                                                             14
# Design Exchange                                                      100
# Dovercourt Village                                                    20
# Dufferin                                                              20
# Exhibition Place                                                      21
# First Canadian Place                                                 100
# Forest Hill North                                                      4
# Forest Hill SE                                                        14
# Forest Hill West                                                       4
# Garden District                                                      100
# Grange Park                                                          100
# Harbord                                                               34
# Harbourfront                                                          48
# Harbourfront East                                                    100
# Harbourfront West                                                     14
# High Park                                                             23
# India Bazaar                                                          18
# Island airport                                                        14
# Kensington Market                                                    100
# King                                                                 100
# King and Spadina                                                      14
# Lawrence Park                                                          3
# Little Portugal                                                       62
# Moore Park                                                             2
# North Midtown                                                         23
# North Toronto West                                                    16
# Parkdale                                                              15
# Parkdale Village                                                      21
# Railway Lands                                                         14
# Rathnelly                                                             14
# Regent Park                                                           48
# Richmond                                                             100
# Riverdale                                                             42
# Roncesvalles                                                          15
# Rosedale                                                               4
# Roselawn                                                               2
# Runnymede                                                             38
# Ryerson                                                              100
# South Hill                                                            14
# South Niagara                                                         14
# St. James Town                                                       146
# Stn A PO Boxes 25 The Esplanade                                       94
# Studio District                                                       38
# Summerhill East                                                        2
# Summerhill West                                                       14
# Swansea                                                               38
# The Annex                                                             23
# The Beaches                                                            4
# The Beaches West                                                      18
# The Danforth West                                                     42
# The Junction South                                                    23
# Toronto Dominion Centre                                              100
# Toronto Islands                                                      100
# Trinity                                                               62
# Underground city                                                     100
# Union Station                                                        100
# University of Toronto                                                 34
# Victoria Hotel                                                       100
# Yorkville                                                             23
#
#                                                    Neighborhood Longitude  \
# Neighborhood
# Adelaide                                                              100
# Bathurst Quay                                                          14
# Berczy Park                                                            55
# Brockton                                                               21
# Business Reply Mail Processing Centre 969 Eastern                      19
# CN Tower                                                               14
# Cabbagetown                                                            46
# Central Bay Street                                                     88
# Chinatown                                                             100
# Christie                                                               15
# Church and Wellesley                                                   87
# Commerce Court                                                        100
# Davisville                                                             38
# Davisville North                                                        8
# Deer Park                                                              14
# Design Exchange                                                       100
# Dovercourt Village                                                     20
# Dufferin                                                               20
# Exhibition Place                                                       21
# First Canadian Place                                                  100
# Forest Hill North                                                       4
# Forest Hill SE                                                         14
# Forest Hill West                                                        4
# Garden District                                                       100
# Grange Park                                                           100
# Harbord                                                                34
# Harbourfront                                                           48
# Harbourfront East                                                     100
# Harbourfront West                                                      14
# High Park                                                              23
# India Bazaar                                                           18
# Island airport                                                         14
# Kensington Market                                                     100
# King                                                                  100
# King and Spadina                                                       14
# Lawrence Park                                                           3
# Little Portugal                                                        62
# Moore Park                                                              2
# North Midtown                                                          23
# North Toronto West                                                     16
# Parkdale                                                               15
# Parkdale Village                                                       21
# Railway Lands                                                          14
# Rathnelly                                                              14
# Regent Park                                                            48
# Richmond                                                              100
# Riverdale                                                              42
# Roncesvalles                                                           15
# Rosedale                                                                4
# Roselawn                                                                2
# Runnymede                                                              38
# Ryerson                                                               100
# South Hill                                                             14
# South Niagara                                                          14
# St. James Town                                                        146
# Stn A PO Boxes 25 The Esplanade                                        94
# Studio District                                                        38
# Summerhill East                                                         2
# Summerhill West                                                        14
# Swansea                                                                38
# The Annex                                                              23
# The Beaches                                                             4
# The Beaches West                                                       18
# The Danforth West                                                      42
# The Junction South                                                     23
# Toronto Dominion Centre                                               100
# Toronto Islands                                                       100
# Trinity                                                                62
# Underground city                                                      100
# Union Station                                                         100
# University of Toronto                                                  34
# Victoria Hotel                                                        100
# Yorkville                                                              23
#
#                                                    Venue  Venue Latitude  \
# Neighborhood
# Adelaide                                             100             100
# Bathurst Quay                                         14              14
# Berczy Park                                           55              55
# Brockton                                              21              21
# Business Reply Mail Processing Centre 969 Eastern     19              19
# CN Tower                                              14              14
# Cabbagetown                                           46              46
# Central Bay Street                                    88              88
# Chinatown                                            100             100
# Christie                                              15              15
# Church and Wellesley                                  87              87
# Commerce Court                                       100             100
# Davisville                                            38              38
# Davisville North                                       8               8
# Deer Park                                             14              14
# Design Exchange                                      100             100
# Dovercourt Village                                    20              20
# Dufferin                                              20              20
# Exhibition Place                                      21              21
# First Canadian Place                                 100             100
# Forest Hill North                                      4               4
# Forest Hill SE                                        14              14
# Forest Hill West                                       4               4
# Garden District                                      100             100
# Grange Park                                          100             100
# Harbord                                               34              34
# Harbourfront                                          48              48
# Harbourfront East                                    100             100
# Harbourfront West                                     14              14
# High Park                                             23              23
# India Bazaar                                          18              18
# Island airport                                        14              14
# Kensington Market                                    100             100
# King                                                 100             100
# King and Spadina                                      14              14
# Lawrence Park                                          3               3
# Little Portugal                                       62              62
# Moore Park                                             2               2
# North Midtown                                         23              23
# North Toronto West                                    16              16
# Parkdale                                              15              15
# Parkdale Village                                      21              21
# Railway Lands                                         14              14
# Rathnelly                                             14              14
# Regent Park                                           48              48
# Richmond                                             100             100
# Riverdale                                             42              42
# Roncesvalles                                          15              15
# Rosedale                                               4               4
# Roselawn                                               2               2
# Runnymede                                             38              38
# Ryerson                                              100             100
# South Hill                                            14              14
# South Niagara                                         14              14
# St. James Town                                       146             146
# Stn A PO Boxes 25 The Esplanade                       94              94
# Studio District                                       38              38
# Summerhill East                                        2               2
# Summerhill West                                       14              14
# Swansea                                               38              38
# The Annex                                             23              23
# The Beaches                                            4               4
# The Beaches West                                      18              18
# The Danforth West                                     42              42
# The Junction South                                    23              23
# Toronto Dominion Centre                              100             100
# Toronto Islands                                      100             100
# Trinity                                               62              62
# Underground city                                     100             100
# Union Station                                        100             100
# University of Toronto                                 34              34
# Victoria Hotel                                       100             100
# Yorkville                                             23              23
#
#                                                    Venue Longitude  \
# Neighborhood
# Adelaide                                                       100
# Bathurst Quay                                                   14
# Berczy Park                                                     55
# Brockton                                                        21
# Business Reply Mail Processing Centre 969 Eastern               19
# CN Tower                                                        14
# Cabbagetown                                                     46
# Central Bay Street                                              88
# Chinatown                                                      100
# Christie                                                        15
# Church and Wellesley                                            87
# Commerce Court                                                 100
# Davisville                                                      38
# Davisville North                                                 8
# Deer Park                                                       14
# Design Exchange                                                100
# Dovercourt Village                                              20
# Dufferin                                                        20
# Exhibition Place                                                21
# First Canadian Place                                           100
# Forest Hill North                                                4
# Forest Hill SE                                                  14
# Forest Hill West                                                 4
# Garden District                                                100
# Grange Park                                                    100
# Harbord                                                         34
# Harbourfront                                                    48
# Harbourfront East                                              100
# Harbourfront West                                               14
# High Park                                                       23
# India Bazaar                                                    18
# Island airport                                                  14
# Kensington Market                                              100
# King                                                           100
# King and Spadina                                                14
# Lawrence Park                                                    3
# Little Portugal                                                 62
# Moore Park                                                       2
# North Midtown                                                   23
# North Toronto West                                              16
# Parkdale                                                        15
# Parkdale Village                                                21
# Railway Lands                                                   14
# Rathnelly                                                       14
# Regent Park                                                     48
# Richmond                                                       100
# Riverdale                                                       42
# Roncesvalles                                                    15
# Rosedale                                                         4
# Roselawn                                                         2
# Runnymede                                                       38
# Ryerson                                                        100
# South Hill                                                      14
# South Niagara                                                   14
# St. James Town                                                 146
# Stn A PO Boxes 25 The Esplanade                                 94
# Studio District                                                 38
# Summerhill East                                                  2
# Summerhill West                                                 14
# Swansea                                                         38
# The Annex                                                       23
# The Beaches                                                      4
# The Beaches West                                                18
# The Danforth West                                               42
# The Junction South                                              23
# Toronto Dominion Centre                                        100
# Toronto Islands                                                100
# Trinity                                                         62
# Underground city                                               100
# Union Station                                                  100
# University of Toronto                                           34
# Victoria Hotel                                                 100
# Yorkville                                                       23
#
#                                                    Venue Category
# Neighborhood
# Adelaide                                                      100
# Bathurst Quay                                                  14
# Berczy Park                                                    55
# Brockton                                                       21
# Business Reply Mail Processing Centre 969 Eastern              19
# CN Tower                                                       14
# Cabbagetown                                                    46
# Central Bay Street                                             88
# Chinatown                                                     100
# Christie                                                       15
# Church and Wellesley                                           87
# Commerce Court                                                100
# Davisville                                                     38
# Davisville North                                                8
# Deer Park                                                      14
# Design Exchange                                               100
# Dovercourt Village                                             20
# Dufferin                                                       20
# Exhibition Place                                               21
# First Canadian Place                                          100
# Forest Hill North                                               4
# Forest Hill SE                                                 14
# Forest Hill West                                                4
# Garden District                                               100
# Grange Park                                                   100
# Harbord                                                        34
# Harbourfront                                                   48
# Harbourfront East                                             100
# Harbourfront West                                              14
# High Park                                                      23
# India Bazaar                                                   18
# Island airport                                                 14
# Kensington Market                                             100
# King                                                          100
# King and Spadina                                               14
# Lawrence Park                                                   3
# Little Portugal                                                62
# Moore Park                                                      2
# North Midtown                                                  23
# North Toronto West                                             16
# Parkdale                                                       15
# Parkdale Village                                               21
# Railway Lands                                                  14
# Rathnelly                                                      14
# Regent Park                                                    48
# Richmond                                                      100
# Riverdale                                                      42
# Roncesvalles                                                   15
# Rosedale                                                        4
# Roselawn                                                        2
# Runnymede                                                      38
# Ryerson                                                       100
# South Hill                                                     14
# South Niagara                                                  14
# St. James Town                                                146
# Stn A PO Boxes 25 The Esplanade                                94
# Studio District                                                38
# Summerhill East                                                 2
# Summerhill West                                                14
# Swansea                                                        38
# The Annex                                                      23
# The Beaches                                                     4
# The Beaches West                                               18
# The Danforth West                                              42
# The Junction South                                             23
# Toronto Dominion Centre                                       100
# Toronto Islands                                               100
# Trinity                                                        62
# Underground city                                              100
# Union Station                                                 100
# University of Toronto                                          34
# Victoria Hotel                                                100
# Yorkville                                                      23

# %%
# how many unique categories
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 237 uniques categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# %%
# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

# %%
# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %%
# group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio  \
# 0                                            Adelaide     0.000000
# 1                                       Bathurst Quay     0.000000
# 2                                         Berczy Park     0.000000
# 3                                            Brockton     0.047619
# 4   Business Reply Mail Processing Centre 969 Eastern     0.052632
# 5                                            CN Tower     0.000000
# 6                                         Cabbagetown     0.000000
# 7                                  Central Bay Street     0.011364
# 8                                           Chinatown     0.000000
# 9                                            Christie     0.000000
# 10                               Church and Wellesley     0.011494
# 11                                     Commerce Court     0.000000
# 12                                         Davisville     0.000000
# 13                                   Davisville North     0.000000
# 14                                          Deer Park     0.000000
# 15                                    Design Exchange     0.000000
# 16                                 Dovercourt Village     0.000000
# 17                                           Dufferin     0.000000
# 18                                   Exhibition Place     0.047619
# 19                               First Canadian Place     0.000000
# 20                                  Forest Hill North     0.000000
# 21                                     Forest Hill SE     0.000000
# 22                                   Forest Hill West     0.000000
# 23                                    Garden District     0.000000
# 24                                        Grange Park     0.000000
# 25                                            Harbord     0.000000
# 26                                       Harbourfront     0.020833
# 27                                  Harbourfront East     0.000000
# 28                                  Harbourfront West     0.000000
# 29                                          High Park     0.000000
# 30                                       India Bazaar     0.000000
# 31                                     Island airport     0.000000
# 32                                  Kensington Market     0.000000
# 33                                               King     0.000000
# 34                                   King and Spadina     0.000000
# 35                                      Lawrence Park     0.000000
# 36                                    Little Portugal     0.016129
# 37                                         Moore Park     0.000000
# 38                                      North Midtown     0.000000
# 39                                 North Toronto West     0.062500
# 40                                           Parkdale     0.000000
# 41                                   Parkdale Village     0.047619
# 42                                      Railway Lands     0.000000
# 43                                          Rathnelly     0.000000
# 44                                        Regent Park     0.020833
# 45                                           Richmond     0.000000
# 46                                          Riverdale     0.023810
# 47                                       Roncesvalles     0.000000
# 48                                           Rosedale     0.000000
# 49                                           Roselawn     0.000000
# 50                                          Runnymede     0.000000
# 51                                            Ryerson     0.000000
# 52                                         South Hill     0.000000
# 53                                      South Niagara     0.000000
# 54                                     St. James Town     0.000000
# 55                    Stn A PO Boxes 25 The Esplanade     0.000000
# 56                                    Studio District     0.026316
# 57                                    Summerhill East     0.000000
# 58                                    Summerhill West     0.000000
# 59                                            Swansea     0.000000
# 60                                          The Annex     0.000000
# 61                                        The Beaches     0.000000
# 62                                   The Beaches West     0.000000
# 63                                  The Danforth West     0.023810
# 64                                 The Junction South     0.000000
# 65                            Toronto Dominion Centre     0.000000
# 66                                    Toronto Islands     0.000000
# 67                                            Trinity     0.016129
# 68                                   Underground city     0.000000
# 69                                      Union Station     0.000000
# 70                              University of Toronto     0.000000
# 71                                     Victoria Hotel     0.000000
# 72                                          Yorkville     0.000000
#
#     Adult Boutique  Afghan Restaurant   Airport  Airport Food Court  \
# 0         0.000000           0.000000  0.000000            0.000000
# 1         0.000000           0.000000  0.071429            0.071429
# 2         0.000000           0.000000  0.000000            0.000000
# 3         0.000000           0.000000  0.000000            0.000000
# 4         0.000000           0.000000  0.000000            0.000000
# 5         0.000000           0.000000  0.071429            0.071429
# 6         0.000000           0.000000  0.000000            0.000000
# 7         0.000000           0.000000  0.000000            0.000000
# 8         0.000000           0.000000  0.000000            0.000000
# 9         0.000000           0.000000  0.000000            0.000000
# 10        0.011494           0.011494  0.000000            0.000000
# 11        0.000000           0.000000  0.000000            0.000000
# 12        0.000000           0.000000  0.000000            0.000000
# 13        0.000000           0.000000  0.000000            0.000000
# 14        0.000000           0.000000  0.000000            0.000000
# 15        0.000000           0.000000  0.000000            0.000000
# 16        0.000000           0.000000  0.000000            0.000000
# 17        0.000000           0.000000  0.000000            0.000000
# 18        0.000000           0.000000  0.000000            0.000000
# 19        0.000000           0.000000  0.000000            0.000000
# 20        0.000000           0.000000  0.000000            0.000000
# 21        0.000000           0.000000  0.000000            0.000000
# 22        0.000000           0.000000  0.000000            0.000000
# 23        0.000000           0.000000  0.000000            0.000000
# 24        0.000000           0.000000  0.000000            0.000000
# 25        0.000000           0.000000  0.000000            0.000000
# 26        0.000000           0.000000  0.000000            0.000000
# 27        0.000000           0.000000  0.000000            0.000000
# 28        0.000000           0.000000  0.071429            0.071429
# 29        0.000000           0.000000  0.000000            0.000000
# 30        0.000000           0.000000  0.000000            0.000000
# 31        0.000000           0.000000  0.071429            0.071429
# 32        0.000000           0.000000  0.000000            0.000000
# 33        0.000000           0.000000  0.000000            0.000000
# 34        0.000000           0.000000  0.071429            0.071429
# 35        0.000000           0.000000  0.000000            0.000000
# 36        0.000000           0.000000  0.000000            0.000000
# 37        0.000000           0.000000  0.000000            0.000000
# 38        0.000000           0.000000  0.000000            0.000000
# 39        0.000000           0.000000  0.000000            0.000000
# 40        0.000000           0.000000  0.000000            0.000000
# 41        0.000000           0.000000  0.000000            0.000000
# 42        0.000000           0.000000  0.071429            0.071429
# 43        0.000000           0.000000  0.000000            0.000000
# 44        0.000000           0.000000  0.000000            0.000000
# 45        0.000000           0.000000  0.000000            0.000000
# 46        0.000000           0.000000  0.000000            0.000000
# 47        0.000000           0.000000  0.000000            0.000000
# 48        0.000000           0.000000  0.000000            0.000000
# 49        0.000000           0.000000  0.000000            0.000000
# 50        0.000000           0.000000  0.000000            0.000000
# 51        0.000000           0.000000  0.000000            0.000000
# 52        0.000000           0.000000  0.000000            0.000000
# 53        0.000000           0.000000  0.071429            0.071429
# 54        0.000000           0.000000  0.000000            0.000000
# 55        0.000000           0.000000  0.000000            0.000000
# 56        0.000000           0.000000  0.000000            0.000000
# 57        0.000000           0.000000  0.000000            0.000000
# 58        0.000000           0.000000  0.000000            0.000000
# 59        0.000000           0.000000  0.000000            0.000000
# 60        0.000000           0.000000  0.000000            0.000000
# 61        0.000000           0.000000  0.000000            0.000000
# 62        0.000000           0.000000  0.000000            0.000000
# 63        0.000000           0.000000  0.000000            0.000000
# 64        0.000000           0.000000  0.000000            0.000000
# 65        0.000000           0.000000  0.000000            0.000000
# 66        0.000000           0.000000  0.000000            0.000000
# 67        0.000000           0.000000  0.000000            0.000000
# 68        0.000000           0.000000  0.000000            0.000000
# 69        0.000000           0.000000  0.000000            0.000000
# 70        0.000000           0.000000  0.000000            0.000000
# 71        0.000000           0.000000  0.000000            0.000000
# 72        0.000000           0.000000  0.000000            0.000000
#
#     Airport Gate  Airport Lounge  Airport Service  Airport Terminal  \
# 0       0.000000        0.000000         0.000000          0.000000
# 1       0.071429        0.142857         0.142857          0.142857
# 2       0.000000        0.000000         0.000000          0.000000
# 3       0.000000        0.000000         0.000000          0.000000
# 4       0.000000        0.000000         0.000000          0.000000
# 5       0.071429        0.142857         0.142857          0.142857
# 6       0.000000        0.000000         0.000000          0.000000
# 7       0.000000        0.000000         0.000000          0.000000
# 8       0.000000        0.000000         0.000000          0.000000
# 9       0.000000        0.000000         0.000000          0.000000
# 10      0.000000        0.000000         0.000000          0.000000
# 11      0.000000        0.000000         0.000000          0.000000
# 12      0.000000        0.000000         0.000000          0.000000
# 13      0.000000        0.000000         0.000000          0.000000
# 14      0.000000        0.000000         0.000000          0.000000
# 15      0.000000        0.000000         0.000000          0.000000
# 16      0.000000        0.000000         0.000000          0.000000
# 17      0.000000        0.000000         0.000000          0.000000
# 18      0.000000        0.000000         0.000000          0.000000
# 19      0.000000        0.000000         0.000000          0.000000
# 20      0.000000        0.000000         0.000000          0.000000
# 21      0.000000        0.000000         0.000000          0.000000
# 22      0.000000        0.000000         0.000000          0.000000
# 23      0.000000        0.000000         0.000000          0.000000
# 24      0.000000        0.000000         0.000000          0.000000
# 25      0.000000        0.000000         0.000000          0.000000
# 26      0.000000        0.000000         0.000000          0.000000
# 27      0.000000        0.000000         0.000000          0.000000
# 28      0.071429        0.142857         0.142857          0.142857
# 29      0.000000        0.000000         0.000000          0.000000
# 30      0.000000        0.000000         0.000000          0.000000
# 31      0.071429        0.142857         0.142857          0.142857
# 32      0.000000        0.000000         0.000000          0.000000
# 33      0.000000        0.000000         0.000000          0.000000
# 34      0.071429        0.142857         0.142857          0.142857
# 35      0.000000        0.000000         0.000000          0.000000
# 36      0.000000        0.000000         0.000000          0.000000
# 37      0.000000        0.000000         0.000000          0.000000
# 38      0.000000        0.000000         0.000000          0.000000
# 39      0.000000        0.000000         0.000000          0.000000
# 40      0.000000        0.000000         0.000000          0.000000
# 41      0.000000        0.000000         0.000000          0.000000
# 42      0.071429        0.142857         0.142857          0.142857
# 43      0.000000        0.000000         0.000000          0.000000
# 44      0.000000        0.000000         0.000000          0.000000
# 45      0.000000        0.000000         0.000000          0.000000
# 46      0.000000        0.000000         0.000000          0.000000
# 47      0.000000        0.000000         0.000000          0.000000
# 48      0.000000        0.000000         0.000000          0.000000
# 49      0.000000        0.000000         0.000000          0.000000
# 50      0.000000        0.000000         0.000000          0.000000
# 51      0.000000        0.000000         0.000000          0.000000
# 52      0.000000        0.000000         0.000000          0.000000
# 53      0.071429        0.142857         0.142857          0.142857
# 54      0.000000        0.000000         0.000000          0.000000
# 55      0.000000        0.000000         0.000000          0.000000
# 56      0.000000        0.000000         0.000000          0.000000
# 57      0.000000        0.000000         0.000000          0.000000
# 58      0.000000        0.000000         0.000000          0.000000
# 59      0.000000        0.000000         0.000000          0.000000
# 60      0.000000        0.000000         0.000000          0.000000
# 61      0.000000        0.000000         0.000000          0.000000
# 62      0.000000        0.000000         0.000000          0.000000
# 63      0.000000        0.000000         0.000000          0.000000
# 64      0.000000        0.000000         0.000000          0.000000
# 65      0.000000        0.000000         0.000000          0.000000
# 66      0.000000        0.000000         0.000000          0.000000
# 67      0.000000        0.000000         0.000000          0.000000
# 68      0.000000        0.000000         0.000000          0.000000
# 69      0.000000        0.000000         0.000000          0.000000
# 70      0.000000        0.000000         0.000000          0.000000
# 71      0.000000        0.000000         0.000000          0.000000
# 72      0.000000        0.000000         0.000000          0.000000
#
#     American Restaurant  Antique Shop  Aquarium  Art Gallery  Art Museum  \
# 0              0.040000      0.000000      0.00     0.010000    0.010000
# 1              0.000000      0.000000      0.00     0.000000    0.000000
# 2              0.000000      0.000000      0.00     0.018182    0.000000
# 3              0.000000      0.000000      0.00     0.000000    0.000000
# 4              0.000000      0.000000      0.00     0.000000    0.000000
# 5              0.000000      0.000000      0.00     0.000000    0.000000
# 6              0.000000      0.000000      0.00     0.000000    0.000000
# 7              0.011364      0.000000      0.00     0.000000    0.011364
# 8              0.000000      0.000000      0.00     0.000000    0.000000
# 9              0.000000      0.000000      0.00     0.000000    0.000000
# 10             0.011494      0.000000      0.00     0.000000    0.000000
# 11             0.040000      0.000000      0.00     0.010000    0.000000
# 12             0.000000      0.000000      0.00     0.000000    0.000000
# 13             0.000000      0.000000      0.00     0.000000    0.000000
# 14             0.071429      0.000000      0.00     0.000000    0.000000
# 15             0.030000      0.000000      0.00     0.010000    0.000000
# 16             0.000000      0.000000      0.00     0.000000    0.000000
# 17             0.000000      0.000000      0.00     0.000000    0.000000
# 18             0.000000      0.000000      0.00     0.000000    0.000000
# 19             0.030000      0.000000      0.00     0.010000    0.000000
# 20             0.000000      0.000000      0.00     0.000000    0.000000
# 21             0.071429      0.000000      0.00     0.000000    0.000000
# 22             0.000000      0.000000      0.00     0.000000    0.000000
# 23             0.010000      0.000000      0.00     0.010000    0.000000
# 24             0.000000      0.000000      0.00     0.000000    0.000000
# 25             0.000000      0.000000      0.00     0.000000    0.000000
# 26             0.000000      0.020833      0.00     0.020833    0.000000
# 27             0.000000      0.000000      0.05     0.010000    0.000000
# 28             0.000000      0.000000      0.00     0.000000    0.000000
# 29             0.000000      0.043478      0.00     0.000000    0.000000
# 30             0.000000      0.000000      0.00     0.000000    0.000000
# 31             0.000000      0.000000      0.00     0.000000    0.000000
# 32             0.000000      0.000000      0.00     0.000000    0.000000
# 33             0.040000      0.000000      0.00     0.010000    0.010000
# 34             0.000000      0.000000      0.00     0.000000    0.000000
# 35             0.000000      0.000000      0.00     0.000000    0.000000
# 36             0.000000      0.000000      0.00     0.016129    0.000000
# 37             0.000000      0.000000      0.00     0.000000    0.000000
# 38             0.043478      0.000000      0.00     0.000000    0.000000
# 39             0.000000      0.000000      0.00     0.000000    0.000000
# 40             0.000000      0.000000      0.00     0.000000    0.000000
# 41             0.000000      0.000000      0.00     0.000000    0.000000
# 42             0.000000      0.000000      0.00     0.000000    0.000000
# 43             0.071429      0.000000      0.00     0.000000    0.000000
# 44             0.000000      0.020833      0.00     0.020833    0.000000
# 45             0.040000      0.000000      0.00     0.010000    0.010000
# 46             0.023810      0.000000      0.00     0.000000    0.000000
# 47             0.000000      0.000000      0.00     0.000000    0.000000
# 48             0.000000      0.000000      0.00     0.000000    0.000000
# 49             0.000000      0.000000      0.00     0.000000    0.000000
# 50             0.000000      0.000000      0.00     0.000000    0.000000
# 51             0.010000      0.000000      0.00     0.010000    0.000000
# 52             0.071429      0.000000      0.00     0.000000    0.000000
# 53             0.000000      0.000000      0.00     0.000000    0.000000
# 54             0.013699      0.000000      0.00     0.006849    0.000000
# 55             0.000000      0.010638      0.00     0.021277    0.000000
# 56             0.052632      0.000000      0.00     0.000000    0.000000
# 57             0.000000      0.000000      0.00     0.000000    0.000000
# 58             0.071429      0.000000      0.00     0.000000    0.000000
# 59             0.000000      0.000000      0.00     0.000000    0.000000
# 60             0.043478      0.000000      0.00     0.000000    0.000000
# 61             0.000000      0.000000      0.00     0.000000    0.000000
# 62             0.000000      0.000000      0.00     0.000000    0.000000
# 63             0.023810      0.000000      0.00     0.000000    0.000000
# 64             0.000000      0.043478      0.00     0.000000    0.000000
# 65             0.030000      0.000000      0.00     0.010000    0.000000
# 66             0.000000      0.000000      0.05     0.010000    0.000000
# 67             0.000000      0.000000      0.00     0.016129    0.000000
# 68             0.030000      0.000000      0.00     0.010000    0.000000
# 69             0.000000      0.000000      0.05     0.010000    0.000000
# 70             0.000000      0.000000      0.00     0.000000    0.000000
# 71             0.040000      0.000000      0.00     0.010000    0.000000
# 72             0.043478      0.000000      0.00     0.000000    0.000000
#
#     Arts & Crafts Store  Asian Restaurant  Auto Workshop  BBQ Joint  \
# 0              0.000000          0.020000       0.000000   0.000000
# 1              0.000000          0.000000       0.000000   0.000000
# 2              0.000000          0.000000       0.000000   0.000000
# 3              0.000000          0.000000       0.000000   0.000000
# 4              0.000000          0.000000       0.052632   0.000000
# 5              0.000000          0.000000       0.000000   0.000000
# 6              0.000000          0.000000       0.000000   0.000000
# 7              0.011364          0.000000       0.000000   0.000000
# 8              0.010000          0.000000       0.000000   0.000000
# 9              0.000000          0.000000       0.000000   0.000000
# 10             0.011494          0.000000       0.000000   0.000000
# 11             0.000000          0.000000       0.000000   0.000000
# 12             0.000000          0.000000       0.000000   0.000000
# 13             0.000000          0.000000       0.000000   0.000000
# 14             0.000000          0.000000       0.000000   0.000000
# 15             0.000000          0.010000       0.000000   0.000000
# 16             0.000000          0.000000       0.000000   0.000000
# 17             0.000000          0.000000       0.000000   0.000000
# 18             0.000000          0.000000       0.000000   0.000000
# 19             0.000000          0.020000       0.000000   0.000000
# 20             0.000000          0.000000       0.000000   0.000000
# 21             0.000000          0.000000       0.000000   0.000000
# 22             0.000000          0.000000       0.000000   0.000000
# 23             0.000000          0.000000       0.000000   0.000000
# 24             0.010000          0.000000       0.000000   0.000000
# 25             0.000000          0.000000       0.000000   0.000000
# 26             0.000000          0.000000       0.000000   0.000000
# 27             0.000000          0.000000       0.000000   0.000000
# 28             0.000000          0.000000       0.000000   0.000000
# 29             0.043478          0.000000       0.000000   0.000000
# 30             0.000000          0.000000       0.000000   0.000000
# 31             0.000000          0.000000       0.000000   0.000000
# 32             0.010000          0.000000       0.000000   0.000000
# 33             0.000000          0.020000       0.000000   0.000000
# 34             0.000000          0.000000       0.000000   0.000000
# 35             0.000000          0.000000       0.000000   0.000000
# 36             0.000000          0.048387       0.000000   0.000000
# 37             0.000000          0.000000       0.000000   0.000000
# 38             0.000000          0.000000       0.000000   0.043478
# 39             0.000000          0.000000       0.000000   0.000000
# 40             0.000000          0.000000       0.000000   0.000000
# 41             0.000000          0.000000       0.000000   0.000000
# 42             0.000000          0.000000       0.000000   0.000000
# 43             0.000000          0.000000       0.000000   0.000000
# 44             0.000000          0.000000       0.000000   0.000000
# 45             0.000000          0.020000       0.000000   0.000000
# 46             0.000000          0.000000       0.000000   0.000000
# 47             0.000000          0.000000       0.000000   0.000000
# 48             0.000000          0.000000       0.000000   0.000000
# 49             0.000000          0.000000       0.000000   0.000000
# 50             0.000000          0.000000       0.000000   0.000000
# 51             0.000000          0.000000       0.000000   0.000000
# 52             0.000000          0.000000       0.000000   0.000000
# 53             0.000000          0.000000       0.000000   0.000000
# 54             0.000000          0.000000       0.000000   0.006849
# 55             0.000000          0.000000       0.000000   0.000000
# 56             0.000000          0.000000       0.000000   0.000000
# 57             0.000000          0.000000       0.000000   0.000000
# 58             0.000000          0.000000       0.000000   0.000000
# 59             0.000000          0.000000       0.000000   0.000000
# 60             0.000000          0.000000       0.000000   0.043478
# 61             0.000000          0.000000       0.000000   0.000000
# 62             0.000000          0.000000       0.000000   0.000000
# 63             0.000000          0.000000       0.000000   0.000000
# 64             0.043478          0.000000       0.000000   0.000000
# 65             0.000000          0.010000       0.000000   0.000000
# 66             0.000000          0.000000       0.000000   0.000000
# 67             0.000000          0.048387       0.000000   0.000000
# 68             0.000000          0.020000       0.000000   0.000000
# 69             0.000000          0.000000       0.000000   0.000000
# 70             0.000000          0.000000       0.000000   0.000000
# 71             0.000000          0.000000       0.000000   0.000000
# 72             0.000000          0.000000       0.000000   0.043478
#
#     Baby Store  Bagel Shop    Bakery      Bank       Bar  Baseball Stadium  \
# 0     0.000000    0.000000  0.030000  0.000000  0.040000              0.00
# 1     0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 2     0.000000    0.018182  0.036364  0.000000  0.000000              0.00
# 3     0.000000    0.000000  0.047619  0.000000  0.047619              0.00
# 4     0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 5     0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 6     0.000000    0.000000  0.043478  0.021739  0.021739              0.00
# 7     0.000000    0.000000  0.022727  0.000000  0.022727              0.00
# 8     0.000000    0.010000  0.040000  0.000000  0.040000              0.00
# 9     0.066667    0.000000  0.000000  0.000000  0.000000              0.00
# 10    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 11    0.000000    0.000000  0.030000  0.010000  0.020000              0.00
# 12    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 13    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 14    0.000000    0.071429  0.000000  0.000000  0.000000              0.00
# 15    0.000000    0.000000  0.030000  0.000000  0.020000              0.00
# 16    0.000000    0.000000  0.100000  0.050000  0.050000              0.00
# 17    0.000000    0.000000  0.100000  0.050000  0.050000              0.00
# 18    0.000000    0.000000  0.047619  0.000000  0.047619              0.00
# 19    0.000000    0.000000  0.030000  0.000000  0.030000              0.00
# 20    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 21    0.000000    0.071429  0.000000  0.000000  0.000000              0.00
# 22    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 23    0.000000    0.000000  0.020000  0.010000  0.010000              0.00
# 24    0.000000    0.010000  0.040000  0.000000  0.040000              0.00
# 25    0.000000    0.000000  0.058824  0.000000  0.058824              0.00
# 26    0.000000    0.000000  0.062500  0.020833  0.000000              0.00
# 27    0.000000    0.000000  0.030000  0.010000  0.020000              0.02
# 28    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 29    0.000000    0.000000  0.043478  0.000000  0.086957              0.00
# 30    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 31    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 32    0.000000    0.010000  0.040000  0.000000  0.040000              0.00
# 33    0.000000    0.000000  0.030000  0.000000  0.040000              0.00
# 34    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 35    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 36    0.000000    0.000000  0.032258  0.000000  0.129032              0.00
# 37    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 38    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 39    0.000000    0.062500  0.000000  0.000000  0.000000              0.00
# 40    0.000000    0.000000  0.000000  0.066667  0.066667              0.00
# 41    0.000000    0.000000  0.047619  0.000000  0.047619              0.00
# 42    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 43    0.000000    0.071429  0.000000  0.000000  0.000000              0.00
# 44    0.000000    0.000000  0.062500  0.020833  0.000000              0.00
# 45    0.000000    0.000000  0.030000  0.000000  0.040000              0.00
# 46    0.000000    0.000000  0.023810  0.000000  0.000000              0.00
# 47    0.000000    0.000000  0.000000  0.066667  0.066667              0.00
# 48    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 49    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 50    0.000000    0.000000  0.000000  0.000000  0.026316              0.00
# 51    0.000000    0.000000  0.020000  0.010000  0.010000              0.00
# 52    0.000000    0.071429  0.000000  0.000000  0.000000              0.00
# 53    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 54    0.000000    0.006849  0.034247  0.013699  0.006849              0.00
# 55    0.000000    0.010638  0.021277  0.000000  0.000000              0.00
# 56    0.000000    0.000000  0.052632  0.026316  0.026316              0.00
# 57    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 58    0.000000    0.071429  0.000000  0.000000  0.000000              0.00
# 59    0.000000    0.000000  0.000000  0.000000  0.026316              0.00
# 60    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 61    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 62    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
# 63    0.000000    0.000000  0.023810  0.000000  0.000000              0.00
# 64    0.000000    0.000000  0.043478  0.000000  0.086957              0.00
# 65    0.000000    0.000000  0.030000  0.000000  0.020000              0.00
# 66    0.000000    0.000000  0.030000  0.010000  0.020000              0.02
# 67    0.000000    0.000000  0.032258  0.000000  0.129032              0.00
# 68    0.000000    0.000000  0.030000  0.000000  0.030000              0.00
# 69    0.000000    0.000000  0.030000  0.010000  0.020000              0.02
# 70    0.000000    0.000000  0.058824  0.000000  0.058824              0.00
# 71    0.000000    0.000000  0.030000  0.010000  0.020000              0.00
# 72    0.000000    0.000000  0.000000  0.000000  0.000000              0.00
#
#     Basketball Stadium     Beach  Bed & Breakfast  Beer Bar  Beer Store  \
# 0             0.000000  0.000000             0.00  0.000000    0.000000
# 1             0.000000  0.000000             0.00  0.000000    0.000000
# 2             0.018182  0.018182             0.00  0.036364    0.000000
# 3             0.000000  0.000000             0.00  0.000000    0.000000
# 4             0.000000  0.000000             0.00  0.000000    0.000000
# 5             0.000000  0.000000             0.00  0.000000    0.000000
# 6             0.000000  0.000000             0.00  0.000000    0.021739
# 7             0.000000  0.000000             0.00  0.000000    0.000000
# 8             0.000000  0.000000             0.01  0.010000    0.000000
# 9             0.000000  0.000000             0.00  0.000000    0.000000
# 10            0.000000  0.000000             0.00  0.000000    0.000000
# 11            0.000000  0.000000             0.00  0.020000    0.000000
# 12            0.000000  0.000000             0.00  0.000000    0.000000
# 13            0.000000  0.000000             0.00  0.000000    0.000000
# 14            0.000000  0.000000             0.00  0.000000    0.000000
# 15            0.010000  0.000000             0.00  0.020000    0.000000
# 16            0.000000  0.000000             0.00  0.000000    0.000000
# 17            0.000000  0.000000             0.00  0.000000    0.000000
# 18            0.000000  0.000000             0.00  0.000000    0.000000
# 19            0.000000  0.000000             0.00  0.020000    0.000000
# 20            0.000000  0.000000             0.00  0.000000    0.000000
# 21            0.000000  0.000000             0.00  0.000000    0.000000
# 22            0.000000  0.000000             0.00  0.000000    0.000000
# 23            0.000000  0.000000             0.00  0.010000    0.000000
# 24            0.000000  0.000000             0.01  0.010000    0.000000
# 25            0.000000  0.000000             0.00  0.029412    0.029412
# 26            0.000000  0.000000             0.00  0.000000    0.020833
# 27            0.010000  0.000000             0.00  0.010000    0.000000
# 28            0.000000  0.000000             0.00  0.000000    0.000000
# 29            0.000000  0.000000             0.00  0.000000    0.000000
# 30            0.000000  0.000000             0.00  0.000000    0.000000
# 31            0.000000  0.000000             0.00  0.000000    0.000000
# 32            0.000000  0.000000             0.01  0.010000    0.000000
# 33            0.000000  0.000000             0.00  0.000000    0.000000
# 34            0.000000  0.000000             0.00  0.000000    0.000000
# 35            0.000000  0.000000             0.00  0.000000    0.000000
# 36            0.000000  0.000000             0.00  0.000000    0.000000
# 37            0.000000  0.000000             0.00  0.000000    0.000000
# 38            0.000000  0.000000             0.00  0.000000    0.000000
# 39            0.000000  0.000000             0.00  0.000000    0.000000
# 40            0.000000  0.000000             0.00  0.000000    0.000000
# 41            0.000000  0.000000             0.00  0.000000    0.000000
# 42            0.000000  0.000000             0.00  0.000000    0.000000
# 43            0.000000  0.000000             0.00  0.000000    0.000000
# 44            0.000000  0.000000             0.00  0.000000    0.020833
# 45            0.000000  0.000000             0.00  0.000000    0.000000
# 46            0.000000  0.000000             0.00  0.000000    0.000000
# 47            0.000000  0.000000             0.00  0.000000    0.000000
# 48            0.000000  0.000000             0.00  0.000000    0.000000
# 49            0.000000  0.000000             0.00  0.000000    0.000000
# 50            0.000000  0.000000             0.00  0.000000    0.000000
# 51            0.000000  0.000000             0.00  0.010000    0.000000
# 52            0.000000  0.000000             0.00  0.000000    0.000000
# 53            0.000000  0.000000             0.00  0.000000    0.000000
# 54            0.000000  0.000000             0.00  0.013699    0.006849
# 55            0.010638  0.000000             0.00  0.031915    0.000000
# 56            0.000000  0.000000             0.00  0.000000    0.000000
# 57            0.000000  0.000000             0.00  0.000000    0.000000
# 58            0.000000  0.000000             0.00  0.000000    0.000000
# 59            0.000000  0.000000             0.00  0.000000    0.000000
# 60            0.000000  0.000000             0.00  0.000000    0.000000
# 61            0.000000  0.000000             0.00  0.000000    0.000000
# 62            0.000000  0.000000             0.00  0.000000    0.000000
# 63            0.000000  0.000000             0.00  0.000000    0.000000
# 64            0.000000  0.000000             0.00  0.000000    0.000000
# 65            0.010000  0.000000             0.00  0.020000    0.000000
# 66            0.010000  0.000000             0.00  0.010000    0.000000
# 67            0.000000  0.000000             0.00  0.000000    0.000000
# 68            0.000000  0.000000             0.00  0.020000    0.000000
# 69            0.010000  0.000000             0.00  0.010000    0.000000
# 70            0.000000  0.000000             0.00  0.029412    0.029412
# 71            0.000000  0.000000             0.00  0.020000    0.000000
# 72            0.000000  0.000000             0.00  0.000000    0.000000
#
#     Belgian Restaurant    Bistro  Boat or Ferry  Bookstore  Boutique  \
# 0             0.000000  0.000000       0.000000   0.010000  0.000000
# 1             0.000000  0.000000       0.071429   0.000000  0.071429
# 2             0.018182  0.018182       0.000000   0.000000  0.000000
# 3             0.000000  0.000000       0.000000   0.000000  0.000000
# 4             0.000000  0.000000       0.000000   0.000000  0.000000
# 5             0.000000  0.000000       0.071429   0.000000  0.071429
# 6             0.000000  0.000000       0.000000   0.000000  0.000000
# 7             0.000000  0.000000       0.000000   0.000000  0.000000
# 8             0.010000  0.000000       0.000000   0.000000  0.000000
# 9             0.000000  0.000000       0.000000   0.000000  0.000000
# 10            0.000000  0.000000       0.000000   0.011494  0.000000
# 11            0.000000  0.000000       0.000000   0.010000  0.000000
# 12            0.000000  0.000000       0.000000   0.000000  0.000000
# 13            0.000000  0.000000       0.000000   0.000000  0.000000
# 14            0.000000  0.000000       0.000000   0.000000  0.000000
# 15            0.000000  0.000000       0.000000   0.010000  0.000000
# 16            0.000000  0.000000       0.000000   0.000000  0.000000
# 17            0.000000  0.000000       0.000000   0.000000  0.000000
# 18            0.000000  0.000000       0.000000   0.000000  0.000000
# 19            0.000000  0.000000       0.000000   0.010000  0.000000
# 20            0.000000  0.000000       0.000000   0.000000  0.000000
# 21            0.000000  0.000000       0.000000   0.000000  0.000000
# 22            0.000000  0.000000       0.000000   0.000000  0.000000
# 23            0.000000  0.000000       0.000000   0.010000  0.000000
# 24            0.010000  0.000000       0.000000   0.000000  0.000000
# 25            0.000000  0.000000       0.000000   0.058824  0.000000
# 26            0.000000  0.000000       0.000000   0.000000  0.000000
# 27            0.000000  0.010000       0.000000   0.000000  0.000000
# 28            0.000000  0.000000       0.071429   0.000000  0.071429
# 29            0.000000  0.000000       0.000000   0.043478  0.000000
# 30            0.000000  0.000000       0.000000   0.000000  0.000000
# 31            0.000000  0.000000       0.071429   0.000000  0.071429
# 32            0.010000  0.000000       0.000000   0.000000  0.000000
# 33            0.000000  0.000000       0.000000   0.010000  0.000000
# 34            0.000000  0.000000       0.071429   0.000000  0.071429
# 35            0.000000  0.000000       0.000000   0.000000  0.000000
# 36            0.000000  0.016129       0.000000   0.000000  0.000000
# 37            0.000000  0.000000       0.000000   0.000000  0.000000
# 38            0.000000  0.000000       0.000000   0.000000  0.000000
# 39            0.000000  0.000000       0.000000   0.000000  0.000000
# 40            0.000000  0.000000       0.000000   0.066667  0.000000
# 41            0.000000  0.000000       0.000000   0.000000  0.000000
# 42            0.000000  0.000000       0.071429   0.000000  0.071429
# 43            0.000000  0.000000       0.000000   0.000000  0.000000
# 44            0.000000  0.000000       0.000000   0.000000  0.000000
# 45            0.000000  0.000000       0.000000   0.010000  0.000000
# 46            0.000000  0.000000       0.000000   0.023810  0.000000
# 47            0.000000  0.000000       0.000000   0.066667  0.000000
# 48            0.000000  0.000000       0.000000   0.000000  0.000000
# 49            0.000000  0.000000       0.000000   0.000000  0.000000
# 50            0.000000  0.000000       0.000000   0.026316  0.026316
# 51            0.000000  0.000000       0.000000   0.010000  0.000000
# 52            0.000000  0.000000       0.000000   0.000000  0.000000
# 53            0.000000  0.000000       0.071429   0.000000  0.071429
# 54            0.000000  0.000000       0.000000   0.006849  0.000000
# 55            0.010638  0.010638       0.000000   0.010638  0.000000
# 56            0.000000  0.000000       0.000000   0.026316  0.000000
# 57            0.000000  0.000000       0.000000   0.000000  0.000000
# 58            0.000000  0.000000       0.000000   0.000000  0.000000
# 59            0.000000  0.000000       0.000000   0.026316  0.026316
# 60            0.000000  0.000000       0.000000   0.000000  0.000000
# 61            0.000000  0.000000       0.000000   0.000000  0.000000
# 62            0.000000  0.000000       0.000000   0.000000  0.000000
# 63            0.000000  0.000000       0.000000   0.023810  0.000000
# 64            0.000000  0.000000       0.000000   0.043478  0.000000
# 65            0.000000  0.000000       0.000000   0.010000  0.000000
# 66            0.000000  0.010000       0.000000   0.000000  0.000000
# 67            0.000000  0.016129       0.000000   0.000000  0.000000
# 68            0.000000  0.000000       0.000000   0.010000  0.000000
# 69            0.000000  0.010000       0.000000   0.000000  0.000000
# 70            0.000000  0.000000       0.000000   0.058824  0.000000
# 71            0.000000  0.000000       0.000000   0.010000  0.000000
# 72            0.000000  0.000000       0.000000   0.000000  0.000000
#
#     Brazilian Restaurant  Breakfast Spot   Brewery  Bubble Tea Shop  \
# 0                   0.01        0.020000  0.000000         0.000000
# 1                   0.00        0.000000  0.000000         0.000000
# 2                   0.00        0.018182  0.000000         0.000000
# 3                   0.00        0.095238  0.000000         0.000000
# 4                   0.00        0.000000  0.052632         0.000000
# 5                   0.00        0.000000  0.000000         0.000000
# 6                   0.00        0.021739  0.000000         0.000000
# 7                   0.00        0.000000  0.000000         0.022727
# 8                   0.00        0.010000  0.010000         0.010000
# 9                   0.00        0.000000  0.000000         0.000000
# 10                  0.00        0.011494  0.000000         0.022989
# 11                  0.00        0.010000  0.000000         0.000000
# 12                  0.00        0.000000  0.026316         0.000000
# 13                  0.00        0.125000  0.000000         0.000000
# 14                  0.00        0.000000  0.000000         0.000000
# 15                  0.00        0.010000  0.000000         0.000000
# 16                  0.05        0.000000  0.050000         0.000000
# 17                  0.05        0.000000  0.050000         0.000000
# 18                  0.00        0.095238  0.000000         0.000000
# 19                  0.01        0.010000  0.000000         0.000000
# 20                  0.00        0.000000  0.000000         0.000000
# 21                  0.00        0.000000  0.000000         0.000000
# 22                  0.00        0.000000  0.000000         0.000000
# 23                  0.00        0.000000  0.000000         0.020000
# 24                  0.00        0.010000  0.010000         0.010000
# 25                  0.00        0.000000  0.000000         0.000000
# 26                  0.00        0.041667  0.020833         0.000000
# 27                  0.00        0.000000  0.030000         0.010000
# 28                  0.00        0.000000  0.000000         0.000000
# 29                  0.00        0.000000  0.000000         0.000000
# 30                  0.00        0.000000  0.055556         0.000000
# 31                  0.00        0.000000  0.000000         0.000000
# 32                  0.00        0.010000  0.010000         0.010000
# 33                  0.01        0.020000  0.000000         0.000000
# 34                  0.00        0.000000  0.000000         0.000000
# 35                  0.00        0.000000  0.000000         0.000000
# 36                  0.00        0.000000  0.016129         0.000000
# 37                  0.00        0.000000  0.000000         0.000000
# 38                  0.00        0.000000  0.000000         0.000000
# 39                  0.00        0.000000  0.000000         0.000000
# 40                  0.00        0.133333  0.000000         0.000000
# 41                  0.00        0.095238  0.000000         0.000000
# 42                  0.00        0.000000  0.000000         0.000000
# 43                  0.00        0.000000  0.000000         0.000000
# 44                  0.00        0.041667  0.020833         0.000000
# 45                  0.01        0.020000  0.000000         0.000000
# 46                  0.00        0.000000  0.023810         0.023810
# 47                  0.00        0.133333  0.000000         0.000000
# 48                  0.00        0.000000  0.000000         0.000000
# 49                  0.00        0.000000  0.000000         0.000000
# 50                  0.00        0.000000  0.000000         0.000000
# 51                  0.00        0.000000  0.000000         0.020000
# 52                  0.00        0.000000  0.000000         0.000000
# 53                  0.00        0.000000  0.000000         0.000000
# 54                  0.00        0.027397  0.000000         0.000000
# 55                  0.00        0.021277  0.000000         0.000000
# 56                  0.00        0.000000  0.026316         0.000000
# 57                  0.00        0.000000  0.000000         0.000000
# 58                  0.00        0.000000  0.000000         0.000000
# 59                  0.00        0.000000  0.000000         0.000000
# 60                  0.00        0.000000  0.000000         0.000000
# 61                  0.00        0.000000  0.000000         0.000000
# 62                  0.00        0.000000  0.055556         0.000000
# 63                  0.00        0.000000  0.023810         0.023810
# 64                  0.00        0.000000  0.000000         0.000000
# 65                  0.00        0.010000  0.000000         0.000000
# ...
# 7           0.000000                    0.00          0.000000  0.00000
# 8           0.000000                    0.01          0.010000  0.00000
# 9           0.000000                    0.00          0.000000  0.00000
# 10          0.011494                    0.00          0.000000  0.00000
# 11          0.000000                    0.00          0.000000  0.00000
# 12          0.000000                    0.00          0.026316  0.00000
# 13          0.000000                    0.00          0.000000  0.00000
# 14          0.000000                    0.00          0.000000  0.00000
# 15          0.000000                    0.00          0.000000  0.00000
# 16          0.000000                    0.00          0.000000  0.00000
# 17          0.000000                    0.00          0.000000  0.00000
# 18          0.000000                    0.00          0.000000  0.00000
# 19          0.000000                    0.00          0.000000  0.00000
# 20          0.000000                    0.00          0.000000  0.25000
# 21          0.000000                    0.00          0.000000  0.00000
# 22          0.000000                    0.00          0.000000  0.25000
# 23          0.000000                    0.00          0.010000  0.00000
# 24          0.000000                    0.01          0.010000  0.00000
# 25          0.000000                    0.00          0.000000  0.00000
# 26          0.000000                    0.00          0.000000  0.00000
# 27          0.000000                    0.00          0.000000  0.00000
# 28          0.000000                    0.00          0.000000  0.00000
# 29          0.000000                    0.00          0.000000  0.00000
# 30          0.000000                    0.00          0.000000  0.00000
# 31          0.000000                    0.00          0.000000  0.00000
# 32          0.000000                    0.01          0.010000  0.00000
# 33          0.000000                    0.00          0.000000  0.00000
# 34          0.000000                    0.00          0.000000  0.00000
# 35          0.000000                    0.00          0.000000  0.00000
# 36          0.000000                    0.00          0.000000  0.00000
# 37          0.000000                    0.00          0.000000  0.00000
# 38          0.000000                    0.00          0.000000  0.00000
# 39          0.000000                    0.00          0.000000  0.00000
# 40          0.000000                    0.00          0.000000  0.00000
# 41          0.000000                    0.00          0.000000  0.00000
# 42          0.000000                    0.00          0.000000  0.00000
# 43          0.000000                    0.00          0.000000  0.00000
# 44          0.000000                    0.00          0.000000  0.00000
# 45          0.000000                    0.00          0.000000  0.00000
# 46          0.000000                    0.00          0.000000  0.02381
# 47          0.000000                    0.00          0.000000  0.00000
# 48          0.000000                    0.00          0.000000  0.25000
# 49          0.000000                    0.00          0.000000  0.00000
# 50          0.000000                    0.00          0.000000  0.00000
# 51          0.000000                    0.00          0.010000  0.00000
# 52          0.000000                    0.00          0.000000  0.00000
# 53          0.000000                    0.00          0.000000  0.00000
# 54          0.000000                    0.00          0.000000  0.00000
# 55          0.000000                    0.00          0.000000  0.00000
# 56          0.000000                    0.00          0.000000  0.00000
# 57          0.000000                    0.00          0.000000  0.00000
# 58          0.000000                    0.00          0.000000  0.00000
# 59          0.000000                    0.00          0.000000  0.00000
# 60          0.000000                    0.00          0.000000  0.00000
# 61          0.000000                    0.00          0.000000  0.25000
# 62          0.000000                    0.00          0.000000  0.00000
# 63          0.000000                    0.00          0.000000  0.02381
# 64          0.000000                    0.00          0.000000  0.00000
# 65          0.000000                    0.00          0.000000  0.00000
# 66          0.000000                    0.00          0.000000  0.00000
# 67          0.000000                    0.00          0.000000  0.00000
# 68          0.000000                    0.00          0.000000  0.00000
# 69          0.000000                    0.00          0.000000  0.00000
# 70          0.000000                    0.00          0.000000  0.00000
# 71          0.000000                    0.00          0.000000  0.00000
# 72          0.000000                    0.00          0.000000  0.00000
#
#     Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0            0.00                       0.010000          0.000000
# 1            0.00                       0.000000          0.000000
# 2            0.00                       0.018182          0.000000
# 3            0.00                       0.000000          0.000000
# 4            0.00                       0.000000          0.000000
# 5            0.00                       0.000000          0.000000
# 6            0.00                       0.000000          0.000000
# 7            0.00                       0.011364          0.000000
# 8            0.00                       0.060000          0.000000
# 9            0.00                       0.000000          0.000000
# 10           0.00                       0.000000          0.011494
# 11           0.00                       0.010000          0.000000
# 12           0.00                       0.000000          0.000000
# 13           0.00                       0.000000          0.000000
# 14           0.00                       0.000000          0.000000
# 15           0.01                       0.010000          0.000000
# 16           0.00                       0.000000          0.000000
# 17           0.00                       0.000000          0.000000
# 18           0.00                       0.000000          0.000000
# 19           0.01                       0.010000          0.000000
# 20           0.00                       0.000000          0.000000
# 21           0.00                       0.000000          0.000000
# 22           0.00                       0.000000          0.000000
# 23           0.00                       0.010000          0.010000
# 24           0.00                       0.060000          0.000000
# 25           0.00                       0.000000          0.029412
# 26           0.00                       0.000000          0.000000
# 27           0.01                       0.010000          0.000000
# 28           0.00                       0.000000          0.000000
# 29           0.00                       0.000000          0.000000
# 30           0.00                       0.000000          0.000000
# 31           0.00                       0.000000          0.000000
# 32           0.00                       0.060000          0.000000
# 33           0.00                       0.010000          0.000000
# 34           0.00                       0.000000          0.000000
# 35           0.00                       0.000000          0.000000
# 36           0.00                       0.016129          0.000000
# 37           0.00                       0.000000          0.000000
# 38           0.00                       0.043478          0.000000
# 39           0.00                       0.000000          0.000000
# 40           0.00                       0.000000          0.000000
# 41           0.00                       0.000000          0.000000
# 42           0.00                       0.000000          0.000000
# 43           0.00                       0.000000          0.000000
# 44           0.00                       0.000000          0.000000
# 45           0.00                       0.010000          0.000000
# 46           0.00                       0.000000          0.000000
# 47           0.00                       0.000000          0.000000
# 48           0.00                       0.000000          0.000000
# 49           0.00                       0.000000          0.000000
# 50           0.00                       0.026316          0.000000
# 51           0.00                       0.010000          0.010000
# 52           0.00                       0.000000          0.000000
# 53           0.00                       0.000000          0.000000
# 54           0.00                       0.006849          0.000000
# 55           0.00                       0.010638          0.000000
# 56           0.00                       0.000000          0.000000
# 57           0.00                       0.000000          0.000000
# 58           0.00                       0.000000          0.000000
# 59           0.00                       0.026316          0.000000
# 60           0.00                       0.043478          0.000000
# 61           0.00                       0.000000          0.000000
# 62           0.00                       0.000000          0.000000
# 63           0.00                       0.000000          0.000000
# 64           0.00                       0.000000          0.000000
# 65           0.01                       0.010000          0.000000
# 66           0.01                       0.010000          0.000000
# 67           0.00                       0.016129          0.000000
# 68           0.01                       0.010000          0.000000
# 69           0.01                       0.010000          0.000000
# 70           0.00                       0.000000          0.029412
# 71           0.00                       0.010000          0.000000
# 72           0.00                       0.043478          0.000000
#
#     Video Store  Vietnamese Restaurant  Wine Bar  Wings Joint  Women's Store
# 0      0.000000               0.000000  0.010000     0.000000       0.000000
# 1      0.000000               0.000000  0.000000     0.000000       0.000000
# 2      0.000000               0.000000  0.000000     0.000000       0.000000
# 3      0.000000               0.000000  0.000000     0.000000       0.000000
# 4      0.000000               0.000000  0.000000     0.000000       0.000000
# 5      0.000000               0.000000  0.000000     0.000000       0.000000
# 6      0.000000               0.000000  0.000000     0.000000       0.000000
# 7      0.011364               0.000000  0.011364     0.000000       0.000000
# 8      0.000000               0.030000  0.010000     0.000000       0.000000
# 9      0.000000               0.000000  0.000000     0.000000       0.000000
# 10     0.000000               0.011494  0.000000     0.011494       0.000000
# 11     0.000000               0.000000  0.010000     0.000000       0.000000
# 12     0.000000               0.000000  0.000000     0.000000       0.000000
# 13     0.000000               0.000000  0.000000     0.000000       0.000000
# 14     0.000000               0.071429  0.000000     0.000000       0.000000
# 15     0.000000               0.000000  0.010000     0.000000       0.000000
# 16     0.000000               0.000000  0.000000     0.000000       0.000000
# 17     0.000000               0.000000  0.000000     0.000000       0.000000
# 18     0.000000               0.000000  0.000000     0.000000       0.000000
# 19     0.000000               0.000000  0.010000     0.000000       0.000000
# 20     0.000000               0.000000  0.000000     0.000000       0.000000
# 21     0.000000               0.071429  0.000000     0.000000       0.000000
# 22     0.000000               0.000000  0.000000     0.000000       0.000000
# 23     0.000000               0.010000  0.010000     0.000000       0.000000
# 24     0.000000               0.030000  0.010000     0.000000       0.000000
# 25     0.000000               0.000000  0.000000     0.000000       0.000000
# 26     0.000000               0.000000  0.000000     0.000000       0.000000
# 27     0.000000               0.000000  0.010000     0.000000       0.000000
# 28     0.000000               0.000000  0.000000     0.000000       0.000000
# 29     0.000000               0.000000  0.000000     0.000000       0.000000
# 30     0.000000               0.000000  0.000000     0.000000       0.000000
# 31     0.000000               0.000000  0.000000     0.000000       0.000000
# 32     0.000000               0.030000  0.010000     0.000000       0.000000
# 33     0.000000               0.000000  0.010000     0.000000       0.000000
# 34     0.000000               0.000000  0.000000     0.000000       0.000000
# 35     0.000000               0.000000  0.000000     0.000000       0.000000
# 36     0.000000               0.032258  0.016129     0.000000       0.000000
# 37     0.000000               0.000000  0.000000     0.000000       0.000000
# 38     0.000000               0.000000  0.000000     0.000000       0.000000
# 39     0.000000               0.000000  0.000000     0.000000       0.000000
# 40     0.000000               0.000000  0.000000     0.000000       0.000000
# 41     0.000000               0.000000  0.000000     0.000000       0.000000
# 42     0.000000               0.000000  0.000000     0.000000       0.000000
# 43     0.000000               0.071429  0.000000     0.000000       0.000000
# 44     0.000000               0.000000  0.000000     0.000000       0.000000
# 45     0.000000               0.000000  0.010000     0.000000       0.000000
# 46     0.000000               0.000000  0.000000     0.000000       0.000000
# 47     0.000000               0.000000  0.000000     0.000000       0.000000
# 48     0.000000               0.000000  0.000000     0.000000       0.000000
# 49     0.000000               0.000000  0.000000     0.000000       0.000000
# 50     0.000000               0.000000  0.000000     0.000000       0.000000
# 51     0.000000               0.010000  0.010000     0.000000       0.000000
# 52     0.000000               0.071429  0.000000     0.000000       0.000000
# 53     0.000000               0.000000  0.000000     0.000000       0.000000
# 54     0.000000               0.000000  0.000000     0.000000       0.006849
# 55     0.000000               0.000000  0.000000     0.000000       0.000000
# 56     0.000000               0.000000  0.000000     0.000000       0.000000
# 57     0.000000               0.000000  0.000000     0.000000       0.000000
# 58     0.000000               0.071429  0.000000     0.000000       0.000000
# 59     0.000000               0.000000  0.000000     0.000000       0.000000
# 60     0.000000               0.000000  0.000000     0.000000       0.000000
# 61     0.000000               0.000000  0.000000     0.000000       0.000000
# 62     0.000000               0.000000  0.000000     0.000000       0.000000
# 63     0.000000               0.000000  0.000000     0.000000       0.000000
# 64     0.000000               0.000000  0.000000     0.000000       0.000000
# 65     0.000000               0.000000  0.010000     0.000000       0.000000
# 66     0.000000               0.000000  0.010000     0.000000       0.000000
# 67     0.000000               0.032258  0.016129     0.000000       0.000000
# 68     0.000000               0.000000  0.010000     0.000000       0.000000
# 69     0.000000               0.000000  0.010000     0.000000       0.000000
# 70     0.000000               0.000000  0.000000     0.000000       0.000000
# 71     0.000000               0.000000  0.010000     0.000000       0.000000
# 72     0.000000               0.000000  0.000000     0.000000       0.000000

# %%
# show top 5 categories for each neighborhood
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1                 Café  0.05
# 2           Steakhouse  0.04
# 3                  Bar  0.04
# 4  American Restaurant  0.04
#
#
# ----Bathurst Quay----
#               venue  freq
# 0    Airport Lounge  0.14
# 1   Airport Service  0.14
# 2  Airport Terminal  0.14
# 3          Boutique  0.07
# 4  Sculpture Garden  0.07
#
#
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1        Cocktail Bar  0.05
# 2              Bakery  0.04
# 3  Italian Restaurant  0.04
# 4      Farmers Market  0.04
#
#
# ----Brockton----
#             venue  freq
# 0  Breakfast Spot  0.10
# 1            Café  0.10
# 2     Coffee Shop  0.10
# 3     Yoga Studio  0.05
# 4             Gym  0.05
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#               venue  freq
# 0       Yoga Studio  0.05
# 1     Auto Workshop  0.05
# 2              Park  0.05
# 3        Comic Shop  0.05
# 4  Recording Studio  0.05
#
#
# ----CN Tower----
#               venue  freq
# 0    Airport Lounge  0.14
# 1   Airport Service  0.14
# 2  Airport Terminal  0.14
# 3          Boutique  0.07
# 4  Sculpture Garden  0.07
#
#
# ----Cabbagetown----
#          venue  freq
# 0  Coffee Shop  0.09
# 1   Restaurant  0.07
# 2          Pub  0.04
# 3         Café  0.04
# 4         Park  0.04
#
#
# ----Central Bay Street----
#                        venue  freq
# 0                Coffee Shop  0.16
# 1         Italian Restaurant  0.05
# 2                       Café  0.05
# 3               Burger Joint  0.03
# 4  Middle Eastern Restaurant  0.03
#
#
# ----Chinatown----
#                            venue  freq
# 0                           Café  0.08
# 1  Vegetarian / Vegan Restaurant  0.06
# 2             Mexican Restaurant  0.04
# 3            Dumpling Restaurant  0.04
# 4                            Bar  0.04
#
#
# ----Christie----
#                venue  freq
# 0      Grocery Store  0.20
# 1               Café  0.20
# 2               Park  0.13
# 3  Convenience Store  0.07
# 4         Baby Store  0.07
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0  Japanese Restaurant  0.07
# 1          Coffee Shop  0.07
# 2     Sushi Restaurant  0.06
# 3           Restaurant  0.03
# 4              Gay Bar  0.03
#
#
# ----Commerce Court----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1                 Café  0.07
# 2                Hotel  0.06
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Davisville----
#               venue  freq
# 0       Pizza Place  0.11
# 1      Dessert Shop  0.08
# 2    Sandwich Place  0.08
# 3        Restaurant  0.05
# 4  Sushi Restaurant  0.05
#
#
# ----Davisville North----
#             venue  freq
# 0   Grocery Store  0.12
# 1             Gym  0.12
# 2  Clothing Store  0.12
# 3            Park  0.12
# 4  Sandwich Place  0.12
#
#
# ----Deer Park----
#                 venue  freq
# 0                 Pub  0.14
# 1         Coffee Shop  0.14
# 2  Light Rail Station  0.07
# 3         Pizza Place  0.07
# 4          Bagel Shop  0.07
#
#
# ----Design Exchange----
#            venue  freq
# 0    Coffee Shop  0.12
# 1           Café  0.07
# 2          Hotel  0.06
# 3     Restaurant  0.05
# 4  Deli / Bodega  0.03
#
#
# ----Dovercourt Village----
#                        venue  freq
# 0                   Pharmacy  0.10
# 1                Supermarket  0.10
# 2                     Bakery  0.10
# 3  Middle Eastern Restaurant  0.05
# 4               Liquor Store  0.05
#
#
# ----Dufferin----
#                        venue  freq
# 0                   Pharmacy  0.10
# 1                Supermarket  0.10
# 2                     Bakery  0.10
# 3  Middle Eastern Restaurant  0.05
# 4               Liquor Store  0.05
#
#
# ----Exhibition Place----
#             venue  freq
# 0  Breakfast Spot  0.10
# 1            Café  0.10
# 2     Coffee Shop  0.10
# 3     Yoga Studio  0.05
# 4             Gym  0.05
#
#
# ----First Canadian Place----
#          venue  freq
# 0         Café  0.09
# 1  Coffee Shop  0.08
# 2   Restaurant  0.04
# 3        Hotel  0.04
# 4       Bakery  0.03
#
#
# ----Forest Hill North----
#                 venue  freq
# 0                Park  0.25
# 1               Trail  0.25
# 2    Sushi Restaurant  0.25
# 3       Jewelry Store  0.25
# 4  Miscellaneous Shop  0.00
#
#
# ----Forest Hill SE----
#                 venue  freq
# 0                 Pub  0.14
# 1         Coffee Shop  0.14
# 2  Light Rail Station  0.07
# 3         Pizza Place  0.07
# 4          Bagel Shop  0.07
#
#
# ----Forest Hill West----
#                 venue  freq
# 0                Park  0.25
# 1               Trail  0.25
# 2    Sushi Restaurant  0.25
# 3       Jewelry Store  0.25
# 4  Miscellaneous Shop  0.00
#
#
# ----Garden District----
#                        venue  freq
# 0                Coffee Shop  0.10
# 1             Clothing Store  0.07
# 2                       Café  0.04
# 3             Cosmetics Shop  0.04
# 4  Middle Eastern Restaurant  0.03
#
#
# ----Grange Park----
#                            venue  freq
# 0                           Café  0.08
# 1  Vegetarian / Vegan Restaurant  0.06
# 2             Mexican Restaurant  0.04
# 3            Dumpling Restaurant  0.04
# 4                            Bar  0.04
#
#
# ----Harbord----
#                  venue  freq
# 0                 Café  0.12
# 1   Italian Restaurant  0.06
# 2  Japanese Restaurant  0.06
# 3                  Bar  0.06
# 4               Bakery  0.06
#
#
# ----Harbourfront----
#                 venue  freq
# 0         Coffee Shop  0.17
# 1                Park  0.06
# 2              Bakery  0.06
# 3                 Pub  0.06
# 4  Mexican Restaurant  0.04
#
#
# ----Harbourfront East----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1               Hotel  0.05
# 2            Aquarium  0.05
# 3  Italian Restaurant  0.04
# 4                Café  0.04
#
#
# ----Harbourfront West----
#               venue  freq
# 0    Airport Lounge  0.14
# 1   Airport Service  0.14
# 2  Airport Terminal  0.14
# 3          Boutique  0.07
# 4  Sculpture Garden  0.07
#
#
# ----High Park----
#                     venue  freq
# 0                    Café  0.09
# 1      Mexican Restaurant  0.09
# 2                     Bar  0.09
# 3  Furniture / Home Store  0.04
# 4                    Park  0.04
#
#
# ----India Bazaar----
#               venue  freq
# 0              Park  0.11
# 1               Gym  0.06
# 2  Sushi Restaurant  0.06
# 3    Sandwich Place  0.06
# 4        Steakhouse  0.06
#
#
# ----Island airport----
#               venue  freq
# 0    Airport Lounge  0.14
# 1   Airport Service  0.14
# 2  Airport Terminal  0.14
# 3          Boutique  0.07
# 4  Sculpture Garden  0.07
#
#
# ----Kensington Market----
#                            venue  freq
# 0                           Café  0.08
# 1  Vegetarian / Vegan Restaurant  0.06
# 2             Mexican Restaurant  0.04
# 3            Dumpling Restaurant  0.04
# 4                            Bar  0.04
#
#
# ----King----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1                 Café  0.05
# 2           Steakhouse  0.04
# 3                  Bar  0.04
# 4  American Restaurant  0.04
#
#
# ----King and Spadina----
#               venue  freq
# 0    Airport Lounge  0.14
# 1   Airport Service  0.14
# 2  Airport Terminal  0.14
# 3          Boutique  0.07
# 4  Sculpture Garden  0.07
#
#
# ----Lawrence Park----
#          venue  freq
# 0  Swim School  0.33
# 1         Park  0.33
# 2     Bus Line  0.33
# 3  Yoga Studio  0.00
# 4    Nightclub  0.00
#
#
# ----Little Portugal----
#                      venue  freq
# 0                      Bar  0.13
# 1         Asian Restaurant  0.05
# 2              Men's Store  0.05
# 3              Coffee Shop  0.05
# 4  New American Restaurant  0.03
#
#
# ----Moore Park----
#           venue  freq
# 0    Playground   0.5
# 1  Tennis Court   0.5
# 2         Plane   0.0
# 3   Pizza Place   0.0
# 4   Men's Store   0.0
#
#
# ----North Midtown----
#             venue  freq
# 0            Café  0.13
# 1  Sandwich Place  0.13
# 2     Coffee Shop  0.13
# 3     Pizza Place  0.09
# 4  History Museum  0.04
#
#
# ----North Toronto West----
#                   venue  freq
# 0           Coffee Shop  0.12
# 1           Yoga Studio  0.06
# 2  Fast Food Restaurant  0.06
# 3                   Spa  0.06
# 4    Chinese Restaurant  0.06
#
#
# ----Parkdale----
#             venue  freq
# 0       Gift Shop  0.13
# 1  Breakfast Spot  0.13
# 2       Bookstore  0.07
# 3    Dessert Shop  0.07
# 4         Dog Run  0.07
#
#
# ----Parkdale Village----
#             venue  freq
# 0  Breakfast Spot  0.10
# 1            Café  0.10
# 2     Coffee Shop  0.10
# 3     Yoga Studio  0.05
# 4             Gym  0.05
#
#
# ----Railway Lands----
#               venue  freq
# 0    Airport Lounge  0.14
# 1   Airport Service  0.14
# 2  Airport Terminal  0.14
# 3          Boutique  0.07
# 4  Sculpture Garden  0.07
#
#
# ----Rathnelly----
#                 venue  freq
# 0                 Pub  0.14
# 1         Coffee Shop  0.14
# 2  Light Rail Station  0.07
# 3         Pizza Place  0.07
# 4          Bagel Shop  0.07
#
#
# ----Regent Park----
#                 venue  freq
# 0         Coffee Shop  0.17
# 1                Park  0.06
# 2              Bakery  0.06
# 3                 Pub  0.06
# 4  Mexican Restaurant  0.04
#
#
# ----Richmond----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1                 Café  0.05
# 2           Steakhouse  0.04
# 3                  Bar  0.04
# 4  American Restaurant  0.04
#
#
# ----Riverdale----
#                     venue  freq
# 0        Greek Restaurant  0.21
# 1             Coffee Shop  0.10
# 2      Italian Restaurant  0.07
# 3          Ice Cream Shop  0.07
# 4  Furniture / Home Store  0.05
#
#
# ----Roncesvalles----
#             venue  freq
# 0       Gift Shop  0.13
# 1  Breakfast Spot  0.13
# 2       Bookstore  0.07
# 3    Dessert Shop  0.07
# 4         Dog Run  0.07
#
#
# ----Rosedale----
#          venue  freq
# 0         Park  0.50
# 1   Playground  0.25
# 2        Trail  0.25
# 3    Nightclub  0.00
# 4  Men's Store  0.00
#
#
# ----Roselawn----
#                        venue  freq
# 0             Ice Cream Shop   0.5
# 1                     Garden   0.5
# 2                Yoga Studio   0.0
# 3               Noodle House   0.0
# 4  Middle Eastern Restaurant   0.0
#
#
# ----Runnymede----
#                 venue  freq
# 0                Café  0.08
# 1         Pizza Place  0.08
# 2         Coffee Shop  0.08
# 3  Italian Restaurant  0.05
# 4               Diner  0.05
#
#
# ----Ryerson----
#                        venue  freq
# 0                Coffee Shop  0.10
# 1             Clothing Store  0.07
# 2                       Café  0.04
# 3             Cosmetics Shop  0.04
# 4  Middle Eastern Restaurant  0.03
#
#
# ----South Hill----
#                 venue  freq
# 0                 Pub  0.14
# 1         Coffee Shop  0.14
# 2  Light Rail Station  0.07
# 3         Pizza Place  0.07
# 4          Bagel Shop  0.07
#
#
# ----South Niagara----
#               venue  freq
# 0    Airport Lounge  0.14
# 1   Airport Service  0.14
# 2  Airport Terminal  0.14
# 3          Boutique  0.07
# 4  Sculpture Garden  0.07
#
#
# ----St. James Town----
#             venue  freq
# 0     Coffee Shop  0.08
# 1            Café  0.05
# 2      Restaurant  0.05
# 3           Hotel  0.03
# 4  Cosmetics Shop  0.03
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1                Café  0.04
# 2          Restaurant  0.04
# 3        Cocktail Bar  0.03
# 4  Seafood Restaurant  0.03
#
#
# ----Studio District----
#                 venue  freq
# 0                Café  0.11
# 1         Coffee Shop  0.08
# 2  Italian Restaurant  0.05
# 3           Gastropub  0.05
# 4              Bakery  0.05
#
#
# ----Summerhill East----
#           venue  freq
# 0    Playground   0.5
# 1  Tennis Court   0.5
# 2         Plane   0.0
# 3   Pizza Place   0.0
# 4   Men's Store   0.0
#
#
# ----Summerhill West----
#                 venue  freq
# 0                 Pub  0.14
# 1         Coffee Shop  0.14
# 2  Light Rail Station  0.07
# 3         Pizza Place  0.07
# 4          Bagel Shop  0.07
#
#
# ----Swansea----
#                 venue  freq
# 0                Café  0.08
# 1         Pizza Place  0.08
# 2         Coffee Shop  0.08
# 3  Italian Restaurant  0.05
# 4               Diner  0.05
#
#
# ----The Annex----
#             venue  freq
# 0            Café  0.13
# 1  Sandwich Place  0.13
# 2     Coffee Shop  0.13
# 3     Pizza Place  0.09
# 4  History Museum  0.04
#
#
# ----The Beaches----
#                  venue  freq
# 0    Health Food Store  0.25
# 1                  Pub  0.25
# 2                Trail  0.25
# 3          Yoga Studio  0.00
# 4  Monument / Landmark  0.00
#
#
# ----The Beaches West----
#               venue  freq
# 0              Park  0.11
# 1               Gym  0.06
# 2  Sushi Restaurant  0.06
# 3    Sandwich Place  0.06
# 4        Steakhouse  0.06
#
#
# ----The Danforth West----
#                     venue  freq
# 0        Greek Restaurant  0.21
# 1             Coffee Shop  0.10
# 2      Italian Restaurant  0.07
# 3          Ice Cream Shop  0.07
# 4  Furniture / Home Store  0.05
#
#
# ----The Junction South----
#                     venue  freq
# 0                    Café  0.09
# 1      Mexican Restaurant  0.09
# 2                     Bar  0.09
# 3  Furniture / Home Store  0.04
# 4                    Park  0.04
#
#
# ----Toronto Dominion Centre----
#            venue  freq
# 0    Coffee Shop  0.12
# 1           Café  0.07
# 2          Hotel  0.06
# 3     Restaurant  0.05
# 4  Deli / Bodega  0.03
#
#
# ----Toronto Islands----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1               Hotel  0.05
# 2            Aquarium  0.05
# 3  Italian Restaurant  0.04
# 4                Café  0.04
#
#
# ----Trinity----
#                      venue  freq
# 0                      Bar  0.13
# 1         Asian Restaurant  0.05
# 2              Men's Store  0.05
# 3              Coffee Shop  0.05
# 4  New American Restaurant  0.03
#
#
# ----Underground city----
#          venue  freq
# 0         Café  0.09
# 1  Coffee Shop  0.08
# 2   Restaurant  0.04
# 3        Hotel  0.04
# 4       Bakery  0.03
#
#
# ----Union Station----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1               Hotel  0.05
# 2            Aquarium  0.05
# 3  Italian Restaurant  0.04
# 4                Café  0.04
#
#
# ----University of Toronto----
#                  venue  freq
# 0                 Café  0.12
# 1   Italian Restaurant  0.06
# 2  Japanese Restaurant  0.06
# 3                  Bar  0.06
# 4               Bakery  0.06
#
#
# ----Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1                 Café  0.07
# 2                Hotel  0.06
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Yorkville----
#             venue  freq
# 0            Café  0.13
# 1  Sandwich Place  0.13
# 2     Coffee Shop  0.13
# 3     Pizza Place  0.09
# 4  History Museum  0.04

# %%
# put into dataframe
# sort venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# create new df and display top 10 venues in each neighborhood
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# %%
# create columns according to number of top venue categories
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# %%
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

# %%
for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                           Adelaide           Coffee Shop
# 1                                      Bathurst Quay        Airport Lounge
# 2                                        Berczy Park           Coffee Shop
# 3                                           Brockton           Coffee Shop
# 4  Business Reply Mail Processing Centre 969 Eastern           Yoga Studio
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café   American Restaurant       Thai Restaurant
# 1       Airport Service      Airport Terminal         Boat or Ferry
# 2          Cocktail Bar    Seafood Restaurant                  Café
# 3                  Café        Breakfast Spot           Yoga Studio
# 4         Auto Workshop           Pizza Place  Gym / Fitness Center
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Steakhouse                   Bar          Burger Joint
# 1       Harbor / Marina              Boutique               Airport
# 2           Cheese Shop        Farmers Market              Beer Bar
# 3    Italian Restaurant             Pet Store          Climbing Gym
# 4      Recording Studio            Restaurant               Butcher
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                 Hotel                Bakery         Cosmetics Shop
# 1    Airport Food Court          Airport Gate                  Plane
# 2            Steakhouse                Bakery     Italian Restaurant
# 3            Restaurant  Caribbean Restaurant          Burrito Place
# 4         Burrito Place               Brewery             Skate Park

# %%
# set number of clusters
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# %%
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# %%
# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 0, 0, 0, 2, 0, 0, 0, 0])

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merged = toronto_data

# %%
# merge data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.head()
# Out:
#   Postcode           Borough     Neighborhood Latitude Longitude  \
# 0      M5A  Downtown Toronto     Harbourfront  43.6543  -79.3606
# 1      M5A  Downtown Toronto      Regent Park  43.6543  -79.3606
# 2      M5B  Downtown Toronto          Ryerson  43.6572  -79.3789
# 3      M5B  Downtown Toronto  Garden District  43.6572  -79.3789
# 4      M5C  Downtown Toronto   St. James Town  43.6515  -79.3754
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0           Coffee Shop                   Pub
# 1               0           Coffee Shop                   Pub
# 2               0           Coffee Shop        Clothing Store
# 3               0           Coffee Shop        Clothing Store
# 4               0           Coffee Shop                  Café
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                Bakery                  Park         Mexican Restaurant
# 1                Bakery                  Park         Mexican Restaurant
# 2                  Café        Cosmetics Shop  Middle Eastern Restaurant
# 3                  Café        Cosmetics Shop  Middle Eastern Restaurant
# 4            Restaurant                Bakery                      Hotel
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0               Theater            Restaurant        Breakfast Spot
# 1               Theater            Restaurant        Breakfast Spot
# 2       Bubble Tea Shop  Fast Food Restaurant    Italian Restaurant
# 3       Bubble Tea Shop  Fast Food Restaurant    Italian Restaurant
# 4        Cosmetics Shop        Breakfast Spot           Pizza Place
#
#   9th Most Common Venue 10th Most Common Venue
# 0                  Café   Gym / Fitness Center
# 1                  Café   Gym / Fitness Center
# 2   Japanese Restaurant               Tea Room
# 3   Japanese Restaurant               Tea Room
# 4             Gastropub                   Park

# %%
# vizualize results
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# %%
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
